# %%
from generate_data import Data
from evaluate import *
from models import *

import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
# %autosave 120
# Out:
# Autosaving every 120 seconds

# %% [markdown]
# # Get the synthetic dataset

# %%
# %%time
data = Data(layer_size=16)
# Out:
# CPU times: total: 438 ms
# Wall time: 449 ms
# c:\Users\franm\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but OneHotEncoder was fitted without feature names
#   warnings.warn(

# %%
# %%time
train, val, test = data.get_splits(['random_subsample'], [[0.05, 0.95]])

train_unshuffled = train.copy()
np.random.shuffle(train)

x_train, y_train = data.get_x_y(train)
x_val, y_val = data.get_x_y(val)
x_test, y_test = data.get_x_y(test)

train_original = data.reverse_encoding(data.get_x_y(train_unshuffled)[0])
val_original = data.reverse_encoding(x_val)
test_original = data.reverse_encoding(x_test)
# Out:
# Number of samples: 198 train | 754 val | 3017 test
# CPU times: total: 219 ms
# Wall time: 204 ms

# %% [markdown]
# #### Peek at unshuffled train data

# %%
train_original[:20]
# Out:
# [[',,..,__._,.,._.,', '______.,_.uw._.,', '___..,__.__dr_._', 'A'],
#  [',___,,._,,.__.,.', '__._,__w__._,,,,', '_,.,,,.,_.dr_...', 'D'],
#  [',...__..,.,,,_..', '.,___.__.wu___.,', '._cr._..__,,,.,.', 'V'],
#  ['.,,._.._.,_,,,..', '_..__,,,.,.__.,,', ',_,._._,_,.r,,__', 'R'],
#  ['.__.,,.,,_.,___,', '_._,,,._..._,_,,', '._.,_dr.,,.._,__', 'D'],
#  [',,__,,_.___...,_', '_,__,_,_,,_._..,', '_,.,,cr.._,.._,.', 'V'],
#  ['.._...,.,._,,.,,', ',._,,.,,,.w_._.,', ',,.,,__.,.__,__,', 'V'],
#  ['._.,..._.._...._', '_,_...__.,,.wu,_', '_.._.,.._._,_,._', 'V'],
#  ['.._._,,_._,....,', '_....__,.,uw,_._', ',.,_,,.._,__r,,,', 'R'],
#  ['.,_..,,._,__.,,.', ',___,_.._,_,w.,_', ',,._,,..__,cr__.', 'V'],
#  [',..._.____.__,_,', '.,,,_wu_...,_,_,', '_..__,.__,.r....', 'R'],
#  [',,.,_,__.,.__.,_', '...,__.,.__._..,', '_,_....,,.cr,__,', 'V'],
#  ['._._..,,_,...._.', '_._._,wu_.,___..', '__,.._,_.,.,....', 'V'],
#  [',__,,_._.,.,.,,.', 'w._.,,_.._,_..._', '_...__.__..._._.', 'V'],
#  ['.,._.,._.,,__,..', '__._wu.,..,,__.,', '__,__._cr,.._,_.', 'V'],
#  ['__,,.,,,__.._,..', ',_.,.._,._.,uw._', '_.,__,,.,..,..__', 'V'],
#  [',_,,_.,__,,.__..', '_.,,.,_,uw,__...', '._...,_,.____..,', 'V'],
#  [',._...,,._,._,_.', ',.__,w_,_,__.,,,', ',,,.___,,_,__,__', 'V'],
#  ['._,,.._..,_.,..,', '_.,..,.__.,...wu', '.dr,_...__.,,_,,', 'V'],
#  ['...__.,..__._.._', '.....,_.,_,w_._,', ',..._.,_,,.cr,_,', 'V']]

# %%
pos_train_ratio = get_stats_and_ratio(train_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 16 | F2-uw 14 | F2-w 14 | F2-noop 12 |
# F3 cr:    F2-wu 12 | F2-uw 12 | F2-w 11 | F2-noop 12 |
# F3 r:    F2-wu 11 | F2-uw 10 | F2-w 13 | F2-noop 14 |
# F3 noop:    F2-wu 11 | F2-uw 13 | F2-w 13 | F2-noop 10 |
#
# Positive samples count: 88
# Total samples count: 198
# Positive class ratio: 0.4444444444444444

# %% [markdown]
# #### Peek at test data

# %%
test_original[:15]
# Out:
# [['_,,.,..._,._.___', ',._wu.,.,,.__.,_', '__._,,_..r.,,,.,', 'R'],
#  ['_,_.,_,__,,.._,.', ',.,,.,,,wu_.,...', '.,_._,__._,__.._', 'V'],
#  ['..,,,,.__._.,.._', 'wu,..,..,..__,,.', 'cr.,._.....,._._', 'V'],
#  [',,__.,_,_.._._,_', ',_,,._.w,___.,_,', ',,,_,,r_,...,,,_', 'R'],
#  ['.__,_,_._,.,..,,', ',...._...uw_,__,', '._,r,_,.._,,_.,_', 'R'],
#  [',..,_,,..,_,__..', '..__,,,.,._.,._,', '_.,._,..cr_..._.', 'V'],
#  [',,_,.,_,._.___,_', 'w,,,.._..._,_,,_', '._.,._.,._.__.__', 'V'],
#  ['._..,_.__.,,.,..', '._._,.._,,_,.wu,', 'cr,_,,.___.,__..', 'V'],
#  ['_,.._..,,.,_,_,.', '.,_.,_,wu__,.___', 'dr_,.__,_,._,,_.', 'V'],
#  ['___,___,,,_,_.,.', '_.____.._,,.,.__', '..._..r,._,.,_,.', 'R'],
#  ['_,..,_,_,.,,,.,.', '_,__.._.,,.wu,._', ',...,.._.,_...,_', 'V'],
#  ['._,._.___,,,._..', ',,____,,._,___,.', ',.._,,.,.,_,.,_.', 'V'],
#  ['_..._,,,.,,,,,.,', '_.._.,_w,,___,_,', '_,_,,_.,..._.,,.', 'V'],
#  ['__..,_._,._._..,', ',.,_.,uw._._,...', ',r__,__,.,,.,__,', 'R'],
#  ['._._.._.__,..,,,', '_,_,_.,.__.w___.', '_,_,dr,__._.....', 'D']]

# %%
pos_test_ratio = get_stats_and_ratio(test_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 176 | F2-uw 170 | F2-w 184 | F2-noop 190 |
# F3 cr:    F2-wu 171 | F2-uw 176 | F2-w 173 | F2-noop 194 |
# F3 r:    F2-wu 171 | F2-uw 187 | F2-w 199 | F2-noop 205 |
# F3 noop:    F2-wu 200 | F2-uw 183 | F2-w 211 | F2-noop 227 |
#
# Positive samples count: 1306
# Total samples count: 3017
# Positive class ratio: 0.43288034471329134

# %% [markdown]
# #### Peek at val data

# %%
val_original[:15]
# Out:
# [['__..__._,__,,___', '.,__.__,.,uw_,.,', '..__,,__.,_...,_', 'V'],
#  ['.,__,_.,__,_,._.', ',,,,,...._,w,,_,', '..,_.,,._r_.__,.', 'R'],
#  ['_,__._._,_,,....', '.,wu_,_,_,.___,.', '_.,.,,_.r,,,.,,_', 'R'],
#  ['._...,,._.._,.,,', ',.,_._._..uw.,.,', ',,,_.,,,__,,,_,,', 'V'],
#  ['__,_,..,..._,,_.', '.,_,_._.._uw_,..', ',_r,,._,..,.__.,', 'R'],
#  [',,_,_.._,.__._,.', '_w.._..._,_...,,', ',,..,_,.__.,.r..', 'R'],
#  [',____.,_,_......', '.__..wu._,..._.,', '_.._,,.__,_..dr,', 'V'],
#  ['.,.._,_,.._,._..', '_wu,...,.,,.__,.', ',,_,..,....,cr__', 'V'],
#  ['.,_,_..,,_..,...', ',._,....__,_.__,', '_,._,,_,r.,,_.,.', 'R'],
#  ['.__,.._,,.____..', '._,wu,____..__..', ',,_.,_,..,.cr_.,', 'V'],
#  [',_.__,_,,.,__.,_', ',.___,,,.,_.,,..', '___,_._.__.,._.,', 'V'],
#  ['._.,,._,_,.,_,..', '..._.,._.,._,,_,', '._.,.,,____.,_._', 'V'],
#  [',_,_.,.._._.._.,', '___..,,,,,uw,_,_', '_._,,,__.,___,,.', 'V'],
#  ['_...,..,_,._,._.', ',,,_._.._.,,._wu', '..__.,,_..,_,_..', 'V'],
#  ['..,,___..,,..__.', ',_,._..._._..,w,', '_,.,,...__,._,_,', 'V']]

# %%
pos_val_ratio = get_stats_and_ratio(val_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 33 | F2-uw 41 | F2-w 42 | F2-noop 53 |
# F3 cr:    F2-wu 42 | F2-uw 37 | F2-w 56 | F2-noop 49 |
# F3 r:    F2-wu 58 | F2-uw 43 | F2-w 44 | F2-noop 53 |
# F3 noop:    F2-wu 44 | F2-uw 59 | F2-w 48 | F2-noop 52 |
#
# Positive samples count: 334
# Total samples count: 754
# Positive class ratio: 0.44297082228116713

# %% [markdown]
# #### Send label arrays to device

# %%
from sklearn.preprocessing import LabelEncoder

# Codificar etiquetas categóricas a índices numéricos
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_val = label_encoder.transform(y_val)
y_test = label_encoder.transform(y_test)

# Convertir a tensores de PyTorch
y_train = torch.tensor(y_train, dtype=torch.long).to(device)
y_val = torch.tensor(y_val, dtype=torch.long).to(device)
y_test = torch.tensor(y_test, dtype=torch.long).to(device)

# Verificar clases codificadas
print("Clases codificadas:", label_encoder.classes_)
# Out:
# Clases codificadas: ['A' 'D' 'R' 'V']

# %% [markdown]
# #### Get data in normal format (same as CNN format)

# %%
x_train_normal = data.to_conv_format(x_train)
x_val_normal = data.to_conv_format(x_val)
x_test_normal = data.to_conv_format(x_test)
for i in range(len(x_train_normal)):
    x_train_normal[i] = x_train_normal[i].to(device)
    x_val_normal[i] = x_val_normal[i].to(device)
    x_test_normal[i] = x_test_normal[i].to(device)

# %%
x_train_normal[0].shape
# Out:
# torch.Size([198, 128])

# %% [markdown]
# #### Get data in convolutional format, send to device

# %%
x_train_cnn = data.to_conv_format(x_train)
x_val_cnn = data.to_conv_format(x_val)
x_test_cnn = data.to_conv_format(x_test)
for i in range(len(x_train_cnn)):
    x_train_cnn[i] = x_train_cnn[i].to(device)
    x_val_cnn[i] = x_val_cnn[i].to(device)
    x_test_cnn[i] = x_test_cnn[i].to(device)

# %%
x_train_cnn[0].shape
# Out:
# torch.Size([198, 128])

# %% [markdown]
# #### Get data in LSTM format, send to device

# %%
x_train_lstm = data.to_lstm_format(x_train)
x_val_lstm = data.to_lstm_format(x_val)
x_test_lstm = data.to_lstm_format(x_test)
for i in range(len(x_train_lstm)):
    x_train_lstm[i] = x_train_lstm[i].to(device)
    x_val_lstm[i] = x_val_lstm[i].to(device)
    x_test_lstm[i] = x_test_lstm[i].to(device)

# %%
x_train_lstm[0].shape
# Out:
# torch.Size([198, 16, 8])

# %% [markdown]
# ### Define training parameters

# %%
num_experiments = 20
epochs = 200
early_stopping_limit = 100

experiment_name = "05per"

# %% [markdown]
# ### Define training procedure for each model

# %%
def train_models(constructor, x_train, x_val, x_test, weight_decay, *argv):
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    wrong_preds = []
    best_accuracy = 0
    
    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []

    for i in range(num_experiments):
        model = constructor(*argv)
        model.to(device)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), weight_decay=weight_decay)

        train_losses.append([])
        val_losses.append([])
        train_accs.append([])
        val_accs.append([])
        
        best_acc = 0

        early_stopping_cnt = 0

        for epoch in range(1, epochs + 1):
            train_loss, train_acc = train_epoch(model, x_train, y_train, criterion, optimizer, epoch, 10, verbose=False)
            val_loss, val_acc = eval_epoch(model, x_val, y_val, criterion, 'Validation', verbose=False)

            
            train_losses[-1].append(train_loss)
            val_losses[-1].append(val_loss)
            train_accs[-1].append(train_acc)
            val_accs[-1].append(val_acc)
            
            model_name = constructor.__name__[:constructor.__name__.find('_')]
            if val_acc > best_acc:
                best_acc = val_acc
                torch.save(model.state_dict(), f'./temp/{model_name}_model_TEMP_' + experiment_name)    
                early_stopping_cnt = 0
            else:
                early_stopping_cnt += 1

            if early_stopping_cnt >= early_stopping_limit:
                break


        model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
        
        accuracies.append(get_accuracy_by_cases(model, x_test, y_test, test_original))
        precisions.append(get_precision(model, x_test, y_test, test_original))
        recalls.append(get_recall(model, x_test, y_test, test_original))
        f1_scores.append(get_f1(precisions[-1], recalls[-1]))
        
        wrong_preds.append((f"Experimento {i}", get_wrong_predictions(model, x_test, y_test, test_original)))

        if accuracies[-1]['Overall'] > best_accuracy:
            torch.save(model.state_dict(), f'./bestmodels/best_{model_name}_model_' + experiment_name)    
            best_accuracy = accuracies[-1]['Overall']

        print(i + 1, "/", num_experiments, "models trained | Current model test accuracy:", accuracies[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test precision:", precisions[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test recall:", recalls[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test f1:", f1_scores[-1]['Overall'])


    
    return accuracies, precisions, recalls, f1_scores, wrong_preds, [train_losses, val_losses, train_accs, val_accs], model
    #return accuracies, precisions, wrong_preds, [train_losses, val_losses, train_accs, val_accs]

# %% [markdown]
# # Train models

# %%
# %%time
cnn_accuracies, cnn_precisions, cnn_recalls, cnn_f1_scores, cnn_wrong_preds, cnn_epoch_stats, model = train_models(
    CNN_Model, x_train_cnn, x_val_cnn, x_test_cnn, 0.0001, data, 64, 128, 4, -1, 'keras')
    
#cnn_accuracies, cnn_precisions, cnn_wrong_preds, cnn_epoch_stats = train_models(CNN_Model, x_train_cnn, x_val_cnn, x_test_cnn, 0.0001, data, 64, 128, 4, -1, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_12740\2177076457.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.99171362280411
# 1 / 20 models trained | Current model test precision: 0.9950427863995193
# 1 / 20 models trained | Current model test recall: 0.988066021863814
# 1 / 20 models trained | Current model test f1: 0.9915421316725903
# 2 / 20 models trained | Current model test accuracy: 0.9953596287703016
# 2 / 20 models trained | Current model test precision: 0.9979710144927536
# 2 / 20 models trained | Current model test recall: 0.9954068241469816
# 2 / 20 models trained | Current model test f1: 0.9966872700911058
# 3 / 20 models trained | Current model test accuracy: 0.9980112694729865
# 3 / 20 models trained | Current model test precision: 0.9967437773759042
# 3 / 20 models trained | Current model test recall: 0.9941121636832466
# 3 / 20 models trained | Current model test f1: 0.9954262312297887
# 4 / 20 models trained | Current model test accuracy: 0.9937023533311237
# 4 / 20 models trained | Current model test precision: 0.9948530211630844
# 4 / 20 models trained | Current model test recall: 0.9887045675739368
# 4 / 20 models trained | Current model test f1: 0.9917692651565148
# 5 / 20 models trained | Current model test accuracy: 1.0
# 5 / 20 models trained | Current model test precision: 1.0
# 5 / 20 models trained | Current model test recall: 1.0
# 5 / 20 models trained | Current model test f1: 1.0
# 6 / 20 models trained | Current model test accuracy: 0.9980112694729865
# 6 / 20 models trained | Current model test precision: 0.999126383226558
# 6 / 20 models trained | Current model test recall: 0.9960745715609078
# 6 / 20 models trained | Current model test f1: 0.9975981434046627
# 7 / 20 models trained | Current model test accuracy: 0.9943652635067949
# 7 / 20 models trained | Current model test precision: 0.9962119146615773
# 7 / 20 models trained | Current model test recall: 0.9934620385382003
# 7 / 20 models trained | Current model test f1: 0.9948350763340985
# 8 / 20 models trained | Current model test accuracy: 0.9923765329797812
# 8 / 20 models trained | Current model test precision: 0.996683967704729
# 8 / 20 models trained | Current model test recall: 0.9932800679326849
# 8 / 20 models trained | Current model test f1: 0.994979106576732
# 9 / 20 models trained | Current model test accuracy: 1.0
# 9 / 20 models trained | Current model test precision: 1.0
# 9 / 20 models trained | Current model test recall: 1.0
# 9 / 20 models trained | Current model test f1: 1.0
# 10 / 20 models trained | Current model test accuracy: 1.0
# 10 / 20 models trained | Current model test precision: 1.0
# 10 / 20 models trained | Current model test recall: 1.0
# 10 / 20 models trained | Current model test f1: 1.0
# 11 / 20 models trained | Current model test accuracy: 0.9996685449121644
# 11 / 20 models trained | Current model test precision: 0.9998539719626168
# 11 / 20 models trained | Current model test recall: 0.9985294117647059
# 11 / 20 models trained | Current model test f1: 0.999191252893909
# 12 / 20 models trained | Current model test accuracy: 0.9970169042094796
# 12 / 20 models trained | Current model test precision: 0.9986918604651163
# 12 / 20 models trained | Current model test recall: 0.9890497143739386
# 12 / 20 models trained | Current model test f1: 0.9938474013359389
# 13 / 20 models trained | Current model test accuracy: 0.9903878024527677
# 13 / 20 models trained | Current model test precision: 0.994438639717043
# 13 / 20 models trained | Current model test recall: 0.9818555849331362
# 13 / 20 models trained | Current model test f1: 0.9881070542037533
# 14 / 20 models trained | Current model test accuracy: 0.996685449121644
# 14 / 20 models trained | Current model test precision: 0.9985473561882626
# 14 / 20 models trained | Current model test recall: 0.9967191601049868
# 14 / 20 models trained | Current model test f1: 0.9976324205891126
# 15 / 20 models trained | Current model test accuracy: 0.9923765329797812
# 15 / 20 models trained | Current model test precision: 0.996683967704729
# 15 / 20 models trained | Current model test recall: 0.9873977149915084
# 15 / 20 models trained | Current model test f1: 0.9920191097606025
# 16 / 20 models trained | Current model test accuracy: 0.9946967185946304
# 16 / 20 models trained | Current model test precision: 0.9976838448176027
# 16 / 20 models trained | Current model test recall: 0.9942643199011888
# 16 / 20 models trained | Current model test f1: 0.9959711472552447
# 17 / 20 models trained | Current model test accuracy: 0.9857474312230693
# 17 / 20 models trained | Current model test precision: 0.9894404665239536
# 17 / 20 models trained | Current model test recall: 0.9658732238437191
# 17 / 20 models trained | Current model test f1: 0.977514818119257
# 18 / 20 models trained | Current model test accuracy: 0.9960225389459728
# 18 / 20 models trained | Current model test precision: 0.9968588819305457
# 18 / 20 models trained | Current model test recall: 0.9859624245193643
# 18 / 20 models trained | Current model test f1: 0.9913807128607559
# 19 / 20 models trained | Current model test accuracy: 0.9993370898243288
# 19 / 20 models trained | Current model test precision: 0.9997081144191478
# 19 / 20 models trained | Current model test recall: 0.9985294117647059
# 19 / 20 models trained | Current model test f1: 0.9991184154505856
# 20 / 20 models trained | Current model test accuracy: 0.9980112694729865
# 20 / 20 models trained | Current model test precision: 0.999126383226558
# 20 / 20 models trained | Current model test recall: 0.9980314960629921
# 20 / 20 models trained | Current model test f1: 0.9985786395238099
# CPU times: total: 1h 9min 41s
# Wall time: 17min 47s

# %%
# %%time
lstm_accuracies, lstm_precisions, lstm_recalls, lstm_f1Scores, lstm_wrong_preds, lstm_epoch_stats, model = train_models(LSTM_Model, x_train_lstm, x_val_lstm, x_test_lstm, 0.0001, data, 16, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_12740\2177076457.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.8743785217103083
# 1 / 20 models trained | Current model test precision: 0.6183180225234046
# 1 / 20 models trained | Current model test recall: 0.6673597440944882
# 1 / 20 models trained | Current model test f1: 0.6419035437872159
# 2 / 20 models trained | Current model test accuracy: 0.9476300961219755
# 2 / 20 models trained | Current model test precision: 0.8711853839569271
# 2 / 20 models trained | Current model test recall: 0.8510889744559426
# 2 / 20 models trained | Current model test f1: 0.861019931430882
# 3 / 20 models trained | Current model test accuracy: 0.9767981438515081
# 3 / 20 models trained | Current model test precision: 0.9887697989840574
# 3 / 20 models trained | Current model test recall: 0.968076057374081
# 3 / 20 models trained | Current model test f1: 0.9783135095091139
# 4 / 20 models trained | Current model test accuracy: 0.9585681140205502
# 4 / 20 models trained | Current model test precision: 0.9667974552180968
# 4 / 20 models trained | Current model test recall: 0.9426752528187904
# 4 / 20 models trained | Current model test f1: 0.9545839871775497
# 5 / 20 models trained | Current model test accuracy: 0.9665230361286046
# 5 / 20 models trained | Current model test precision: 0.9091453415053117
# 5 / 20 models trained | Current model test recall: 0.9609542063464778
# 5 / 20 models trained | Current model test f1: 0.9343321226973241
# 6 / 20 models trained | Current model test accuracy: 0.8849850845210474
# 6 / 20 models trained | Current model test precision: 0.6293663654741094
# 6 / 20 models trained | Current model test recall: 0.6698542805100183
# 6 / 20 models trained | Current model test f1: 0.648979455837581
# 7 / 20 models trained | Current model test accuracy: 0.9956910838581372
# 7 / 20 models trained | Current model test precision: 0.9879045135192677
# 7 / 20 models trained | Current model test recall: 0.9949056644890201
# 7 / 20 models trained | Current model test f1: 0.9913927287400487
# 8 / 20 models trained | Current model test accuracy: 0.9303944315545244
# 8 / 20 models trained | Current model test precision: 0.8594964296842742
# 8 / 20 models trained | Current model test recall: 0.8838634352093463
# 8 / 20 models trained | Current model test f1: 0.8715096431765869
# 9 / 20 models trained | Current model test accuracy: 0.9814385150812065
# 9 / 20 models trained | Current model test precision: 0.9579641160775254
# 9 / 20 models trained | Current model test recall: 0.941487606147076
# 9 / 20 models trained | Current model test f1: 0.9496543996015101
# 10 / 20 models trained | Current model test accuracy: 0.883659264169705
# 10 / 20 models trained | Current model test precision: 0.6290494227994228
# 10 / 20 models trained | Current model test recall: 0.6683595800524935
# 10 / 20 models trained | Current model test f1: 0.6481089727762168
# 11 / 20 models trained | Current model test accuracy: 0.954590652966523
# 11 / 20 models trained | Current model test precision: 0.8961826282804544
# 11 / 20 models trained | Current model test recall: 0.9106844299261354
# 11 / 20 models trained | Current model test f1: 0.9033753338282148
# 12 / 20 models trained | Current model test accuracy: 0.9943652635067949
# 12 / 20 models trained | Current model test precision: 0.9975405092592593
# 12 / 20 models trained | Current model test recall: 0.9944225721784776
# 12 / 20 models trained | Current model test f1: 0.9959791005301595
# 13 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 13 / 20 models trained | Current model test precision: 0.14177991382167715
# 13 / 20 models trained | Current model test recall: 0.25
# 13 / 20 models trained | Current model test f1: 0.18094331641285955
# 14 / 20 models trained | Current model test accuracy: 0.9910507126284388
# 14 / 20 models trained | Current model test precision: 0.9722314078217217
# 14 / 20 models trained | Current model test recall: 0.9913536316563929
# 14 / 20 models trained | Current model test f1: 0.9816994095765148
# 15 / 20 models trained | Current model test accuracy: 0.9923765329797812
# 15 / 20 models trained | Current model test precision: 0.996683967704729
# 15 / 20 models trained | Current model test recall: 0.9901690597498842
# 15 / 20 models trained | Current model test f1: 0.9934158325080434
# 16 / 20 models trained | Current model test accuracy: 0.9436526350679483
# 16 / 20 models trained | Current model test precision: 0.8706956628389053
# 16 / 20 models trained | Current model test recall: 0.8926488545044566
# 16 / 20 models trained | Current model test f1: 0.8815356028396628
# 17 / 20 models trained | Current model test accuracy: 0.9960225389459728
# 17 / 20 models trained | Current model test precision: 0.9915379242765407
# 17 / 20 models trained | Current model test recall: 0.9889753154330113
# 17 / 20 models trained | Current model test f1: 0.9902549619602583
# 18 / 20 models trained | Current model test accuracy: 0.9903878024527677
# 18 / 20 models trained | Current model test precision: 0.9851900504981576
# 18 / 20 models trained | Current model test recall: 0.9828012951822422
# 18 / 20 models trained | Current model test f1: 0.9839942231000951
# 19 / 20 models trained | Current model test accuracy: 0.9821014252568777
# 19 / 20 models trained | Current model test precision: 0.9549100343124948
# 19 / 20 models trained | Current model test recall: 0.9601405102278466
# 19 / 20 models trained | Current model test f1: 0.9575181294095347
# 20 / 20 models trained | Current model test accuracy: 0.9814385150812065
# 20 / 20 models trained | Current model test precision: 0.988764689054382
# 20 / 20 models trained | Current model test recall: 0.9728512038326147
# 20 / 20 models trained | Current model test f1: 0.9807433978708594
# CPU times: total: 35min 29s
# Wall time: 12min 27s

# %%
# %%time
deepset_accuracies, deepset_precisions, deepset_recalls, deepset_f1Scores, deepset_wrong_preds, deepset_epoch_stats, model = train_models(DEEPSET_Model, x_train_normal, x_val_normal, x_test_normal, 0.005, data, 128, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_12740\2177076457.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.5710971163407358
# 1 / 20 models trained | Current model test precision: 0.41966226407779517
# 1 / 20 models trained | Current model test recall: 0.39604226893813416
# 1 / 20 models trained | Current model test f1: 0.407510289635325
# 2 / 20 models trained | Current model test accuracy: 0.5591647331786543
# 2 / 20 models trained | Current model test precision: 0.37906079340373866
# 2 / 20 models trained | Current model test recall: 0.3821271386124194
# 2 / 20 models trained | Current model test f1: 0.3805877898244171
# 3 / 20 models trained | Current model test accuracy: 0.5667882001988731
# 3 / 20 models trained | Current model test precision: 0.41139740995789287
# 3 / 20 models trained | Current model test recall: 0.4261307409370435
# 3 / 20 models trained | Current model test f1: 0.4186344851516022
# 4 / 20 models trained | Current model test accuracy: 0.5737487570434207
# 4 / 20 models trained | Current model test precision: 0.38483707168766196
# 4 / 20 models trained | Current model test recall: 0.40629276732056996
# 4 / 20 models trained | Current model test f1: 0.39527397682164234
# 5 / 20 models trained | Current model test accuracy: 0.5618163738813391
# 5 / 20 models trained | Current model test precision: 0.3122017079371322
# 5 / 20 models trained | Current model test recall: 0.2558415030785489
# 5 / 20 models trained | Current model test f1: 0.2812256274641792
# 6 / 20 models trained | Current model test accuracy: 0.573417301955585
# 6 / 20 models trained | Current model test precision: 0.40778197196882315
# 6 / 20 models trained | Current model test recall: 0.40224022359121214
# 6 / 20 models trained | Current model test f1: 0.4049921409074473
# 7 / 20 models trained | Current model test accuracy: 0.5667882001988731
# 7 / 20 models trained | Current model test precision: 0.1418380889183809
# 7 / 20 models trained | Current model test recall: 0.24985388661601401
# 7 / 20 models trained | Current model test f1: 0.18095238095238095
# 8 / 20 models trained | Current model test accuracy: 0.5548558170367915
# 8 / 20 models trained | Current model test precision: 0.4089634814300305
# 8 / 20 models trained | Current model test recall: 0.40996743824280624
# 8 / 20 models trained | Current model test f1: 0.40946484444306974
# 9 / 20 models trained | Current model test accuracy: 0.573417301955585
# 9 / 20 models trained | Current model test precision: 0.3327045545642776
# 9 / 20 models trained | Current model test recall: 0.3759226496049871
# 9 / 20 models trained | Current model test f1: 0.352995699153473
# 10 / 20 models trained | Current model test accuracy: 0.5714285714285714
# 10 / 20 models trained | Current model test precision: 0.4127871542428504
# 10 / 20 models trained | Current model test recall: 0.3758596640952195
# 10 / 20 models trained | Current model test f1: 0.3934588653092898
# 11 / 20 models trained | Current model test accuracy: 0.5571760026516407
# 11 / 20 models trained | Current model test precision: 0.405338578643191
# 11 / 20 models trained | Current model test recall: 0.36581757262694414
# 11 / 20 models trained | Current model test f1: 0.38456536899065863
# 12 / 20 models trained | Current model test accuracy: 0.5780576731852834
# 12 / 20 models trained | Current model test precision: 0.34962595543990893
# 12 / 20 models trained | Current model test recall: 0.3978136145056512
# 12 / 20 models trained | Current model test f1: 0.37216644836898927
# 13 / 20 models trained | Current model test accuracy: 0.5641365594961882
# 13 / 20 models trained | Current model test precision: 0.35353829580077645
# 13 / 20 models trained | Current model test recall: 0.36160939610875825
# 13 / 20 models trained | Current model test f1: 0.3575283010547988
# 14 / 20 models trained | Current model test accuracy: 0.5545243619489559
# 14 / 20 models trained | Current model test precision: 0.4173891629183111
# 14 / 20 models trained | Current model test recall: 0.39839593548797636
# 14 / 20 models trained | Current model test f1: 0.4076714476600258
# 15 / 20 models trained | Current model test accuracy: 0.5555187272124628
# 15 / 20 models trained | Current model test precision: 0.40272227511051084
# 15 / 20 models trained | Current model test recall: 0.4279094295152944
# 15 / 20 models trained | Current model test f1: 0.4149339786476684
# 16 / 20 models trained | Current model test accuracy: 0.54292343387471
# 16 / 20 models trained | Current model test precision: 0.3651689727094548
# 16 / 20 models trained | Current model test recall: 0.3911241034033512
# 16 / 20 models trained | Current model test f1: 0.37770116255938024
# 17 / 20 models trained | Current model test accuracy: 0.5644680145840238
# 17 / 20 models trained | Current model test precision: 0.3714727157138837
# 17 / 20 models trained | Current model test recall: 0.34940299776901085
# 17 / 20 models trained | Current model test f1: 0.36010002288114634
# 18 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 18 / 20 models trained | Current model test precision: 0.14182692307692307
# 18 / 20 models trained | Current model test recall: 0.25
# 18 / 20 models trained | Current model test f1: 0.18098159509202455
# 19 / 20 models trained | Current model test accuracy: 0.5836924096784886
# 19 / 20 models trained | Current model test precision: 0.46658554601195545
# 19 / 20 models trained | Current model test recall: 0.4126329331913189
# 19 / 20 models trained | Current model test f1: 0.43795385786261176
# 20 / 20 models trained | Current model test accuracy: 0.5495525356314219
# 20 / 20 models trained | Current model test precision: 0.34632763270021744
# 20 / 20 models trained | Current model test recall: 0.3307976784427371
# 20 / 20 models trained | Current model test f1: 0.338384564843461
# CPU times: total: 18min 54s
# Wall time: 10min 40s

# %%
# %%time
deepsetv2_accuracies, deepsetv2_precisions, deepsetv2_recalls, deepsetv2_f1Scores, deepsetv2_wrong_preds, deepsetv2_epoch_stats, model = train_models(DEEPSETV2_Model, x_train_normal, x_val_normal, x_test_normal, 0.0001, data, 16, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_12740\2177076457.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.5694398409015579
# 1 / 20 models trained | Current model test precision: 0.41468636905934386
# 1 / 20 models trained | Current model test recall: 0.45137985310534334
# 1 / 20 models trained | Current model test f1: 0.43225579652083773
# 2 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 2 / 20 models trained | Current model test precision: 0.14177991382167715
# 2 / 20 models trained | Current model test recall: 0.25
# 2 / 20 models trained | Current model test f1: 0.18094331641285955
# 3 / 20 models trained | Current model test accuracy: 0.5674511103745442
# 3 / 20 models trained | Current model test precision: 0.26687396351575454
# 3 / 20 models trained | Current model test recall: 0.375
# 3 / 20 models trained | Current model test f1: 0.3118298669422555
# 4 / 20 models trained | Current model test accuracy: 0.5591647331786543
# 4 / 20 models trained | Current model test precision: 0.28377766515358305
# 4 / 20 models trained | Current model test recall: 0.32248795743279707
# 4 / 20 models trained | Current model test f1: 0.3018969777966861
# 5 / 20 models trained | Current model test accuracy: 0.5853496851176666
# 5 / 20 models trained | Current model test precision: 0.2905904159245629
# 5 / 20 models trained | Current model test recall: 0.3297949102281354
# 5 / 20 models trained | Current model test f1: 0.3089539229669316
# 6 / 20 models trained | Current model test accuracy: 0.5604905535299967
# 6 / 20 models trained | Current model test precision: 0.17084368958851145
# 6 / 20 models trained | Current model test recall: 0.2478056147423419
# 6 / 20 models trained | Current model test f1: 0.2022505475842056
# 7 / 20 models trained | Current model test accuracy: 0.5644680145840238
# 7 / 20 models trained | Current model test precision: 0.1608752432653897
# 7 / 20 models trained | Current model test recall: 0.2501555677794204
# 7 / 20 models trained | Current model test f1: 0.1958190809025195
# 8 / 20 models trained | Current model test accuracy: 0.5611534637056679
# 8 / 20 models trained | Current model test precision: 0.4379366105547854
# 8 / 20 models trained | Current model test recall: 0.47673272760384955
# 8 / 20 models trained | Current model test f1: 0.4565118915818697
# 9 / 20 models trained | Current model test accuracy: 0.6165064633742128
# 9 / 20 models trained | Current model test precision: 0.3287183632481974
# 9 / 20 models trained | Current model test recall: 0.3608075989246488
# 9 / 20 models trained | Current model test f1: 0.3440162948825752
# 10 / 20 models trained | Current model test accuracy: 0.1153463705667882
# 10 / 20 models trained | Current model test precision: 0.07601752433272374
# 10 / 20 models trained | Current model test recall: 0.25355874633317893
# 10 / 20 models trained | Current model test f1: 0.11696781525085385
# 11 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 11 / 20 models trained | Current model test precision: 0.14177991382167715
# 11 / 20 models trained | Current model test recall: 0.25
# 11 / 20 models trained | Current model test f1: 0.18094331641285955
# 12 / 20 models trained | Current model test accuracy: 0.5651309247596951
# 12 / 20 models trained | Current model test precision: 0.2019607843137255
# 12 / 20 models trained | Current model test recall: 0.3214285714285714
# 12 / 20 models trained | Current model test f1: 0.24805994112924806
# 13 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 13 / 20 models trained | Current model test precision: 0.14177991382167715
# 13 / 20 models trained | Current model test recall: 0.25
# 13 / 20 models trained | Current model test f1: 0.18094331641285955
# 14 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 14 / 20 models trained | Current model test precision: 0.14177991382167715
# 14 / 20 models trained | Current model test recall: 0.25
# 14 / 20 models trained | Current model test f1: 0.18094331641285955
# 15 / 20 models trained | Current model test accuracy: 0.5661252900232019
# 15 / 20 models trained | Current model test precision: 0.1417192167275141
# 15 / 20 models trained | Current model test recall: 0.24956165984804207
# 15 / 20 models trained | Current model test f1: 0.18077900084674003
# 16 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 16 / 20 models trained | Current model test precision: 0.14177991382167715
# 16 / 20 models trained | Current model test recall: 0.25
# 16 / 20 models trained | Current model test f1: 0.18094331641285955
# 17 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 17 / 20 models trained | Current model test precision: 0.14177991382167715
# 17 / 20 models trained | Current model test recall: 0.25
# 17 / 20 models trained | Current model test f1: 0.18094331641285955
# 18 / 20 models trained | Current model test accuracy: 0.5555187272124628
# 18 / 20 models trained | Current model test precision: 0.2022890733056708
# 18 / 20 models trained | Current model test recall: 0.2503451497259511
# 18 / 20 models trained | Current model test f1: 0.22376605995651416
# 19 / 20 models trained | Current model test accuracy: 0.2333443818362612
# 19 / 20 models trained | Current model test precision: 0.11530693098043768
# 19 / 20 models trained | Current model test recall: 0.29180406080560883
# 19 / 20 models trained | Current model test f1: 0.1652965966431418
# 20 / 20 models trained | Current model test accuracy: 0.5992707988067617
# 20 / 20 models trained | Current model test precision: 0.4151808798266966
# 20 / 20 models trained | Current model test recall: 0.45720596371963496
# 20 / 20 models trained | Current model test f1: 0.4351811944056432
# CPU times: total: 9min 2s
# Wall time: 4min 54s

# %%
# %%time
feedforward_accuracies, feedforward_precisions, feedforward_recalls, feedforward_f1Scores, feedforward_wrong_preds, feedforward_epoch_stats, model = train_models(FEEDFORWARD_Model, x_train_normal, x_val_normal, x_test_normal, 0.0001, data, 128, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_12740\2177076457.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.5210473980775605
# 1 / 20 models trained | Current model test precision: 0.3341475927121588
# 1 / 20 models trained | Current model test recall: 0.33148150530796316
# 1 / 20 models trained | Current model test f1: 0.33280920968364935
# 2 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 2 / 20 models trained | Current model test precision: 0.14177991382167715
# 2 / 20 models trained | Current model test recall: 0.25
# 2 / 20 models trained | Current model test f1: 0.18094331641285955
# 3 / 20 models trained | Current model test accuracy: 0.5518727212462712
# 3 / 20 models trained | Current model test precision: 0.38841809782462383
# 3 / 20 models trained | Current model test recall: 0.3461551809224062
# 3 / 20 models trained | Current model test f1: 0.3660708626792345
# 4 / 20 models trained | Current model test accuracy: 0.5628107391448459
# 4 / 20 models trained | Current model test precision: 0.29619035961046736
# 4 / 20 models trained | Current model test recall: 0.3189909398437033
# 4 / 20 models trained | Current model test f1: 0.3071681186298027
# 5 / 20 models trained | Current model test accuracy: 0.5614849187935035
# 5 / 20 models trained | Current model test precision: 0.2869736365765881
# 5 / 20 models trained | Current model test recall: 0.3566595847528824
# 5 / 20 models trained | Current model test f1: 0.3180441738076084
# 6 / 20 models trained | Current model test accuracy: 0.5707656612529002
# 6 / 20 models trained | Current model test precision: 0.3458325051813509
# 6 / 20 models trained | Current model test recall: 0.4125370085868656
# 6 / 20 models trained | Current model test f1: 0.37625116666601816
# 7 / 20 models trained | Current model test accuracy: 0.5512098110706
# 7 / 20 models trained | Current model test precision: 0.2766555538953843
# 7 / 20 models trained | Current model test recall: 0.357215206270809
# 7 / 20 models trained | Current model test f1: 0.31181615231721294
# 8 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 8 / 20 models trained | Current model test precision: 0.14177991382167715
# 8 / 20 models trained | Current model test recall: 0.25
# 8 / 20 models trained | Current model test f1: 0.18094331641285955
# 9 / 20 models trained | Current model test accuracy: 0.5777262180974478
# 9 / 20 models trained | Current model test precision: 0.5605431986833936
# 9 / 20 models trained | Current model test recall: 0.38238132438601513
# 9 / 20 models trained | Current model test f1: 0.4546307693650929
# 10 / 20 models trained | Current model test accuracy: 0.5472323500165728
# 10 / 20 models trained | Current model test precision: 0.32327897454246024
# 10 / 20 models trained | Current model test recall: 0.32452858490053643
# 10 / 20 models trained | Current model test f1: 0.3239025744823619
# 11 / 20 models trained | Current model test accuracy: 0.5372886973815048
# 11 / 20 models trained | Current model test precision: 0.36520429399305887
# 11 / 20 models trained | Current model test recall: 0.3694791725716964
# 11 / 20 models trained | Current model test f1: 0.3673292962345238
# 12 / 20 models trained | Current model test accuracy: 0.5598276433543254
# 12 / 20 models trained | Current model test precision: 0.2805559499630629
# 12 / 20 models trained | Current model test recall: 0.3250582180595414
# 12 / 20 models trained | Current model test f1: 0.3011720067869719
# 13 / 20 models trained | Current model test accuracy: 0.5174013921113689
# 13 / 20 models trained | Current model test precision: 0.323363505181687
# 13 / 20 models trained | Current model test recall: 0.39027713447583756
# 13 / 20 models trained | Current model test f1: 0.3536832831071262
# 14 / 20 models trained | Current model test accuracy: 0.568445475638051
# 14 / 20 models trained | Current model test precision: 0.30810879280825054
# 14 / 20 models trained | Current model test recall: 0.3375718030281282
# 14 / 20 models trained | Current model test f1: 0.3221680855450638
# 15 / 20 models trained | Current model test accuracy: 0.5432548889625456
# 15 / 20 models trained | Current model test precision: 0.30063167595832174
# 15 / 20 models trained | Current model test recall: 0.3552247923771513
# 15 / 20 models trained | Current model test f1: 0.32565608431162246
# 16 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 16 / 20 models trained | Current model test precision: 0.41882559774964834
# 16 / 20 models trained | Current model test recall: 0.38310259609711383
# 16 / 20 models trained | Current model test f1: 0.40016843164009336
# 17 / 20 models trained | Current model test accuracy: 0.5217103082532317
# 17 / 20 models trained | Current model test precision: 0.33443752096809
# 17 / 20 models trained | Current model test recall: 0.347400870847276
# 17 / 20 models trained | Current model test f1: 0.3407959640377066
# 18 / 20 models trained | Current model test accuracy: 0.5293337752734505
# 18 / 20 models trained | Current model test precision: 0.33167724962718426
# 18 / 20 models trained | Current model test recall: 0.34864595949925886
# 18 / 20 models trained | Current model test f1: 0.33994998668008897
# 19 / 20 models trained | Current model test accuracy: 0.5667882001988731
# 19 / 20 models trained | Current model test precision: 0.14174403183023873
# 19 / 20 models trained | Current model test recall: 0.24985388661601401
# 19 / 20 models trained | Current model test f1: 0.18087581975883224
# 20 / 20 models trained | Current model test accuracy: 0.5568445475638051
# 20 / 20 models trained | Current model test precision: 0.37583902664109403
# 20 / 20 models trained | Current model test recall: 0.37210942764994703
# 20 / 20 models trained | Current model test f1: 0.37396492843746454
# CPU times: total: 12min 14s
# Wall time: 6min 44s

# %% [markdown]
# # Evaluation

# %% [markdown]
# # Evaluacion general de los modelos

# %%
import pandas as pd
# Lista de modelos y nombres
model_names = ['CNN', 'LSTM', 'DeepSet', 'DeepSetV2', 'Feedforward']
all_accuracies = [cnn_accuracies, lstm_accuracies, deepset_accuracies, deepsetv2_accuracies, feedforward_accuracies]
all_precisions = [cnn_precisions, lstm_precisions, deepset_precisions, deepsetv2_precisions, feedforward_precisions]
all_recalls = [cnn_recalls, lstm_recalls, deepset_recalls, deepsetv2_recalls, feedforward_recalls]
all_f1_scores = [cnn_f1_scores, lstm_f1Scores, deepset_f1Scores, deepsetv2_f1Scores, feedforward_f1Scores]

get_summary_df(model_names, all_accuracies, all_precisions, all_recalls, all_f1_scores)
# Out:
#         Modelo  Accuracy  Precision    Recall  F1-score  Precision clase A
# 0          CNN  1.000000   1.000000  1.000000  1.000000           1.000000  \
# 1         LSTM  0.996023   0.991538  0.988975  0.990255           0.970238
# 2      DeepSet  0.583692   0.466586  0.412633  0.437954           0.423077
# 3    DeepSetV2  0.616506   0.328718  0.360808  0.344016           0.065068
# 4  Feedforward  0.577726   0.560543  0.382381  0.454631           0.264706
#
#    Recall clase A  Precision clase D  Recall clase D  Precision clase R
# 0        1.000000           1.000000        1.000000           1.000000  \
# 1        0.958824           1.000000        1.000000           1.000000
# 2        0.064706           0.454545        0.555556           0.386792
# 3        0.111765           0.000000        0.000000           0.525449
# 4        0.052941           0.382979        0.480000           1.000000
#
#    Recall clase R  Precision clase V  Recall clase V
# 0        1.000000           1.000000        1.000000
# 1        1.000000           0.995914        0.997078
# 2        0.055480           0.601927        0.974790
# 3        0.460630           0.724356        0.870836
# 4        0.001377           0.594488        0.995207

# %% [markdown]
# ### Get best 50% performing models

# %%
top_half = int(num_experiments / 2)
best_cnn_accs = filter_top_k_accuracies(cnn_accuracies, top_half)
best_lstm_accs = filter_top_k_accuracies(lstm_accuracies, top_half)
best_deepset_accs = filter_top_k_accuracies(deepset_accuracies, top_half)
best_deepsetv2_accs = filter_top_k_accuracies(deepsetv2_accuracies, top_half)
best_feedforward_accs = filter_top_k_accuracies(feedforward_accuracies, top_half)

# %% [markdown]
# ## Accuracy breakdown by cases for all the models

# %%
all_accuracies = [cnn_accuracies, lstm_accuracies, deepset_accuracies, deepsetv2_accuracies, feedforward_accuracies]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']

# %%
get_stats_df(all_accuracies, model_names, test_original)
# Out:
#                        Overall cr_noop   cr_uw    cr_w   cr_wu dr_noop  dr_uw
# CNN                      99.6%  100.0%  100.0%  100.0%  100.0%  100.0%  98.1%  \
# LSTM                     94.0%  100.0%  100.0%  100.0%  100.0%   94.4%  68.3%
# DeepSet(like in paper)   56.4%   92.1%   92.0%   91.9%   93.0%   12.3%   2.8%
# DeepSet(sum at start)    53.1%   84.1%   85.6%   85.1%   85.8%    5.9%   8.1%
# Feedforward              55.2%   93.4%   93.4%   92.9%   94.3%    8.4%   1.4%
# Sample count              3017     194     176     173     171     190    170
#
#                          dr_w  dr_wu noop_noop noop_uw  noop_w noop_wu r_noop
# CNN                     99.6%  99.6%    100.0%  100.0%  100.0%  100.0%  99.9%  \
# LSTM                    93.7%  71.4%    100.0%  100.0%  100.0%  100.0%  94.9%
# DeepSet(like in paper)  14.0%  79.9%     94.9%   94.9%   93.7%   95.4%   9.9%
# DeepSet(sum at start)    5.3%  72.5%     83.0%   84.6%   83.8%   85.2%  19.7%
# Feedforward              9.2%  85.9%     91.4%   91.1%   90.4%   92.4%   9.1%
# Sample count              184    176       227     183     211     200    205
#
#                          r_uw    r_w   r_wu
# CNN                     99.2%  99.9%  96.1%
# LSTM                    92.5%  94.9%  87.9%
# DeepSet(like in paper)   8.7%  10.9%   8.2%
# DeepSet(sum at start)   17.8%  19.7%  16.7%
# Feedforward              8.2%   8.9%   6.5%
# Sample count              187    199    171

# %% [markdown]
# ## Accuracy breakdown by cases for top 50% of models

# %%
best_accuracies = [best_cnn_accs, best_lstm_accs, best_deepset_accs, best_deepsetv2_accs, best_feedforward_accs]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']
collapsed_cases = ['dr', 'r', 'cr', 'noop']

# %%
get_stats_df(best_accuracies, model_names, test_original, collapsed_cases)
# Out:
#                        Overall   f3_cr  f3_dr f3_noop   f3_r
# CNN                      99.9%  100.0%  99.7%  100.0%  99.7%
# LSTM                     98.8%  100.0%  97.3%  100.0%  97.8%
# DeepSet(like in paper)   57.3%   95.8%  27.0%   97.7%   6.2%
# DeepSet(sum at start)    57.7%   95.6%  23.6%   93.8%  15.6%
# Feedforward              56.7%   98.0%  26.1%   97.6%   2.8%
# Sample count              3017     714    720     821    762

# %% [markdown]
# ## Accuracies per CNN model

# %%
get_stats_per_model(cnn_accuracies, ['CNN #' + str(i) for i in range(len(cnn_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#              Overall   f3_cr   f3_dr f3_noop    f3_r
# CNN #0         99.2%  100.0%   99.0%  100.0%   97.6%
# CNN #1         99.5%  100.0%  100.0%  100.0%   98.2%
# CNN #2         99.8%  100.0%   99.2%  100.0%  100.0%
# CNN #3         99.4%  100.0%   99.0%  100.0%   98.4%
# CNN #4        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #5         99.8%  100.0%   99.6%  100.0%   99.6%
# CNN #6         99.4%  100.0%   99.7%  100.0%   98.0%
# CNN #7         99.2%  100.0%   99.0%  100.0%   97.9%
# CNN #8        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #9        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #10       100.0%  100.0%   99.9%  100.0%  100.0%
# CNN #11        99.7%  100.0%   99.0%  100.0%   99.7%
# CNN #12        99.0%  100.0%   98.6%  100.0%   97.5%
# CNN #13        99.7%  100.0%  100.0%  100.0%   98.7%
# CNN #14        99.2%  100.0%   99.0%  100.0%   97.9%
# CNN #15        99.5%  100.0%   99.6%  100.0%   98.3%
# CNN #16        98.6%  100.0%   97.1%  100.0%   97.1%
# CNN #17        99.6%  100.0%   98.6%  100.0%   99.7%
# CNN #18        99.9%  100.0%   99.7%  100.0%  100.0%
# CNN #19        99.8%  100.0%  100.0%  100.0%   99.2%
# Sample count    3017     714     720     821     762

# %%
get_stats_per_model_multiclass(cnn_accuracies, cnn_precisions, cnn_recalls, cnn_f1_scores, "CNN")
# Out:
#    Modelo  Accuracy  F1-score  Precision_Overall  Recall_Overall  Precision_A
# 0     CNN  0.991714  0.991542           0.995043        0.988066     0.994012  \
# 1     CNN  0.995360  0.996687           0.997971        0.995407     1.000000
# 2     CNN  0.998011  0.995426           0.996744        0.994112     0.994048
# 3     CNN  0.993702  0.991769           0.994853        0.988705     0.994012
# 4     CNN  1.000000  1.000000           1.000000        1.000000     1.000000
# 5     CNN  0.998011  0.997598           0.999126        0.996075     1.000000
# 6     CNN  0.994365  0.994835           0.996212        0.993462     0.994118
# 7     CNN  0.992377  0.994979           0.996684        0.993280     1.000000
# 8     CNN  1.000000  1.000000           1.000000        1.000000     1.000000
# 9     CNN  1.000000  1.000000           1.000000        1.000000     1.000000
# 10    CNN  0.999669  0.999191           0.999854        0.998529     1.000000
# 11    CNN  0.997017  0.993847           0.998692        0.989050     1.000000
# 12    CNN  0.990388  0.988107           0.994439        0.981856     0.993865
# 13    CNN  0.996685  0.997632           0.998547        0.996719     1.000000
# 14    CNN  0.992377  0.992019           0.996684        0.987398     1.000000
# 15    CNN  0.994697  0.995971           0.997684        0.994264     1.000000
# 16    CNN  0.985747  0.977515           0.989440        0.965873     0.980645
# 17    CNN  0.996023  0.991381           0.996859        0.985962     0.993827
# 18    CNN  0.999337  0.999118           0.999708        0.998529     1.000000
# 19    CNN  0.998011  0.998579           0.999126        0.998031     1.000000
#
#     Precision_D  Precision_R  Precision_V  Recall_A  Recall_D  Recall_R
# 0      1.000000          1.0     0.986159  0.976471  1.000000  0.976378  \
# 1      1.000000          1.0     0.991884  1.000000  1.000000  0.981627
# 2      0.994681          1.0     0.998247  0.982353  0.994681  1.000000
# 3      0.994681          1.0     0.990719  0.976471  0.994681  0.984252
# 4      1.000000          1.0     1.000000  1.000000  1.000000  1.000000
# 5      1.000000          1.0     0.996506  0.988235  1.000000  0.996063
# 6      1.000000          1.0     0.990730  0.994118  1.000000  0.980315
# 7      1.000000          1.0     0.986736  0.994118  1.000000  0.979003
# 8      1.000000          1.0     1.000000  1.000000  1.000000  1.000000
# 9      1.000000          1.0     1.000000  1.000000  1.000000  1.000000
# 10     1.000000          1.0     0.999416  0.994118  1.000000  1.000000
# 11     1.000000          1.0     0.994767  0.958824  1.000000  0.997375
# 12     1.000000          1.0     0.983890  0.952941  1.000000  0.975066
# 13     1.000000          1.0     0.994189  1.000000  1.000000  0.986877
# 14     1.000000          1.0     0.986736  0.970588  1.000000  0.979003
# 15     1.000000          1.0     0.990735  0.994118  1.000000  0.982940
# 16     1.000000          1.0     0.977117  0.894118  1.000000  0.971129
# 17     1.000000          1.0     0.993608  0.947059  1.000000  0.997375
# 18     1.000000          1.0     0.998832  0.994118  1.000000  1.000000
# 19     1.000000          1.0     0.996506  1.000000  1.000000  0.992126
#
#     Recall_V
# 0   0.999416
# 1   1.000000
# 2   0.999415
# 3   0.999415
# 4   1.000000
# 5   1.000000
# 6   0.999416
# 7   1.000000
# 8   1.000000
# 9   1.000000
# 10  1.000000
# 11  1.000000
# 12  0.999416
# 13  1.000000
# 14  1.000000
# 15  1.000000
# 16  0.998247
# 17  0.999416
# 18  1.000000
# 19  1.000000

# %% [markdown]
# ## Accuracies per LSTM model

# %%
get_stats_per_model(lstm_accuracies, ['LSTM #' + str(i) for i in range(len(lstm_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#              Overall   f3_cr   f3_dr f3_noop    f3_r
# LSTM #0        87.4%  100.0%   48.6%  100.0%   98.8%
# LSTM #1        94.8%  100.0%   78.1%  100.0%  100.0%
# LSTM #2        97.7%  100.0%   98.8%  100.0%   92.0%
# LSTM #3        95.9%  100.0%   96.4%  100.0%   87.0%
# LSTM #4        96.7%  100.0%   86.0%  100.0%  100.0%
# LSTM #5        88.5%  100.0%   51.8%  100.0%  100.0%
# LSTM #6        99.6%  100.0%   98.6%  100.0%   99.6%
# LSTM #7        93.0%  100.0%   77.1%  100.0%   94.1%
# LSTM #8        98.1%  100.0%   92.2%  100.0%  100.0%
# LSTM #9        88.4%  100.0%   51.9%  100.0%   99.3%
# LSTM #10       95.5%  100.0%   82.9%  100.0%   98.2%
# LSTM #11       99.4%  100.0%  100.0%  100.0%   97.8%
# LSTM #12       56.7%  100.0%   24.4%  100.0%    0.0%
# LSTM #13       99.1%  100.0%   96.8%  100.0%   99.5%
# LSTM #14       99.2%  100.0%   99.7%  100.0%   97.2%
# LSTM #15       94.4%  100.0%   77.9%  100.0%   98.6%
# LSTM #16       99.6%  100.0%   98.3%  100.0%  100.0%
# LSTM #17       99.0%  100.0%   97.8%  100.0%   98.3%
# LSTM #18       98.2%  100.0%   92.6%  100.0%   99.9%
# LSTM #19       98.1%  100.0%   98.6%  100.0%   94.0%
# Sample count    3017     714     720     821     762

# %%
get_stats_per_model_multiclass(lstm_accuracies, lstm_precisions, lstm_recalls, lstm_f1Scores, "LSTM")
# Out:
#    Modelo  Accuracy  F1-score  Precision_Overall  Recall_Overall  Precision_A
# 0    LSTM  0.874379  0.641904           0.618318        0.667360     0.000000  \
# 1    LSTM  0.947630  0.861020           0.871185        0.851089     0.543478
# 2    LSTM  0.976798  0.978314           0.988770        0.968076     0.993865
# 3    LSTM  0.958568  0.954584           0.966797        0.942675     0.939024
# 4    LSTM  0.966523  0.934332           0.909145        0.960954     0.648069
# 5    LSTM  0.884985  0.648979           0.629366        0.669854     0.000000
# 6    LSTM  0.995691  0.991393           0.987905        0.994906     0.954545
# 7    LSTM  0.930394  0.871510           0.859496        0.883863     0.527778
# 8    LSTM  0.981439  0.949654           0.957964        0.941488     0.880000
# 9    LSTM  0.883659  0.648109           0.629049        0.668360     0.000000
# 10   LSTM  0.954591  0.903375           0.896183        0.910684     0.625000
# 11   LSTM  0.994365  0.995979           0.997541        0.994423     1.000000
# 12   LSTM  0.567120  0.180943           0.141780        0.250000     0.000000
# 13   LSTM  0.991051  0.981699           0.972231        0.991354     0.893048
# 14   LSTM  0.992377  0.993416           0.996684        0.990169     1.000000
# 15   LSTM  0.943653  0.881536           0.870696        0.892649     0.532020
# 16   LSTM  0.996023  0.990255           0.991538        0.988975     0.970238
# 17   LSTM  0.990388  0.983994           0.985190        0.982801     0.952941
# 18   LSTM  0.982101  0.957518           0.954910        0.960141     0.834286
# 19   LSTM  0.981439  0.980743           0.988765        0.972851     0.987805
#
#     Precision_D  Precision_R  Precision_V  Recall_A  Recall_D  Recall_R
# 0      0.521531     1.000000     0.951741  0.000000  0.681250  0.988189  \
# 1      0.994681     1.000000     0.946582  0.441176  1.000000  1.000000
# 2      1.000000     1.000000     0.961214  0.952941  1.000000  0.919948
# 3      0.989390     1.000000     0.938776  0.905882  1.000000  0.870079
# 4      1.000000     1.000000     0.988513  0.888235  1.000000  1.000000
# 5      0.518776     0.998689     1.000000  0.000000  0.679417  1.000000
# 6      1.000000     1.000000     0.997073  0.988235  1.000000  0.996063
# 7      0.966057     1.000000     0.944150  0.670588  0.981432  0.940945
# 8      0.966408     1.000000     0.985448  0.776471  1.000000  1.000000
# 9      0.519444     1.000000     0.996753  0.000000  0.680000  0.993438
# 10     0.997333     1.000000     0.962397  0.705882  0.997333  0.981627
# 11     1.000000     1.000000     0.990162  1.000000  1.000000  0.977690
# 12     0.000000     0.000000     0.567120  0.000000  0.000000  0.000000
# 13     1.000000     1.000000     0.995878  0.982353  1.000000  0.994751
# 14     1.000000     1.000000     0.986736  0.988235  1.000000  0.972441
# 15     0.994521     0.998670     0.957572  0.635294  1.000000  0.985564
# 16     1.000000     1.000000     0.995914  0.958824  1.000000  1.000000
# 17     1.000000     1.000000     0.987819  0.952941  1.000000  0.982940
# 18     1.000000     1.000000     0.985354  0.858824  1.000000  0.998688
# 19     0.997333     1.000000     0.969921  0.952941  1.000000  0.939633
#
#     Recall_V
# 0   1.000000
# 1   0.963179
# 2   0.999416
# 3   0.994740
# 4   0.955582
# 5   1.000000
# 6   0.995324
# 7   0.942488
# 8   0.989480
# 9   1.000000
# 10  0.957895
# 11  1.000000
# 12  1.000000
# 13  0.988311
# 14  1.000000
# 15  0.949737
# 16  0.997078
# 17  0.995324
# 18  0.983051
# 19  0.998831

# %% [markdown]
# ## Accuracies per DeepSets V1 model

# %%
get_stats_per_model(deepset_accuracies, ['DeepSet(like in paper) #' + str(i) for i in range(len(deepset_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                            Overall   f3_cr  f3_dr f3_noop   f3_r
# DeepSet(like in paper) #0    57.1%   91.9%  28.1%   95.9%  10.2%
# DeepSet(like in paper) #1    55.9%   86.3%  28.3%   90.7%  16.0%
# DeepSet(like in paper) #2    56.7%   90.5%  24.6%   92.1%  17.2%
# DeepSet(like in paper) #3    57.4%   92.6%  28.7%   95.6%  10.2%
# DeepSet(like in paper) #4    56.2%   98.2%  23.6%   97.1%   3.5%
# DeepSet(like in paper) #5    57.3%   99.0%  27.9%   99.4%   0.8%
# DeepSet(like in paper) #6    56.7%  100.0%  24.4%   99.9%   0.0%
# DeepSet(like in paper) #7    55.5%   82.2%  23.9%   86.4%  27.0%
# DeepSet(like in paper) #8    57.3%   96.8%  26.4%   99.1%   4.6%
# DeepSet(like in paper) #9    57.1%   96.5%  25.0%   97.8%   6.8%
# DeepSet(like in paper) #10   55.7%   93.3%  28.5%   91.5%   7.7%
# DeepSet(like in paper) #11   57.8%   94.7%  28.9%   98.5%   6.7%
# DeepSet(like in paper) #12   56.4%   97.2%  26.9%   98.2%   1.0%
# DeepSet(like in paper) #13   55.5%   83.1%  29.0%   88.9%  18.5%
# DeepSet(like in paper) #14   55.6%   87.8%  26.8%   91.4%  13.9%
# DeepSet(like in paper) #15   54.3%   78.7%  27.2%   84.9%  24.0%
# DeepSet(like in paper) #16   56.4%   91.3%  26.0%   93.5%  12.6%
# DeepSet(like in paper) #17   56.7%  100.0%  24.4%  100.0%   0.0%
# DeepSet(like in paper) #18   58.4%   95.9%  31.7%   98.3%   5.4%
# DeepSet(like in paper) #19   55.0%   88.9%  29.9%   95.4%   3.3%
# Sample count                  3017     714    720     821    762

# %%
get_stats_per_model_multiclass(deepset_accuracies, deepset_precisions, deepset_recalls, deepset_f1Scores, "DEEPSET")
# Out:
#      Modelo  Accuracy  F1-score  Precision_Overall  Recall_Overall
# 0   DEEPSET  0.571097  0.407510           0.419662        0.396042  \
# 1   DEEPSET  0.559165  0.380588           0.379061        0.382127
# 2   DEEPSET  0.566788  0.418634           0.411397        0.426131
# 3   DEEPSET  0.573749  0.395274           0.384837        0.406293
# 4   DEEPSET  0.561816  0.281226           0.312202        0.255842
# 5   DEEPSET  0.573417  0.404992           0.407782        0.402240
# 6   DEEPSET  0.566788  0.180952           0.141838        0.249854
# 7   DEEPSET  0.554856  0.409465           0.408963        0.409967
# 8   DEEPSET  0.573417  0.352996           0.332705        0.375923
# 9   DEEPSET  0.571429  0.393459           0.412787        0.375860
# 10  DEEPSET  0.557176  0.384565           0.405339        0.365818
# 11  DEEPSET  0.578058  0.372166           0.349626        0.397814
# 12  DEEPSET  0.564137  0.357528           0.353538        0.361609
# 13  DEEPSET  0.554524  0.407671           0.417389        0.398396
# 14  DEEPSET  0.555519  0.414934           0.402722        0.427909
# 15  DEEPSET  0.542923  0.377701           0.365169        0.391124
# 16  DEEPSET  0.564468  0.360100           0.371473        0.349403
# 17  DEEPSET  0.567120  0.180982           0.141827        0.250000
# 18  DEEPSET  0.583692  0.437954           0.466586        0.412633
# 19  DEEPSET  0.549553  0.338385           0.346328        0.330798
#
#     Precision_A  Precision_D  Precision_R  Precision_V  Recall_A  Recall_D
# 0      0.333333     0.386243     0.352941     0.606131  0.058824  0.477124  \
# 1      0.214286     0.360595     0.314433     0.626930  0.035294  0.427313
# 2      0.200000     0.474359     0.370056     0.601174  0.035294  0.587302
# 3      0.153846     0.416667     0.364486     0.604349  0.023529  0.550847
# 4      0.400000     0.000000     0.275510     0.573297  0.011765  0.000000
# 5      0.333333     0.444444     0.272727     0.580623  0.011765  0.594595
# 6      0.000000     0.000000     0.000000     0.567352  0.000000  0.000000
# 7      0.281250     0.369863     0.380776     0.603965  0.052941  0.465517
# 8      0.000000     0.366071     0.376344     0.588403  0.000000  0.471264
# 9      0.250000     0.433333     0.385185     0.582630  0.011765  0.448276
# 10     0.375000     0.357143     0.301020     0.588191  0.017647  0.426357
# 11     0.000000     0.441860     0.356643     0.600000  0.000000  0.554745
# 12     0.285714     0.341176     0.210526     0.576736  0.023529  0.426471
# 13     0.333333     0.402542     0.315436     0.618245  0.041176  0.489691
# 14     0.209302     0.486239     0.320242     0.595107  0.052941  0.623529
# 15     0.139535     0.366071     0.334552     0.620517  0.035294  0.445652
# 16     0.230769     0.237037     0.421053     0.597032  0.035294  0.288288
# 17     0.000000     0.000000     0.000000     0.567308  0.000000  0.000000
# 18     0.423077     0.454545     0.386792     0.601927  0.064706  0.555556
# 19     0.304348     0.244514     0.233645     0.602804  0.041176  0.276596
#
#     Recall_R  Recall_V
# 0   0.106122  0.942099
# 1   0.172805  0.893097
# 2   0.173052  0.908876
# 3   0.104558  0.946237
# 4   0.035620  0.975981
# 5   0.007937  0.994665
# 6   0.000000  0.999416
# 7   0.273572  0.847839
# 8   0.046729  0.985697
# 9   0.068692  0.974706
# 10  0.080491  0.938776
# 11  0.068826  0.967684
# 12  0.010681  0.985757
# 13  0.193416  0.869301
# 14  0.140212  0.894955
# 15  0.251029  0.832521
# 16  0.131687  0.942342
# 17  0.000000  1.000000
# 18  0.055480  0.974790
# 19  0.037313  0.968105

# %% [markdown]
# ## Accuracies per DeepSets V2 model

# %%
get_stats_per_model(deepsetv2_accuracies, ['DeepSet(sum at start) #' + str(i) for i in range(len(deepsetv2_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                           Overall   f3_cr  f3_dr f3_noop   f3_r
# DeepSet(sum at start) #0    56.9%   88.9%  34.6%   69.3%  34.8%
# DeepSet(sum at start) #1    56.7%  100.0%  24.4%  100.0%   0.0%
# DeepSet(sum at start) #2    56.7%  100.0%  24.6%  100.0%   0.0%
# DeepSet(sum at start) #3    55.9%   84.3%  11.9%   82.3%  42.4%
# DeepSet(sum at start) #4    58.5%   89.6%  12.9%   88.4%  40.3%
# DeepSet(sum at start) #5    56.0%   98.5%  23.8%   99.0%   0.5%
# DeepSet(sum at start) #6    56.4%   99.7%  24.2%   99.5%   0.0%
# DeepSet(sum at start) #7    56.1%   67.9%  38.1%   68.5%  48.8%
# DeepSet(sum at start) #8    61.7%   87.8%  16.5%   92.9%  46.1%
# DeepSet(sum at start) #9    11.5%    0.0%  16.9%    0.0%  29.7%
# DeepSet(sum at start) #10   56.7%  100.0%  24.4%  100.0%   0.0%
# DeepSet(sum at start) #11   56.5%   99.7%  25.0%   99.0%   0.0%
# DeepSet(sum at start) #12   56.7%  100.0%  24.4%  100.0%   0.0%
# DeepSet(sum at start) #13   56.7%  100.0%  24.4%  100.0%   0.0%
# DeepSet(sum at start) #14   56.6%   99.9%  24.3%   99.9%   0.0%
# DeepSet(sum at start) #15   56.7%  100.0%  24.4%  100.0%   0.0%
# DeepSet(sum at start) #16   56.7%  100.0%  24.4%  100.0%   0.0%
# DeepSet(sum at start) #17   55.6%   96.9%  23.3%   95.7%   3.9%
# DeepSet(sum at start) #18   23.3%    0.0%   2.9%    0.0%  89.6%
# DeepSet(sum at start) #19   59.9%   89.4%  25.3%   87.6%  35.3%
# Sample count                 3017     714    720     821    762

# %%
get_stats_per_model_multiclass(deepsetv2_accuracies, deepsetv2_precisions, deepsetv2_recalls, deepsetv2_f1Scores, "DEEPSETv2")
# Out:
#        Modelo  Accuracy  F1-score  Precision_Overall  Recall_Overall
# 0   DEEPSETv2  0.569440  0.432256           0.414686        0.451380  \
# 1   DEEPSETv2  0.567120  0.180943           0.141780        0.250000
# 2   DEEPSETv2  0.567451  0.311830           0.266874        0.375000
# 3   DEEPSETv2  0.559165  0.301897           0.283778        0.322488
# 4   DEEPSETv2  0.585350  0.308954           0.290590        0.329795
# 5   DEEPSETv2  0.560491  0.202251           0.170844        0.247806
# 6   DEEPSETv2  0.564468  0.195819           0.160875        0.250156
# 7   DEEPSETv2  0.561153  0.456512           0.437937        0.476733
# 8   DEEPSETv2  0.616506  0.344016           0.328718        0.360808
# 9   DEEPSETv2  0.115346  0.116968           0.076018        0.253559
# 10  DEEPSETv2  0.567120  0.180943           0.141780        0.250000
# 11  DEEPSETv2  0.565131  0.248060           0.201961        0.321429
# 12  DEEPSETv2  0.567120  0.180943           0.141780        0.250000
# 13  DEEPSETv2  0.567120  0.180943           0.141780        0.250000
# 14  DEEPSETv2  0.566125  0.180779           0.141719        0.249562
# 15  DEEPSETv2  0.567120  0.180943           0.141780        0.250000
# 16  DEEPSETv2  0.567120  0.180943           0.141780        0.250000
# 17  DEEPSETv2  0.555519  0.223766           0.202289        0.250345
# 18  DEEPSETv2  0.233344  0.165297           0.115307        0.291804
# 19  DEEPSETv2  0.599271  0.435181           0.415181        0.457206
#
#     Precision_A  Precision_D  Precision_R  Precision_V  Recall_A  Recall_D
# 0      0.137931     0.450633     0.352394     0.717788  0.094118  0.563291  \
# 1      0.000000     0.000000     0.000000     0.567120  0.000000  0.000000
# 2      0.000000     0.500000     0.000000     0.567496  0.000000  0.500000
# 3      0.094891     0.000000     0.334369     0.705852  0.076471  0.000000
# 4      0.086957     0.000000     0.366786     0.708619  0.070588  0.000000
# 5      0.000000     0.000000     0.117647     0.565728  0.000000  0.000000
# 6      0.076923     0.000000     0.000000     0.566578  0.005882  0.000000
# 7      0.189189     0.422145     0.485007     0.655405  0.205882  0.467433
# 8      0.065068     0.000000     0.525449     0.724356  0.111765  0.000000
# 9      0.058151     0.000000     0.245919     0.000000  0.717647  0.000000
# 10     0.000000     0.000000     0.000000     0.567120  0.000000  0.000000
# 11     0.000000     0.238095     0.000000     0.569748  0.000000  0.285714
# 12     0.000000     0.000000     0.000000     0.567120  0.000000  0.000000
# 13     0.000000     0.000000     0.000000     0.567120  0.000000  0.000000
# 14     0.000000     0.000000     0.000000     0.566877  0.000000  0.000000
# 15     0.000000     0.000000     0.000000     0.567120  0.000000  0.000000
# 16     0.000000     0.000000     0.000000     0.567120  0.000000  0.000000
# 17     0.000000     0.000000     0.240000     0.569156  0.000000  0.000000
# 18     0.055901     0.150000     0.255327     0.000000  0.105882  0.157895
# 19     0.182243     0.243056     0.446844     0.788581  0.229412  0.280749
#
#     Recall_R  Recall_V
# 0   0.374294  0.773817
# 1   0.000000  1.000000
# 2   0.000000  1.000000
# 3   0.423885  0.789597
# 4   0.402887  0.845704
# 5   0.005249  0.985973
# 6   0.000000  0.994740
# 7   0.504749  0.728867
# 8   0.460630  0.870836
# 9   0.296588  0.000000
# 10  0.000000  1.000000
# 11  0.000000  1.000000
# 12  0.000000  1.000000
# 13  0.000000  1.000000
# 14  0.000000  0.998247
# 15  0.000000  1.000000
# 16  0.000000  1.000000
# 17  0.039370  0.962011
# 18  0.903439  0.000000
# 19  0.450586  0.868077

# %% [markdown]
# ## Accuracies per FeedForward model

# %%
get_stats_per_model(feedforward_accuracies, ['Feedforward #' + str(i) for i in range(len(feedforward_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                 Overall   f3_cr  f3_dr f3_noop   f3_r
# Feedforward #0    52.1%   86.8%  24.3%   75.3%  20.9%
# Feedforward #1    56.7%  100.0%  24.4%  100.0%   0.0%
# Feedforward #2    55.2%   90.2%  30.3%   86.4%  12.3%
# Feedforward #3    56.3%   97.1%  26.5%   96.1%   3.3%
# Feedforward #4    56.1%   96.9%  26.2%   96.3%   2.9%
# Feedforward #5    57.1%   96.8%  26.8%   97.6%   4.9%
# Feedforward #6    55.1%   95.0%  23.8%   94.4%   5.1%
# Feedforward #7    56.7%  100.0%  24.4%  100.0%   0.0%
# Feedforward #8    57.8%   98.5%  31.7%   98.8%   0.1%
# Feedforward #9    54.7%   93.3%  27.6%   93.9%   2.0%
# Feedforward #10   53.7%   87.8%  31.7%   84.3%   9.7%
# Feedforward #11   56.0%   96.8%  25.8%   95.7%   3.4%
# Feedforward #12   51.7%   81.8%  19.2%   79.0%  24.9%
# Feedforward #13   56.8%   95.1%  25.6%   94.5%  10.0%
# Feedforward #14   54.3%   90.1%  27.2%   87.2%  11.0%
# Feedforward #15   56.7%   99.0%  24.7%   97.0%   3.9%
# Feedforward #16   52.2%   83.8%  27.1%   74.2%  22.6%
# Feedforward #17   52.9%   85.6%  20.7%   81.5%  22.0%
# Feedforward #18   56.7%  100.0%  24.3%  100.0%   0.0%
# Feedforward #19   55.7%   95.5%  25.1%   94.0%   5.9%
# Sample count       3017     714    720     821    762

# %%
get_stats_per_model_multiclass(feedforward_accuracies, feedforward_precisions, feedforward_recalls, feedforward_f1Scores, "FEEDFORWARD")
# Out:
#          Modelo  Accuracy  F1-score  Precision_Overall  Recall_Overall
# 0   FEEDFORWARD  0.521047  0.332809           0.334148        0.331482  \
# 1   FEEDFORWARD  0.567120  0.180943           0.141780        0.250000
# 2   FEEDFORWARD  0.551873  0.366071           0.388418        0.346155
# 3   FEEDFORWARD  0.562811  0.307168           0.296190        0.318991
# 4   FEEDFORWARD  0.561485  0.318044           0.286974        0.356660
# 5   FEEDFORWARD  0.570766  0.376251           0.345833        0.412537
# 6   FEEDFORWARD  0.551210  0.311816           0.276656        0.357215
# 7   FEEDFORWARD  0.567120  0.180943           0.141780        0.250000
# 8   FEEDFORWARD  0.577726  0.454631           0.560543        0.382381
# 9   FEEDFORWARD  0.547232  0.323903           0.323279        0.324529
# 10  FEEDFORWARD  0.537289  0.367329           0.365204        0.369479
# 11  FEEDFORWARD  0.559828  0.301172           0.280556        0.325058
# 12  FEEDFORWARD  0.517401  0.353683           0.323364        0.390277
# 13  FEEDFORWARD  0.568445  0.322168           0.308109        0.337572
# 14  FEEDFORWARD  0.543255  0.325656           0.300632        0.355225
# 15  FEEDFORWARD  0.567120  0.400168           0.418826        0.383103
# 16  FEEDFORWARD  0.521710  0.340796           0.334438        0.347401
# 17  FEEDFORWARD  0.529334  0.339950           0.331677        0.348646
# 18  FEEDFORWARD  0.566788  0.180876           0.141744        0.249854
# 19  FEEDFORWARD  0.556845  0.373965           0.375839        0.372109
#
#     Precision_A  Precision_D  Precision_R  Precision_V  Recall_A  Recall_D
# 0      0.210526     0.229508     0.313609     0.582946  0.023529  0.252252  \
# 1      0.000000     0.000000     0.000000     0.567120  0.000000  0.000000
# 2      0.333333     0.266476     0.333333     0.620530  0.017647  0.300000
# 3      0.000000     0.218182     0.378788     0.587792  0.000000  0.248276
# 4      0.000000     0.348485     0.220000     0.579410  0.000000  0.425926
# 5      0.000000     0.513158     0.284615     0.585557  0.000000  0.629032
# 6      0.000000     0.315789     0.216667     0.574166  0.000000  0.428571
# 7      0.000000     0.000000     0.000000     0.567120  0.000000  0.000000
# 8      0.264706     0.382979     1.000000     0.594488  0.052941  0.480000
# 9      0.200000     0.257862     0.263158     0.572096  0.023529  0.282759
# 10     0.263158     0.359551     0.237942     0.600167  0.058824  0.430493
# 11     0.000000     0.260274     0.285714     0.576236  0.000000  0.287879
# 12     0.090909     0.333333     0.274170     0.595041  0.011765  0.500000
# 13     0.000000     0.260000     0.378109     0.594326  0.000000  0.282609
# 14     0.000000     0.345238     0.265823     0.591466  0.000000  0.402778
# 15     0.222222     0.500000     0.379747     0.573333  0.011765  0.500000
# 16     0.137931     0.244444     0.351738     0.603636  0.047059  0.259843
# 17     0.142857     0.300000     0.273616     0.610236  0.005882  0.323529
# 18     0.000000     0.000000     0.000000     0.566976  0.000000  0.000000
# 19     0.230769     0.439024     0.254237     0.579325  0.017647  0.461538
#
#     Recall_R  Recall_V
# 0   0.217213  0.832931
# 1   0.000000  1.000000
# 2   0.142209  0.924765
# 3   0.034965  0.992723
# 4   0.029570  0.971143
# 5   0.048877  0.972239
# 6   0.051316  0.948974
# 7   0.000000  1.000000
# 8   0.001377  0.995207
# 9   0.020520  0.971306
# 10  0.102921  0.885679
# 11  0.034946  0.977408
# 12  0.249344  0.800000
# 13  0.103542  0.964136
# 14  0.115226  0.902895
# 15  0.039370  0.981276
# 16  0.247482  0.835220
# 17  0.227334  0.837838
# 18  0.000000  0.999416
# 19  0.059840  0.949412

# %% [markdown]
# # Training evolution

# %% [markdown]
# ### CNN

# %%
display_epochs_stats(cnn_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### LSTM

# %%
display_epochs_stats(lstm_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### DeepSets V1

# %%
display_epochs_stats(deepset_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### DeepSets V2

# %%
display_epochs_stats(deepsetv2_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### FeedForward

# %%
display_epochs_stats(feedforward_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# # Best performing models

# %%
best_lstm_model = LSTM_Model(data, 16, 32, 8).to(device)
best_lstm_model.load_state_dict(torch.load('./bestmodels/best_LSTM_model_' + experiment_name))
best_cnn_model = CNN_Model(data, 64, 128, 4, -1,).to(device)
best_cnn_model.load_state_dict(torch.load('./bestmodels/best_CNN_model_' + experiment_name))
best_deepset_model = DEEPSET_Model(data).to(device)
best_deepset_model.load_state_dict(torch.load('./bestmodels/best_DEEPSET_model_' + experiment_name))
best_deepsetv2_model = DEEPSETV2_Model(data).to(device)
best_feedforward_model = FEEDFORWARD_Model(data).to(device)
best_feedforward_model.load_state_dict(torch.load('./bestmodels/best_FEEDFORWARD_model_' + experiment_name))
#best_deepsetv2_model.load_state_dict(torch.load('./bestmodels/best_DEEPSETV2_model_' + experiment_name))
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_12740\482518558.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_lstm_model.load_state_dict(torch.load('./bestmodels/best_LSTM_model_' + experiment_name))
# C:\Users\franm\AppData\Local\Temp\ipykernel_12740\482518558.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_cnn_model.load_state_dict(torch.load('./bestmodels/best_CNN_model_' + experiment_name))
# C:\Users\franm\AppData\Local\Temp\ipykernel_12740\482518558.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_deepset_model.load_state_dict(torch.load('./bestmodels/best_DEEPSET_model_' + experiment_name))
# C:\Users\franm\AppData\Local\Temp\ipykernel_12740\482518558.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_feedforward_model.load_state_dict(torch.load('./bestmodels/best_FEEDFORWARD_model_' + experiment_name))
# <All keys matched successfully>

# %% [markdown]
# ## Top wrong predictions for best performing CNN model

# %%
print_wrong_preds_bycases(get_wrong_predictions_bycases(best_cnn_model, x_test_cnn, y_test, test_original), k=10)
# Out:
# 0 Atomicity violation cases wrong predicted:
#
#
# 0 DeadLock cases wrong predicted:
#
#
# 0 Data race cases wrong predicted:
#
#
# 0 Valid cases wrong predicted:

# %%
print_wrong_preds(get_wrong_predictions(best_cnn_model, x_test_cnn, y_test, test_original), k=10)
# Out:
# 0 false Atomicity violation:
#
#
# 0 false DeadLock:
#
#
# 0 false Data race :
#
#
# 0 false Valid:

# %% [markdown]
# ## Top wrong predictions for best performing LSTM model

# %%
print_wrong_preds_bycases(get_wrong_predictions_bycases(best_lstm_model, x_test_lstm, y_test, test_original), k=10)
# Out:
# 7 Atomicity violation cases wrong predicted:
# Sample [',.,_,,_,_,._.,__', ',_uw.,.._......_', '_dr_,,.,_,_,,._.', 'A'] | Prediction V
# Sample ['_,,..,,_.,,..._.', '.__,_,_,,uw..._.', '._.._...dr._,_..', 'A'] | Prediction V
# Sample ['_.._..,,.,____..', '.,.,,.,._,uw,.,,', '_.,,dr.,,,...,_.', 'A'] | Prediction V
# Sample ['_,_,___.,.,.,,._', '.,uw._,..,,,_..,', '.____,,____.,,dr', 'A'] | Prediction V
# Sample ['_,,,,....,..,,..', ',_,.,__,,uw.,_.,', ',_._...____,,_dr', 'A'] | Prediction V
# Sample ['_,___.__._.._.__', 'uw,...,,,_,._..,', ',._.._.,,dr,,_..', 'A'] | Prediction V
# Sample ['_,._,.,,,.._,_,.', '..,...._,__.,uw,', '_,_.dr,_._.__,,_', 'A'] | Prediction V
#
#
# 0 DeadLock cases wrong predicted:
#
#
# 0 Data race cases wrong predicted:
#
#
# 5 Valid cases wrong predicted:
# Sample ['...,,.,._,_,_..,', '_,._.wu___._.,,_', '.._,,....,,_dr,.', 'V'] | Prediction A
# Sample ['.,..,,____,_.._,', ',,.,_,wu____,__,', ',,dr,,.,_..___,.', 'V'] | Prediction A
# Sample ['__,,.,__,__,_,,,', '.._,__.,wu_._.__', '.,_,,.,_.__dr.,,', 'V'] | Prediction A
# Sample ['_,,__,,.__.___._', ',.._,,_._wu____,', '.,,.,dr,__.,_,..', 'V'] | Prediction A
# Sample ['.,..,_,,,_,.._,,', ',_wu_,__,,____,_', '_.__,dr.,,,_,_.,', 'V'] | Prediction A

# %%
print_wrong_preds(get_wrong_predictions(best_lstm_model, x_test_lstm, y_test, test_original), k=10)
# Out:
# 5 false Atomicity violation:
# Sample ['...,,.,._,_,_..,', '_,._.wu___._.,,_', '.._,,....,,_dr,.', 'V'] | Prediction A
# Sample ['.,..,,____,_.._,', ',,.,_,wu____,__,', ',,dr,,.,_..___,.', 'V'] | Prediction A
# Sample ['__,,.,__,__,_,,,', '.._,__.,wu_._.__', '.,_,,.,_.__dr.,,', 'V'] | Prediction A
# Sample ['_,,__,,.__.___._', ',.._,,_._wu____,', '.,,.,dr,__.,_,..', 'V'] | Prediction A
# Sample ['.,..,_,,,_,.._,,', ',_wu_,__,,____,_', '_.__,dr.,,,_,_.,', 'V'] | Prediction A
#
#
# 0 false DeadLock:
#
#
# 0 false Data race :
#
#
# 7 false Valid:
# Sample [',.,_,,_,_,._.,__', ',_uw.,.._......_', '_dr_,,.,_,_,,._.', 'A'] | Prediction V
# Sample ['_,,..,,_.,,..._.', '.__,_,_,,uw..._.', '._.._...dr._,_..', 'A'] | Prediction V
# Sample ['_.._..,,.,____..', '.,.,,.,._,uw,.,,', '_.,,dr.,,,...,_.', 'A'] | Prediction V
# Sample ['_,_,___.,.,.,,._', '.,uw._,..,,,_..,', '.____,,____.,,dr', 'A'] | Prediction V
# Sample ['_,,,,....,..,,..', ',_,.,__,,uw.,_.,', ',_._...____,,_dr', 'A'] | Prediction V
# Sample ['_,___.__._.._.__', 'uw,...,,,_,._..,', ',._.._.,,dr,,_..', 'A'] | Prediction V
# Sample ['_,._,.,,,.._,_,.', '..,...._,__.,uw,', '_,_.dr,_._.__,,_', 'A'] | Prediction V

# %% [markdown]
# ## Top wrong predictions for best performing DeepSets V1 model

# %%
print_wrong_preds_bycases(get_wrong_predictions_bycases(best_deepset_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 10 Atomicity violation cases wrong predicted:
# Sample ['__,..,.,_._,_...', ',___,_..__,,,.uw', '____._.._._,,,dr', 'A'] | Prediction V
# Sample [',.._,_,._._.,.,.', '..._uw...,_,_,,.', '_dr,_,._,,...._,', 'A'] | Prediction D
# Sample [',.._,.___.,.__,.', '.,.,,_..,_.uw..,', ',._..,.,__dr._,,', 'A'] | Prediction V
# Sample ['_.._,_,,_._,_.,.', '.uw._,._.._..._,', ',.__.,,_dr_.,...', 'A'] | Prediction V
# Sample [',_.,.__._,,__,_,', '.,_.__,..,_,_uw.', ',_....__..._dr_.', 'A'] | Prediction V
# Sample [',,,_,,..,,,,._,.', ',,_,_._,.._.,_uw', '.,dr,..,.,.__,__', 'A'] | Prediction V
# Sample ['.,,____,._.,_,_,', '_,_uw_,,,_,_.,,,', '_dr,,_.,..._..,,', 'A'] | Prediction V
# Sample [',...__...,..,__,', ',__uw_._.,,_._..', '__.,,,_,...,..dr', 'A'] | Prediction V
# Sample [',.,_,,_,_,._.,__', ',_uw.,.._......_', '_dr_,,.,_,_,,._.', 'A'] | Prediction V
# Sample [',..,___,_.,.,,,_', '.,_,,.,uw.._....', ',_,,,._.,_dr_,,_', 'A'] | Prediction V
#
#
# 10 DeadLock cases wrong predicted:
# Sample [',,.__,_._.._..,_', ',,__,.,,.,.._,__', ',.,,,,..,.,,dr..', 'D'] | Prediction V
# Sample ['_,._,,,_,._..,,,', '__.._.__,__.,w,.', '.,_.,__,..._dr_,', 'D'] | Prediction V
# Sample [',,_.__,_,____,__', '._.___.,.w_,,,__', '_,,.dr.____,_,__', 'D'] | Prediction V
# Sample ['.,____.._,_.,,..', ',,.__,.,,w,,_,,_', ',,,___,.dr,..,,,', 'D'] | Prediction V
# Sample ['.___._.._...,.,.', '..,_.__,,_.,._,.', 'dr_...,__..,._.,', 'D'] | Prediction V
# Sample ['.,,_.._,.,._,_,,', '..____,w...,,.,,', '_,,dr,,,..,,..__', 'D'] | Prediction V
# Sample ['._.._,.,_,,._,_.', '_,.,__...__,.,,,', '._,,,___dr..__._', 'D'] | Prediction V
# Sample [',..,_,,.._,,____', '..,,,..._.,,,_w_', '__,._dr..,.,,._.', 'D'] | Prediction V
# Sample [',_.___..._...,,_', '___..,_.,,_,_,.w', '..___,,.,_,_,dr,', 'D'] | Prediction V
# Sample ['...._,__,_,,,,,,', ',__.__,,.,..,_.,', ',dr,,,.,.,,.,...', 'D'] | Prediction V
#
#
# 10 Data race cases wrong predicted:
# Sample ['_,,.,..._,._.___', ',._wu.,.,,.__.,_', '__._,,_..r.,,,.,', 'R'] | Prediction V
# Sample [',,__.,_,_.._._,_', ',_,,._.w,___.,_,', ',,,_,,r_,...,,,_', 'R'] | Prediction V
# Sample ['.__,_,_._,.,..,,', ',...._...uw_,__,', '._,r,_,.._,,_.,_', 'R'] | Prediction V
# Sample ['___,___,,,_,_.,.', '_.____.._,,.,.__', '..._..r,._,.,_,.', 'R'] | Prediction V
# Sample ['__..,_._,._._..,', ',.,_.,uw._._,...', ',r__,__,.,,.,__,', 'R'] | Prediction V
# Sample ['._,.,.,...,_.._.', 'wu__.,,,,,_._.._', '___r_..__,.,,_,.', 'R'] | Prediction V
# Sample ['.,_,._,,_...._._', ',,.,,....,,___.,', '__,_,__.,.._r_..', 'R'] | Prediction V
# Sample ['_.,,_..,___,,_._', '.,.__w_.,_.._,,_', '...,_.._r,_,._,.', 'R'] | Prediction V
# Sample ['_,._,..,__,.._..', ',,,.,...__.,.._,', '.,...,.r,,._,,..', 'R'] | Prediction V
# Sample ['..,__,_,..,,_._,', '...,..w,,,_.._._', ',,_,.,_.r_.._,.,', 'R'] | Prediction V
#
#
# 10 Valid cases wrong predicted:
# Sample [',,,,,,,_,.__,,_.', '____..,,_,_..,.,', '.___.,__.__.....', 'V'] | Prediction D
# Sample ['..,.._.,__,_.,..', ',.,,,,wu.,_...._', ',,,,dr._.._.._..', 'V'] | Prediction R
# Sample [',__.._,._...__.,', '_.__wu._,,....,.', '_,..__,..dr...._', 'V'] | Prediction D
# Sample ['._._,.,,,.,.._..', ',.wu.,,.__.._,,.', '___,_..__..,,.dr', 'V'] | Prediction D
# Sample ['.,..,,____,_.._,', ',,.,_,wu____,__,', ',,dr,,.,_..___,.', 'V'] | Prediction D
# Sample ['_,,,._._.,....__', '_,._,wu._,_,,_.,', '.,..._dr.__...,_', 'V'] | Prediction D
# Sample [',,,,..,,,...__,.', '.,wu.__...,,,,,_', '___,__,._cr_,..,', 'V'] | Prediction R
# Sample ['.._._.,.,,..,,__', '...,,.,_.,wu,_._', ',,dr....,__...,,', 'V'] | Prediction D
# Sample ['___,.__,.,_._...', '_...,,_.,,_wu...', '___dr_,.._...._.', 'V'] | Prediction D
# Sample ['_.._,_..__,_._.,', '__.__.,,wu.__.,.', '__,,..,..,,...dr', 'V'] | Prediction D

# %%
print_wrong_preds(get_wrong_predictions(best_deepset_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 10 false Atomicity violation:
# Sample ['_.,.,_._,.._,._.', '.,,_._,.w.,.._,.', '__dr_.,_,_,_..,,', 'D'] | Prediction A
# Sample [',,_,__,.__....,.', '..__..,,_._,,,,_', '._,dr_,.,,_,__,.', 'D'] | Prediction A
# Sample ['._,,__._.,,_,...', '._._.,wu_...,_,_', ',,_dr,_.,..,_,,,', 'V'] | Prediction A
# Sample ['._,___.,,,,,__._', '__,._._...wu..,_', '__.,dr,_,_..,__.', 'V'] | Prediction A
# Sample ['_____._._,...._,', '_,,,,uw,__,._._.', ',__.cr,__,__.___', 'V'] | Prediction A
# Sample [',_..,.,.,...,,_.', ',,__.,,._,_,,wu_', '._,_dr__,_.,___,', 'V'] | Prediction A
# Sample ['...,._,_.,,.,.,,', '_._._,_.,.,,uw,.', '._,.cr___,.,....', 'V'] | Prediction A
# Sample ['_.___.__,,._.___', '.,.__,_...,.w...', ',_,._...,.dr_,._', 'D'] | Prediction A
# Sample ['....__,,,..,,,,,', '.,.,,,,.,.w_....', '_,,,_...,dr._..,', 'D'] | Prediction A
# Sample ['.._,_,,,.,__..__', '_,__._,_,,,__wu.', ',...cr__,,__,...', 'V'] | Prediction A
#
#
# 10 false DeadLock:
# Sample ['___..._,.__.,.,.', '_._...,_,_.,.,_,', '.__..__,,.._..r.', 'R'] | Prediction D
# Sample [',.._,_,._._.,.,.', '..._uw...,_,_,,.', '_dr,_,._,,...._,', 'A'] | Prediction D
# Sample [',,,,,,,_,.__,,_.', '____..,,_,_..,.,', '.___.,__.__.....', 'V'] | Prediction D
# Sample ['_._,._..___,.___', '.._,,w,,,,.._.__', '___r,,_.._...,._', 'R'] | Prediction D
# Sample ['_._...__,_.,,...', ',,,._.,.uw_,_.,,', '_,dr_,...,...,._', 'A'] | Prediction D
# Sample [',__.._,._...__.,', '_.__wu._,,....,.', '_,..__,..dr...._', 'V'] | Prediction D
# Sample ['.._,__..,,_,._,,', '_._....,______..', '_,,..._____,_.r.', 'R'] | Prediction D
# Sample ['._._,.,,,.,.._..', ',.wu.,,.__.._,,.', '___,_..__..,,.dr', 'V'] | Prediction D
# Sample ['.,,_.,.,,_,..._,', '.._.___..,,_.uw,', '.___.,._,..,_.dr', 'A'] | Prediction D
# Sample ['_._,.,_..,_._...', '__,.,_wu.,...__,', '._,r_,,,_,_...,,', 'R'] | Prediction D
#
#
# 10 false Data race :
# Sample ['..,.._.,__,_.,..', ',.,,,,wu.,_...._', ',,,,dr._.._.._..', 'V'] | Prediction R
# Sample ['.,__,__._.___,_.', '_,____,,,_.,,.__', ',_,_dr,,.,__,,.,', 'D'] | Prediction R
# Sample [',__.,,,.,,,,,_,_', '.__._,,uw,.,.,_.', ',dr..,__,,,_,_.,', 'A'] | Prediction R
# Sample [',,,,..,,,...__,.', '.,wu.__...,,,,,_', '___,__,._cr_,..,', 'V'] | Prediction R
# Sample [',_,._,.,,_,_..,,', '_,_,_,...uw,_,,,', '.,__cr___.,_._..', 'V'] | Prediction R
# Sample ['..,__.__,.,.,__,', '..__.w._,_._.._.', '_.,dr.__...,,..,', 'D'] | Prediction R
# Sample ['._,_.,.,..,__,_.', ',._.wu_.,,_.____', '_,_.,_,__cr,..._', 'V'] | Prediction R
# Sample ['..,,_..._..___._', ',,,,.._...,,.,,_', '_dr_,_.._,_.,_..', 'D'] | Prediction R
# Sample [',,__...._.__,._,', '_..__wu._,__,,._', '___._.,__,,.,.,.', 'V'] | Prediction R
# Sample [',_..,__,_.__._,.', ',,...,.___,.._._', '.,,,__,_,,dr__.,', 'D'] | Prediction R
#
#
# 10 false Valid:
# Sample ['_,,.,..._,._.___', ',._wu.,.,,.__.,_', '__._,,_..r.,,,.,', 'R'] | Prediction V
# Sample [',,__.,_,_.._._,_', ',_,,._.w,___.,_,', ',,,_,,r_,...,,,_', 'R'] | Prediction V
# Sample ['.__,_,_._,.,..,,', ',...._...uw_,__,', '._,r,_,.._,,_.,_', 'R'] | Prediction V
# Sample ['___,___,,,_,_.,.', '_.____.._,,.,.__', '..._..r,._,.,_,.', 'R'] | Prediction V
# Sample ['__..,_._,._._..,', ',.,_.,uw._._,...', ',r__,__,.,,.,__,', 'R'] | Prediction V
# Sample ['._,.,.,...,_.._.', 'wu__.,,,,,_._.._', '___r_..__,.,,_,.', 'R'] | Prediction V
# Sample ['.,_,._,,_...._._', ',,.,,....,,___.,', '__,_,__.,.._r_..', 'R'] | Prediction V
# Sample ['_.,,_..,___,,_._', '.,.__w_.,_.._,,_', '...,_.._r,_,._,.', 'R'] | Prediction V
# Sample ['_,._,..,__,.._..', ',,,.,...__.,.._,', '.,...,.r,,._,,..', 'R'] | Prediction V
# Sample ['..,__,_,..,,_._,', '...,..w,,,_.._._', ',,_,.,_.r_.._,.,', 'R'] | Prediction V

# %% [markdown]
# ## Top wrong predictions for best performing DeepSets V2 model

# %%
print_wrong_preds_bycases(get_wrong_predictions_bycases(best_deepsetv2_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 10 Atomicity violation cases wrong predicted:
# Sample ['__,..,.,_._,_...', ',___,_..__,,,.uw', '____._.._._,,,dr', 'A'] | Prediction R
# Sample [',.._,_,._._.,.,.', '..._uw...,_,_,,.', '_dr,_,._,,...._,', 'A'] | Prediction R
# Sample [',.._,.___.,.__,.', '.,.,,_..,_.uw..,', ',._..,.,__dr._,,', 'A'] | Prediction R
# Sample ['_.._,_,,_._,_.,.', '.uw._,._.._..._,', ',.__.,,_dr_.,...', 'A'] | Prediction R
# Sample [',_.,.__._,,__,_,', '.,_.__,..,_,_uw.', ',_....__..._dr_.', 'A'] | Prediction R
# Sample ['__,__,._.___,,,.', '__._,uw_____._._', ',,___.___.dr,._.', 'A'] | Prediction R
# Sample [',,,_,,..,,,,._,.', ',,_,_._,.._.,_uw', '.,dr,..,.,.__,__', 'A'] | Prediction R
# Sample ['.,,____,._.,_,_,', '_,_uw_,,,_,_.,,,', '_dr,,_.,..._..,,', 'A'] | Prediction R
# Sample [',...__...,..,__,', ',__uw_._.,,_._..', '__.,,,_,...,..dr', 'A'] | Prediction R
# Sample [',.,_,,_,_,._.,__', ',_uw.,.._......_', '_dr_,,.,_,_,,._.', 'A'] | Prediction R
#
#
# 10 DeadLock cases wrong predicted:
# Sample ['._._.._.__,..,,,', '_,_,_.,.__.w___.', '_,_,dr,__._.....', 'D'] | Prediction R
# Sample [',,.__,_._.._..,_', ',,__,.,,.,.._,__', ',.,,,,..,.,,dr..', 'D'] | Prediction R
# Sample ['_,._,,,_,._..,,,', '__.._.__,__.,w,.', '.,_.,__,..._dr_,', 'D'] | Prediction R
# Sample [',,_.__,_,____,__', '._.___.,.w_,,,__', '_,,.dr.____,_,__', 'D'] | Prediction R
# Sample ['._,_,,_,.,,._._.', ',...._,_.,___,..', '.dr_.__.,..,,.__', 'D'] | Prediction R
# Sample ['.,____.._,_.,,..', ',,.__,.,,w,,_,,_', ',,,___,.dr,..,,,', 'D'] | Prediction R
# Sample ['.___._.._...,.,.', '..,_.__,,_.,._,.', 'dr_...,__..,._.,', 'D'] | Prediction R
# Sample ['.,,_.._,.,._,_,,', '..____,w...,,.,,', '_,,dr,,,..,,..__', 'D'] | Prediction R
# Sample ['_,_,,,_...__,,,.', ',..,.,___.._,,.,', ',___._,,._dr,,..', 'D'] | Prediction R
# Sample ['._.._,.,_,,._,_.', '_,.,__...__,.,,,', '._,,,___dr..__._', 'D'] | Prediction R
#
#
# 0 Data race cases wrong predicted:
#
#
# 10 Valid cases wrong predicted:
# Sample ['_,_.,_,__,,.._,.', ',.,,.,,,wu_.,...', '.,_._,__._,__.._', 'V'] | Prediction R
# Sample ['..,,,,.__._.,.._', 'wu,..,..,..__,,.', 'cr.,._.....,._._', 'V'] | Prediction R
# Sample [',..,_,,..,_,__..', '..__,,,.,._.,._,', '_.,._,..cr_..._.', 'V'] | Prediction R
# Sample [',,_,.,_,._.___,_', 'w,,,.._..._,_,,_', '._.,._.,._.__.__', 'V'] | Prediction R
# Sample ['._..,_.__.,,.,..', '._._,.._,,_,.wu,', 'cr,_,,.___.,__..', 'V'] | Prediction R
# Sample ['_,.._..,,.,_,_,.', '.,_.,_,wu__,.___', 'dr_,.__,_,._,,_.', 'V'] | Prediction R
# Sample ['_,..,_,_,.,,,.,.', '_,__.._.,,.wu,._', ',...,.._.,_...,_', 'V'] | Prediction R
# Sample ['._,._.___,,,._..', ',,____,,._,___,.', ',.._,,.,.,_,.,_.', 'V'] | Prediction R
# Sample ['_..._,,,.,,,,,.,', '_.._.,_w,,___,_,', '_,_,,_.,..._.,,.', 'V'] | Prediction R
# Sample ['._,.,_.,.,,.__._', '__,._,_,uw__,,.,', '_,_,._cr_,,..,..', 'V'] | Prediction R

# %%
print_wrong_preds(get_wrong_predictions(best_deepsetv2_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 0 false Atomicity violation:
#
#
# 0 false DeadLock:
#
#
# 10 false Data race :
# Sample ['_,_.,_,__,,.._,.', ',.,,.,,,wu_.,...', '.,_._,__._,__.._', 'V'] | Prediction R
# Sample ['..,,,,.__._.,.._', 'wu,..,..,..__,,.', 'cr.,._.....,._._', 'V'] | Prediction R
# Sample [',..,_,,..,_,__..', '..__,,,.,._.,._,', '_.,._,..cr_..._.', 'V'] | Prediction R
# Sample [',,_,.,_,._.___,_', 'w,,,.._..._,_,,_', '._.,._.,._.__.__', 'V'] | Prediction R
# Sample ['._..,_.__.,,.,..', '._._,.._,,_,.wu,', 'cr,_,,.___.,__..', 'V'] | Prediction R
# Sample ['_,.._..,,.,_,_,.', '.,_.,_,wu__,.___', 'dr_,.__,_,._,,_.', 'V'] | Prediction R
# Sample ['_,..,_,_,.,,,.,.', '_,__.._.,,.wu,._', ',...,.._.,_...,_', 'V'] | Prediction R
# Sample ['._,._.___,,,._..', ',,____,,._,___,.', ',.._,,.,.,_,.,_.', 'V'] | Prediction R
# Sample ['_..._,,,.,,,,,.,', '_.._.,_w,,___,_,', '_,_,,_.,..._.,,.', 'V'] | Prediction R
# Sample ['._._.._.__,..,,,', '_,_,_.,.__.w___.', '_,_,dr,__._.....', 'D'] | Prediction R
#
#
# 0 false Valid:

# %% [markdown]
# ## Top wrong predictions for best performing Feedforward model

# %%
print_wrong_preds_bycases(get_wrong_predictions_bycases(best_feedforward_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 10 Atomicity violation cases wrong predicted:
# Sample [',.._,_,._._.,.,.', '..._uw...,_,_,,.', '_dr,_,._,,...._,', 'A'] | Prediction D
# Sample [',.._,.___.,.__,.', '.,.,,_..,_.uw..,', ',._..,.,__dr._,,', 'A'] | Prediction V
# Sample ['_.._,_,,_._,_.,.', '.uw._,._.._..._,', ',.__.,,_dr_.,...', 'A'] | Prediction V
# Sample [',_.,.__._,,__,_,', '.,_.__,..,_,_uw.', ',_....__..._dr_.', 'A'] | Prediction V
# Sample ['__,__,._.___,,,.', '__._,uw_____._._', ',,___.___.dr,._.', 'A'] | Prediction D
# Sample [',,,_,,..,,,,._,.', ',,_,_._,.._.,_uw', '.,dr,..,.,.__,__', 'A'] | Prediction V
# Sample ['.,,____,._.,_,_,', '_,_uw_,,,_,_.,,,', '_dr,,_.,..._..,,', 'A'] | Prediction V
# Sample [',...__...,..,__,', ',__uw_._.,,_._..', '__.,,,_,...,..dr', 'A'] | Prediction V
# Sample [',.,_,,_,_,._.,__', ',_uw.,.._......_', '_dr_,,.,_,_,,._.', 'A'] | Prediction V
# Sample [',..,___,_.,.,,,_', '.,_,,.,uw.._....', ',_,,,._.,_dr_,,_', 'A'] | Prediction V
#
#
# 10 DeadLock cases wrong predicted:
# Sample ['._._.._.__,..,,,', '_,_,_.,.__.w___.', '_,_,dr,__._.....', 'D'] | Prediction A
# Sample [',,.__,_._.._..,_', ',,__,.,,.,.._,__', ',.,,,,..,.,,dr..', 'D'] | Prediction V
# Sample ['_,._,,,_,._..,,,', '__.._.__,__.,w,.', '.,_.,__,..._dr_,', 'D'] | Prediction V
# Sample [',,_.__,_,____,__', '._.___.,.w_,,,__', '_,,.dr.____,_,__', 'D'] | Prediction V
# Sample ['.,____.._,_.,,..', ',,.__,.,,w,,_,,_', ',,,___,.dr,..,,,', 'D'] | Prediction V
# Sample ['.___._.._...,.,.', '..,_.__,,_.,._,.', 'dr_...,__..,._.,', 'D'] | Prediction V
# Sample ['.,,_.._,.,._,_,,', '..____,w...,,.,,', '_,,dr,,,..,,..__', 'D'] | Prediction V
# Sample ['_,_,,,_...__,,,.', ',..,.,___.._,,.,', ',___._,,._dr,,..', 'D'] | Prediction V
# Sample ['._.._,.,_,,._,_.', '_,.,__...__,.,,,', '._,,,___dr..__._', 'D'] | Prediction V
# Sample [',_.___..._...,,_', '___..,_.,,_,_,.w', '..___,,.,_,_,dr,', 'D'] | Prediction V
#
#
# 10 Data race cases wrong predicted:
# Sample ['_,,.,..._,._.___', ',._wu.,.,,.__.,_', '__._,,_..r.,,,.,', 'R'] | Prediction V
# Sample [',,__.,_,_.._._,_', ',_,,._.w,___.,_,', ',,,_,,r_,...,,,_', 'R'] | Prediction V
# Sample ['.__,_,_._,.,..,,', ',...._...uw_,__,', '._,r,_,.._,,_.,_', 'R'] | Prediction V
# Sample ['___,___,,,_,_.,.', '_.____.._,,.,.__', '..._..r,._,.,_,.', 'R'] | Prediction V
# Sample ['__..,_._,._._..,', ',.,_.,uw._._,...', ',r__,__,.,,.,__,', 'R'] | Prediction V
# Sample ['._,.,.,...,_.._.', 'wu__.,,,,,_._.._', '___r_..__,.,,_,.', 'R'] | Prediction V
# Sample ['...,_.._..__,,_.', '_._,,_..,,,_..,_', '.r,_.____,._,...', 'R'] | Prediction D
# Sample ['.,_,._,,_...._._', ',,.,,....,,___.,', '__,_,__.,.._r_..', 'R'] | Prediction V
# Sample ['_.,,_..,___,,_._', '.,.__w_.,_.._,,_', '...,_.._r,_,._,.', 'R'] | Prediction V
# Sample ['_,._,..,__,.._..', ',,,.,...__.,.._,', '.,...,.r,,._,,..', 'R'] | Prediction V
#
#
# 10 Valid cases wrong predicted:
# Sample [',_.._.._,_._,...', ',,,_._._,,,_._,_', '.,,,,,__,,.._cr_', 'V'] | Prediction D
# Sample [',_,.,.,._.___._,', '._,__,______,_.,', '..cr,.__._.,__,,', 'V'] | Prediction D
# Sample ['_.._,,,_,_,._._.', '__..._,,_,,wu_,_', ',,.___,.__._.dr,', 'V'] | Prediction D
# Sample [',__.._,._...__.,', '_.__wu._,,....,.', '_,..__,..dr...._', 'V'] | Prediction A
# Sample ['._._,.,,,.,.._..', ',.wu.,,.__.._,,.', '___,_..__..,,.dr', 'V'] | Prediction D
# Sample ['_,,,._._.,....__', '_,._,wu._,_,,_.,', '.,..._dr.__...,_', 'V'] | Prediction A
# Sample ['.._._.,.,,..,,__', '...,,.,_.,wu,_._', ',,dr....,__...,,', 'V'] | Prediction D
# Sample ['_,_.,,,_,__,._.,', '.,,.,,,,,__,wu_,', '_.___,dr,,...,._', 'V'] | Prediction D
# Sample [',_,,,..,,...__,_', '..,,wu._.,_..,,.', ',dr,,____._,_.,,', 'V'] | Prediction D
# Sample [',,,._..,,_.__..,', ',,.,wu,.,,,._,,.', '_.,.dr,,,._...,.', 'V'] | Prediction A

# %%
print_wrong_preds(get_wrong_predictions(best_feedforward_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 10 false Atomicity violation:
# Sample ['._._.._.__,..,,,', '_,_,_.,.__.w___.', '_,_,dr,__._.....', 'D'] | Prediction A
# Sample ['._,.,._,,...,,__', '._..__,,_,,.,.,_', '_..._.dr,_,__.,_', 'D'] | Prediction A
# Sample ['..,,,,,__._.....', '.__,._.__,..._._', '_,.,._dr_._.__,_', 'D'] | Prediction A
# Sample [',__.._,._...__.,', '_.__wu._,,....,.', '_,..__,..dr...._', 'V'] | Prediction A
# Sample [',_.,,,._,.,_,.,_', '.,_._,.uw_,,____', '_..___._,.r,_.,,', 'R'] | Prediction A
# Sample ['_,,,._._.,....__', '_,._,wu._,_,,_.,', '.,..._dr.__...,_', 'V'] | Prediction A
# Sample [',,,._..,,_.__..,', ',,.,wu,.,,,._,,.', '_.,.dr,,,._...,.', 'V'] | Prediction A
# Sample ['._._.._,.,....__', ',._w,..,_,.,._,.', '_,,___._,..dr.,,', 'D'] | Prediction A
# Sample [',_,,..._,_,__,..', ',.,_wu_,._,.,.__', '_,___,dr,_,,_.,_', 'V'] | Prediction A
# Sample ['_,,,,,.,,_.,,...', '_,.__.._.._,,_.,', ',,_.__,.,__.,,dr', 'D'] | Prediction A
#
#
# 10 false DeadLock:
# Sample ['...,_.._..__,,_.', '_._,,_..,,,_..,_', '.r,_.____,._,...', 'R'] | Prediction D
# Sample [',_.._.._,_._,...', ',,,_._._,,,_._,_', '.,,,,,__,,.._cr_', 'V'] | Prediction D
# Sample [',_,.,.,._.___._,', '._,__,______,_.,', '..cr,.__._.,__,,', 'V'] | Prediction D
# Sample ['___..._,.__.,.,.', '_._...,_,_.,.,_,', '.__..__,,.._..r.', 'R'] | Prediction D
# Sample [',.._,_,._._.,.,.', '..._uw...,_,_,,.', '_dr,_,._,,...._,', 'A'] | Prediction D
# Sample ['__,__,._.___,,,.', '__._,uw_____._._', ',,___.___.dr,._.', 'A'] | Prediction D
# Sample ['_,_,..._,_,_.,,.', '.,,.____,,..,.wu', '._._,._._,_r__._', 'R'] | Prediction D
# Sample ['__....,,_,_._.,_', '..._,_..._..w.,_', '.,,,_.r.__...,._', 'R'] | Prediction D
# Sample ['_,...,_._____,.,', '._uw_.__._.,,_..', '__,_._,__.dr__.,', 'A'] | Prediction D
# Sample ['__..____,_,.,,__', '.__,,,._,.,._,.,', '._,,..,r,_..,,_.', 'R'] | Prediction D
#
#
# 0 false Data race :
#
#
# 10 false Valid:
# Sample ['_,,.,..._,._.___', ',._wu.,.,,.__.,_', '__._,,_..r.,,,.,', 'R'] | Prediction V
# Sample [',,__.,_,_.._._,_', ',_,,._.w,___.,_,', ',,,_,,r_,...,,,_', 'R'] | Prediction V
# Sample ['.__,_,_._,.,..,,', ',...._...uw_,__,', '._,r,_,.._,,_.,_', 'R'] | Prediction V
# Sample ['___,___,,,_,_.,.', '_.____.._,,.,.__', '..._..r,._,.,_,.', 'R'] | Prediction V
# Sample ['__..,_._,._._..,', ',.,_.,uw._._,...', ',r__,__,.,,.,__,', 'R'] | Prediction V
# Sample ['._,.,.,...,_.._.', 'wu__.,,,,,_._.._', '___r_..__,.,,_,.', 'R'] | Prediction V
# Sample ['.,_,._,,_...._._', ',,.,,....,,___.,', '__,_,__.,.._r_..', 'R'] | Prediction V
# Sample ['_.,,_..,___,,_._', '.,.__w_.,_.._,,_', '...,_.._r,_,._,.', 'R'] | Prediction V
# Sample ['_,._,..,__,.._..', ',,,.,...__.,.._,', '.,...,.r,,._,,..', 'R'] | Prediction V
# Sample [',_.__..____,,...', '__..,,_..uw.,,,,', 'r_.._._._.__.,..', 'R'] | Prediction V

# %% [markdown]
# # Saving Notebook State

# %%
import dill
# dill.dump_session('notebook_env_5per.db')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[254], line 1
# ----> 1 import dill
#       2 # dill.dump_session('notebook_env_5per.db')
#
# ModuleNotFoundError: No module named 'dill'

# %% [markdown]
# # Loading Notebook State

# %%
import dill
dill.load_session('notebook_env_5per.db')
