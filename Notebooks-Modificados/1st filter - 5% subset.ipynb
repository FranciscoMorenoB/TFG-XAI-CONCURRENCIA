# %%
from generate_data import Data
from evaluate import *
from models import *

import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
# %autosave 120
# Out:
# Autosaving every 120 seconds

# %% [markdown]
# # Get the synthetic dataset

# %%
# %%time
data = Data(layer_size=16)
# Out:
# Wall time: 625 ms
# c:\Users\juand\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but OneHotEncoder was fitted without feature names
#   warnings.warn(

# %%
# %%time
train, val, test = data.get_splits(['random_subsample'], [[0.05, 0.95]])

train_unshuffled = train.copy()
np.random.shuffle(train)

x_train, y_train = data.get_x_y(train)
x_val, y_val = data.get_x_y(val)
x_test, y_test = data.get_x_y(test)

train_original = data.reverse_encoding(data.get_x_y(train_unshuffled)[0])
val_original = data.reverse_encoding(x_val)
test_original = data.reverse_encoding(x_test)
# Out:
# Number of samples: 198 train | 754 val | 3017 test
# Wall time: 262 ms

# %% [markdown]
# #### Peek at unshuffled train data

# %%
train_original[:20]
# Out:
# [[',,..,__._,.,._.,', '______.,_.uw._.,', '___..,__.__dr_._', 'A'],
#  [',___,,._,,.__.,.', '__._,__w__._,,,,', '_,.,,,.,_.dr_...', 'D'],
#  [',...__..,.,,,_..', '.,___.__.wu___.,', '._cr._..__,,,.,.', 'V'],
#  ['.,,._.._.,_,,,..', '_..__,,,.,.__.,,', ',_,._._,_,.r,,__', 'R'],
#  ['.__.,,.,,_.,___,', '_._,,,._..._,_,,', '._.,_dr.,,.._,__', 'D'],
#  [',,__,,_.___...,_', '_,__,_,_,,_._..,', '_,.,,cr.._,.._,.', 'V'],
#  ['.._...,.,._,,.,,', ',._,,.,,,.w_._.,', ',,.,,__.,.__,__,', 'V'],
#  ['._.,..._.._...._', '_,_...__.,,.wu,_', '_.._.,.._._,_,._', 'V'],
#  ['.._._,,_._,....,', '_....__,.,uw,_._', ',.,_,,.._,__r,,,', 'R'],
#  ['.,_..,,._,__.,,.', ',___,_.._,_,w.,_', ',,._,,..__,cr__.', 'V'],
#  [',..._.____.__,_,', '.,,,_wu_...,_,_,', '_..__,.__,.r....', 'R'],
#  [',,.,_,__.,.__.,_', '...,__.,.__._..,', '_,_....,,.cr,__,', 'V'],
#  ['._._..,,_,...._.', '_._._,wu_.,___..', '__,.._,_.,.,....', 'V'],
#  [',__,,_._.,.,.,,.', 'w._.,,_.._,_..._', '_...__.__..._._.', 'V'],
#  ['.,._.,._.,,__,..', '__._wu.,..,,__.,', '__,__._cr,.._,_.', 'V'],
#  ['__,,.,,,__.._,..', ',_.,.._,._.,uw._', '_.,__,,.,..,..__', 'V'],
#  [',_,,_.,__,,.__..', '_.,,.,_,uw,__...', '._...,_,.____..,', 'V'],
#  [',._...,,._,._,_.', ',.__,w_,_,__.,,,', ',,,.___,,_,__,__', 'V'],
#  ['._,,.._..,_.,..,', '_.,..,.__.,...wu', '.dr,_...__.,,_,,', 'V'],
#  ['...__.,..__._.._', '.....,_.,_,w_._,', ',..._.,_,,.cr,_,', 'V']]

# %%
pos_train_ratio = get_stats_and_ratio(train_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 16 | F2-uw 14 | F2-w 14 | F2-noop 12 |
# F3 cr:    F2-wu 12 | F2-uw 12 | F2-w 11 | F2-noop 12 |
# F3 r:    F2-wu 11 | F2-uw 10 | F2-w 13 | F2-noop 14 |
# F3 noop:    F2-wu 11 | F2-uw 13 | F2-w 13 | F2-noop 10 |
#
# Positive samples count: 88
# Total samples count: 198
# Positive class ratio: 0.4444444444444444

# %% [markdown]
# #### Peek at test data

# %%
test_original[:15]
# Out:
# [['_,,.,..._,._.___', ',._wu.,.,,.__.,_', '__._,,_..r.,,,.,', 'R'],
#  ['_,_.,_,__,,.._,.', ',.,,.,,,wu_.,...', '.,_._,__._,__.._', 'V'],
#  ['..,,,,.__._.,.._', 'wu,..,..,..__,,.', 'cr.,._.....,._._', 'V'],
#  [',,__.,_,_.._._,_', ',_,,._.w,___.,_,', ',,,_,,r_,...,,,_', 'R'],
#  ['.__,_,_._,.,..,,', ',...._...uw_,__,', '._,r,_,.._,,_.,_', 'R'],
#  [',..,_,,..,_,__..', '..__,,,.,._.,._,', '_.,._,..cr_..._.', 'V'],
#  [',,_,.,_,._.___,_', 'w,,,.._..._,_,,_', '._.,._.,._.__.__', 'V'],
#  ['._..,_.__.,,.,..', '._._,.._,,_,.wu,', 'cr,_,,.___.,__..', 'V'],
#  ['_,.._..,,.,_,_,.', '.,_.,_,wu__,.___', 'dr_,.__,_,._,,_.', 'V'],
#  ['___,___,,,_,_.,.', '_.____.._,,.,.__', '..._..r,._,.,_,.', 'R'],
#  ['_,..,_,_,.,,,.,.', '_,__.._.,,.wu,._', ',...,.._.,_...,_', 'V'],
#  ['._,._.___,,,._..', ',,____,,._,___,.', ',.._,,.,.,_,.,_.', 'V'],
#  ['_..._,,,.,,,,,.,', '_.._.,_w,,___,_,', '_,_,,_.,..._.,,.', 'V'],
#  ['__..,_._,._._..,', ',.,_.,uw._._,...', ',r__,__,.,,.,__,', 'R'],
#  ['._._.._.__,..,,,', '_,_,_.,.__.w___.', '_,_,dr,__._.....', 'D']]

# %%
pos_test_ratio = get_stats_and_ratio(test_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 176 | F2-uw 170 | F2-w 184 | F2-noop 190 |
# F3 cr:    F2-wu 171 | F2-uw 176 | F2-w 173 | F2-noop 194 |
# F3 r:    F2-wu 171 | F2-uw 187 | F2-w 199 | F2-noop 205 |
# F3 noop:    F2-wu 200 | F2-uw 183 | F2-w 211 | F2-noop 227 |
#
# Positive samples count: 1306
# Total samples count: 3017
# Positive class ratio: 0.43288034471329134

# %% [markdown]
# #### Peek at val data

# %%
val_original[:15]
# Out:
# [['__..__._,__,,___', '.,__.__,.,uw_,.,', '..__,,__.,_...,_', 'V'],
#  ['.,__,_.,__,_,._.', ',,,,,...._,w,,_,', '..,_.,,._r_.__,.', 'R'],
#  ['_,__._._,_,,....', '.,wu_,_,_,.___,.', '_.,.,,_.r,,,.,,_', 'R'],
#  ['._...,,._.._,.,,', ',.,_._._..uw.,.,', ',,,_.,,,__,,,_,,', 'V'],
#  ['__,_,..,..._,,_.', '.,_,_._.._uw_,..', ',_r,,._,..,.__.,', 'R'],
#  [',,_,_.._,.__._,.', '_w.._..._,_...,,', ',,..,_,.__.,.r..', 'R'],
#  [',____.,_,_......', '.__..wu._,..._.,', '_.._,,.__,_..dr,', 'V'],
#  ['.,.._,_,.._,._..', '_wu,...,.,,.__,.', ',,_,..,....,cr__', 'V'],
#  ['.,_,_..,,_..,...', ',._,....__,_.__,', '_,._,,_,r.,,_.,.', 'R'],
#  ['.__,.._,,.____..', '._,wu,____..__..', ',,_.,_,..,.cr_.,', 'V'],
#  [',_.__,_,,.,__.,_', ',.___,,,.,_.,,..', '___,_._.__.,._.,', 'V'],
#  ['._.,,._,_,.,_,..', '..._.,._.,._,,_,', '._.,.,,____.,_._', 'V'],
#  [',_,_.,.._._.._.,', '___..,,,,,uw,_,_', '_._,,,__.,___,,.', 'V'],
#  ['_...,..,_,._,._.', ',,,_._.._.,,._wu', '..__.,,_..,_,_..', 'V'],
#  ['..,,___..,,..__.', ',_,._..._._..,w,', '_,.,,...__,._,_,', 'V']]

# %%
pos_val_ratio = get_stats_and_ratio(val_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 33 | F2-uw 41 | F2-w 42 | F2-noop 53 |
# F3 cr:    F2-wu 42 | F2-uw 37 | F2-w 56 | F2-noop 49 |
# F3 r:    F2-wu 58 | F2-uw 43 | F2-w 44 | F2-noop 53 |
# F3 noop:    F2-wu 44 | F2-uw 59 | F2-w 48 | F2-noop 52 |
#
# Positive samples count: 334
# Total samples count: 754
# Positive class ratio: 0.44297082228116713

# %% [markdown]
# #### Send label arrays to device

# %%
from sklearn.preprocessing import LabelEncoder

# Codificar etiquetas categóricas a índices numéricos
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_val = label_encoder.transform(y_val)
y_test = label_encoder.transform(y_test)

# Convertir a tensores de PyTorch
y_train = torch.tensor(y_train, dtype=torch.long).to(device)
y_val = torch.tensor(y_val, dtype=torch.long).to(device)
y_test = torch.tensor(y_test, dtype=torch.long).to(device)

# Verificar clases codificadas
print("Clases codificadas:", label_encoder.classes_)
# Out:
# Clases codificadas: ['A' 'D' 'R' 'V']

# %% [markdown]
# #### Get data in normal format (same as CNN format)

# %%
x_train_normal = data.to_conv_format(x_train)
x_val_normal = data.to_conv_format(x_val)
x_test_normal = data.to_conv_format(x_test)
for i in range(len(x_train_normal)):
    x_train_normal[i] = x_train_normal[i].to(device)
    x_val_normal[i] = x_val_normal[i].to(device)
    x_test_normal[i] = x_test_normal[i].to(device)

# %%
x_train_normal[0].shape
# Out:
# torch.Size([198, 128])

# %% [markdown]
# #### Get data in convolutional format, send to device

# %%
x_train_cnn = data.to_conv_format(x_train)
x_val_cnn = data.to_conv_format(x_val)
x_test_cnn = data.to_conv_format(x_test)
for i in range(len(x_train_cnn)):
    x_train_cnn[i] = x_train_cnn[i].to(device)
    x_val_cnn[i] = x_val_cnn[i].to(device)
    x_test_cnn[i] = x_test_cnn[i].to(device)

# %%
x_train_cnn[0].shape
# Out:
# torch.Size([198, 128])

# %% [markdown]
# #### Get data in LSTM format, send to device

# %%
x_train_lstm = data.to_lstm_format(x_train)
x_val_lstm = data.to_lstm_format(x_val)
x_test_lstm = data.to_lstm_format(x_test)
for i in range(len(x_train_lstm)):
    x_train_lstm[i] = x_train_lstm[i].to(device)
    x_val_lstm[i] = x_val_lstm[i].to(device)
    x_test_lstm[i] = x_test_lstm[i].to(device)

# %%
x_train_lstm[0].shape
# Out:
# torch.Size([198, 16, 8])

# %% [markdown]
# ### Define training parameters

# %%
num_experiments = 20
epochs = 200
early_stopping_limit = 100

experiment_name = "05per"

# %% [markdown]
# ### Define training procedure for each model

# %%
def train_models(constructor, x_train, x_val, x_test, weight_decay, *argv):
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    wrong_preds = []
    best_accuracy = 0
    
    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []

    for i in range(num_experiments):
        model = constructor(*argv)
        model.to(device)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), weight_decay=weight_decay)

        train_losses.append([])
        val_losses.append([])
        train_accs.append([])
        val_accs.append([])
        
        best_acc = 0

        early_stopping_cnt = 0

        for epoch in range(1, epochs + 1):
            train_loss, train_acc = train_epoch(model, x_train, y_train, criterion, optimizer, epoch, 10, verbose=False)
            val_loss, val_acc = eval_epoch(model, x_val, y_val, criterion, 'Validation', verbose=False)

            
            train_losses[-1].append(train_loss)
            val_losses[-1].append(val_loss)
            train_accs[-1].append(train_acc)
            val_accs[-1].append(val_acc)
            
            model_name = constructor.__name__[:constructor.__name__.find('_')]
            if val_acc > best_acc:
                best_acc = val_acc
                torch.save(model.state_dict(), f'./temp/{model_name}_model_TEMP_' + experiment_name)    
                early_stopping_cnt = 0
            else:
                early_stopping_cnt += 1

            if early_stopping_cnt >= early_stopping_limit:
                break


        model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
        
        accuracies.append(get_accuracy_by_cases(model, x_test, y_test, test_original))
        precisions.append(get_precision(model, x_test, y_test, test_original))
        recalls.append(get_recall(model, x_test, y_test, test_original))
        f1_scores.append(get_f1(precisions[-1], recalls[-1]))
        
        wrong_preds.append((f"Experimento {i}", get_wrong_predictions(model, x_test, y_test, test_original)))

        if accuracies[-1]['Overall'] > best_accuracy:
            torch.save(model.state_dict(), f'./bestmodels/best_{model_name}_model_' + experiment_name)    
            best_accuracy = accuracies[-1]['Overall']

        print(i + 1, "/", num_experiments, "models trained | Current model test accuracy:", accuracies[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test precision:", precisions[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test recall:", recalls[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test f1:", f1_scores[-1]['Overall'])


    
    return accuracies, precisions, recalls, f1_scores, wrong_preds, [train_losses, val_losses, train_accs, val_accs], model
    #return accuracies, precisions, wrong_preds, [train_losses, val_losses, train_accs, val_accs]

# %% [markdown]
# # Train models

# %%
# %%time
cnn_accuracies, cnn_precisions, cnn_recalls, cnn_f1_scores, cnn_wrong_preds, cnn_epoch_stats, model = train_models(
    CNN_Model, x_train_cnn, x_val_cnn, x_test_cnn, 0.0001, data, 64, 128, 4, -1, 'keras')
    
#cnn_accuracies, cnn_precisions, cnn_wrong_preds, cnn_epoch_stats = train_models(CNN_Model, x_train_cnn, x_val_cnn, x_test_cnn, 0.0001, data, 64, 128, 4, -1, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_16360\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.9990056347364932
# 1 / 20 models trained | Current model test precision: 0.9995624270711785
# 1 / 20 models trained | Current model test recall: 0.9990157480314961
# 1 / 20 models trained | Current model test f1: 0.999289012783691
# 2 / 20 models trained | Current model test accuracy: 0.9946967185946304
# 2 / 20 models trained | Current model test precision: 0.9976838448176027
# 2 / 20 models trained | Current model test recall: 0.9913231434306006
# 2 / 20 models trained | Current model test f1: 0.994493323591174
# 3 / 20 models trained | Current model test accuracy: 1.0
# 3 / 20 models trained | Current model test precision: 1.0
# 3 / 20 models trained | Current model test recall: 1.0
# 3 / 20 models trained | Current model test f1: 1.0
# 4 / 20 models trained | Current model test accuracy: 0.9923765329797812
# 4 / 20 models trained | Current model test precision: 0.996683967704729
# 4 / 20 models trained | Current model test recall: 0.9802146055272503
# 4 / 20 models trained | Current model test f1: 0.9883806842369385
# 5 / 20 models trained | Current model test accuracy: 0.9963539940338084
# 5 / 20 models trained | Current model test precision: 0.9943164265453421
# 5 / 20 models trained | Current model test recall: 0.9889394582114819
# 5 / 20 models trained | Current model test f1: 0.9916206534076126
# 6 / 20 models trained | Current model test accuracy: 0.9907192575406032
# 6 / 20 models trained | Current model test precision: 0.9945238688587071
# 6 / 20 models trained | Current model test recall: 0.9758028408213679
# 6 / 20 models trained | Current model test f1: 0.9850744160642869
# 7 / 20 models trained | Current model test accuracy: 0.9963539940338084
# 7 / 20 models trained | Current model test precision: 0.9984030197444832
# 7 / 20 models trained | Current model test recall: 0.9895360506407288
# 7 / 20 models trained | Current model test f1: 0.9939497601546639
# 8 / 20 models trained | Current model test accuracy: 0.9897248922770965
# 8 / 20 models trained | Current model test precision: 0.9869533209728433
# 8 / 20 models trained | Current model test recall: 0.9714986477800737
# 8 / 20 models trained | Current model test f1: 0.9791650058772902
# 9 / 20 models trained | Current model test accuracy: 0.9900563473649321
# 9 / 20 models trained | Current model test precision: 0.9877578709538245
# 9 / 20 models trained | Current model test recall: 0.9796168734826797
# 9 / 20 models trained | Current model test f1: 0.9836705284928733
# 10 / 20 models trained | Current model test accuracy: 0.9698375870069605
# 10 / 20 models trained | Current model test precision: 0.9756757128418984
# 10 / 20 models trained | Current model test recall: 0.9578763665610929
# 10 / 20 models trained | Current model test f1: 0.9666941136102879
# 11 / 20 models trained | Current model test accuracy: 0.9990056347364932
# 11 / 20 models trained | Current model test precision: 0.9969298245614036
# 11 / 20 models trained | Current model test recall: 0.998237184996734
# 11 / 20 models trained | Current model test f1: 0.9975830764461774
# 12 / 20 models trained | Current model test accuracy: 1.0
# 12 / 20 models trained | Current model test precision: 1.0
# 12 / 20 models trained | Current model test recall: 1.0
# 12 / 20 models trained | Current model test f1: 1.0
# 13 / 20 models trained | Current model test accuracy: 1.0
# 13 / 20 models trained | Current model test precision: 1.0
# 13 / 20 models trained | Current model test recall: 1.0
# 13 / 20 models trained | Current model test f1: 1.0
# 14 / 20 models trained | Current model test accuracy: 0.9970169042094796
# 14 / 20 models trained | Current model test precision: 0.9986918604651163
# 14 / 20 models trained | Current model test recall: 0.9970472440944882
# 14 / 20 models trained | Current model test f1: 0.997868874645386
# 15 / 20 models trained | Current model test accuracy: 0.9618826648989062
# 15 / 20 models trained | Current model test precision: 0.923641415998097
# 15 / 20 models trained | Current model test recall: 0.886405409529399
# 15 / 20 models trained | Current model test f1: 0.9046404060486226
# 16 / 20 models trained | Current model test accuracy: 0.9960225389459728
# 16 / 20 models trained | Current model test precision: 0.9982588508415554
# 16 / 20 models trained | Current model test recall: 0.9960629921259843
# 16 / 20 models trained | Current model test f1: 0.9971597126027871
# 17 / 20 models trained | Current model test accuracy: 0.9960225389459728
# 17 / 20 models trained | Current model test precision: 0.9969315035717948
# 17 / 20 models trained | Current model test recall: 0.9951024584857068
# 17 / 20 models trained | Current model test f1: 0.996016141332744
# 18 / 20 models trained | Current model test accuracy: 0.9993370898243288
# 18 / 20 models trained | Current model test precision: 0.9997081144191478
# 18 / 20 models trained | Current model test recall: 0.9985294117647059
# 18 / 20 models trained | Current model test f1: 0.9991184154505856
# 19 / 20 models trained | Current model test accuracy: 0.9990056347364932
# 19 / 20 models trained | Current model test precision: 0.9982286539844052
# 19 / 20 models trained | Current model test recall: 0.9969127101454258
# 19 / 20 models trained | Current model test f1: 0.9975702480835901
# 20 / 20 models trained | Current model test accuracy: 0.996685449121644
# 20 / 20 models trained | Current model test precision: 0.9972030042383446
# 20 / 20 models trained | Current model test recall: 0.9938017019626252
# 20 / 20 models trained | Current model test f1: 0.995499447819263
# CPU times: total: 1h 15min 27s
# Wall time: 1h 51s

# %%
# %%time
lstm_accuracies, lstm_precisions, lstm_recalls, lstm_f1Scores, lstm_wrong_preds, lstm_epoch_stats, model = train_models(LSTM_Model, x_train_lstm, x_val_lstm, x_test_lstm, 0.0001, data, 16, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_16360\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.974477958236659
# 1 / 20 models trained | Current model test precision: 0.9323786116968041
# 1 / 20 models trained | Current model test recall: 0.9499755575341133
# 1 / 20 models trained | Current model test f1: 0.9410948332230632
# 2 / 20 models trained | Current model test accuracy: 0.964534305601591
# 2 / 20 models trained | Current model test precision: 0.9082805885495868
# 2 / 20 models trained | Current model test recall: 0.9353602984150995
# 2 / 20 models trained | Current model test f1: 0.9216215677979338
# 3 / 20 models trained | Current model test accuracy: 0.9927079880676168
# 3 / 20 models trained | Current model test precision: 0.989856668369649
# 3 / 20 models trained | Current model test recall: 0.9771510340009025
# 3 / 20 models trained | Current model test f1: 0.9834628159761818
# 4 / 20 models trained | Current model test accuracy: 0.9489559164733179
# 4 / 20 models trained | Current model test precision: 0.8772202366360012
# 4 / 20 models trained | Current model test recall: 0.9196599855605597
# 4 / 20 models trained | Current model test f1: 0.8979389279179743
# 5 / 20 models trained | Current model test accuracy: 0.9844216108717269
# 5 / 20 models trained | Current model test precision: 0.9831035500463783
# 5 / 20 models trained | Current model test recall: 0.9848933130917682
# 5 / 20 models trained | Current model test f1: 0.9839976177334877
# 6 / 20 models trained | Current model test accuracy: 0.9353662578720583
# 6 / 20 models trained | Current model test precision: 0.8468853243722534
# 6 / 20 models trained | Current model test recall: 0.8879177668538937
# 6 / 20 models trained | Current model test f1: 0.8669162855439267
# 7 / 20 models trained | Current model test accuracy: 0.9582366589327146
# 7 / 20 models trained | Current model test precision: 0.8975228770894739
# 7 / 20 models trained | Current model test recall: 0.9375687829262687
# 7 / 20 models trained | Current model test f1: 0.9171088832849278
# 8 / 20 models trained | Current model test accuracy: 0.9844216108717269
# 8 / 20 models trained | Current model test precision: 0.9526208595788014
# 8 / 20 models trained | Current model test recall: 0.9831181072813407
# 8 / 20 models trained | Current model test f1: 0.9676292438798649
# 9 / 20 models trained | Current model test accuracy: 0.9665230361286046
# 9 / 20 models trained | Current model test precision: 0.9240830390803089
# 9 / 20 models trained | Current model test recall: 0.9401455396490652
# 9 / 20 models trained | Current model test f1: 0.9320450907890765
# 10 / 20 models trained | Current model test accuracy: 0.9602253894597282
# 10 / 20 models trained | Current model test precision: 0.8990113683822294
# 10 / 20 models trained | Current model test recall: 0.9383947826174838
# 10 / 20 models trained | Current model test f1: 0.918280998618275
# 11 / 20 models trained | Current model test accuracy: 0.9363606231355651
# 11 / 20 models trained | Current model test precision: 0.869174582894914
# 11 / 20 models trained | Current model test recall: 0.8847015772100101
# 11 / 20 models trained | Current model test f1: 0.8768693501278686
# 12 / 20 models trained | Current model test accuracy: 0.9459728206827975
# 12 / 20 models trained | Current model test precision: 0.8788183509678498
# 12 / 20 models trained | Current model test recall: 0.9038027040247707
# 12 / 20 models trained | Current model test f1: 0.8911354432023363
# 13 / 20 models trained | Current model test accuracy: 0.9297315213788532
# 13 / 20 models trained | Current model test precision: 0.8593025127649647
# 13 / 20 models trained | Current model test recall: 0.9049836604840568
# 13 / 20 models trained | Current model test f1: 0.8815516952480509
# 14 / 20 models trained | Current model test accuracy: 0.9764666887636725
# 14 / 20 models trained | Current model test precision: 0.9460318386397732
# 14 / 20 models trained | Current model test recall: 0.9497604142049371
# 14 / 20 models trained | Current model test f1: 0.9478924598086416
# 15 / 20 models trained | Current model test accuracy: 0.9953596287703016
# 15 / 20 models trained | Current model test precision: 0.9912030167071105
# 15 / 20 models trained | Current model test recall: 0.9871766432082159
# 15 / 20 models trained | Current model test f1: 0.9891857327452118
# 16 / 20 models trained | Current model test accuracy: 0.9651972157772621
# 16 / 20 models trained | Current model test precision: 0.9115105139349395
# 16 / 20 models trained | Current model test recall: 0.933369403544938
# 16 / 20 models trained | Current model test f1: 0.922310462220828
# 17 / 20 models trained | Current model test accuracy: 0.9705004971826318
# 17 / 20 models trained | Current model test precision: 0.9363717214069486
# 17 / 20 models trained | Current model test recall: 0.9683534231386828
# 17 / 20 models trained | Current model test f1: 0.9520940744140599
# 18 / 20 models trained | Current model test accuracy: 0.9956910838581372
# 18 / 20 models trained | Current model test precision: 0.9927716514254976
# 18 / 20 models trained | Current model test recall: 0.9907502693295802
# 18 / 20 models trained | Current model test f1: 0.9917599303950781
# 19 / 20 models trained | Current model test accuracy: 0.9771295989393437
# 19 / 20 models trained | Current model test precision: 0.9878171722254169
# 19 / 20 models trained | Current model test recall: 0.9649766286262039
# 19 / 20 models trained | Current model test f1: 0.9762633250243318
# 20 / 20 models trained | Current model test accuracy: 0.942326814716606
# 20 / 20 models trained | Current model test precision: 0.8675076452599388
# 20 / 20 models trained | Current model test recall: 0.9142470204555128
# 20 / 20 models trained | Current model test f1: 0.8902642941392905
# CPU times: total: 33min 14s
# Wall time: 24min 33s

# %%
# %%time
deepset_accuracies, deepset_precisions, deepset_recalls, deepset_f1Scores, deepset_wrong_preds, deepset_epoch_stats, model = train_models(DEEPSET_Model, x_train_normal, x_val_normal, x_test_normal, 0.005, data, 128, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_16360\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.5575074577394763
# 1 / 20 models trained | Current model test precision: 0.39321141365588375
# 1 / 20 models trained | Current model test recall: 0.39235749135401965
# 1 / 20 models trained | Current model test f1: 0.3927839883933423
# 2 / 20 models trained | Current model test accuracy: 0.5628107391448459
# 2 / 20 models trained | Current model test precision: 0.3701905334377097
# 2 / 20 models trained | Current model test recall: 0.34592973507743996
# 2 / 20 models trained | Current model test f1: 0.35764917930841655
# 3 / 20 models trained | Current model test accuracy: 0.5707656612529002
# 3 / 20 models trained | Current model test precision: 0.396748385646128
# 3 / 20 models trained | Current model test recall: 0.41677832564475237
# 3 / 20 models trained | Current model test f1: 0.40651677585231216
# 4 / 20 models trained | Current model test accuracy: 0.5439177991382168
# 4 / 20 models trained | Current model test precision: 0.32998544285319653
# 4 / 20 models trained | Current model test recall: 0.35825267225491875
# 4 / 20 models trained | Current model test f1: 0.343538563506642
# 5 / 20 models trained | Current model test accuracy: 0.5535299966854491
# 5 / 20 models trained | Current model test precision: 0.30380622779484545
# 5 / 20 models trained | Current model test recall: 0.30939457326264796
# 5 / 20 models trained | Current model test f1: 0.3065749361090871
# 6 / 20 models trained | Current model test accuracy: 0.5147497514086842
# 6 / 20 models trained | Current model test precision: 0.26660929997260935
# 6 / 20 models trained | Current model test recall: 0.31232727752609935
# 6 / 20 models trained | Current model test f1: 0.28766313983251457
# 7 / 20 models trained | Current model test accuracy: 0.5525356314219423
# 7 / 20 models trained | Current model test precision: 0.4182884717424191
# 7 / 20 models trained | Current model test recall: 0.3899193430842641
# 7 / 20 models trained | Current model test f1: 0.4036060110517508
# 8 / 20 models trained | Current model test accuracy: 0.5568445475638051
# 8 / 20 models trained | Current model test precision: 0.315280299228084
# 8 / 20 models trained | Current model test recall: 0.30584996156165783
# 8 / 20 models trained | Current model test f1: 0.31049354213543745
# 9 / 20 models trained | Current model test accuracy: 0.5677825654623798
# 9 / 20 models trained | Current model test precision: 0.28511369706806927
# 9 / 20 models trained | Current model test recall: 0.36293923707736286
# 9 / 20 models trained | Current model test f1: 0.3193533806945754
# 10 / 20 models trained | Current model test accuracy: 0.5710971163407358
# 10 / 20 models trained | Current model test precision: 0.34800801496044687
# 10 / 20 models trained | Current model test recall: 0.3859449631032017
# 10 / 20 models trained | Current model test f1: 0.365996036552305
# 11 / 20 models trained | Current model test accuracy: 0.5667882001988731
# 11 / 20 models trained | Current model test precision: 0.3156918775202452
# 11 / 20 models trained | Current model test recall: 0.4107429313131867
# 11 / 20 models trained | Current model test f1: 0.35699888162754967
# 12 / 20 models trained | Current model test accuracy: 0.5674511103745442
# 12 / 20 models trained | Current model test precision: 0.45334011363384563
# 12 / 20 models trained | Current model test recall: 0.38008363564799397
# 12 / 20 models trained | Current model test f1: 0.41349231702001216
# 13 / 20 models trained | Current model test accuracy: 0.5651309247596951
# 13 / 20 models trained | Current model test precision: 0.38439607486549976
# 13 / 20 models trained | Current model test recall: 0.3957586775237106
# 13 / 20 models trained | Current model test f1: 0.3899946305990852
# 14 / 20 models trained | Current model test accuracy: 0.5492210805435863
# 14 / 20 models trained | Current model test precision: 0.3291571758513907
# 14 / 20 models trained | Current model test recall: 0.3417894240719648
# 14 / 20 models trained | Current model test f1: 0.3353543831245372
# 15 / 20 models trained | Current model test accuracy: 0.5691083858137223
# 15 / 20 models trained | Current model test precision: 0.35396325796505657
# 15 / 20 models trained | Current model test recall: 0.3684780299209087
# 15 / 20 models trained | Current model test f1: 0.3610748337515781
# 16 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 16 / 20 models trained | Current model test precision: 0.14177991382167715
# 16 / 20 models trained | Current model test recall: 0.25
# 16 / 20 models trained | Current model test f1: 0.18094331641285955
# 17 / 20 models trained | Current model test accuracy: 0.5538614517732847
# 17 / 20 models trained | Current model test precision: 0.3218164311995788
# 17 / 20 models trained | Current model test recall: 0.34128402420914017
# 17 / 20 models trained | Current model test f1: 0.33126445865195225
# 18 / 20 models trained | Current model test accuracy: 0.5323168710639709
# 18 / 20 models trained | Current model test precision: 0.381763088561033
# 18 / 20 models trained | Current model test recall: 0.3649097240855029
# 18 / 20 models trained | Current model test f1: 0.37314620528116876
# 19 / 20 models trained | Current model test accuracy: 0.5737487570434207
# 19 / 20 models trained | Current model test precision: 0.41338808312148057
# 19 / 20 models trained | Current model test recall: 0.38304407749346725
# 19 / 20 models trained | Current model test f1: 0.39763802813737953
# 20 / 20 models trained | Current model test accuracy: 0.5508783559827644
# 20 / 20 models trained | Current model test precision: 0.38280593800735896
# 20 / 20 models trained | Current model test recall: 0.3632966448663934
# 20 / 20 models trained | Current model test f1: 0.3727962242868643
# CPU times: total: 12min 1s
# Wall time: 7min 51s

# %%
# %%time
deepsetv2_accuracies, deepsetv2_precisions, deepsetv2_recalls, deepsetv2_f1Scores, deepsetv2_wrong_preds, deepsetv2_epoch_stats, model = train_models(DEEPSETV2_Model, x_train_normal, x_val_normal, x_test_normal, 0.0001, data, 16, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_16360\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.5667882001988731
# 1 / 20 models trained | Current model test precision: 0.22104209824093254
# 1 / 20 models trained | Current model test recall: 0.3333333333333333
# 1 / 20 models trained | Current model test f1: 0.26581516862827886
# 2 / 20 models trained | Current model test accuracy: 0.1541266158435532
# 2 / 20 models trained | Current model test precision: 0.11254420187456907
# 2 / 20 models trained | Current model test recall: 0.29967402890359685
# 2 / 20 models trained | Current model test f1: 0.16363455998452292
# 3 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 3 / 20 models trained | Current model test precision: 0.14177991382167715
# 3 / 20 models trained | Current model test recall: 0.25
# 3 / 20 models trained | Current model test f1: 0.18094331641285955
# 4 / 20 models trained | Current model test accuracy: 0.5492210805435863
# 4 / 20 models trained | Current model test precision: 0.35766828576863463
# 4 / 20 models trained | Current model test recall: 0.4155658596146401
# 4 / 20 models trained | Current model test f1: 0.3844494698527896
# 5 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 5 / 20 models trained | Current model test precision: 0.14177991382167715
# 5 / 20 models trained | Current model test recall: 0.25
# 5 / 20 models trained | Current model test f1: 0.18094331641285955
# 6 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 6 / 20 models trained | Current model test precision: 0.14177991382167715
# 6 / 20 models trained | Current model test recall: 0.25
# 6 / 20 models trained | Current model test f1: 0.18094331641285955
# 7 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 7 / 20 models trained | Current model test precision: 0.14177991382167715
# 7 / 20 models trained | Current model test recall: 0.25
# 7 / 20 models trained | Current model test f1: 0.18094331641285955
# 8 / 20 models trained | Current model test accuracy: 0.5243619489559165
# 8 / 20 models trained | Current model test precision: 0.29142666384214805
# 8 / 20 models trained | Current model test recall: 0.33857651119309895
# 8 / 20 models trained | Current model test f1: 0.3132372248974719
# 9 / 20 models trained | Current model test accuracy: 0.5568445475638051
# 9 / 20 models trained | Current model test precision: 0.3709468656590153
# 9 / 20 models trained | Current model test recall: 0.3780602669713091
# 9 / 20 models trained | Current model test f1: 0.37446978794642216
# 10 / 20 models trained | Current model test accuracy: 0.06861120318196884
# 10 / 20 models trained | Current model test precision: 0.0423496185624802
# 10 / 20 models trained | Current model test recall: 0.2145581620954229
# 10 / 20 models trained | Current model test f1: 0.07073710497158846
# 11 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 11 / 20 models trained | Current model test precision: 0.14182692307692307
# 11 / 20 models trained | Current model test recall: 0.25
# 11 / 20 models trained | Current model test f1: 0.18098159509202455
# 12 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 12 / 20 models trained | Current model test precision: 0.14177991382167715
# 12 / 20 models trained | Current model test recall: 0.25
# 12 / 20 models trained | Current model test f1: 0.18094331641285955
# 13 / 20 models trained | Current model test accuracy: 0.08816705336426914
# 13 / 20 models trained | Current model test precision: 0.04386415487478405
# 13 / 20 models trained | Current model test recall: 0.16642862906479466
# 13 / 20 models trained | Current model test f1: 0.06942940241823653
# 14 / 20 models trained | Current model test accuracy: 0.5667882001988731
# 14 / 20 models trained | Current model test precision: 0.14174403183023873
# 14 / 20 models trained | Current model test recall: 0.25
# 14 / 20 models trained | Current model test f1: 0.18091409225560726
# 15 / 20 models trained | Current model test accuracy: 0.5999337089824329
# 15 / 20 models trained | Current model test precision: 0.36198978748636235
# 15 / 20 models trained | Current model test recall: 0.4295933769060384
# 15 / 20 models trained | Current model test f1: 0.39290480699177055
# 16 / 20 models trained | Current model test accuracy: 0.5667882001988731
# 16 / 20 models trained | Current model test precision: 0.14174403183023873
# 16 / 20 models trained | Current model test recall: 0.24985388661601401
# 16 / 20 models trained | Current model test f1: 0.18087581975883224
# 17 / 20 models trained | Current model test accuracy: 0.5880013258203514
# 17 / 20 models trained | Current model test precision: 0.3059852631150549
# 17 / 20 models trained | Current model test recall: 0.3462194193958986
# 17 / 20 models trained | Current model test f1: 0.3248613295186405
# 18 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 18 / 20 models trained | Current model test precision: 0.14177991382167715
# 18 / 20 models trained | Current model test recall: 0.25
# 18 / 20 models trained | Current model test f1: 0.18094331641285955
# 19 / 20 models trained | Current model test accuracy: 0.544580709313888
# 19 / 20 models trained | Current model test precision: 0.2572549179027971
# 19 / 20 models trained | Current model test recall: 0.2915320424823818
# 19 / 20 models trained | Current model test f1: 0.27332300899496864
# 20 / 20 models trained | Current model test accuracy: 0.5399403380841896
# 20 / 20 models trained | Current model test precision: 0.4200511003075974
# 20 / 20 models trained | Current model test recall: 0.4258238825664128
# 20 / 20 models trained | Current model test f1: 0.4229177928907173
# CPU times: total: 6min 45s
# Wall time: 4min 25s

# %%
# %%time
feedforward_accuracies, feedforward_precisions, feedforward_recalls, feedforward_f1Scores, feedforward_wrong_preds, feedforward_epoch_stats, model = train_models(FEEDFORWARD_Model, x_train_normal, x_val_normal, x_test_normal, 0.0001, data, 128, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_16360\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.5515412661584356
# 1 / 20 models trained | Current model test precision: 0.3810957094837336
# 1 / 20 models trained | Current model test recall: 0.3913774093121919
# 1 / 20 models trained | Current model test f1: 0.38616813413578194
# 2 / 20 models trained | Current model test accuracy: 0.5624792840570103
# 2 / 20 models trained | Current model test precision: 0.2068290311656817
# 2 / 20 models trained | Current model test recall: 0.3200268060162296
# 2 / 20 models trained | Current model test f1: 0.2512673470201304
# 3 / 20 models trained | Current model test accuracy: 0.5531985415976135
# 3 / 20 models trained | Current model test precision: 0.33447700811924075
# 3 / 20 models trained | Current model test recall: 0.33315119113734337
# 3 / 20 models trained | Current model test f1: 0.3338127831839961
# 4 / 20 models trained | Current model test accuracy: 0.531322505800464
# 4 / 20 models trained | Current model test precision: 0.2858042576729046
# 4 / 20 models trained | Current model test recall: 0.33315968431085063
# 4 / 20 models trained | Current model test f1: 0.3076704467010808
# 5 / 20 models trained | Current model test accuracy: 0.5469008949287372
# 5 / 20 models trained | Current model test precision: 0.36275362456132165
# 5 / 20 models trained | Current model test recall: 0.3476595874343152
# 5 / 20 models trained | Current model test f1: 0.3550462556883475
# 6 / 20 models trained | Current model test accuracy: 0.5664567451110375
# 6 / 20 models trained | Current model test precision: 0.39144619592464647
# 6 / 20 models trained | Current model test recall: 0.4029566687139047
# 6 / 20 models trained | Current model test f1: 0.39711804202089557
# 7 / 20 models trained | Current model test accuracy: 0.5575074577394763
# 7 / 20 models trained | Current model test precision: 0.3794797236222357
# 7 / 20 models trained | Current model test recall: 0.34288390802893354
# 7 / 20 models trained | Current model test f1: 0.3602548216773066
# 8 / 20 models trained | Current model test accuracy: 0.5505469008949287
# 8 / 20 models trained | Current model test precision: 0.2899523343725974
# 8 / 20 models trained | Current model test recall: 0.33577812243423166
# 8 / 20 models trained | Current model test f1: 0.31118718730071165
# 9 / 20 models trained | Current model test accuracy: 0.5329797812396421
# 9 / 20 models trained | Current model test precision: 0.38106479680081956
# 9 / 20 models trained | Current model test recall: 0.4019362038241464
# 9 / 20 models trained | Current model test f1: 0.3912223297668607
# 10 / 20 models trained | Current model test accuracy: 0.5551872721246272
# 10 / 20 models trained | Current model test precision: 0.3551697474363795
# 10 / 20 models trained | Current model test recall: 0.36139490476039027
# 10 / 20 models trained | Current model test f1: 0.35825528556297065
# 11 / 20 models trained | Current model test accuracy: 0.5293337752734505
# 11 / 20 models trained | Current model test precision: 0.3154479329894251
# 11 / 20 models trained | Current model test recall: 0.3480324655793742
# 11 / 20 models trained | Current model test f1: 0.33094006128002473
# 12 / 20 models trained | Current model test accuracy: 0.5522041763341067
# 12 / 20 models trained | Current model test precision: 0.27770191526105514
# 12 / 20 models trained | Current model test recall: 0.32166944603042613
# 12 / 20 models trained | Current model test f1: 0.29807303789468376
# 13 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 13 / 20 models trained | Current model test precision: 0.14177991382167715
# 13 / 20 models trained | Current model test recall: 0.25
# 13 / 20 models trained | Current model test f1: 0.18094331641285955
# 14 / 20 models trained | Current model test accuracy: 0.5674511103745442
# 14 / 20 models trained | Current model test precision: 0.4078204290715328
# 14 / 20 models trained | Current model test recall: 0.35663746721026346
# 14 / 20 models trained | Current model test f1: 0.38051551461000394
# 15 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 15 / 20 models trained | Current model test precision: 0.3169547872340426
# 15 / 20 models trained | Current model test recall: 0.31301074584656174
# 15 / 20 models trained | Current model test f1: 0.3149704202597128
# 16 / 20 models trained | Current model test accuracy: 0.5455750745773947
# 16 / 20 models trained | Current model test precision: 0.37298072945061145
# 16 / 20 models trained | Current model test recall: 0.38121751396784
# 16 / 20 models trained | Current model test f1: 0.37705414373441914
# 17 / 20 models trained | Current model test accuracy: 0.5575074577394763
# 17 / 20 models trained | Current model test precision: 0.27692752822684724
# 17 / 20 models trained | Current model test recall: 0.32741787624140567
# 17 / 20 models trained | Current model test f1: 0.30006358117207893
# 18 / 20 models trained | Current model test accuracy: 0.5671196552867086
# 18 / 20 models trained | Current model test precision: 0.14177991382167715
# 18 / 20 models trained | Current model test recall: 0.25
# 18 / 20 models trained | Current model test f1: 0.18094331641285955
# 19 / 20 models trained | Current model test accuracy: 0.5638051044083526
# 19 / 20 models trained | Current model test precision: 0.23442909112245497
# 19 / 20 models trained | Current model test recall: 0.25235351222949415
# 19 / 20 models trained | Current model test f1: 0.243061293095337
# 20 / 20 models trained | Current model test accuracy: 0.5631421942326815
# 20 / 20 models trained | Current model test precision: 0.22501840264998157
# 20 / 20 models trained | Current model test recall: 0.2537057575576285
# 20 / 20 models trained | Current model test f1: 0.2385025409369909
# CPU times: total: 8min 51s
# Wall time: 5min 34s

# %% [markdown]
# # Evaluation

# %% [markdown]
# # Evaluacion general de los modelos

# %%
import pandas as pd
# Lista de modelos y nombres
model_names = ['CNN', 'LSTM', 'DeepSet', 'DeepSetV2', 'Feedforward']
all_accuracies = [cnn_accuracies, lstm_accuracies, deepset_accuracies, deepsetv2_accuracies, feedforward_accuracies]
all_precisions = [cnn_precisions, lstm_precisions, deepset_precisions, deepsetv2_precisions, feedforward_precisions]
all_recalls = [cnn_recalls, lstm_recalls, deepset_recalls, deepsetv2_recalls, feedforward_recalls]
all_f1_scores = [cnn_f1_scores, lstm_f1Scores, deepset_f1Scores, deepsetv2_f1Scores, feedforward_f1Scores]

get_summary_df(model_names, all_accuracies, all_precisions, all_recalls, all_f1_scores)
# Out:
#         Modelo  Accuracy  Precision    Recall  F1-score  Precision clase A
# 0          CNN  1.000000   1.000000  1.000000  1.000000           1.000000  \
# 1         LSTM  0.995691   0.992772  0.990750  0.991760           0.976331
# 2      DeepSet  0.573749   0.413388  0.383044  0.397638           0.333333
# 3    DeepSetV2  0.599934   0.361990  0.429593  0.392905           0.000000
# 4  Feedforward  0.567451   0.407820  0.356637  0.380516           0.333333
#
#    Recall clase A  Precision clase D  Recall clase D  Precision clase R
# 0        1.000000           1.000000        1.000000           1.000000  \
# 1        0.970588           1.000000        1.000000           1.000000
# 2        0.064706           0.357616        0.439024           0.366337
# 3        0.000000           0.286445        0.318182           0.376828
# 4        0.005882           0.335821        0.401786           0.378378
#
#    Recall clase R  Precision clase V  Recall clase V
# 0        1.000000           1.000000        1.000000
# 1        0.994751           0.994755        0.997662
# 2        0.050068           0.596266        0.978378
# 3        0.573630           0.784686        0.826562
# 4        0.038043           0.583749        0.980838

# %% [markdown]
# ### Get best 50% performing models

# %%
top_half = int(num_experiments / 2)
best_cnn_accs = filter_top_k_accuracies(cnn_accuracies, top_half)
best_lstm_accs = filter_top_k_accuracies(lstm_accuracies, top_half)
best_deepset_accs = filter_top_k_accuracies(deepset_accuracies, top_half)
best_deepsetv2_accs = filter_top_k_accuracies(deepsetv2_accuracies, top_half)
best_feedforward_accs = filter_top_k_accuracies(feedforward_accuracies, top_half)

# %% [markdown]
# ## Accuracy breakdown by cases for all the models

# %%
all_accuracies = [cnn_accuracies, lstm_accuracies, deepset_accuracies, deepsetv2_accuracies, feedforward_accuracies]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']

# %%
get_stats_df(all_accuracies, model_names, test_original)
# Out:
#                        Overall cr_noop   cr_uw    cr_w   cr_wu dr_noop  dr_uw
# CNN                      99.3%  100.0%  100.0%  100.0%  100.0%  100.0%  95.3%  \
# LSTM                     96.5%  100.0%  100.0%  100.0%  100.0%   99.0%  82.6%
# DeepSet(like in paper)   55.7%   92.2%   92.4%   92.5%   93.6%    8.4%   2.9%
# DeepSet(sum at start)    49.4%   78.9%   79.9%   79.2%   79.2%   13.1%  10.1%
# Feedforward              55.4%   92.9%   93.4%   93.2%   94.1%    7.3%   2.1%
# Sample count              3017     194     176     173     171     190    170
#
#                          dr_w  dr_wu noop_noop noop_uw  noop_w noop_wu
# CNN                     99.3%  98.2%    100.0%  100.0%  100.0%  100.0%  \
# LSTM                    98.7%  67.6%     99.8%  100.0%   99.9%  100.0%
# DeepSet(like in paper)   9.3%  83.3%     94.8%   94.3%   93.2%   95.0%
# DeepSet(sum at start)   12.1%  64.9%     76.9%   78.4%   77.3%   78.3%
# Feedforward              7.0%  85.9%     91.1%   92.2%   89.9%   93.2%
# Sample count              184    176       227     183     211     200
#
#                         r_noop   r_uw    r_w   r_wu
# CNN                     100.0%  99.5%  99.9%  96.0%
# LSTM                     99.9%  98.3%  99.9%  94.4%
# DeepSet(like in paper)    8.3%   7.4%   9.5%   6.5%
# DeepSet(sum at start)    14.5%  13.6%  15.6%  13.2%
# Feedforward              11.1%   8.5%  10.9%   7.6%
# Sample count               205    187    199    171

# %% [markdown]
# ## Accuracy breakdown by cases for top 50% of models

# %%
best_accuracies = [best_cnn_accs, best_lstm_accs, best_deepset_accs, best_deepsetv2_accs, best_feedforward_accs]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']
collapsed_cases = ['dr', 'r', 'cr', 'noop']

# %%
get_stats_df(best_accuracies, model_names, test_original, collapsed_cases)
# Out:
#                        Overall   f3_cr  f3_dr f3_noop   f3_r
# CNN                      99.9%  100.0%  99.7%  100.0%  99.8%
# LSTM                     98.2%  100.0%  94.6%  100.0%  97.9%
# DeepSet(like in paper)   56.8%   96.0%  26.5%   97.8%   4.6%
# DeepSet(sum at start)    57.2%   97.6%  22.9%   96.8%   9.2%
# Feedforward              56.4%   97.5%  25.5%   96.9%   3.4%
# Sample count              3017     714    720     821    762

# %%
best_accuracies = [best_cnn_accs, best_lstm_accs, best_deepset_accs, best_deepsetv2_accs, best_feedforward_accs]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']
collapsed_cases = ['r', 'cr', 'noop']

# %%
get_stats_df(best_accuracies, model_names, test_original, collapsed_cases)
# Out:
#                        Overall dr_noop  dr_uw   dr_w  dr_wu   f3_cr f3_noop
# CNN                      99.9%  100.0%  99.2%  99.9%  99.6%  100.0%  100.0%  \
# LSTM                     98.2%   99.8%  91.4%  99.7%  86.8%  100.0%  100.0%
# DeepSet(like in paper)   56.8%    7.4%   2.8%   9.6%  87.5%   96.0%   97.8%
# DeepSet(sum at start)    57.2%    3.3%   0.9%   3.0%  86.3%   97.6%   96.8%
# Feedforward              56.4%    4.4%   0.9%   4.0%  94.7%   97.5%   96.9%
# Sample count              3017     190    170    184    176     714     821
#
#                          f3_r
# CNN                     99.8%
# LSTM                    97.9%
# DeepSet(like in paper)   4.6%
# DeepSet(sum at start)    9.2%
# Feedforward              3.4%
# Sample count              762

# %% [markdown]
# ## Accuracies per CNN model

# %%
get_stats_per_model(cnn_accuracies, ['CNN #' + str(i) for i in range(len(cnn_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#              Overall   f3_cr   f3_dr f3_noop    f3_r
# CNN #0         99.9%  100.0%  100.0%  100.0%   99.6%
# CNN #1         99.5%  100.0%   99.6%  100.0%   98.3%
# CNN #2        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #3         99.2%  100.0%   98.3%  100.0%   98.6%
# CNN #4         99.6%  100.0%   98.6%  100.0%   99.9%
# CNN #5         99.1%  100.0%   97.6%  100.0%   98.6%
# CNN #6         99.6%  100.0%   99.2%  100.0%   99.3%
# CNN #7         99.0%  100.0%   96.8%  100.0%   99.0%
# CNN #8         99.0%  100.0%   97.4%  100.0%   98.6%
# CNN #9         97.0%  100.0%   94.9%  100.0%   92.9%
# CNN #10        99.9%  100.0%   99.6%  100.0%  100.0%
# CNN #11       100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #12       100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #13        99.7%  100.0%  100.0%  100.0%   98.8%
# CNN #14        96.2%  100.0%   85.0%  100.0%   99.1%
# CNN #15        99.6%  100.0%  100.0%  100.0%   98.4%
# CNN #16        99.6%  100.0%   99.7%  100.0%   98.7%
# CNN #17        99.9%  100.0%   99.7%  100.0%  100.0%
# CNN #18        99.9%  100.0%   99.6%  100.0%  100.0%
# CNN #19        99.7%  100.0%   99.3%  100.0%   99.3%
# Sample count    3017     714     720     821     762

# %% [markdown]
# ## Accuracies per LSTM model

# %%
get_stats_per_model(lstm_accuracies, ['LSTM #' + str(i) for i in range(len(lstm_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#              Overall   f3_cr  f3_dr f3_noop    f3_r
# LSTM #0        97.4%  100.0%  89.6%  100.0%   99.7%
# LSTM #1        96.5%  100.0%  85.1%  100.0%  100.0%
# LSTM #2        99.3%  100.0%  97.8%  100.0%   99.2%
# LSTM #3        94.9%  100.0%  78.6%  100.0%  100.0%
# LSTM #4        98.4%  100.0%  98.8%  100.0%   95.0%
# LSTM #5        93.5%  100.0%  75.4%  100.0%   97.6%
# LSTM #6        95.8%  100.0%  83.8%  100.0%   98.8%
# LSTM #7        98.4%  100.0%  93.8%  100.0%   99.7%
# LSTM #8        96.7%  100.0%  87.2%   99.6%   99.2%
# LSTM #9        96.0%  100.0%  83.6%  100.0%   99.7%
# LSTM #10       93.6%  100.0%  74.0%  100.0%   99.3%
# LSTM #11       94.6%  100.0%  80.3%   98.9%   98.4%
# LSTM #12       93.0%  100.0%  78.5%  100.0%   92.5%
# LSTM #13       97.6%  100.0%  91.2%  100.0%   99.0%
# LSTM #14       99.5%  100.0%  98.2%  100.0%   99.9%
# LSTM #15       96.5%  100.0%  85.4%  100.0%  100.0%
# LSTM #16       97.1%  100.0%  92.5%  100.0%   95.4%
# LSTM #17       99.6%  100.0%  98.8%  100.0%   99.5%
# LSTM #18       97.7%  100.0%  98.3%  100.0%   92.5%
# LSTM #19       94.2%  100.0%  76.4%  100.0%   99.5%
# Sample count    3017     714    720     821     762

# %% [markdown]
# ## Accuracies per DeepSets V1 model

# %%
get_stats_per_model(deepset_accuracies, ['DeepSet(like in paper) #' + str(i) for i in range(len(deepset_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                            Overall   f3_cr  f3_dr f3_noop   f3_r
# DeepSet(like in paper) #0    55.8%   92.2%  23.6%   94.9%   9.8%
# DeepSet(like in paper) #1    56.3%   97.5%  25.7%   98.1%   1.6%
# DeepSet(like in paper) #2    57.1%   88.8%  24.9%   96.8%  15.0%
# DeepSet(like in paper) #3    54.4%   88.0%  22.9%   88.3%  16.1%
# DeepSet(like in paper) #4    55.4%   95.4%  23.8%   94.6%   5.4%
# DeepSet(like in paper) #5    51.5%   81.8%  21.7%   77.1%  23.6%
# DeepSet(like in paper) #6    55.3%   94.4%  20.6%   96.7%   6.7%
# DeepSet(like in paper) #7    55.7%   93.6%  24.9%   95.4%   6.6%
# DeepSet(like in paper) #8    56.8%   97.6%  28.2%   98.7%   0.4%
# DeepSet(like in paper) #9    57.1%   95.0%  25.7%   98.7%   6.6%
# DeepSet(like in paper) #10   56.7%   98.7%  26.8%   97.8%   1.2%
# DeepSet(like in paper) #11   56.7%   89.2%  27.4%   93.2%  14.8%
# DeepSet(like in paper) #12   56.5%   98.2%  25.8%   98.2%   1.6%
# DeepSet(like in paper) #13   54.9%   90.6%  29.2%   93.8%   3.9%
# DeepSet(like in paper) #14   56.9%   98.9%  27.5%   98.7%   0.4%
# DeepSet(like in paper) #15   56.7%  100.0%  24.4%  100.0%   0.0%
# DeepSet(like in paper) #16   55.4%   95.4%  26.7%   93.7%   3.8%
# DeepSet(like in paper) #17   53.2%   77.5%  27.5%   82.9%  22.8%
# DeepSet(like in paper) #18   57.4%   95.8%  28.3%   98.2%   4.9%
# DeepSet(like in paper) #19   55.1%   85.0%  27.4%   90.9%  14.7%
# Sample count                  3017     714    720     821    762

# %% [markdown]
# ## Accuracies per DeepSets V2 model

# %%
get_stats_per_model(deepsetv2_accuracies, ['DeepSet(sum at start) #' + str(i) for i in range(len(deepsetv2_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                           Overall   f3_cr  f3_dr f3_noop   f3_r
# DeepSet(sum at start) #0    56.7%  100.0%  24.6%   99.8%   0.0%
# DeepSet(sum at start) #1    15.4%    0.0%  18.9%    0.0%  43.2%
# DeepSet(sum at start) #2    56.7%  100.0%  24.4%  100.0%   0.0%
# DeepSet(sum at start) #3    54.9%   77.0%  30.8%   74.7%  35.7%
# DeepSet(sum at start) #4    56.7%  100.0%  24.4%  100.0%   0.0%
# DeepSet(sum at start) #5    56.7%  100.0%  24.4%  100.0%   0.0%
# DeepSet(sum at start) #6    56.7%  100.0%  24.4%  100.0%   0.0%
# DeepSet(sum at start) #7    52.4%   81.8%  25.4%   78.4%  22.4%
# DeepSet(sum at start) #8    55.7%   83.9%  29.6%   80.8%  26.9%
# DeepSet(sum at start) #9     6.9%    0.0%  28.7%    0.0%   0.0%
# DeepSet(sum at start) #10   56.7%  100.0%  24.4%  100.0%   0.0%
# DeepSet(sum at start) #11   56.7%  100.0%  24.4%  100.0%   0.0%
# DeepSet(sum at start) #12    8.8%    0.0%  36.9%    0.0%   0.0%
# DeepSet(sum at start) #13   56.7%   99.9%  24.4%  100.0%   0.0%
# DeepSet(sum at start) #14   60.0%   86.8%  21.7%   85.1%  44.0%
# DeepSet(sum at start) #15   56.7%   99.9%  24.4%  100.0%   0.0%
# DeepSet(sum at start) #16   58.8%   89.2%  12.1%   82.9%  48.4%
# DeepSet(sum at start) #17   56.7%  100.0%  24.4%  100.0%   0.0%
# DeepSet(sum at start) #18   54.5%   85.3%  14.3%   81.6%  34.3%
# DeepSet(sum at start) #19   54.0%   81.9%  33.1%   70.2%  30.2%
# Sample count                 3017     714    720     821    762

# %% [markdown]
# ## Accuracies per FeedForward model

# %%
get_stats_per_model(feedforward_accuracies, ['Feedforward #' + str(i) for i in range(len(feedforward_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                 Overall   f3_cr  f3_dr f3_noop   f3_r
# Feedforward #0    55.2%   83.8%  15.0%   80.0%  39.5%
# Feedforward #1    56.2%   98.3%  25.8%   98.5%   0.0%
# Feedforward #2    55.3%   93.7%  28.9%   91.1%   5.8%
# Feedforward #3    53.1%   85.4%  22.5%   78.4%  24.5%
# Feedforward #4    54.7%   91.7%  28.5%   87.7%   9.2%
# Feedforward #5    56.6%   95.4%  31.0%   93.7%   4.7%
# Feedforward #6    55.8%   93.4%  26.4%   89.5%  11.8%
# Feedforward #7    55.1%   94.0%  26.4%   92.0%   5.9%
# Feedforward #8    53.3%   83.8%  31.0%   78.2%  19.0%
# Feedforward #9    55.5%   93.1%  23.5%   93.9%   9.2%
# Feedforward #10   52.9%   81.0%  22.9%   79.5%  26.4%
# Feedforward #11   55.2%   94.0%  23.5%   92.3%   8.9%
# Feedforward #12   56.7%  100.0%  24.4%  100.0%   0.0%
# Feedforward #13   56.7%   96.1%  27.5%   97.4%   3.7%
# Feedforward #14   56.7%  100.0%  24.3%   99.9%   0.3%
# Feedforward #15   54.6%   91.9%  26.1%   88.3%  10.1%
# Feedforward #16   55.8%   95.8%  23.5%   94.4%   7.1%
# Feedforward #17   56.7%  100.0%  24.4%  100.0%   0.0%
# Feedforward #18   56.4%   98.9%  24.2%   97.9%   2.2%
# Feedforward #19   56.3%   97.2%  23.9%   97.8%   3.9%
# Sample count       3017     714    720     821    762

# %% [markdown]
# # Training evolution

# %% [markdown]
# ### CNN

# %%
display_epochs_stats(cnn_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### LSTM

# %%
display_epochs_stats(lstm_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### DeepSets V1

# %%
display_epochs_stats(deepset_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### DeepSets V2

# %%
display_epochs_stats(deepsetv2_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### FeedForward

# %%
display_epochs_stats(feedforward_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# # Best performing models

# %%
best_lstm_model = LSTM_Model(data, 16, 32, 8).to(device)
best_lstm_model.load_state_dict(torch.load('./bestmodels/best_LSTM_model_05per'))
best_cnn_model = CNN_Model(data, 64, 128, 4, -1,).to(device)
best_cnn_model.load_state_dict(torch.load('./bestmodels/best_CNN_model_05per'))
best_deepset_model = DEEPSET_Model(data).to(device)
best_deepset_model.load_state_dict(torch.load('./bestmodels/best_DEEPSET_model_05per'))
best_feedforward_model = FEEDFORWARD_Model(data).to(device)
best_feedforward_model.load_state_dict(torch.load('./bestmodels/best_FEEDFORWARD_model_05per'))
best_deepsetv2_model = DEEPSETV2_Model(data).to(device)
best_deepsetv2_model.load_state_dict(torch.load('./bestmodels/best_DEEPSETV2_model_05per'))
# Out:
# HOOOOOLA
# Número de características de entrada por paso de tiempo 8
# C:\Users\juand\AppData\Local\Temp\ipykernel_19056\3577318639.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_lstm_model.load_state_dict(torch.load('./bestmodels/best_LSTM_model_05per'))
# C:\Users\juand\AppData\Local\Temp\ipykernel_19056\3577318639.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_cnn_model.load_state_dict(torch.load('./bestmodels/best_CNN_model_05per'))
# C:\Users\juand\AppData\Local\Temp\ipykernel_19056\3577318639.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_deepset_model.load_state_dict(torch.load('./bestmodels/best_DEEPSET_model_05per'))
# C:\Users\juand\AppData\Local\Temp\ipykernel_19056\3577318639.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_feedforward_model.load_state_dict(torch.load('./bestmodels/best_FEEDFORWARD_model_05per'))
# C:\Users\juand\AppData\Local\Temp\ipykernel_19056\3577318639.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_deepsetv2_model.load_state_dict(torch.load('./bestmodels/best_DEEPSETV2_model_05per'))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19056\3577318639.py in <module>
#       8 best_feedforward_model.load_state_dict(torch.load('./bestmodels/best_FEEDFORWARD_model_05per'))
#       9 best_deepsetv2_model = DEEPSETV2_Model(data).to(device)
# ---> 10 best_deepsetv2_model.load_state_dict(torch.load('./bestmodels/best_DEEPSETV2_model_05per'))
#
# c:\Users\juand\anaconda3\lib\site-packages\torch\nn\modules\module.py in load_state_dict(self, state_dict, strict, assign)
#    2582
#    2583         if len(error_msgs) > 0:
# -> 2584             raise RuntimeError(
#    2585                 "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2586                     self.__class__.__name__, "\n\t".join(error_msgs)
#
# RuntimeError: Error(s) in loading state_dict for DEEPSETV2_Model:
# 	size mismatch for densef1_2.weight: copying a param with shape torch.Size([16, 1]) from checkpoint, the shape in current model is torch.Size([32, 1]).
# 	size mismatch for densef1_2.bias: copying a param with shape torch.Size([16]) from checkpoint, the shape in current model is torch.Size([32]).
# 	size mismatch for densef2_2.weight: copying a param with shape torch.Size([16, 1]) from checkpoint, the shape in current model is torch.Size([32, 1]).
# 	size mismatch for densef2_2.bias: copying a param with shape torch.Size([16]) from checkpoint, the shape in current model is torch.Size([32]).
# 	size mismatch for densef3_2.weight: copying a param with shape torch.Size([16, 1]) from checkpoint, the shape in current model is torch.Size([32, 1]).
# 	size mismatch for densef3_2.bias: copying a param with shape torch.Size([16]) from checkpoint, the shape in current model is torch.Size([32]).
# 	size mismatch for densef1_3.weight: copying a param with shape torch.Size([8, 16]) from checkpoint, the shape in current model is torch.Size([8, 32]).
# 	size mismatch for densef2_3.weight: copying a param with shape torch.Size([8, 16]) from checkpoint, the shape in current model is torch.Size([8, 32]).
# 	size mismatch for densef3_3.weight: copying a param with shape torch.Size([8, 16]) from checkpoint, the shape in current model is torch.Size([8, 32]).

# %% [markdown]
# ## Top wrong predictions for best performing CNN model

# %%
print_wrong_preds([get_wrong_predictions(best_cnn_model, x_test_cnn, y_test, test_original)])
# Out:
# 4 false Atomicity violation:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 print_wrong_preds([get_wrong_predictions(best_cnn_model, x_test_cnn, y_test, test_original)])
#
# File ~\TFGNuestro\src\evaluate.py:405, in print_wrong_preds(wrong_preds_list, k)
#     403 print(f'{min(k,len(i))} false {cases[a]}:')
#     404 for j in range(min(k,len(i))):
# --> 405     print(f"Sample {i[j][0]} | Prediction {i[j][1]}")
#     406 a+=1
#     407 print("\n")
#
# IndexError: list index out of range

# %% [markdown]
# ## Top wrong predictions for best performing LSTM model

# %%
print_wrong_preds([get_wrong_predictions(best_lstm_model, x_test_lstm, y_test, test_original)])
# Out:
# 4 false Atomicity violation:
# Sample (['._,,..._,,,_,,._', '....,_,,.wu__,__', '.._dr._,,.,,._._', 'V'], 'A') | Prediction ([',..,.._.,..,.,,_', '.___,..wu___..,_', '._,dr__,__,.,,,_', 'V'], 'A')
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 print_wrong_preds([get_wrong_predictions(best_lstm_model, x_test_lstm, y_test, test_original)])
#
# File ~\TFGNuestro\src\evaluate.py:405, in print_wrong_preds(wrong_preds_list, k)
#     403 print(f'{min(k,len(i))} false {cases[a]}:')
#     404 for j in range(min(k,len(i))):
# --> 405     print(f"Sample {i[j][0]} | Prediction {i[j][1]}")
#     406 a+=1
#     407 print("\n")
#
# IndexError: list index out of range

# %% [markdown]
# ## Top wrong predictions for best performing DeepSets V1 model

# %%
print_wrong_preds([get_wrong_predictions(best_deepset_model, x_test_normal, y_test, test_original)])
# Out:
# 4 false Atomicity violation:
# Sample (['._._.._.__,..,,,', '_,_,_.,.__.w___.', '_,_,dr,__._.....', 'D'], 'A') | Prediction (['.,,,.,__,,.,.,..', ',.__,_.__,._..,,', '.._dr_..,_.,,_._', 'D'], 'A')
# Sample ([',_.._.._,_._,...', ',,,_._._,,,_._,_', '.,,,,,__,,.._cr_', 'V'], 'D') | Prediction (['._,.,_.__,.___._', '..,.,_wu_.,__.._', ',,_,,.,_,_r,_.,.', 'R'], 'D')
# Sample (['._,,..._,,,_,,._', '....,_,,.wu__,__', '.._dr._,,.,,._._', 'V'], 'R') | Prediction ([',.._,.___.,.__,.', '.,.,,_..,_.uw..,', ',._..,.,__dr._,,', 'A'], 'R')
# Sample (['_,,.,..._,._.___', ',._wu.,.,,.__.,_', '__._,,_..r.,,,.,', 'R'], 'V') | Prediction ([',,__.,_,_.._._,_', ',_,,._.w,___.,_,', ',,,_,,r_,...,,,_', 'R'], 'V')

# %% [markdown]
# ## Top wrong predictions for best performing DeepSets V2 model

# %%
print_wrong_preds([get_wrong_predictions(best_deepsetv2_model, x_test_normal, y_test, test_original)])
# Out:
# 4 false Atomicity violation:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 print_wrong_preds([get_wrong_predictions(best_deepsetv2_model, x_test_normal, y_test, test_original)])
#
# File ~\TFGNuestro\src\evaluate.py:405, in print_wrong_preds(wrong_preds_list, k)
#     403 print(f'{min(k,len(i))} false {cases[a]}:')
#     404 for j in range(min(k,len(i))):
# --> 405     print(f"Sample {i[j][0]} | Prediction {i[j][1]}")
#     406 a+=1
#     407 print("\n")
#
# IndexError: list index out of range

# %% [markdown]
# ## Top wrong predictions for best performing Feedforward model

# %%
print_wrong_preds([get_wrong_predictions(best_feedforward_model, x_test_normal, y_test, test_original)])
# Out:
# 4 false Atomicity violation:
# Sample ([',,,,_,,__.,,___,', '.,,,,._uw,______', 'cr_...,_,..,,.,_', 'V'], 'A') | Prediction ([',,,,_,_.,._,.__,', '_.._...,_,,._.,,', '.__,,_,,__..__.,', 'V'], 'A')
# Sample ([',_.._.._,_._,...', ',,,_._._,,,_._,_', '.,,,,,__,,.._cr_', 'V'], 'D') | Prediction (['..,..,..,..____,', ',,,._,.,,,._,_,_', ',_._cr..,.,,.,,_', 'V'], 'D')
# Sample ([',,.,.,,.,_._.._,', '__,w_,,,_,,,_,_,', ',_.,_.__,,__.,.,', 'V'], 'R') | Prediction (['_._..,__.,_,,..,', ',._.,,._,._.___.', '.,,.....____,_._', 'V'], 'R')
# Sample (['_,,.,..._,._.___', ',._wu.,.,,.__.,_', '__._,,_..r.,,,.,', 'R'], 'V') | Prediction ([',,__.,_,_.._._,_', ',_,,._.w,___.,_,', ',,,_,,r_,...,,,_', 'R'], 'V')

# %% [markdown]
# # Saving Notebook State

# %%
import dill
# dill.dump_session('notebook_env_5per.db')

# %% [markdown]
# # Loading Notebook State

# %%
import dill
dill.load_session('notebook_env_5per.db')
