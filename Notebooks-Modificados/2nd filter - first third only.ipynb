# %%
from generate_data import Data
from evaluate import *
from models import *

import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# c:\Users\juand\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# %autosave 120
# Out:
# Autosaving every 120 seconds

# %% [markdown]
# # Get the synthetic dataset

# %%
# %%time
data = Data(layer_size=16, permutation_intervals=3)

# hack to get only third interval in train and all other intervals in test

train = data.samples[:400]
test = data.samples[1680:2583] + data.samples[-2*data.last_interval_size+52:]
data.samples = train+test
data.first_interval_size = 400
data.last_interval_size = len(data.samples) - data.first_interval_size
data.samples_char_sep = data.separate_string_chars(data.samples)
data.np_data = data.one_hot_encode(data.samples_char_sep)
num_experiments = 20
epochs = 200
early_stopping_limit = 100

experiment_name = "2nd_interval"
# Out:
# c:\Users\juand\anaconda3\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but OneHotEncoder was fitted without feature names
#   warnings.warn(
# Wall time: 1.14 s
# c:\Users\juand\anaconda3\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but OneHotEncoder was fitted without feature names
#   warnings.warn(

# %%
# %%time
train, val, test = data.get_splits(['1st_interval'], [])

train_unshuffled = train.copy()
np.random.shuffle(train)

x_train, y_train = data.get_x_y(train)
x_val, y_val = data.get_x_y(val)
x_test, y_test = data.get_x_y(test)

train_original = data.reverse_encoding(data.get_x_y(train_unshuffled)[0])
val_original = data.reverse_encoding(x_val)
test_original = data.reverse_encoding(x_test)
# Out:
# Number of samples: 400 train | 363 val | 1456 test
# Wall time: 152 ms

# %% [markdown]
# #### Peek at unshuffled train data

# %%
train_original[:20]
# Out:
# [[',..._.._,.___._.', 'w,,_,.,_,__.._.,', 'cr__,._,._,._,__', 'V'],
#  [',___._.,_.,,..,_', 'w_.,.,._,_._..,,', ',cr,__,,._._.,,_', 'V'],
#  [',_..,__......___', 'w__.____,_,..___', '.,cr_.__._.,..._', 'V'],
#  ['_.,,.,....,__._,', 'w,.,.,.___,_,_,_', '.._cr_.___.,,,.,', 'V'],
#  [',.._.._,_...,.,_', 'w.__,,_,,_,__..,', '..,_cr_.,.,_.___', 'V'],
#  [',,.._.....,,,,,_', '_w,.._.,...,_.,_', 'cr...__..,__,_..', 'V'],
#  ['__....,,,._..,,.', '.w._.,.,__.,.__.', '.cr_..,_.,_,__.,', 'V'],
#  [',,,__..__.____,.', '_w__,_._,,.__,,.', '..cr.__,..,,__,.', 'V'],
#  ['..,._,.__.,__,,_', ',w,_,..__,_,_,..', '_,.cr_,__.._,___', 'V'],
#  [',.,.,,__,,._.,__', ',w,,_,.__..__,,,', '_,_,cr.,._____.,', 'V'],
#  [',__._,_.___._.,_', '..w.._,__.__.___', 'cr,,,,,__..._,,.', 'V'],
#  ['__,,._,..,,,._,_', '_.w___,.,,,.,,._', '_cr_..__.,.,,._.', 'V'],
#  ['_,,,,,._.,..,___', '.,w_.,_,__,.,__,', '.,cr..,.__...,..', 'V'],
#  [',,_._,._,.,....,', '..w,,,_____.,.._', '.,_cr,_,_._,,,..', 'V'],
#  ['.,....__,___,,_,', '_.w.,,,_._..,_._', '_,_.cr.,.,...___', 'V'],
#  ['.._...._,,_,_.,,', '._,w,....,._,.__', 'cr,_,.__.._,_,..', 'V'],
#  ['_.,,____._.,_,._', ',._w...._.,,_,_.', '_cr____,._.,,,_.', 'V'],
#  [',,,__,,____..__,', '__.w_,.,,_,_,_,_', ',.cr,,_..,___,_.', 'V'],
#  [',___,.,_.,.._,..', ',_.w..,..,._._.,', ',,,cr_,._.,_,__.', 'V'],
#  ['__,..._,,.,,.__,', ',_,w,,,._.___.,,', '__.,cr._...,_,.,', 'V']]

# %%
pos_train_ratio = get_stats_and_ratio(train_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 25 | F2-uw 25 | F2-w 25 | F2-noop 25 |
# F3 cr:    F2-wu 25 | F2-uw 25 | F2-w 25 | F2-noop 25 |
# F3 r:    F2-wu 25 | F2-uw 25 | F2-w 25 | F2-noop 25 |
# F3 noop:    F2-wu 25 | F2-uw 25 | F2-w 25 | F2-noop 25 |
#
# Positive samples count: 175
# Total samples count: 400
# Positive class ratio: 0.4375

# %% [markdown]
# #### Peek at test data

# %%
test_original[:15]
# Out:
# [['.._...,._,_____,', '_._.__,_.,.,,uw.', '.,__.._dr_._,,,.', 'A'],
#  [',_,._,__,,_,_,.,', '_,._._..,w.,_,.,', '.,..____,_.__.,,', 'V'],
#  ['._.,,,,..,_..,__', '._,_.._,_.,,_.__', ',__,,_,,_,._.cr,', 'V'],
#  ['.,.,___.._,.,_.,', '._...,,__..w._..', '__._...,_.dr,__.', 'D'],
#  [',,,....______.._', '_,,._.___,.._uw,', '...._,,,,.___._.', 'V'],
#  [',.__,_,.,.,__._,', ',.,_.,_.,_.,...,', '.__..,_,,_cr_.,.', 'V'],
#  ['._,_.,._,_,.__._', '_,,,..wu,,_.,.,.', '_.___,,._,__r,..', 'R'],
#  ['._._,,,,___,._,.', '_..__w.,._.,_,,.', '.,,,.._r,,,_.._,', 'R'],
#  [',__,.._,,,_,.,,,', ',,,,_,.._wu.__._', '.,.,,___dr,_..,.', 'V'],
#  ['__._,__..,,.____', '._.,____._,..w_,', ',_,_,_,__.,,,,._', 'V'],
#  [',__,,...,..___.,', ',._.._,_____w__,', '___,.r,,._...,_,', 'R'],
#  [',.,__..,,.._,_.,', '._,,_,___.uw,.,,', '._.,_..__cr.,.,,', 'V'],
#  ['.,._.._..,,.._..', '__.__,.,.,_._,.,', ',__,,.__r._,.,__', 'R'],
#  [',_,__,._..,__.,.', '._,.._,___.w,,.,', '__.,__,.r..,_,_.', 'R'],
#  ['.._.,_,_._,._.__', '_,.,____._wu,,.,', '__.._.,_.._,.,..', 'V']]

# %%
pos_test_ratio = get_stats_and_ratio(test_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 73 | F2-uw 85 | F2-w 88 | F2-noop 97 |
# F3 cr:    F2-wu 74 | F2-uw 84 | F2-w 70 | F2-noop 90 |
# F3 r:    F2-wu 87 | F2-uw 86 | F2-w 103 | F2-noop 103 |
# F3 noop:    F2-wu 94 | F2-uw 99 | F2-w 102 | F2-noop 121 |
#
# Positive samples count: 649
# Total samples count: 1456
# Positive class ratio: 0.44574175824175827

# %% [markdown]
# #### Peek at val data

# %%
val_original[:15]
# Out:
# [['.,_..,_,,,,,,___', ',.,.,.,,_,__,___', '.,..,..._cr.,_,,', 'V'],
#  ['..___.,,.___,_._', '_..,..,wu.,,.__.', '__,___.,.,_,.._.', 'V'],
#  ['_,_._,..,.,,_.,.', ',_,,,._,.._..,._', '_,__.,,_,_cr_,.,', 'V'],
#  ['_.._.,__........', ',..,__.,.._..w._', '.,_._.,_.._,dr._', 'D'],
#  ['...,,,,,,,__._,,', ',._,,.,__.___.wu', '.__....,__r,_,__', 'R'],
#  [',,,_,.._,___..._', ',..,_,,._,.__.._', '___,_,.,r,__.__,', 'R'],
#  [',,__,,,_.,._..,,', '_,.,_,,_,,_._,.,', ',_.,,.,,,cr.,,,_', 'V'],
#  ['._,._..,__,__.__', ',.,._uw,_.....,_', '.,.,__..._cr_.,.', 'V'],
#  [',___.,.._,._,.__', '.._.,wu_.__,__.,', '._.,._.,__,.,_,,', 'V'],
#  [',_,__,_,._._._..', ',_,.._.__.,__wu_', ',._,._,,r____._,', 'R'],
#  ['_...__,..,_,.___', '___,,._,w__,.__.', ',___,,_,,,_.,.cr', 'V'],
#  ['.,....,,_._,._..', ',__.,_,,uw_,,,_,', '._.,,___._,r._,.', 'R'],
#  ['.._,_.._,,,,.,..', '__.__.,,,w,,_.,_', '____.,_.__cr,._.', 'V'],
#  ['.,.__.._.,,_,.,,', ',___.,,_,,.,,__,', '.._,,,.,_,,.dr,.', 'D'],
#  ['.....,..,,._.._.', '__.,.__.,.,,,wu_', '_._,__,.,,,,____', 'V']]

# %%
pos_val_ratio = get_stats_and_ratio(val_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 27 | F2-uw 15 | F2-w 22 | F2-noop 23 |
# F3 cr:    F2-wu 26 | F2-uw 16 | F2-w 10 | F2-noop 30 |
# F3 r:    F2-wu 23 | F2-uw 24 | F2-w 18 | F2-noop 29 |
# F3 noop:    F2-wu 26 | F2-uw 21 | F2-w 30 | F2-noop 23 |
#
# Positive samples count: 154
# Total samples count: 363
# Positive class ratio: 0.42424242424242425

# %% [markdown]
# #### Send label arrays to device

# %%
from sklearn.preprocessing import LabelEncoder

# Codificar etiquetas categóricas a índices numéricos
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_val = label_encoder.transform(y_val)
y_test = label_encoder.transform(y_test)

# Convertir a tensores de PyTorch
y_train = torch.tensor(y_train, dtype=torch.long).to(device)
y_val = torch.tensor(y_val, dtype=torch.long).to(device)
y_test = torch.tensor(y_test, dtype=torch.long).to(device)

# Verificar clases codificadas
print("Clases codificadas:", label_encoder.classes_)
# Out:
# Clases codificadas: ['A' 'D' 'R' 'V']

# %% [markdown]
# #### Get data in normal format (same as CNN format)

# %%
x_train_normal = data.to_conv_format(x_train)
x_val_normal = data.to_conv_format(x_val)
x_test_normal = data.to_conv_format(x_test)
for i in range(len(x_train_normal)):
    x_train_normal[i] = x_train_normal[i].to(device)
    x_val_normal[i] = x_val_normal[i].to(device)
    x_test_normal[i] = x_test_normal[i].to(device)

# %%
x_train_normal[0].shape
# Out:
# torch.Size([400, 128])

# %% [markdown]
# #### Get data in convolutional format, send to device

# %%
x_train_cnn = data.to_conv_format(x_train)
x_val_cnn = data.to_conv_format(x_val)
x_test_cnn = data.to_conv_format(x_test)
for i in range(len(x_train_cnn)):
    x_train_cnn[i] = x_train_cnn[i].to(device)
    x_val_cnn[i] = x_val_cnn[i].to(device)
    x_test_cnn[i] = x_test_cnn[i].to(device)

# %%
x_train_cnn[0].shape
# Out:
# torch.Size([400, 128])

# %% [markdown]
# #### Get data in LSTM format, send to device

# %%
x_train_lstm = data.to_lstm_format(x_train, padding_left_size=2, padding_right_size=0)
x_val_lstm = data.to_lstm_format(x_val, padding_left_size=0, padding_right_size=2)
x_test_lstm = data.to_lstm_format(x_test, padding_left_size=0, padding_right_size=2)
for i in range(len(x_train_lstm)):
    x_train_lstm[i] = x_train_lstm[i].to(device)
    x_val_lstm[i] = x_val_lstm[i].to(device)
    x_test_lstm[i] = x_test_lstm[i].to(device)

# %%
x_train_lstm[0].shape
# Out:
# torch.Size([400, 18, 8])

# %% [markdown]
# ### Define training procedure for each model

# %%
def train_models(constructor, x_train, x_val, x_test, weight_decay, *argv):
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    wrong_preds = []
    best_accuracy = 0
    
    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []

    for i in range(num_experiments):
        model = constructor(*argv)
        model.to(device)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), weight_decay=weight_decay)

        train_losses.append([])
        val_losses.append([])
        train_accs.append([])
        val_accs.append([])
        
        best_acc = 0

        early_stopping_cnt = 0

        for epoch in range(1, epochs + 1):
            train_loss, train_acc = train_epoch(model, x_train, y_train, criterion, optimizer, epoch, 10, verbose=False)
            val_loss, val_acc = eval_epoch(model, x_val, y_val, criterion, 'Validation', verbose=False)

            
            train_losses[-1].append(train_loss)
            val_losses[-1].append(val_loss)
            train_accs[-1].append(train_acc)
            val_accs[-1].append(val_acc)
            
            model_name = constructor.__name__[:constructor.__name__.find('_')]
            if val_acc > best_acc:
                best_acc = val_acc
                torch.save(model.state_dict(), f'./temp/{model_name}_model_TEMP_' + experiment_name)    
                early_stopping_cnt = 0
            else:
                early_stopping_cnt += 1

            if early_stopping_cnt >= early_stopping_limit:
                break


        model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
        
        accuracies.append(get_accuracy_by_cases(model, x_test, y_test, test_original))
        precisions.append(get_precision(model, x_test, y_test, test_original))
        recalls.append(get_recall(model, x_test, y_test, test_original))
        f1_scores.append(get_f1(precisions[-1], recalls[-1]))
        
        wrong_preds.append((f"Experimento {i}", get_wrong_predictions(model, x_test, y_test, test_original)))

        if accuracies[-1]['Overall'] > best_accuracy:
            torch.save(model.state_dict(), f'./bestmodels/best_{model_name}_model_' + experiment_name)    
            best_accuracy = accuracies[-1]['Overall']

        print(i + 1, "/", num_experiments, "models trained | Current model test accuracy:", accuracies[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test precision:", precisions[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test recall:", recalls[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test f1:", f1_scores[-1]['Overall'])


    
    return accuracies, precisions, recalls, f1_scores, wrong_preds, [train_losses, val_losses, train_accs, val_accs], model
    #return accuracies, precisions, wrong_preds, [train_losses, val_losses, train_accs, val_accs]

# %% [markdown]
# # Train models

# %%
# %%time
cnn_accuracies, cnn_precisions, cnn_recall, cnn_f1, cnn_wrong_preds, cnn_epoch_stats, model = train_models(
    CNN_Model, x_train_cnn, x_val_cnn, x_test_cnn, 0.0001, data, 64, 128, 4, -1, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_22740\2177076457.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.9910714285714286
# 1 / 20 models trained | Current model test precision: 0.9960365853658537
# 1 / 20 models trained | Current model test recall: 0.9845801645196337
# 1 / 20 models trained | Current model test f1: 0.9902752414305149
# 2 / 20 models trained | Current model test accuracy: 0.9979395604395604
# 2 / 20 models trained | Current model test precision: 0.9990740740740741
# 2 / 20 models trained | Current model test recall: 0.9911764705882353
# 2 / 20 models trained | Current model test f1: 0.9951096029117976
# 3 / 20 models trained | Current model test accuracy: 0.9560439560439561
# 3 / 20 models trained | Current model test precision: 0.964966832504146
# 3 / 20 models trained | Current model test recall: 0.9122358244089193
# 3 / 20 models trained | Current model test f1: 0.9378607160339743
# 4 / 20 models trained | Current model test accuracy: 0.9629120879120879
# 4 / 20 models trained | Current model test precision: 0.9759738658777121
# 4 / 20 models trained | Current model test recall: 0.9416475891148016
# 4 / 20 models trained | Current model test f1: 0.9585034996872082
# 5 / 20 models trained | Current model test accuracy: 0.9574175824175825
# 5 / 20 models trained | Current model test precision: 0.965526337506779
# 5 / 20 models trained | Current model test recall: 0.9181181773500957
# 5 / 20 models trained | Current model test f1: 0.9412256656533664
# 6 / 20 models trained | Current model test accuracy: 0.9766483516483516
# 6 / 20 models trained | Current model test precision: 0.9898929845422116
# 6 / 20 models trained | Current model test recall: 0.971744528946143
# 6 / 20 models trained | Current model test f1: 0.9807348048319974
# 7 / 20 models trained | Current model test accuracy: 0.9910714285714286
# 7 / 20 models trained | Current model test precision: 0.9921212589772537
# 7 / 20 models trained | Current model test recall: 0.9751189825596658
# 7 / 20 models trained | Current model test f1: 0.9835466479415838
# 8 / 20 models trained | Current model test accuracy: 0.9642857142857143
# 8 / 20 models trained | Current model test precision: 0.9764250483860897
# 8 / 20 models trained | Current model test recall: 0.9533026458743475
# 8 / 20 models trained | Current model test f1: 0.9647253183887009
# 9 / 20 models trained | Current model test accuracy: 0.9560439560439561
# 9 / 20 models trained | Current model test precision: 0.981630309988519
# 9 / 20 models trained | Current model test recall: 0.94912307931088
# 9 / 20 models trained | Current model test f1: 0.965103039802792
# 10 / 20 models trained | Current model test accuracy: 0.9917582417582418
# 10 / 20 models trained | Current model test precision: 0.9847290616425219
# 10 / 20 models trained | Current model test recall: 0.9788082107843137
# 10 / 20 models trained | Current model test f1: 0.9817597093457241
# 11 / 20 models trained | Current model test accuracy: 0.9635989010989011
# 11 / 20 models trained | Current model test precision: 0.9771960930695534
# 11 / 20 models trained | Current model test recall: 0.945794905936267
# 11 / 20 models trained | Current model test f1: 0.961239119063821
# 12 / 20 models trained | Current model test accuracy: 0.9773351648351648
# 12 / 20 models trained | Current model test precision: 0.9670013303400682
# 12 / 20 models trained | Current model test recall: 0.9300995024875622
# 12 / 20 models trained | Current model test f1: 0.9481915148532624
# 13 / 20 models trained | Current model test accuracy: 0.9725274725274725
# 13 / 20 models trained | Current model test precision: 0.9881936245572609
# 13 / 20 models trained | Current model test recall: 0.9667701381344095
# 13 / 20 models trained | Current model test f1: 0.9773644966200236
# 14 / 20 models trained | Current model test accuracy: 0.9835164835164835
# 14 / 20 models trained | Current model test precision: 0.9916978122301541
# 14 / 20 models trained | Current model test recall: 0.9785966300530333
# 14 / 20 models trained | Current model test f1: 0.9851036639526897
# 15 / 20 models trained | Current model test accuracy: 0.9656593406593407
# 15 / 20 models trained | Current model test precision: 0.9781333407473309
# 15 / 20 models trained | Current model test recall: 0.9488320253893114
# 15 / 20 models trained | Current model test f1: 0.9632599060800063
# 16 / 20 models trained | Current model test accuracy: 0.9718406593406593
# 16 / 20 models trained | Current model test precision: 0.9879127358490566
# 16 / 20 models trained | Current model test recall: 0.9638289616638211
# 16 / 20 models trained | Current model test f1: 0.9757222563018777
# 17 / 20 models trained | Current model test accuracy: 0.9745879120879121
# 17 / 20 models trained | Current model test precision: 0.9890402843601895
# 17 / 20 models trained | Current model test recall: 0.9755936675461742
# 17 / 20 models trained | Current model test f1: 0.9822709593648074
# 18 / 20 models trained | Current model test accuracy: 0.9622252747252747
# 18 / 20 models trained | Current model test precision: 0.9667679190138355
# 18 / 20 models trained | Current model test recall: 0.9358192085397736
# 18 / 20 models trained | Current model test f1: 0.9510418479247061
# 19 / 20 models trained | Current model test accuracy: 0.9491758241758241
# 19 / 20 models trained | Current model test precision: 0.9765169047249567
# 19 / 20 models trained | Current model test recall: 0.9431690004380701
# 19 / 20 models trained | Current model test f1: 0.9595533003219078
# 20 / 20 models trained | Current model test accuracy: 0.970467032967033
# 20 / 20 models trained | Current model test precision: 0.9862738385067965
# 20 / 20 models trained | Current model test recall: 0.9595436991717275
# 20 / 20 models trained | Current model test f1: 0.972725169828811
# CPU times: total: 2h 42min 4s
# Wall time: 1h 19min 54s

# %%
# %%time
lstm_accuracies, lstm_precision, lstm_recall, lstm_f1, lstm_wrong_preds, lstm_epoch_stats, model = train_models(LSTM_Model, x_train_lstm, x_val_lstm, x_test_lstm, 0.0001, data, 16, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_22740\2177076457.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.7616758241758241
# 1 / 20 models trained | Current model test precision: 0.7285746732779217
# 1 / 20 models trained | Current model test recall: 0.6654844275282641
# 1 / 20 models trained | Current model test f1: 0.6956019283222032
# 2 / 20 models trained | Current model test accuracy: 0.9024725274725275
# 2 / 20 models trained | Current model test precision: 0.8134625179381587
# 2 / 20 models trained | Current model test recall: 0.760114879422143
# 2 / 20 models trained | Current model test f1: 0.7858843991712706
# 3 / 20 models trained | Current model test accuracy: 0.7156593406593407
# 3 / 20 models trained | Current model test precision: 0.5170798940761261
# 3 / 20 models trained | Current model test recall: 0.5894812903291634
# 3 / 20 models trained | Current model test f1: 0.5509120100341828
# 4 / 20 models trained | Current model test accuracy: 0.676510989010989
# 4 / 20 models trained | Current model test precision: 0.6612176825433589
# 4 / 20 models trained | Current model test recall: 0.565945798474271
# 4 / 20 models trained | Current model test f1: 0.6098834834980429
# 5 / 20 models trained | Current model test accuracy: 0.8468406593406593
# 5 / 20 models trained | Current model test precision: 0.7752418673684056
# 5 / 20 models trained | Current model test recall: 0.6957413721459547
# 5 / 20 models trained | Current model test f1: 0.7333432850342428
# 6 / 20 models trained | Current model test accuracy: 0.7431318681318682
# 6 / 20 models trained | Current model test precision: 0.7084219101293858
# 6 / 20 models trained | Current model test recall: 0.6197877347634821
# 6 / 20 models trained | Current model test f1: 0.6611474515701566
# 7 / 20 models trained | Current model test accuracy: 0.9189560439560439
# 7 / 20 models trained | Current model test precision: 0.8521276041214185
# 7 / 20 models trained | Current model test recall: 0.817349511039617
# 7 / 20 models trained | Current model test f1: 0.8343763136936676
# 8 / 20 models trained | Current model test accuracy: 0.7781593406593407
# 8 / 20 models trained | Current model test precision: 0.7170800329325788
# 8 / 20 models trained | Current model test recall: 0.6364843980004453
# 8 / 20 models trained | Current model test f1: 0.6743827521599755
# 9 / 20 models trained | Current model test accuracy: 0.7809065934065934
# 9 / 20 models trained | Current model test precision: 0.6943920268690428
# 9 / 20 models trained | Current model test recall: 0.6400393557100992
# 9 / 20 models trained | Current model test f1: 0.6661087730543288
# 10 / 20 models trained | Current model test accuracy: 0.7699175824175825
# 10 / 20 models trained | Current model test precision: 0.6914055773325671
# 10 / 20 models trained | Current model test recall: 0.6215554571108401
# 10 / 20 models trained | Current model test f1: 0.6546224882448354
# 11 / 20 models trained | Current model test accuracy: 0.7843406593406593
# 11 / 20 models trained | Current model test precision: 0.7357346686911366
# 11 / 20 models trained | Current model test recall: 0.690961461548526
# 11 / 20 models trained | Current model test f1: 0.7126455188539007
# 12 / 20 models trained | Current model test accuracy: 0.7087912087912088
# 12 / 20 models trained | Current model test precision: 0.6814903638926009
# 12 / 20 models trained | Current model test recall: 0.6161151284081922
# 12 / 20 models trained | Current model test f1: 0.6471558968421898
# 13 / 20 models trained | Current model test accuracy: 0.8228021978021978
# 13 / 20 models trained | Current model test precision: 0.7964305526050178
# 13 / 20 models trained | Current model test recall: 0.7424080666988471
# 13 / 20 models trained | Current model test f1: 0.768471052652507
# 14 / 20 models trained | Current model test accuracy: 0.6572802197802198
# 14 / 20 models trained | Current model test precision: 0.6809947148969167
# 14 / 20 models trained | Current model test recall: 0.5820023209919567
# 14 / 20 models trained | Current model test f1: 0.6276190575131863
# 15 / 20 models trained | Current model test accuracy: 0.7925824175824175
# 15 / 20 models trained | Current model test precision: 0.6975527604204075
# 15 / 20 models trained | Current model test recall: 0.6043596484440171
# 15 / 20 models trained | Current model test f1: 0.6476207434362535
# 16 / 20 models trained | Current model test accuracy: 0.7891483516483516
# 16 / 20 models trained | Current model test precision: 0.7203225688921255
# 16 / 20 models trained | Current model test recall: 0.6141336530915885
# 16 / 20 models trained | Current model test f1: 0.6630031369338354
# 17 / 20 models trained | Current model test accuracy: 0.760989010989011
# 17 / 20 models trained | Current model test precision: 0.7221550238251385
# 17 / 20 models trained | Current model test recall: 0.6925544965261543
# 17 / 20 models trained | Current model test f1: 0.7070450884007083
# 18 / 20 models trained | Current model test accuracy: 0.7671703296703297
# 18 / 20 models trained | Current model test precision: 0.5291213403169487
# 18 / 20 models trained | Current model test recall: 0.5878536512055222
# 18 / 20 models trained | Current model test f1: 0.5569433768827947
# 19 / 20 models trained | Current model test accuracy: 0.7383241758241759
# 19 / 20 models trained | Current model test precision: 0.49835933053528025
# 19 / 20 models trained | Current model test recall: 0.5695967239187556
# 19 / 20 models trained | Current model test f1: 0.5316021025834397
# 20 / 20 models trained | Current model test accuracy: 0.7747252747252747
# 20 / 20 models trained | Current model test precision: 0.7563137690589713
# 20 / 20 models trained | Current model test recall: 0.7869687975826912
# 20 / 20 models trained | Current model test f1: 0.7713368248910846
# CPU times: total: 1h 6min 30s
# Wall time: 32min 3s

# %%
# %%time
deepset_accuracies, deepset_procision, deepset_recall, deepset_f1, deepset_wrong_preds, deepset_epoch_stats, model = train_models(DEEPSET_Model, x_train_normal, x_val_normal, x_test_normal, 0.005, data, 128, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_22740\2177076457.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.5418956043956044
# 1 / 20 models trained | Current model test precision: 0.26236224036079525
# 1 / 20 models trained | Current model test recall: 0.2891356399858998
# 1 / 20 models trained | Current model test f1: 0.2750990601347924
# 2 / 20 models trained | Current model test accuracy: 0.5446428571428571
# 2 / 20 models trained | Current model test precision: 0.20504558738367473
# 2 / 20 models trained | Current model test recall: 0.2508845694329565
# 2 / 20 models trained | Current model test f1: 0.22566076464018792
# 3 / 20 models trained | Current model test accuracy: 0.5322802197802198
# 3 / 20 models trained | Current model test precision: 0.3094660702139905
# 3 / 20 models trained | Current model test recall: 0.36934757380854033
# 3 / 20 models trained | Current model test f1: 0.3367656004445514
# 4 / 20 models trained | Current model test accuracy: 0.5528846153846154
# 4 / 20 models trained | Current model test precision: 0.19429086999923212
# 4 / 20 models trained | Current model test recall: 0.2500801038407339
# 4 / 20 models trained | Current model test f1: 0.21868341455719334
# 5 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 5 / 20 models trained | Current model test precision: 0.13856456043956045
# 5 / 20 models trained | Current model test recall: 0.25
# 5 / 20 models trained | Current model test f1: 0.17830313742819268
# 6 / 20 models trained | Current model test accuracy: 0.540521978021978
# 6 / 20 models trained | Current model test precision: 0.19634879505769426
# 6 / 20 models trained | Current model test recall: 0.24837483527074605
# 6 / 20 models trained | Current model test f1: 0.21931867929773707
# 7 / 20 models trained | Current model test accuracy: 0.551510989010989
# 7 / 20 models trained | Current model test precision: 0.27767023153923387
# 7 / 20 models trained | Current model test recall: 0.3134367832001898
# 7 / 20 models trained | Current model test f1: 0.29447143070185183
# 8 / 20 models trained | Current model test accuracy: 0.5501373626373627
# 8 / 20 models trained | Current model test precision: 0.17423717059639388
# 8 / 20 models trained | Current model test recall: 0.24884094646774757
# 8 / 20 models trained | Current model test f1: 0.20496140401653432
# 9 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 9 / 20 models trained | Current model test precision: 0.2523906888958792
# 9 / 20 models trained | Current model test recall: 0.25174920631806785
# 9 / 20 models trained | Current model test f1: 0.25206953948623007
# 10 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 10 / 20 models trained | Current model test precision: 0.13856456043956045
# 10 / 20 models trained | Current model test recall: 0.25
# 10 / 20 models trained | Current model test f1: 0.17830313742819268
# 11 / 20 models trained | Current model test accuracy: 0.5535714285714286
# 11 / 20 models trained | Current model test precision: 0.18869745003445898
# 11 / 20 models trained | Current model test recall: 0.250040051920367
# 11 / 20 models trained | Current model test f1: 0.2150804068201811
# 12 / 20 models trained | Current model test accuracy: 0.5590659340659341
# 12 / 20 models trained | Current model test precision: 0.3145228215767635
# 12 / 20 models trained | Current model test recall: 0.2546174142480211
# 12 / 20 models trained | Current model test f1: 0.28141741704770823
# 13 / 20 models trained | Current model test accuracy: 0.5487637362637363
# 13 / 20 models trained | Current model test precision: 0.19176587301587303
# 13 / 20 models trained | Current model test recall: 0.24888239001142226
# 13 / 20 models trained | Current model test f1: 0.21662243019376656
# 14 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 14 / 20 models trained | Current model test precision: 0.2636019283746557
# 14 / 20 models trained | Current model test recall: 0.25069968252722713
# 14 / 20 models trained | Current model test f1: 0.2569889666151505
# 15 / 20 models trained | Current model test accuracy: 0.5446428571428571
# 15 / 20 models trained | Current model test precision: 0.21764069264069263
# 15 / 20 models trained | Current model test recall: 0.25335945699404616
# 15 / 20 models trained | Current model test f1: 0.23414569082415854
# 16 / 20 models trained | Current model test accuracy: 0.5508241758241759
# 16 / 20 models trained | Current model test precision: 0.16954419889502761
# 16 / 20 models trained | Current model test recall: 0.2488008945473806
# 16 / 20 models trained | Current model test f1: 0.20166484087715975
# 17 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 17 / 20 models trained | Current model test precision: 0.3888888888888889
# 17 / 20 models trained | Current model test recall: 0.25132978723404253
# 17 / 20 models trained | Current model test f1: 0.3053311793214863
# 18 / 20 models trained | Current model test accuracy: 0.551510989010989
# 18 / 20 models trained | Current model test precision: 0.20817879771287282
# 18 / 20 models trained | Current model test recall: 0.25051004894508144
# 18 / 20 models trained | Current model test f1: 0.2273911004566852
# 19 / 20 models trained | Current model test accuracy: 0.5521978021978022
# 19 / 20 models trained | Current model test precision: 0.13871635610766045
# 19 / 20 models trained | Current model test recall: 0.24907063197026022
# 19 / 20 models trained | Current model test f1: 0.17819148936170212
# 20 / 20 models trained | Current model test accuracy: 0.554945054945055
# 20 / 20 models trained | Current model test precision: 0.26375515818431916
# 20 / 20 models trained | Current model test recall: 0.25065963060686014
# 20 / 20 models trained | Current model test f1: 0.25704070707801174
# CPU times: total: 26min 49s
# Wall time: 12min 36s

# %%
# %%time
deepsetv2_accuracies, deepsetv2_procision, deepsetv2_recall, deepsetv2_f1, deepsetv2_wrong_preds, deepsetv2_epoch_stats, model = train_models(DEEPSETV2_Model, x_train_normal, x_val_normal, x_test_normal, 0.0001, data, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_22740\2177076457.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.5501373626373627
# 1 / 20 models trained | Current model test precision: 0.1578309078309078
# 1 / 20 models trained | Current model test recall: 0.24849110520413403
# 1 / 20 models trained | Current model test f1: 0.19304677307203505
# 2 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 2 / 20 models trained | Current model test precision: 0.13856456043956045
# 2 / 20 models trained | Current model test recall: 0.25
# 2 / 20 models trained | Current model test f1: 0.17830313742819268
# 3 / 20 models trained | Current model test accuracy: 0.5666208791208791
# 3 / 20 models trained | Current model test precision: 0.2806880218368658
# 3 / 20 models trained | Current model test recall: 0.2695698587229813
# 3 / 20 models trained | Current model test f1: 0.2750166169898862
# 4 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 4 / 20 models trained | Current model test precision: 0.13856456043956045
# 4 / 20 models trained | Current model test recall: 0.25
# 4 / 20 models trained | Current model test f1: 0.17830313742819268
# 5 / 20 models trained | Current model test accuracy: 0.5460164835164835
# 5 / 20 models trained | Current model test precision: 0.20297496084084357
# 5 / 20 models trained | Current model test recall: 0.2490812579899494
# 5 / 20 models trained | Current model test f1: 0.22367686354347835
# 6 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 6 / 20 models trained | Current model test precision: 0.29979514265969
# 6 / 20 models trained | Current model test recall: 0.377321597784095
# 6 / 20 models trained | Current model test f1: 0.3341201759747549
# 7 / 20 models trained | Current model test accuracy: 0.540521978021978
# 7 / 20 models trained | Current model test precision: 0.19497017490648064
# 7 / 20 models trained | Current model test recall: 0.2487285052910053
# 7 / 20 models trained | Current model test f1: 0.21859267266348556
# 8 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 8 / 20 models trained | Current model test precision: 0.13856456043956045
# 8 / 20 models trained | Current model test recall: 0.25
# 8 / 20 models trained | Current model test f1: 0.17830313742819268
# 9 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 9 / 20 models trained | Current model test precision: 0.13856456043956045
# 9 / 20 models trained | Current model test recall: 0.25
# 9 / 20 models trained | Current model test f1: 0.17830313742819268
# 10 / 20 models trained | Current model test accuracy: 0.5528846153846154
# 10 / 20 models trained | Current model test precision: 0.13850653819683414
# 10 / 20 models trained | Current model test recall: 0.24938042131350682
# 10 / 20 models trained | Current model test f1: 0.1780973451327434
# 11 / 20 models trained | Current model test accuracy: 0.5673076923076923
# 11 / 20 models trained | Current model test precision: 0.3903966597077244
# 11 / 20 models trained | Current model test recall: 0.262532981530343
# 11 / 20 models trained | Current model test f1: 0.31394500288947846
# 12 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 12 / 20 models trained | Current model test precision: 0.13856456043956045
# 12 / 20 models trained | Current model test recall: 0.25
# 12 / 20 models trained | Current model test f1: 0.17830313742819268
# 13 / 20 models trained | Current model test accuracy: 0.5666208791208791
# 13 / 20 models trained | Current model test precision: 0.34248251748251746
# 13 / 20 models trained | Current model test recall: 0.2629228747143235
# 13 / 20 models trained | Current model test f1: 0.29747501160883094
# 14 / 20 models trained | Current model test accuracy: 0.5762362637362637
# 14 / 20 models trained | Current model test precision: 0.38434888723421856
# 14 / 20 models trained | Current model test recall: 0.2714580206831386
# 14 / 20 models trained | Current model test f1: 0.31818691422968587
# 15 / 20 models trained | Current model test accuracy: 0.05837912087912088
# 15 / 20 models trained | Current model test precision: 0.01459478021978022
# 15 / 20 models trained | Current model test recall: 0.25
# 15 / 20 models trained | Current model test f1: 0.027579493835171966
# 16 / 20 models trained | Current model test accuracy: 0.554945054945055
# 16 / 20 models trained | Current model test precision: 0.2503077870113881
# 16 / 20 models trained | Current model test recall: 0.2517302064383453
# 16 / 20 models trained | Current model test f1: 0.25101698166121356
# 17 / 20 models trained | Current model test accuracy: 0.5604395604395604
# 17 / 20 models trained | Current model test precision: 0.2737344794651385
# 17 / 20 models trained | Current model test recall: 0.26398302452485345
# 17 / 20 models trained | Current model test f1: 0.26877033114878324
# 18 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 18 / 20 models trained | Current model test precision: 0.13856456043956045
# 18 / 20 models trained | Current model test recall: 0.25
# 18 / 20 models trained | Current model test f1: 0.17830313742819268
# 19 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 19 / 20 models trained | Current model test precision: 0.13856456043956045
# 19 / 20 models trained | Current model test recall: 0.25
# 19 / 20 models trained | Current model test f1: 0.17830313742819268
# 20 / 20 models trained | Current model test accuracy: 0.5556318681318682
# 20 / 20 models trained | Current model test precision: 0.2722993291695582
# 20 / 20 models trained | Current model test recall: 0.2534183087954017
# 20 / 20 models trained | Current model test f1: 0.26251976536831045
# CPU times: total: 18min 8s
# Wall time: 54min 33s

# %%
# %%time
feedforward_accuracies, feedforward_precision, feedforward_recall, feedforward_f1, feedforward_wrong_preds, feedforward_epoch_stats, model = train_models(FEEDFORWARD_Model, x_train_normal, x_val_normal, x_test_normal, 0.0001, data, 128, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_22740\2177076457.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 1 / 20 models trained | Current model test precision: 0.13856456043956045
# 1 / 20 models trained | Current model test recall: 0.25
# 1 / 20 models trained | Current model test f1: 0.17830313742819268
# 2 / 20 models trained | Current model test accuracy: 0.5350274725274725
# 2 / 20 models trained | Current model test precision: 0.20721940622737148
# 2 / 20 models trained | Current model test recall: 0.2486725649249803
# 2 / 20 models trained | Current model test f1: 0.22606136764611487
# 3 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 3 / 20 models trained | Current model test precision: 0.13856456043956045
# 3 / 20 models trained | Current model test recall: 0.25
# 3 / 20 models trained | Current model test f1: 0.17830313742819268
# 4 / 20 models trained | Current model test accuracy: 0.5480769230769231
# 4 / 20 models trained | Current model test precision: 0.1935568820224719
# 4 / 20 models trained | Current model test recall: 0.24966078475607564
# 4 / 20 models trained | Current model test f1: 0.21805792811419772
# 5 / 20 models trained | Current model test accuracy: 0.5123626373626373
# 5 / 20 models trained | Current model test precision: 0.18733042154721727
# 5 / 20 models trained | Current model test recall: 0.2417772249861802
# 5 / 20 models trained | Current model test f1: 0.21109961494779575
# 6 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 6 / 20 models trained | Current model test precision: 0.13856456043956045
# 6 / 20 models trained | Current model test recall: 0.25
# 6 / 20 models trained | Current model test f1: 0.17830313742819268
# 7 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 7 / 20 models trained | Current model test precision: 0.13856456043956045
# 7 / 20 models trained | Current model test recall: 0.25
# 7 / 20 models trained | Current model test f1: 0.17830313742819268
# 8 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 8 / 20 models trained | Current model test precision: 0.13856456043956045
# 8 / 20 models trained | Current model test recall: 0.25
# 8 / 20 models trained | Current model test f1: 0.17830313742819268
# 9 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 9 / 20 models trained | Current model test precision: 0.13856456043956045
# 9 / 20 models trained | Current model test recall: 0.25
# 9 / 20 models trained | Current model test f1: 0.17830313742819268
# 10 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 10 / 20 models trained | Current model test precision: 0.13856456043956045
# 10 / 20 models trained | Current model test recall: 0.25
# 10 / 20 models trained | Current model test f1: 0.17830313742819268
# 11 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 11 / 20 models trained | Current model test precision: 0.13856456043956045
# 11 / 20 models trained | Current model test recall: 0.25
# 11 / 20 models trained | Current model test f1: 0.17830313742819268
# 12 / 20 models trained | Current model test accuracy: 0.5199175824175825
# 12 / 20 models trained | Current model test precision: 0.1996580547112462
# 12 / 20 models trained | Current model test recall: 0.24675497706414518
# 12 / 20 models trained | Current model test f1: 0.2207221349027886
# 13 / 20 models trained | Current model test accuracy: 0.5432692307692307
# 13 / 20 models trained | Current model test precision: 0.1950972186453773
# 13 / 20 models trained | Current model test recall: 0.2485417831441902
# 13 / 20 models trained | Current model test f1: 0.2186003052616836
# 14 / 20 models trained | Current model test accuracy: 0.5425824175824175
# 14 / 20 models trained | Current model test precision: 0.18319172043697696
# 14 / 20 models trained | Current model test recall: 0.2468326287464893
# 14 / 20 models trained | Current model test f1: 0.21030294682573542
# 15 / 20 models trained | Current model test accuracy: 0.5226648351648352
# 15 / 20 models trained | Current model test precision: 0.21537973982499106
# 15 / 20 models trained | Current model test recall: 0.25639032476385715
# 15 / 20 models trained | Current model test f1: 0.23410252403110973
# 16 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 16 / 20 models trained | Current model test precision: 0.13856456043956045
# 16 / 20 models trained | Current model test recall: 0.25
# 16 / 20 models trained | Current model test f1: 0.17830313742819268
# 17 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 17 / 20 models trained | Current model test precision: 0.13856456043956045
# 17 / 20 models trained | Current model test recall: 0.25
# 17 / 20 models trained | Current model test f1: 0.17830313742819268
# 18 / 20 models trained | Current model test accuracy: 0.5528846153846154
# 18 / 20 models trained | Current model test precision: 0.2804209919261822
# 18 / 20 models trained | Current model test recall: 0.29267808548630464
# 18 / 20 models trained | Current model test f1: 0.2864184650852389
# 19 / 20 models trained | Current model test accuracy: 0.5391483516483516
# 19 / 20 models trained | Current model test precision: 0.2159905694150378
# 19 / 20 models trained | Current model test recall: 0.2519571261340357
# 19 / 20 models trained | Current model test f1: 0.23259164927828918
# 20 / 20 models trained | Current model test accuracy: 0.5364010989010989
# 20 / 20 models trained | Current model test precision: 0.18660714285714286
# 20 / 20 models trained | Current model test recall: 0.24579373097533783
# 20 / 20 models trained | Current model test f1: 0.21214973717779576
# CPU times: total: 23min 14s
# Wall time: 11min 43s

# %% [markdown]
# # Evaluation

# %% [markdown]
# # Evaluacion general de los modelos

# %%
import pandas as pd
# Lista de modelos y nombres
model_names = ['CNN', 'LSTM', 'DeepSet', 'DeepSetV2', 'Feedforward']
all_accuracies = [cnn_accuracies, lstm_accuracies, deepset_accuracies, deepsetv2_accuracies, feedforward_accuracies]
all_precisions = [cnn_precisions, lstm_precision, deepset_procision, deepsetv2_procision, feedforward_precision]
all_recalls = [cnn_recall, lstm_recall, deepset_recall, deepsetv2_recall, feedforward_recall]
all_f1_scores = [cnn_f1, lstm_f1, deepset_f1, deepsetv2_f1, feedforward_f1]

get_summary_df(model_names, all_accuracies, all_precisions, all_recalls, all_f1_scores)
# Out:
#         Modelo  Accuracy  Precision    Recall  F1-score  Precision clase A
# 0          CNN  0.997940   0.999074  0.991176  0.995110           1.000000  \
# 1         LSTM  0.918956   0.852128  0.817350  0.834376           0.507463
# 2      DeepSet  0.559066   0.314523  0.254617  0.281417           0.000000
# 3    DeepSetV2  0.576236   0.384349  0.271458  0.318187           0.000000
# 4  Feedforward  0.554258   0.138565  0.250000  0.178303           0.000000
#
#    Recall clase A  Precision clase D  Recall clase D  Precision clase R
# 0        0.964706                1.0             1.0           1.000000  \
# 1        0.400000                1.0             1.0           1.000000
# 2        0.000000                0.0             0.0           0.700000
# 3        0.000000                0.0             0.0           0.970588
# 4        0.000000                0.0             0.0           0.000000
#
#    Recall clase R  Precision clase V  Recall clase V
# 0        1.000000           0.996296        1.000000
# 1        0.910290           0.901048        0.959108
# 2        0.018470           0.558091        1.000000
# 3        0.087071           0.566807        0.998761
# 4        0.000000           0.554258        1.000000

# %% [markdown]
# ### Get best 50% performing models

# %%
top_half = int(num_experiments / 2)
best_cnn_accs = filter_top_k_accuracies(cnn_accuracies, top_half)
best_lstm_accs = filter_top_k_accuracies(lstm_accuracies, top_half)
best_deepset_accs = filter_top_k_accuracies(deepset_accuracies, top_half)
best_deepsetv2_accs = filter_top_k_accuracies(deepsetv2_accuracies, top_half)
best_feedforward_accs = filter_top_k_accuracies(feedforward_accuracies, top_half)

# %% [markdown]
# ## Accuracy breakdown by cases for all the models

# %%
all_accuracies = [cnn_accuracies, lstm_accuracies, deepset_accuracies, deepsetv2_accuracies, feedforward_accuracies]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']

# %%
get_stats_df(all_accuracies, model_names, test_original)
# Out:
#                        Overall cr_noop   cr_uw    cr_w   cr_wu dr_noop  dr_uw
# CNN                      97.2%  100.0%  100.0%  100.0%  100.0%   99.0%  91.8%  \
# LSTM                     77.5%   99.9%   99.9%   99.7%   99.7%   69.7%  19.1%
# DeepSet(like in paper)   55.0%   98.2%   98.8%   98.4%   98.3%    0.2%   0.0%
# DeepSet(sum at start)    53.1%   93.6%   94.1%   94.1%   93.7%    0.0%   5.1%
# Feedforward              54.5%   96.7%   96.6%   97.0%   97.2%    0.1%   0.0%
# Sample count              1456      90      84      70      74      97     85
#
#                          dr_w  dr_wu noop_noop noop_uw  noop_w noop_wu r_noop
# CNN                     98.2%  94.2%    100.0%  100.0%  100.0%  100.0%  93.4%  \
# LSTM                    64.9%  28.7%     99.5%   99.7%   99.8%   99.3%  64.2%
# DeepSet(like in paper)   0.0%  98.6%     98.2%   98.9%   98.0%   98.8%   1.5%
# DeepSet(sum at start)    0.1%  93.8%     94.6%   94.7%   94.7%   94.7%   3.1%
# Feedforward              0.0%  97.7%     96.9%   97.2%   96.7%   97.6%   2.9%
# Sample count               88     73       121      99     102      94    103
#
#                          r_uw    r_w   r_wu
# CNN                     92.8%  92.9%  91.9%
# LSTM                    58.5%  61.9%  61.8%
# DeepSet(like in paper)   1.5%   2.4%   1.0%
# DeepSet(sum at start)    2.0%   2.0%   2.1%
# Feedforward              2.6%   2.6%   2.5%
# Sample count               86    103     87

# %% [markdown]
# ## Accuracy breakdown by cases for top 50% of models

# %%
best_accuracies = [best_cnn_accs, best_lstm_accs, best_deepset_accs, best_deepsetv2_accs, best_feedforward_accs]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']
collapsed_cases = ['dr', 'r', 'cr', 'noop']

# %%
get_stats_df(best_accuracies, model_names, test_original, collapsed_cases)
# Out:
#                        Overall   f3_cr  f3_dr f3_noop   f3_r
# CNN                      98.3%  100.0%  97.6%  100.0%  95.6%
# LSTM                     81.9%   99.6%  57.1%   99.2%  70.5%
# DeepSet(like in paper)   55.4%   99.8%  21.2%   99.8%   0.5%
# DeepSet(sum at start)    56.1%   98.8%  21.0%   99.7%   4.1%
# Feedforward              55.4%  100.0%  21.3%  100.0%   0.0%
# Sample count              1456     318    343     416    379

# %%
best_accuracies = [best_cnn_accs, best_lstm_accs, best_deepset_accs, best_deepsetv2_accs, best_feedforward_accs]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']
collapsed_cases = ['r', 'cr', 'noop']

# %%
get_stats_df(best_accuracies, model_names, test_original, collapsed_cases)
# Out:
#                        Overall dr_noop  dr_uw   dr_w   dr_wu   f3_cr f3_noop
# CNN                      98.3%  100.0%  94.4%  99.1%   96.3%  100.0%  100.0%  \
# LSTM                     81.9%   84.3%  26.8%  78.4%   30.4%   99.6%   99.2%
# DeepSet(like in paper)   55.4%    0.0%   0.0%   0.0%   99.7%   99.8%   99.8%
# DeepSet(sum at start)    56.1%    0.0%   0.1%   0.1%   98.6%   98.8%   99.7%
# Feedforward              55.4%    0.0%   0.0%   0.0%  100.0%  100.0%  100.0%
# Sample count              1456      97     85     88      73     318     416
#
#                          f3_r
# CNN                     95.6%
# LSTM                    70.5%
# DeepSet(like in paper)   0.5%
# DeepSet(sum at start)    4.1%
# Feedforward              0.0%
# Sample count              379

# %% [markdown]
# ## Accuracies per CNN model

# %%
get_stats_per_model(cnn_accuracies, ['CNN #' + str(i) for i in range(len(cnn_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#              Overall   f3_cr   f3_dr f3_noop    f3_r
# CNN #0         99.1%  100.0%   99.1%  100.0%   97.4%
# CNN #1         99.8%  100.0%   99.1%  100.0%  100.0%
# CNN #2         95.6%  100.0%   92.1%  100.0%   90.2%
# CNN #3         96.3%  100.0%   95.0%  100.0%   90.2%
# CNN #4         95.7%  100.0%   92.7%  100.0%   90.2%
# CNN #5         97.7%  100.0%   97.4%  100.0%   93.4%
# CNN #6         99.1%  100.0%   97.4%  100.0%   98.9%
# CNN #7         96.4%  100.0%   95.6%  100.0%   90.2%
# CNN #8         95.6%  100.0%   92.1%  100.0%   90.2%
# CNN #9         99.2%  100.0%   96.5%  100.0%  100.0%
# CNN #10        96.4%  100.0%   95.3%  100.0%   90.2%
# CNN #11        97.7%  100.0%   90.4%  100.0%  100.0%
# CNN #12        97.3%  100.0%   99.1%  100.0%   90.2%
# CNN #13        98.4%  100.0%   98.0%  100.0%   95.5%
# CNN #14        96.6%  100.0%   96.2%  100.0%   90.2%
# CNN #15        97.2%  100.0%   98.8%  100.0%   90.2%
# CNN #16        97.5%  100.0%  100.0%  100.0%   90.2%
# CNN #17        96.2%  100.0%   94.8%  100.0%   90.2%
# CNN #18        94.9%  100.0%   91.8%  100.0%   87.9%
# CNN #19        97.0%  100.0%   98.3%  100.0%   90.2%
# Sample count    1456     318     343     416     379

# %%
get_stats_per_model_multiclass(cnn_accuracies, cnn_precisions, cnn_recall, cnn_f1, "CNN")
# Out:
#    Modelo  Accuracy  F1-score  Precision_Overall  Recall_Overall  Precision_A
# 0     CNN  0.991071  0.990275           0.996037        0.984580     1.000000  \
# 1     CNN  0.997940  0.995110           0.999074        0.991176     1.000000
# 2     CNN  0.956044  0.937861           0.964967        0.912236     1.000000
# 3     CNN  0.962912  0.958503           0.975974        0.941648     1.000000
# 4     CNN  0.957418  0.941226           0.965526        0.918118     1.000000
# 5     CNN  0.976648  0.980735           0.989893        0.971745     1.000000
# 6     CNN  0.991071  0.983547           0.992121        0.975119     0.987342
# 7     CNN  0.964286  0.964725           0.976425        0.953303     1.000000
# 8     CNN  0.956044  0.965103           0.981630        0.949123     1.000000
# 9     CNN  0.991758  0.981760           0.984729        0.978808     0.987805
# 10    CNN  0.963599  0.961239           0.977196        0.945795     1.000000
# 11    CNN  0.977335  0.948192           0.967001        0.930100     1.000000
# 12    CNN  0.972527  0.977364           0.988194        0.966770     1.000000
# 13    CNN  0.983516  0.985104           0.991698        0.978597     1.000000
# 14    CNN  0.965659  0.963260           0.978133        0.948832     1.000000
# 15    CNN  0.971841  0.975722           0.987913        0.963829     1.000000
# 16    CNN  0.974588  0.982271           0.989040        0.975594     1.000000
# 17    CNN  0.962225  0.951042           0.966768        0.935819     1.000000
# 18    CNN  0.949176  0.959553           0.976517        0.943169     1.000000
# 19    CNN  0.970467  0.972725           0.986274        0.959544     1.000000
#
#     Precision_D  Precision_R  Precision_V  Recall_A  Recall_D  Recall_R
# 0      1.000000          1.0     0.984146  0.964706  1.000000  0.973615  \
# 1      1.000000          1.0     0.996296  0.964706  1.000000  1.000000
# 2      0.915423          1.0     0.944444  0.788235  0.958333  0.902375
# 3      0.958333          1.0     0.945562  0.905882  0.958333  0.902375
# 4      0.915423          1.0     0.946682  0.811765  0.958333  0.902375
# 5      1.000000          1.0     0.959572  0.952941  1.000000  0.934037
# 6      0.994624          1.0     0.986520  0.917647  0.994624  0.989446
# 7      0.957895          1.0     0.947805  0.952941  0.957895  0.902375
# 8      1.000000          1.0     0.926521  0.894118  1.000000  0.902375
# 9      0.953608          1.0     0.997503  0.952941  0.963542  1.000000
# 10     0.963158          1.0     0.945626  0.917647  0.963158  0.902375
# 11     0.876777          1.0     0.991228  0.800000  0.920398  1.000000
# 12     1.000000          1.0     0.952774  0.964706  1.000000  0.902375
# 13     0.994536          1.0     0.972256  0.964706  0.994536  0.955145
# 14     0.963542          1.0     0.948992  0.929412  0.963542  0.902375
# 15     1.000000          1.0     0.951651  0.952941  1.000000  0.902375
# 16     1.000000          1.0     0.956161  1.000000  1.000000  0.902375
# 17     0.911330          1.0     0.955742  0.882353  0.958549  0.902375
# 18     0.988166          1.0     0.917902  0.905882  0.988166  0.878628
# 19     0.994624          1.0     0.950472  0.941176  0.994624  0.902375
#
#     Recall_V
# 0   1.000000
# 1   1.000000
# 2   1.000000
# 3   1.000000
# 4   1.000000
# 5   1.000000
# 6   0.998759
# 7   1.000000
# 8   1.000000
# 9   0.998750
# 10  1.000000
# 11  1.000000
# 12  1.000000
# 13  1.000000
# 14  1.000000
# 15  1.000000
# 16  1.000000
# 17  1.000000
# 18  1.000000
# 19  1.000000

# %% [markdown]
# ## Accuracies per LSTM model

# %%
get_stats_per_model(best_lstm_accs, ['LSTM #' + str(i) for i in range(len(best_lstm_accs))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#              Overall   f3_cr  f3_dr f3_noop   f3_r
# LSTM #0        91.9%  100.0%  75.5%  100.0%  91.0%
# LSTM #1        90.2%  100.0%  66.5%  100.0%  92.9%
# LSTM #2        84.7%  100.0%  57.1%  100.0%  79.9%
# LSTM #3        82.3%   99.7%  57.1%   98.3%  72.8%
# LSTM #4        79.3%  100.0%  51.0%  100.0%  64.6%
# LSTM #5        78.9%  100.0%  56.6%  100.0%  58.3%
# LSTM #6        78.4%  100.0%  49.0%  100.0%  63.3%
# LSTM #7        78.1%  100.0%  48.4%  100.0%  62.5%
# LSTM #8        77.8%   96.5%  59.8%   97.4%  57.0%
# LSTM #9        77.5%  100.0%  49.9%   96.6%  62.5%
# Sample count    1456     318    343     416    379

# %%
get_stats_per_model_multiclass(lstm_accuracies, lstm_precision, lstm_recall, lstm_f1, "LSTM")
# Out:
#    Modelo  Accuracy  F1-score  Precision_Overall  Recall_Overall  Precision_A
# 0    LSTM  0.761676  0.695602           0.728575        0.665484     0.714286  \
# 1    LSTM  0.902473  0.785884           0.813463        0.760115     0.595238
# 2    LSTM  0.715659  0.550912           0.517080        0.589481     0.142857
# 3    LSTM  0.676511  0.609883           0.661218        0.565946     0.428571
# 4    LSTM  0.846841  0.733343           0.775242        0.695741     0.653846
# 5    LSTM  0.743132  0.661147           0.708422        0.619788     0.700000
# 6    LSTM  0.918956  0.834376           0.852128        0.817350     0.507463
# 7    LSTM  0.778159  0.674383           0.717080        0.636484     0.533333
# 8    LSTM  0.780907  0.666109           0.694392        0.640039     0.538462
# 9    LSTM  0.769918  0.654622           0.691406        0.621555     0.600000
# 10   LSTM  0.784341  0.712646           0.735735        0.690961     0.651163
# 11   LSTM  0.708791  0.647156           0.681490        0.616115     0.555556
# 12   LSTM  0.822802  0.768471           0.796431        0.742408     0.541667
# 13   LSTM  0.657280  0.627619           0.680995        0.582002     0.600000
# 14   LSTM  0.792582  0.647621           0.697553        0.604360     0.461538
# 15   LSTM  0.789148  0.663003           0.720323        0.614134     0.526316
# 16   LSTM  0.760989  0.707045           0.722155        0.692554     0.530612
# 17   LSTM  0.767170  0.556943           0.529121        0.587854     0.000000
# 18   LSTM  0.738324  0.531602           0.498359        0.569597     0.000000
# 19   LSTM  0.774725  0.771337           0.756314        0.786969     0.382353
#
#     Precision_D  Precision_R  Precision_V  Recall_A  Recall_D  Recall_R
# 0      0.750000     0.634831     0.815182  0.294118  0.823944  0.596306  \
# 1      0.748988     0.977778     0.931846  0.294118  0.844749  0.928760
# 2      0.560976     0.536170     0.828317  0.011765  0.741935  0.664908
# 3      0.774194     0.785276     0.656830  0.070588  0.878049  0.337731
# 4      0.684874     0.875723     0.886525  0.200000  0.806931  0.799472
# 5      0.664634     0.698962     0.770092  0.164706  0.813433  0.532982
# 6      1.000000     1.000000     0.901048  0.400000  1.000000  0.910290
# 7      0.739130     0.808989     0.786868  0.188235  0.845771  0.569921
# 8      0.661836     0.752381     0.824890  0.164706  0.801170  0.625330
# 9      0.644330     0.689266     0.832027  0.105882  0.771605  0.643799
# 10     0.746914     0.727273     0.817590  0.329412  0.840278  0.634921
# 11     0.831776     0.618110     0.720520  0.117647  0.967391  0.414248
# 12     0.976562     0.865204     0.802289  0.305882  0.976562  0.728232
# 13     1.000000     0.433460     0.690519  0.070588  1.000000  0.300792
# 14     0.496429     1.000000     0.832244  0.070588  0.584034  0.768025
# 15     0.625874     0.917012     0.812088  0.117647  0.778261  0.583113
# 16     0.938931     0.621622     0.797455  0.305882  0.984000  0.546174
# 17     0.541667     0.732353     0.842466  0.000000  0.718232  0.656992
# 18     0.528571     0.633609     0.831257  0.000000  0.707006  0.606860
# 19     1.000000     0.861818     0.781084  0.611765  1.000000  0.625330
#
#     Recall_V
# 0   0.947570
# 1   0.972833
# 2   0.939317
# 3   0.977415
# 4   0.976562
# 5   0.968031
# 6   0.959108
# 7   0.942010
# 8   0.968952
# 9   0.964935
# 10  0.959236
# 11  0.965174
# 12  0.958955
# 13  0.956629
# 14  0.994792
# 15  0.977513
# 16  0.934161
# 17  0.976190
# 18  0.964520
# 19  0.910781

# %% [markdown]
# ## Accuracies per DeepSets V1 model

# %%
get_stats_per_model(deepset_accuracies, ['DeepSet(like in paper) #' + str(i) for i in range(len(deepset_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                            Overall   f3_cr  f3_dr f3_noop  f3_r
# DeepSet(like in paper) #0    54.2%   96.9%  21.3%   92.5%  6.1%
# DeepSet(like in paper) #1    54.5%   95.0%  20.7%   97.6%  3.7%
# DeepSet(like in paper) #2    53.2%   94.7%  20.1%   94.2%  3.4%
# DeepSet(like in paper) #3    55.3%   99.4%  20.7%  100.0%  0.5%
# DeepSet(like in paper) #4    55.4%  100.0%  21.3%  100.0%  0.0%
# DeepSet(like in paper) #5    54.1%   95.3%  20.4%   96.4%  3.4%
# DeepSet(like in paper) #6    55.2%   98.1%  21.3%   98.8%  1.8%
# DeepSet(like in paper) #7    55.0%   99.1%  21.0%   99.0%  0.5%
# DeepSet(like in paper) #8    55.4%   99.4%  21.3%   99.3%  1.3%
# DeepSet(like in paper) #9    55.4%  100.0%  21.3%  100.0%  0.0%
# DeepSet(like in paper) #10   55.4%  100.0%  21.3%   99.5%  0.3%
# DeepSet(like in paper) #11   55.9%  100.0%  21.3%  100.0%  1.8%
# DeepSet(like in paper) #12   54.9%   98.1%  21.0%   99.0%  0.8%
# DeepSet(like in paper) #13   55.4%   99.7%  21.3%   99.8%  0.5%
# DeepSet(like in paper) #14   54.5%   95.0%  20.4%   95.9%  5.8%
# DeepSet(like in paper) #15   55.1%   98.7%  21.3%   99.5%  0.3%
# DeepSet(like in paper) #16   55.4%  100.0%  21.3%   99.5%  0.5%
# DeepSet(like in paper) #17   55.2%   99.4%  21.0%   98.6%  1.3%
# DeepSet(like in paper) #18   55.2%   99.7%  21.3%   99.5%  0.0%
# DeepSet(like in paper) #19   55.5%  100.0%  21.3%  100.0%  0.3%
# Sample count                  1456     318    343     416   379

# %%
get_stats_per_model_multiclass(deepset_accuracies, deepset_procision, deepset_recall, deepset_f1, "DEEPSET")
# Out:
#      Modelo  Accuracy  F1-score  Precision_Overall  Recall_Overall
# 0   DEEPSET  0.541896  0.275099           0.262362        0.289136  \
# 1   DEEPSET  0.544643  0.225661           0.205046        0.250885
# 2   DEEPSET  0.532280  0.336766           0.309466        0.369348
# 3   DEEPSET  0.552885  0.218683           0.194291        0.250080
# 4   DEEPSET  0.554258  0.178303           0.138565        0.250000
# 5   DEEPSET  0.540522  0.219319           0.196349        0.248375
# 6   DEEPSET  0.551511  0.294471           0.277670        0.313437
# 7   DEEPSET  0.550137  0.204961           0.174237        0.248841
# 8   DEEPSET  0.554258  0.252070           0.252391        0.251749
# 9   DEEPSET  0.554258  0.178303           0.138565        0.250000
# 10  DEEPSET  0.553571  0.215080           0.188697        0.250040
# 11  DEEPSET  0.559066  0.281417           0.314523        0.254617
# 12  DEEPSET  0.548764  0.216622           0.191766        0.248882
# 13  DEEPSET  0.554258  0.256989           0.263602        0.250700
# 14  DEEPSET  0.544643  0.234146           0.217641        0.253359
# 15  DEEPSET  0.550824  0.201665           0.169544        0.248801
# 16  DEEPSET  0.554258  0.305331           0.388889        0.251330
# 17  DEEPSET  0.551511  0.227391           0.208179        0.250510
# 18  DEEPSET  0.552198  0.178191           0.138716        0.249071
# 19  DEEPSET  0.554945  0.257041           0.263755        0.250660
#
#     Precision_A  Precision_D  Precision_R  Precision_V  Recall_A  Recall_D
# 0           0.0     0.142857     0.353846     0.552746       0.0  0.142857  \
# 1           0.0     0.000000     0.264151     0.556031       0.0  0.000000
# 2           0.0     0.500000     0.188406     0.549458       0.0  0.500000
# 3           0.0     0.000000     0.222222     0.554941       0.0  0.000000
# 4           0.0     0.000000     0.000000     0.554258       0.0  0.000000
# 5           0.0     0.000000     0.232143     0.553252       0.0  0.000000
# 6           0.0     0.250000     0.304348     0.556333       0.0  0.250000
# 7           0.0     0.000000     0.142857     0.554092       0.0  0.000000
# 8           0.0     0.000000     0.454545     0.555017       0.0  0.000000
# 9           0.0     0.000000     0.000000     0.554258       0.0  0.000000
# 10          0.0     0.000000     0.200000     0.554790       0.0  0.000000
# 11          0.0     0.000000     0.700000     0.558091       0.0  0.000000
# 12          0.0     0.000000     0.214286     0.552778       0.0  0.000000
# 13          0.0     0.000000     0.500000     0.554408       0.0  0.000000
# 14          0.0     0.000000     0.314286     0.556277       0.0  0.000000
# 15          0.0     0.000000     0.125000     0.553177       0.0  0.000000
# 16          0.0     0.000000     1.000000     0.555556       0.0  0.000000
# 17          0.0     0.000000     0.277778     0.554937       0.0  0.000000
# 18          0.0     0.000000     0.000000     0.554865       0.0  0.000000
# 19          0.0     0.000000     0.500000     0.555021       0.0  0.000000
#
#     Recall_R  Recall_V
# 0   0.061008  0.952677
# 1   0.037037  0.966501
# 2   0.034392  0.942999
# 3   0.005277  0.995043
# 4   0.000000  1.000000
# 5   0.034392  0.959108
# 6   0.018617  0.985130
# 7   0.005277  0.990087
# 8   0.013193  0.993804
# 9   0.000000  1.000000
# 10  0.002639  0.997522
# 11  0.018470  1.000000
# 12  0.007937  0.987593
# 13  0.005277  0.997522
# 14  0.058047  0.955390
# 15  0.002639  0.992565
# 16  0.005319  1.000000
# 17  0.013193  0.988848
# 18  0.000000  0.996283
# 19  0.002639  1.000000

# %% [markdown]
# ## Accuracies per DeepSets V2 model

# %%
get_stats_per_model(deepsetv2_accuracies, ['DeepSet(sum at start) #' + str(i) for i in range(len(deepsetv2_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                           Overall   f3_cr  f3_dr f3_noop   f3_r
# DeepSet(sum at start) #0    55.0%   99.1%  20.1%  100.0%   0.3%
# DeepSet(sum at start) #1    55.4%  100.0%  21.3%  100.0%   0.0%
# DeepSet(sum at start) #2    56.7%   96.5%  19.8%   98.6%  10.6%
# DeepSet(sum at start) #3    55.4%  100.0%  21.3%  100.0%   0.0%
# DeepSet(sum at start) #4    54.6%   95.6%  20.7%   99.0%   2.1%
# DeepSet(sum at start) #5    55.4%   99.4%  21.9%  100.0%   0.0%
# DeepSet(sum at start) #6    54.1%   95.0%  20.7%   97.6%   2.1%
# DeepSet(sum at start) #7    55.4%  100.0%  21.3%  100.0%   0.0%
# DeepSet(sum at start) #8    55.4%  100.0%  21.3%  100.0%   0.0%
# DeepSet(sum at start) #9    55.3%   99.4%  21.3%  100.0%   0.0%
# DeepSet(sum at start) #10   56.7%  100.0%  21.3%  100.0%   5.0%
# DeepSet(sum at start) #11   55.4%  100.0%  21.3%  100.0%   0.0%
# DeepSet(sum at start) #12   56.7%   99.4%  21.0%  100.0%   5.5%
# DeepSet(sum at start) #13   57.6%   99.7%  21.3%  100.0%   8.7%
# DeepSet(sum at start) #14    5.8%    0.0%  24.8%    0.0%   0.0%
# DeepSet(sum at start) #15   55.5%   99.4%  21.3%   99.8%   1.1%
# DeepSet(sum at start) #16   56.0%   95.6%  20.4%   98.6%   8.4%
# DeepSet(sum at start) #17   55.4%  100.0%  21.3%  100.0%   0.0%
# DeepSet(sum at start) #18   55.4%  100.0%  21.3%  100.0%   0.0%
# DeepSet(sum at start) #19   55.6%   98.4%  21.0%  100.0%   2.1%
# Sample count                 1456     318    343     416    379

# %%
get_stats_per_model_multiclass(deepsetv2_accuracies, deepsetv2_procision, deepsetv2_recall, deepsetv2_f1, "DEEPSETv2")
# Out:
#        Modelo  Accuracy  F1-score  Precision_Overall  Recall_Overall
# 0   DEEPSETv2  0.550137  0.193047           0.157831        0.248491  \
# 1   DEEPSETv2  0.554258  0.178303           0.138565        0.250000
# 2   DEEPSETv2  0.566621  0.275017           0.280688        0.269570
# 3   DEEPSETv2  0.554258  0.178303           0.138565        0.250000
# 4   DEEPSETv2  0.546016  0.223677           0.202975        0.249081
# 5   DEEPSETv2  0.554258  0.334120           0.299795        0.377322
# 6   DEEPSETv2  0.540522  0.218593           0.194970        0.248729
# 7   DEEPSETv2  0.554258  0.178303           0.138565        0.250000
# 8   DEEPSETv2  0.554258  0.178303           0.138565        0.250000
# 9   DEEPSETv2  0.552885  0.178097           0.138507        0.249380
# 10  DEEPSETv2  0.567308  0.313945           0.390397        0.262533
# 11  DEEPSETv2  0.554258  0.178303           0.138565        0.250000
# 12  DEEPSETv2  0.566621  0.297475           0.342483        0.262923
# 13  DEEPSETv2  0.576236  0.318187           0.384349        0.271458
# 14  DEEPSETv2  0.058379  0.027579           0.014595        0.250000
# 15  DEEPSETv2  0.554945  0.251017           0.250308        0.251730
# 16  DEEPSETv2  0.560440  0.268770           0.273734        0.263983
# 17  DEEPSETv2  0.554258  0.178303           0.138565        0.250000
# 18  DEEPSETv2  0.554258  0.178303           0.138565        0.250000
# 19  DEEPSETv2  0.555632  0.262520           0.272299        0.253418
#
#     Precision_A  Precision_D  Precision_R  Precision_V  Recall_A  Recall_D
# 0      0.000000          0.0     0.076923     0.554401  0.000000       0.0  \
# 1      0.000000          0.0     0.000000     0.554258  0.000000       0.0
# 2      0.000000          0.0     0.555556     0.567197  0.000000       0.0
# 3      0.000000          0.0     0.000000     0.554258  0.000000       0.0
# 4      0.000000          0.0     0.258065     0.553835  0.000000       0.0
# 5      0.142857          0.5     0.000000     0.556323  0.011765       0.5
# 6      0.000000          0.0     0.228571     0.551309  0.000000       0.0
# 7      0.000000          0.0     0.000000     0.554258  0.000000       0.0
# 8      0.000000          0.0     0.000000     0.554258  0.000000       0.0
# 9      0.000000          0.0     0.000000     0.554026  0.000000       0.0
# 10     0.000000          0.0     1.000000     0.561587  0.000000       0.0
# 11     0.000000          0.0     0.000000     0.554258  0.000000       0.0
# 12     0.000000          0.0     0.807692     0.562238  0.000000       0.0
# 13     0.000000          0.0     0.970588     0.566807  0.000000       0.0
# 14     0.058379          0.0     0.000000     0.000000  1.000000       0.0
# 15     0.000000          0.0     0.444444     0.556787  0.000000       0.0
# 16     0.000000          0.0     0.533333     0.561605  0.000000       0.0
# 17     0.000000          0.0     0.000000     0.554258  0.000000       0.0
# 18     0.000000          0.0     0.000000     0.554258  0.000000       0.0
# 19     0.000000          0.0     0.533333     0.555864  0.000000       0.0
#
#     Recall_R  Recall_V
# 0   0.002639  0.991326
# 1   0.000000  1.000000
# 2   0.105541  0.972739
# 3   0.000000  1.000000
# 4   0.021108  0.975217
# 5   0.000000  0.997522
# 6   0.021164  0.973750
# 7   0.000000  1.000000
# 8   0.000000  1.000000
# 9   0.000000  0.997522
# 10  0.050132  1.000000
# 11  0.000000  1.000000
# 12  0.055409  0.996283
# 13  0.087071  0.998761
# 14  0.000000  0.000000
# 15  0.010638  0.996283
# 16  0.084433  0.971499
# 17  0.000000  1.000000
# 18  0.000000  1.000000
# 19  0.021108  0.992565

# %% [markdown]
# ## Accuracies per FeedForward model

# %%
get_stats_per_model(feedforward_accuracies, ['Feedforward #' + str(i) for i in range(len(feedforward_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                 Overall   f3_cr  f3_dr f3_noop   f3_r
# Feedforward #0    55.4%  100.0%  21.3%  100.0%   0.0%
# Feedforward #1    53.5%   96.5%  21.0%   91.1%   5.5%
# Feedforward #2    55.4%  100.0%  21.3%  100.0%   0.0%
# Feedforward #3    54.8%   97.2%  20.4%   99.0%   1.8%
# Feedforward #4    51.2%   89.6%  19.5%   88.0%   7.4%
# Feedforward #5    55.4%  100.0%  21.3%  100.0%   0.0%
# Feedforward #6    55.4%  100.0%  21.3%  100.0%   0.0%
# Feedforward #7    55.4%  100.0%  21.3%  100.0%   0.0%
# Feedforward #8    55.4%  100.0%  21.3%  100.0%   0.0%
# Feedforward #9    55.4%  100.0%  21.3%  100.0%   0.0%
# Feedforward #10   55.4%  100.0%  21.3%  100.0%   0.0%
# Feedforward #11   52.0%   90.3%  20.1%   88.0%   9.2%
# Feedforward #12   54.3%   95.0%  20.4%   98.3%   2.6%
# Feedforward #13   54.3%   95.3%  21.0%   98.3%   1.6%
# Feedforward #14   52.3%   87.7%  19.0%   86.1%  15.6%
# Feedforward #15   55.4%  100.0%  21.3%  100.0%   0.0%
# Feedforward #16   55.4%  100.0%  21.3%  100.0%   0.0%
# Feedforward #17   55.3%   99.4%  21.3%   99.5%   0.5%
# Feedforward #18   53.9%   92.1%  20.7%   95.9%   5.8%
# Feedforward #19   53.6%   94.0%  19.8%   96.9%   2.9%
# Sample count       1456     318    343     416    379

# %%
get_stats_per_model_multiclass(feedforward_accuracies, feedforward_precision, feedforward_recall, feedforward_f1, "FEEDFORWARD")
# Out:
#          Modelo  Accuracy  F1-score  Precision_Overall  Recall_Overall
# 0   FEEDFORWARD  0.554258  0.178303           0.138565        0.250000  \
# 1   FEEDFORWARD  0.535027  0.226061           0.207219        0.248673
# 2   FEEDFORWARD  0.554258  0.178303           0.138565        0.250000
# 3   FEEDFORWARD  0.548077  0.218058           0.193557        0.249661
# 4   FEEDFORWARD  0.512363  0.211100           0.187330        0.241777
# 5   FEEDFORWARD  0.554258  0.178303           0.138565        0.250000
# 6   FEEDFORWARD  0.554258  0.178303           0.138565        0.250000
# 7   FEEDFORWARD  0.554258  0.178303           0.138565        0.250000
# 8   FEEDFORWARD  0.554258  0.178303           0.138565        0.250000
# 9   FEEDFORWARD  0.554258  0.178303           0.138565        0.250000
# 10  FEEDFORWARD  0.554258  0.178303           0.138565        0.250000
# 11  FEEDFORWARD  0.519918  0.220722           0.199658        0.246755
# 12  FEEDFORWARD  0.543269  0.218600           0.195097        0.248542
# 13  FEEDFORWARD  0.542582  0.210303           0.183192        0.246833
# 14  FEEDFORWARD  0.522665  0.234103           0.215380        0.256390
# 15  FEEDFORWARD  0.554258  0.178303           0.138565        0.250000
# 16  FEEDFORWARD  0.554258  0.178303           0.138565        0.250000
# 17  FEEDFORWARD  0.552885  0.286418           0.280421        0.292678
# 18  FEEDFORWARD  0.539148  0.232592           0.215991        0.251957
# 19  FEEDFORWARD  0.536401  0.212150           0.186607        0.245794
#
#     Precision_A  Precision_D  Precision_R  Precision_V  Recall_A  Recall_D
# 0           0.0     0.000000     0.000000     0.554258       0.0  0.000000  \
# 1           0.0     0.000000     0.280000     0.548878       0.0  0.000000
# 2           0.0     0.000000     0.000000     0.554258       0.0  0.000000
# 3           0.0     0.000000     0.218750     0.555478       0.0  0.000000
# 4           0.0     0.000000     0.202899     0.546423       0.0  0.000000
# 5           0.0     0.000000     0.000000     0.554258       0.0  0.000000
# 6           0.0     0.000000     0.000000     0.554258       0.0  0.000000
# 7           0.0     0.000000     0.000000     0.554258       0.0  0.000000
# 8           0.0     0.000000     0.000000     0.554258       0.0  0.000000
# 9           0.0     0.000000     0.000000     0.554258       0.0  0.000000
# 10          0.0     0.000000     0.000000     0.554258       0.0  0.000000
# 11          0.0     0.000000     0.250000     0.548632       0.0  0.000000
# 12          0.0     0.000000     0.227273     0.553116       0.0  0.000000
# 13          0.0     0.000000     0.181818     0.550949       0.0  0.000000
# 14          0.0     0.000000     0.305699     0.555819       0.0  0.000000
# 15          0.0     0.000000     0.000000     0.554258       0.0  0.000000
# 16          0.0     0.000000     0.000000     0.554258       0.0  0.000000
# 17          0.0     0.166667     0.400000     0.555017       0.0  0.166667
# 18          0.0     0.000000     0.309859     0.554103       0.0  0.000000
# 19          0.0     0.000000     0.196429     0.550000       0.0  0.000000
#
#     Recall_R  Recall_V
# 0   0.000000  1.000000
# 1   0.055409  0.939281
# 2   0.000000  1.000000
# 3   0.018470  0.980173
# 4   0.074074  0.893035
# 5   0.000000  1.000000
# 6   0.000000  1.000000
# 7   0.000000  1.000000
# 8   0.000000  1.000000
# 9   0.000000  1.000000
# 10  0.000000  1.000000
# 11  0.092348  0.894672
# 12  0.026385  0.967782
# 13  0.015831  0.971499
# 14  0.155673  0.869888
# 15  0.000000  1.000000
# 16  0.000000  1.000000
# 17  0.005291  0.998755
# 18  0.058824  0.949005
# 19  0.029024  0.954151

# %% [markdown]
# # Training evolution

# %% [markdown]
# ### CNN

# %%
display_epochs_stats(cnn_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### LSTM

# %%
display_epochs_stats(lstm_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### DeepSets V1

# %%
display_epochs_stats(deepset_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### DeepSets V2

# %%
display_epochs_stats(deepsetv2_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### FeedForward

# %%
display_epochs_stats(feedforward_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# # Best performing models

# %%
best_lstm_model = LSTM_Model(data, 16, 32, 8).to(device)
best_lstm_model.load_state_dict(torch.load('./bestmodels/best_LSTM_model_' + experiment_name))
best_cnn_model = CNN_Model(data, 64, 128, 4, -1,).to(device)
best_cnn_model.load_state_dict(torch.load('./bestmodels/best_CNN_model_' + experiment_name))
best_deepset_model = DEEPSET_Model(data).to(device)
best_deepset_model.load_state_dict(torch.load('./bestmodels/best_DEEPSET_model_' + experiment_name))
best_deepsetv2_model = DEEPSETV2_Model(data).to(device)
best_deepsetv2_model.load_state_dict(torch.load('./bestmodels/best_DEEPSETV2_model_' + experiment_name))
best_feedforward_model = FEEDFORWARD_Model(data).to(device)
best_feedforward_model.load_state_dict(torch.load('./bestmodels/best_FEEDFORWARD_model_' + experiment_name))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Top wrong predictions for best performing CNN model

# %%
print_wrong_preds_bycases(get_wrong_predictions_bycases(best_cnn_model, x_test_cnn, y_test, test_original), k=10)
# Out:
# 3 Atomicity violation cases wrong predicted:
# Sample ['__,..,,,_._,..,_', '.___,,,uw._...,.', ',..._._,,.,.,.dr', 'A'] | Prediction V
# Sample ['.,.,.,.,.._.,_..', '_,_._._,,.uw,,__', '_,..._,_._._,.dr', 'A'] | Prediction V
# Sample ['.,.,,____.,_._,.', '__.,,,.,..,uw._,', ',.,._.,.,_.___dr', 'A'] | Prediction V
#
#
# 0 DeadLock cases wrong predicted:
#
#
# 0 Data race cases wrong predicted:
#
#
# 0 Valid cases wrong predicted:

# %%
print_wrong_preds(get_wrong_predictions(best_cnn_model, x_test_cnn, y_test, test_original), k=10)
# Out:
# 0 false Atomicity violation:
#
#
# 0 false DeadLock:
#
#
# 0 false Data race :
#
#
# 3 false Valid:
# Sample ['__,..,,,_._,..,_', '.___,,,uw._...,.', ',..._._,,.,.,.dr', 'A'] | Prediction V
# Sample ['.,.,.,.,.._.,_..', '_,_._._,,.uw,,__', '_,..._,_._._,.dr', 'A'] | Prediction V
# Sample ['.,.,,____.,_._,.', '__.,,,.,..,uw._,', ',.,._.,.,_.___dr', 'A'] | Prediction V

# %% [markdown]
# ## Top wrong predictions for best performing LSTM model

# %%
print_wrong_preds_bycases(get_wrong_predictions_bycases(best_lstm_model, x_test_lstm, y_test, test_original), k=10)
# Out:
# 10 Atomicity violation cases wrong predicted:
# Sample ['.._...,._,_____,', '_._.__,_.,.,,uw.', '.,__.._dr_._,,,.', 'A'] | Prediction V
# Sample ['._._,,..,.,.,._.', '___,,..,.,.uw._.', '___,.,,,dr____._', 'A'] | Prediction V
# Sample [',,__._._.._.,,._', '._...,,.___,uw..', '__.,.,_,_._dr...', 'A'] | Prediction V
# Sample [',__.,.,_.,__._.,', '__._..,_.._.,uw.', ',,.._,,_,,,.,dr,', 'A'] | Prediction V
# Sample ['._......_,._.,,.', '_,_,.,_,...uw.._', '.,._.,._,,_,.dr_', 'A'] | Prediction V
# Sample [',,,,_.,__.,.._..', '_,_.__.,.__uw.__', ',.__,.___dr.._,,', 'A'] | Prediction V
# Sample ['_.__,..___,,..,.', ',,__.,.,.,,.,uw.', '.._..,._dr_,.__,', 'A'] | Prediction V
# Sample ['__,.,,,,...,_,._', '___,,,,._..,.uw_', ',,..,_dr,.__,.,.', 'A'] | Prediction V
# Sample [',_,__.,,....._,.', '.,_.,uw__.,..__,', '_,_,._.,_dr.._._', 'A'] | Prediction V
# Sample [',..,_,,._._.,,_,', '_,,.__,,._uw._._', '..,,,__dr,,,___,', 'A'] | Prediction V
#
#
# 0 DeadLock cases wrong predicted:
#
#
# 10 Data race cases wrong predicted:
# Sample ['.__._,_,..,.__,.', '__,..__.w,,.,..,', ',.__,,.,,__,.,r.', 'R'] | Prediction V
# Sample ['...___,,__,,,_._', '_,_.__.,_.,,,.,.', '_,,,_....___.._r', 'R'] | Prediction V
# Sample [',,.._._.,_,_.,,_', '.._,__wu,,_,,_.,', '.___,,_,,.,_._,r', 'R'] | Prediction V
# Sample [',____.___,,_,_,.', ',,,,_...,,_,_,_,', ',,,.,.._.._,,,r_', 'R'] | Prediction V
# Sample ['_,..._._,__._,.,', '_.._,,.w._,_....', ',..,..,.,.._,.r.', 'R'] | Prediction V
# Sample ['_.,,_._._.,.,_,.', '.,,,.w...,_,._..', '_,_._.__._,_,r,_', 'R'] | Prediction V
# Sample ['._..._,_,.,_,..,', '_____,.,uw._,..,', '__,,,_,__,,_.._r', 'R'] | Prediction V
# Sample ['_,.,__,,.,.,...,', '_.._...,_.,_.__,', '_.,.,,.,__,.,.,r', 'R'] | Prediction V
# Sample ['_,,.,,,_.._,,._,', '_._._,,,_,......', '_.,._.,,.._.__r.', 'R'] | Prediction V
# Sample ['._,_,._._,__,.,,', ',,_.___.._.__...', '_,,_,,._,_,____r', 'R'] | Prediction V
#
#
# 10 Valid cases wrong predicted:
# Sample ['.,..____.,.,._.,', ',_...__,,,_..wu.', '._..__.,,,.,__dr', 'V'] | Prediction A
# Sample [',_,,_._,.___,,_.', ',.._,_.wu..___,.', ',_,.,.._,_.,dr_.', 'V'] | Prediction A
# Sample ['..,__._.,_._,,,.', '._,__._._.....wu', '.,..___,._.__.dr', 'V'] | Prediction A
# Sample ['_,,.._._._,_,_,.', '..._._,_,_.wu___', '___,.,,dr._.._..', 'V'] | Prediction A
# Sample ['.,...,__,_,,,,_.', '.,_,_,wu_...,,,,', ',_,_,_.,dr._._,.', 'V'] | Prediction A
# Sample ['._....,_,,.,,,__', '.,___.,..wu._,_,', '_.._,....,dr,,__', 'V'] | Prediction A
# Sample ['._,,,,___,,,.,_,', ',___.._.,..,,.wu', '___,,._dr,.._,._', 'V'] | Prediction A
# Sample ['__.,,.__...___,,', '._..,._,__.wu.__', '_.__,.____dr.._.', 'V'] | Prediction A
# Sample [',...,._,....__,_', '.__,_,._,,_,.wu,', ',_.,.,,,_,,dr._.', 'V'] | Prediction A
# Sample [',.,...._,_...,..', '___._._,_.,,_wu_', ',..,_,_..,dr,_..', 'V'] | Prediction A

# %%
print_wrong_preds(get_wrong_predictions(best_lstm_model, x_test_lstm, y_test, test_original), k=10)
# Out:
# 10 false Atomicity violation:
# Sample ['.,..____.,.,._.,', ',_...__,,,_..wu.', '._..__.,,,.,__dr', 'V'] | Prediction A
# Sample [',_,,_._,.___,,_.', ',.._,_.wu..___,.', ',_,.,.._,_.,dr_.', 'V'] | Prediction A
# Sample ['..,__._.,_._,,,.', '._,__._._.....wu', '.,..___,._.__.dr', 'V'] | Prediction A
# Sample ['_,,.._._._,_,_,.', '..._._,_,_.wu___', '___,.,,dr._.._..', 'V'] | Prediction A
# Sample ['.,...,__,_,,,,_.', '.,_,_,wu_...,,,,', ',_,_,_.,dr._._,.', 'V'] | Prediction A
# Sample ['._....,_,,.,,,__', '.,___.,..wu._,_,', '_.._,....,dr,,__', 'V'] | Prediction A
# Sample ['._,,,,___,,,.,_,', ',___.._.,..,,.wu', '___,,._dr,.._,._', 'V'] | Prediction A
# Sample ['__.,,.__...___,,', '._..,._,__.wu.__', '_.__,.____dr.._.', 'V'] | Prediction A
# Sample [',...,._,....__,_', '.__,_,._,,_,.wu,', ',_.,.,,,_,,dr._.', 'V'] | Prediction A
# Sample [',.,...._,_...,..', '___._._,_.,,_wu_', ',..,_,_..,dr,_..', 'V'] | Prediction A
#
#
# 0 false DeadLock:
#
#
# 0 false Data race :
#
#
# 10 false Valid:
# Sample ['.._...,._,_____,', '_._.__,_.,.,,uw.', '.,__.._dr_._,,,.', 'A'] | Prediction V
# Sample ['.__._,_,..,.__,.', '__,..__.w,,.,..,', ',.__,,.,,__,.,r.', 'R'] | Prediction V
# Sample ['...___,,__,,,_._', '_,_.__.,_.,,,.,.', '_,,,_....___.._r', 'R'] | Prediction V
# Sample ['._._,,..,.,.,._.', '___,,..,.,.uw._.', '___,.,,,dr____._', 'A'] | Prediction V
# Sample [',,.._._.,_,_.,,_', '.._,__wu,,_,,_.,', '.___,,_,,.,_._,r', 'R'] | Prediction V
# Sample [',____.___,,_,_,.', ',,,,_...,,_,_,_,', ',,,.,.._.._,,,r_', 'R'] | Prediction V
# Sample ['_,..._._,__._,.,', '_.._,,.w._,_....', ',..,..,.,.._,.r.', 'R'] | Prediction V
# Sample ['_.,,_._._.,.,_,.', '.,,,.w...,_,._..', '_,_._.__._,_,r,_', 'R'] | Prediction V
# Sample [',,__._._.._.,,._', '._...,,.___,uw..', '__.,.,_,_._dr...', 'A'] | Prediction V
# Sample [',__.,.,_.,__._.,', '__._..,_.._.,uw.', ',,.._,,_,,,.,dr,', 'A'] | Prediction V

# %% [markdown]
# ## Top wrong predictions for best performing DeepSets V1 model

# %%
print_wrong_preds_bycases(get_wrong_predictions_bycases(best_deepset_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 10 Atomicity violation cases wrong predicted:
# Sample ['.._...,._,_____,', '_._.__,_.,.,,uw.', '.,__.._dr_._,,,.', 'A'] | Prediction V
# Sample ['._._,,..,.,.,._.', '___,,..,.,.uw._.', '___,.,,,dr____._', 'A'] | Prediction V
# Sample ['__,_._..____,...', '.,.,..._._.uw,..', '_.......__dr..,_', 'A'] | Prediction V
# Sample [',,__._._.._.,,._', '._...,,.___,uw..', '__.,.,_,_._dr...', 'A'] | Prediction V
# Sample [',__.,.,_.,__._.,', '__._..,_.._.,uw.', ',,.._,,_,,,.,dr,', 'A'] | Prediction V
# Sample ['._......_,._.,,.', '_,_,.,_,...uw.._', '.,._.,._,,_,.dr_', 'A'] | Prediction V
# Sample [',,,,_.,__.,.._..', '_,_.__.,.__uw.__', ',.__,.___dr.._,,', 'A'] | Prediction V
# Sample ['_.__,..___,,..,.', ',,__.,.,.,,.,uw.', '.._..,._dr_,.__,', 'A'] | Prediction V
# Sample ['__,.,,,,...,_,._', '___,,,,._..,.uw_', ',,..,_dr,.__,.,.', 'A'] | Prediction V
# Sample [',_,__.,,....._,.', '.,_.,uw__.,..__,', '_,_,._.,_dr.._._', 'A'] | Prediction V
#
#
# 10 DeadLock cases wrong predicted:
# Sample ['.,.,___.._,.,_.,', '._...,,__..w._..', '__._...,_.dr,__.', 'D'] | Prediction V
# Sample ['_.,,.,.__..,.,,,', '_.__,.___,,.,,_.', ',.,.,_.dr,....__', 'D'] | Prediction V
# Sample ['_,_..,.,,..,_.__', '.,.,,_.._._.._,.', ',._.._.,____.dr,', 'D'] | Prediction V
# Sample [',,._._..,_._._.,', ',,_,_..,.,.,_._,', '._.._,,,,dr._,,,', 'D'] | Prediction R
# Sample ['.,..,,_,_,_.__._', '.,,._.,,.,,._,._', '__.,..,,dr___.__', 'D'] | Prediction V
# Sample ['_.,._.__,,,..,,,', '__,,,_,w.____,,,', '..__.,,.,.dr_,_,', 'D'] | Prediction V
# Sample ['_,____,,.._,,_..', '.,_...,,,__..___', ',.,._dr.._..,,._', 'D'] | Prediction V
# Sample ['__,..____.,.....', ',__,.,.w_,,.....', ',.,_._,__._dr._,', 'D'] | Prediction V
# Sample [',_..__.....,,.._', '_____,.._,,_..,_', '.,_._.,___dr,,_.', 'D'] | Prediction V
# Sample [',.,,_,.._,.,,,,,', '.,_,___w__,_..,,', ',,....,,..__.dr.', 'D'] | Prediction V
#
#
# 10 Data race cases wrong predicted:
# Sample ['._,_.,._,_,.__._', '_,,,..wu,,_.,.,.', '_.___,,._,__r,..', 'R'] | Prediction V
# Sample ['._._,,,,___,._,.', '_..__w.,._.,_,,.', '.,,,.._r,,,_.._,', 'R'] | Prediction V
# Sample [',__,,...,..___.,', ',._.._,_____w__,', '___,.r,,._...,_,', 'R'] | Prediction V
# Sample ['.,._.._..,,.._..', '__.__,.,.,_._,.,', ',__,,.__r._,.,__', 'R'] | Prediction V
# Sample [',_,__,._..,__.,.', '._,.._,___.w,,.,', '__.,__,.r..,_,_.', 'R'] | Prediction V
# Sample [',_..,_____,__.,,', '____,wu.,,_.,,..', '__,,.,r.......__', 'R'] | Prediction V
# Sample ['._.._,._____,_,.', '.,,,_,__,,_wu,.,', ',,,,,.__,_r_._.,', 'R'] | Prediction V
# Sample [',,._.,,.,__,.,.,', '_..,...._....,,.', '_.,._,,_._r..__.', 'R'] | Prediction V
# Sample ['.__,...,._,,.,__', '..,.,.,_.uw..__.', ',,,.,..,__._r..,', 'R'] | Prediction V
# Sample [',,_,._..,.._._..', '.,.....uw,__,_,_', '.__,..,_.r,,_.,_', 'R'] | Prediction V
#
#
# 0 Valid cases wrong predicted:

# %%
print_wrong_preds(get_wrong_predictions(best_deepset_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 0 false Atomicity violation:
#
#
# 0 false DeadLock:
#
#
# 3 false Data race :
# Sample [',,._._..,_._._.,', ',,_,_..,.,.,_._,', '._.._,,,,dr._,,,', 'D'] | Prediction R
# Sample ['_,__._..__..._,_', '_...._,,__._w,__', '..,,.,,_dr,.__,_', 'D'] | Prediction R
# Sample ['_,..._,,,,___,_.', '..___.,_.w._,...', '.__,___.__._dr..', 'D'] | Prediction R
#
#
# 10 false Valid:
# Sample ['.._...,._,_____,', '_._.__,_.,.,,uw.', '.,__.._dr_._,,,.', 'A'] | Prediction V
# Sample ['.,.,___.._,.,_.,', '._...,,__..w._..', '__._...,_.dr,__.', 'D'] | Prediction V
# Sample ['._,_.,._,_,.__._', '_,,,..wu,,_.,.,.', '_.___,,._,__r,..', 'R'] | Prediction V
# Sample ['._._,,,,___,._,.', '_..__w.,._.,_,,.', '.,,,.._r,,,_.._,', 'R'] | Prediction V
# Sample [',__,,...,..___.,', ',._.._,_____w__,', '___,.r,,._...,_,', 'R'] | Prediction V
# Sample ['.,._.._..,,.._..', '__.__,.,.,_._,.,', ',__,,.__r._,.,__', 'R'] | Prediction V
# Sample [',_,__,._..,__.,.', '._,.._,___.w,,.,', '__.,__,.r..,_,_.', 'R'] | Prediction V
# Sample ['_.,,.,.__..,.,,,', '_.__,.___,,.,,_.', ',.,.,_.dr,....__', 'D'] | Prediction V
# Sample [',_..,_____,__.,,', '____,wu.,,_.,,..', '__,,.,r.......__', 'R'] | Prediction V
# Sample ['._.._,._____,_,.', '.,,,_,__,,_wu,.,', ',,,,,.__,_r_._.,', 'R'] | Prediction V

# %% [markdown]
# ## Top wrong predictions for best performing DeepSets V2 model

# %%
print_wrong_preds_bycases(get_wrong_predictions_bycases(best_deepsetv2_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 10 Atomicity violation cases wrong predicted:
# Sample ['.._...,._,_____,', '_._.__,_.,.,,uw.', '.,__.._dr_._,,,.', 'A'] | Prediction V
# Sample ['._._,,..,.,.,._.', '___,,..,.,.uw._.', '___,.,,,dr____._', 'A'] | Prediction V
# Sample ['__,_._..____,...', '.,.,..._._.uw,..', '_.......__dr..,_', 'A'] | Prediction V
# Sample [',,__._._.._.,,._', '._...,,.___,uw..', '__.,.,_,_._dr...', 'A'] | Prediction V
# Sample [',__.,.,_.,__._.,', '__._..,_.._.,uw.', ',,.._,,_,,,.,dr,', 'A'] | Prediction V
# Sample ['._......_,._.,,.', '_,_,.,_,...uw.._', '.,._.,._,,_,.dr_', 'A'] | Prediction V
# Sample [',,,,_.,__.,.._..', '_,_.__.,.__uw.__', ',.__,.___dr.._,,', 'A'] | Prediction V
# Sample ['_.__,..___,,..,.', ',,__.,.,.,,.,uw.', '.._..,._dr_,.__,', 'A'] | Prediction V
# Sample ['__,.,,,,...,_,._', '___,,,,._..,.uw_', ',,..,_dr,.__,.,.', 'A'] | Prediction V
# Sample [',_,__.,,....._,.', '.,_.,uw__.,..__,', '_,_,._.,_dr.._._', 'A'] | Prediction V
#
#
# 10 DeadLock cases wrong predicted:
# Sample ['.,.,___.._,.,_.,', '._...,,__..w._..', '__._...,_.dr,__.', 'D'] | Prediction V
# Sample ['_.,,.,.__..,.,,,', '_.__,.___,,.,,_.', ',.,.,_.dr,....__', 'D'] | Prediction V
# Sample ['_,_..,.,,..,_.__', '.,.,,_.._._.._,.', ',._.._.,____.dr,', 'D'] | Prediction V
# Sample [',,._._..,_._._.,', ',,_,_..,.,.,_._,', '._.._,,,,dr._,,,', 'D'] | Prediction V
# Sample ['.,..,,_,_,_.__._', '.,,._.,,.,,._,._', '__.,..,,dr___.__', 'D'] | Prediction V
# Sample ['_.,._.__,,,..,,,', '__,,,_,w.____,,,', '..__.,,.,.dr_,_,', 'D'] | Prediction V
# Sample ['_,____,,.._,,_..', '.,_...,,,__..___', ',.,._dr.._..,,._', 'D'] | Prediction V
# Sample ['__,..____.,.....', ',__,.,.w_,,.....', ',.,_._,__._dr._,', 'D'] | Prediction V
# Sample [',_..__.....,,.._', '_____,.._,,_..,_', '.,_._.,___dr,,_.', 'D'] | Prediction V
# Sample [',.,,_,.._,.,,,,,', '.,_,___w__,_..,,', ',,....,,..__.dr.', 'D'] | Prediction V
#
#
# 10 Data race cases wrong predicted:
# Sample ['._,_.,._,_,.__._', '_,,,..wu,,_.,.,.', '_.___,,._,__r,..', 'R'] | Prediction V
# Sample ['._._,,,,___,._,.', '_..__w.,._.,_,,.', '.,,,.._r,,,_.._,', 'R'] | Prediction V
# Sample ['.,._.._..,,.._..', '__.__,.,.,_._,.,', ',__,,.__r._,.,__', 'R'] | Prediction V
# Sample [',_,__,._..,__.,.', '._,.._,___.w,,.,', '__.,__,.r..,_,_.', 'R'] | Prediction V
# Sample [',_..,_____,__.,,', '____,wu.,,_.,,..', '__,,.,r.......__', 'R'] | Prediction V
# Sample ['._.._,._____,_,.', '.,,,_,__,,_wu,.,', ',,,,,.__,_r_._.,', 'R'] | Prediction V
# Sample [',,._.,,.,__,.,.,', '_..,...._....,,.', '_.,._,,_._r..__.', 'R'] | Prediction V
# Sample ['.__,...,._,,.,__', '..,.,.,_.uw..__.', ',,,.,..,__._r..,', 'R'] | Prediction V
# Sample [',.,._._.__...,..', '_.,,..__,.._w,,.', '_,.,,.,.,.,r.,_.', 'R'] | Prediction V
# Sample [',,_,._..,.._._..', '.,.....uw,__,_,_', '.__,..,_.r,,_.,_', 'R'] | Prediction V
#
#
# 1 Valid cases wrong predicted:
# Sample ['__,_._,_..,...,,', ',__,.,..,_.__,..', ',_,_,._._cr,_.__', 'V'] | Prediction R

# %%
print_wrong_preds(get_wrong_predictions(best_deepsetv2_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 0 false Atomicity violation:
#
#
# 0 false DeadLock:
#
#
# 1 false Data race :
# Sample ['__,_._,_..,...,,', ',__,.,..,_.__,..', ',_,_,._._cr,_.__', 'V'] | Prediction R
#
#
# 10 false Valid:
# Sample ['.._...,._,_____,', '_._.__,_.,.,,uw.', '.,__.._dr_._,,,.', 'A'] | Prediction V
# Sample ['.,.,___.._,.,_.,', '._...,,__..w._..', '__._...,_.dr,__.', 'D'] | Prediction V
# Sample ['._,_.,._,_,.__._', '_,,,..wu,,_.,.,.', '_.___,,._,__r,..', 'R'] | Prediction V
# Sample ['._._,,,,___,._,.', '_..__w.,._.,_,,.', '.,,,.._r,,,_.._,', 'R'] | Prediction V
# Sample ['.,._.._..,,.._..', '__.__,.,.,_._,.,', ',__,,.__r._,.,__', 'R'] | Prediction V
# Sample [',_,__,._..,__.,.', '._,.._,___.w,,.,', '__.,__,.r..,_,_.', 'R'] | Prediction V
# Sample ['_.,,.,.__..,.,,,', '_.__,.___,,.,,_.', ',.,.,_.dr,....__', 'D'] | Prediction V
# Sample [',_..,_____,__.,,', '____,wu.,,_.,,..', '__,,.,r.......__', 'R'] | Prediction V
# Sample ['._.._,._____,_,.', '.,,,_,__,,_wu,.,', ',,,,,.__,_r_._.,', 'R'] | Prediction V
# Sample ['_,_..,.,,..,_.__', '.,.,,_.._._.._,.', ',._.._.,____.dr,', 'D'] | Prediction V

# %% [markdown]
# ## Top wrong predictions for best performing Feedforward model

# %%
print_wrong_preds_bycases(get_wrong_predictions_bycases(best_feedforward_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 10 Atomicity violation cases wrong predicted:
# Sample ['.._...,._,_____,', '_._.__,_.,.,,uw.', '.,__.._dr_._,,,.', 'A'] | Prediction V
# Sample ['._._,,..,.,.,._.', '___,,..,.,.uw._.', '___,.,,,dr____._', 'A'] | Prediction V
# Sample ['__,_._..____,...', '.,.,..._._.uw,..', '_.......__dr..,_', 'A'] | Prediction V
# Sample [',,__._._.._.,,._', '._...,,.___,uw..', '__.,.,_,_._dr...', 'A'] | Prediction V
# Sample [',__.,.,_.,__._.,', '__._..,_.._.,uw.', ',,.._,,_,,,.,dr,', 'A'] | Prediction V
# Sample ['._......_,._.,,.', '_,_,.,_,...uw.._', '.,._.,._,,_,.dr_', 'A'] | Prediction V
# Sample [',,,,_.,__.,.._..', '_,_.__.,.__uw.__', ',.__,.___dr.._,,', 'A'] | Prediction V
# Sample ['_.__,..___,,..,.', ',,__.,.,.,,.,uw.', '.._..,._dr_,.__,', 'A'] | Prediction V
# Sample ['__,.,,,,...,_,._', '___,,,,._..,.uw_', ',,..,_dr,.__,.,.', 'A'] | Prediction V
# Sample [',_,__.,,....._,.', '.,_.,uw__.,..__,', '_,_,._.,_dr.._._', 'A'] | Prediction V
#
#
# 10 DeadLock cases wrong predicted:
# Sample ['.,.,___.._,.,_.,', '._...,,__..w._..', '__._...,_.dr,__.', 'D'] | Prediction V
# Sample ['_.,,.,.__..,.,,,', '_.__,.___,,.,,_.', ',.,.,_.dr,....__', 'D'] | Prediction V
# Sample ['_,_..,.,,..,_.__', '.,.,,_.._._.._,.', ',._.._.,____.dr,', 'D'] | Prediction V
# Sample [',,._._..,_._._.,', ',,_,_..,.,.,_._,', '._.._,,,,dr._,,,', 'D'] | Prediction V
# Sample ['.,..,,_,_,_.__._', '.,,._.,,.,,._,._', '__.,..,,dr___.__', 'D'] | Prediction V
# Sample ['_.,._.__,,,..,,,', '__,,,_,w.____,,,', '..__.,,.,.dr_,_,', 'D'] | Prediction V
# Sample ['_,____,,.._,,_..', '.,_...,,,__..___', ',.,._dr.._..,,._', 'D'] | Prediction V
# Sample ['__,..____.,.....', ',__,.,.w_,,.....', ',.,_._,__._dr._,', 'D'] | Prediction V
# Sample [',_..__.....,,.._', '_____,.._,,_..,_', '.,_._.,___dr,,_.', 'D'] | Prediction V
# Sample [',.,,_,.._,.,,,,,', '.,_,___w__,_..,,', ',,....,,..__.dr.', 'D'] | Prediction V
#
#
# 10 Data race cases wrong predicted:
# Sample ['._,_.,._,_,.__._', '_,,,..wu,,_.,.,.', '_.___,,._,__r,..', 'R'] | Prediction V
# Sample ['._._,,,,___,._,.', '_..__w.,._.,_,,.', '.,,,.._r,,,_.._,', 'R'] | Prediction V
# Sample [',__,,...,..___.,', ',._.._,_____w__,', '___,.r,,._...,_,', 'R'] | Prediction V
# Sample ['.,._.._..,,.._..', '__.__,.,.,_._,.,', ',__,,.__r._,.,__', 'R'] | Prediction V
# Sample [',_,__,._..,__.,.', '._,.._,___.w,,.,', '__.,__,.r..,_,_.', 'R'] | Prediction V
# Sample [',_..,_____,__.,,', '____,wu.,,_.,,..', '__,,.,r.......__', 'R'] | Prediction V
# Sample ['._.._,._____,_,.', '.,,,_,__,,_wu,.,', ',,,,,.__,_r_._.,', 'R'] | Prediction V
# Sample [',,._.,,.,__,.,.,', '_..,...._....,,.', '_.,._,,_._r..__.', 'R'] | Prediction V
# Sample ['.__,...,._,,.,__', '..,.,.,_.uw..__.', ',,,.,..,__._r..,', 'R'] | Prediction V
# Sample [',.,._._.__...,..', '_.,,..__,.._w,,.', '_,.,,.,.,.,r.,_.', 'R'] | Prediction V
#
#
# 0 Valid cases wrong predicted:

# %%
print_wrong_preds(get_wrong_predictions(best_feedforward_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 0 false Atomicity violation:
#
#
# 0 false DeadLock:
#
#
# 0 false Data race :
#
#
# 10 false Valid:
# Sample ['.._...,._,_____,', '_._.__,_.,.,,uw.', '.,__.._dr_._,,,.', 'A'] | Prediction V
# Sample ['.,.,___.._,.,_.,', '._...,,__..w._..', '__._...,_.dr,__.', 'D'] | Prediction V
# Sample ['._,_.,._,_,.__._', '_,,,..wu,,_.,.,.', '_.___,,._,__r,..', 'R'] | Prediction V
# Sample ['._._,,,,___,._,.', '_..__w.,._.,_,,.', '.,,,.._r,,,_.._,', 'R'] | Prediction V
# Sample [',__,,...,..___.,', ',._.._,_____w__,', '___,.r,,._...,_,', 'R'] | Prediction V
# Sample ['.,._.._..,,.._..', '__.__,.,.,_._,.,', ',__,,.__r._,.,__', 'R'] | Prediction V
# Sample [',_,__,._..,__.,.', '._,.._,___.w,,.,', '__.,__,.r..,_,_.', 'R'] | Prediction V
# Sample ['_.,,.,.__..,.,,,', '_.__,.___,,.,,_.', ',.,.,_.dr,....__', 'D'] | Prediction V
# Sample [',_..,_____,__.,,', '____,wu.,,_.,,..', '__,,.,r.......__', 'R'] | Prediction V
# Sample ['._.._,._____,_,.', '.,,,_,__,,_wu,.,', ',,,,,.__,_r_._.,', 'R'] | Prediction V

# %%
confusionMatrix(best_lstm_model, x_test_lstm, y_test)

# %% [markdown]
# # Saving Notebook State

# %%
import dill
dill.dump_session('notebook_env_first_third.db')

# %% [markdown]
# # Loading Notebook State

# %%
import dill
# dill.load_session('notebook_env_first_third.db')
