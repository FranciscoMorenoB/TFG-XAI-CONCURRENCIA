# %%
from src.generate_data import Data
from src.evaluate import *
from src.models import *

import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
# %autosave 120
# Out:
# Autosaving every 120 seconds

# %% [markdown]
# # Get the synthetic dataset

# %%
# %%time
data = Data(layer_size=16, permutation_intervals=3)

# hack to get only third interval in train and all other intervals in test

train = data.samples[:400]
test = data.samples[1680:2583] + data.samples[-2*data.last_interval_size+52:]
data.samples = train+test
data.first_interval_size = 400
data.last_interval_size = len(data.samples) - data.first_interval_size
data.samples_char_sep = data.separate_string_chars(data.samples)
data.np_data = data.one_hot_encode(data.samples_char_sep)
# Out:
# C:\Users\franm\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but OneHotEncoder was fitted without feature names
#   warnings.warn(
# C:\Users\franm\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but OneHotEncoder was fitted without feature names
#   warnings.warn(
# CPU times: total: 1.14 s
# Wall time: 1.16 s

# %%
# %%time
train, val, test = data.get_splits(['1st_interval'], [])

train_unshuffled = train.copy()
np.random.shuffle(train)

x_train, y_train = data.get_x_y(train)
x_val, y_val = data.get_x_y(val)
x_test, y_test = data.get_x_y(test)

train_original = data.reverse_encoding(data.get_x_y(train_unshuffled)[0])
val_original = data.reverse_encoding(x_val)
test_original = data.reverse_encoding(x_test)
# Out:
# Number of samples: 400 train | 363 val | 1456 test
# CPU times: total: 172 ms
# Wall time: 160 ms

# %% [markdown]
# #### Peek at unshuffled train data

# %%
train_original[:20]
# Out:
# [[',..._.._,.___._.', 'w,,_,.,_,__.._.,', 'cr__,._,._,._,__', 'V'],
#  [',___._.,_.,,..,_', 'w_.,.,._,_._..,,', ',cr,__,,._._.,,_', 'V'],
#  [',_..,__......___', 'w__.____,_,..___', '.,cr_.__._.,..._', 'V'],
#  ['_.,,.,....,__._,', 'w,.,.,.___,_,_,_', '.._cr_.___.,,,.,', 'V'],
#  [',.._.._,_...,.,_', 'w.__,,_,,_,__..,', '..,_cr_.,.,_.___', 'V'],
#  [',,.._.....,,,,,_', '_w,.._.,...,_.,_', 'cr...__..,__,_..', 'V'],
#  ['__....,,,._..,,.', '.w._.,.,__.,.__.', '.cr_..,_.,_,__.,', 'V'],
#  [',,,__..__.____,.', '_w__,_._,,.__,,.', '..cr.__,..,,__,.', 'V'],
#  ['..,._,.__.,__,,_', ',w,_,..__,_,_,..', '_,.cr_,__.._,___', 'V'],
#  [',.,.,,__,,._.,__', ',w,,_,.__..__,,,', '_,_,cr.,._____.,', 'V'],
#  [',__._,_.___._.,_', '..w.._,__.__.___', 'cr,,,,,__..._,,.', 'V'],
#  ['__,,._,..,,,._,_', '_.w___,.,,,.,,._', '_cr_..__.,.,,._.', 'V'],
#  ['_,,,,,._.,..,___', '.,w_.,_,__,.,__,', '.,cr..,.__...,..', 'V'],
#  [',,_._,._,.,....,', '..w,,,_____.,.._', '.,_cr,_,_._,,,..', 'V'],
#  ['.,....__,___,,_,', '_.w.,,,_._..,_._', '_,_.cr.,.,...___', 'V'],
#  ['.._...._,,_,_.,,', '._,w,....,._,.__', 'cr,_,.__.._,_,..', 'V'],
#  ['_.,,____._.,_,._', ',._w...._.,,_,_.', '_cr____,._.,,,_.', 'V'],
#  [',,,__,,____..__,', '__.w_,.,,_,_,_,_', ',.cr,,_..,___,_.', 'V'],
#  [',___,.,_.,.._,..', ',_.w..,..,._._.,', ',,,cr_,._.,_,__.', 'V'],
#  ['__,..._,,.,,.__,', ',_,w,,,._.___.,,', '__.,cr._...,_,.,', 'V']]

# %%
pos_train_ratio = get_stats_and_ratio(train_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 25 | F2-uw 25 | F2-w 25 | F2-noop 25 |
# F3 cr:    F2-wu 25 | F2-uw 25 | F2-w 25 | F2-noop 25 |
# F3 r:    F2-wu 25 | F2-uw 25 | F2-w 25 | F2-noop 25 |
# F3 noop:    F2-wu 25 | F2-uw 25 | F2-w 25 | F2-noop 25 |
#
# Positive samples count: 175
# Total samples count: 400
# Positive class ratio: 0.4375

# %% [markdown]
# #### Peek at test data

# %%
test_original[:15]
# Out:
# [['.._...,._,_____,', '_._.__,_.,.,,uw.', '.,__.._dr_._,,,.', 'A'],
#  [',_,._,__,,_,_,.,', '_,._._..,w.,_,.,', '.,..____,_.__.,,', 'V'],
#  ['._.,,,,..,_..,__', '._,_.._,_.,,_.__', ',__,,_,,_,._.cr,', 'V'],
#  ['.,.,___.._,.,_.,', '._...,,__..w._..', '__._...,_.dr,__.', 'D'],
#  [',,,....______.._', '_,,._.___,.._uw,', '...._,,,,.___._.', 'V'],
#  [',.__,_,.,.,__._,', ',.,_.,_.,_.,...,', '.__..,_,,_cr_.,.', 'V'],
#  ['._,_.,._,_,.__._', '_,,,..wu,,_.,.,.', '_.___,,._,__r,..', 'R'],
#  ['._._,,,,___,._,.', '_..__w.,._.,_,,.', '.,,,.._r,,,_.._,', 'R'],
#  [',__,.._,,,_,.,,,', ',,,,_,.._wu.__._', '.,.,,___dr,_..,.', 'V'],
#  ['__._,__..,,.____', '._.,____._,..w_,', ',_,_,_,__.,,,,._', 'V'],
#  [',__,,...,..___.,', ',._.._,_____w__,', '___,.r,,._...,_,', 'R'],
#  [',.,__..,,.._,_.,', '._,,_,___.uw,.,,', '._.,_..__cr.,.,,', 'V'],
#  ['.,._.._..,,.._..', '__.__,.,.,_._,.,', ',__,,.__r._,.,__', 'R'],
#  [',_,__,._..,__.,.', '._,.._,___.w,,.,', '__.,__,.r..,_,_.', 'R'],
#  ['.._.,_,_._,._.__', '_,.,____._wu,,.,', '__.._.,_.._,.,..', 'V']]

# %%
pos_test_ratio = get_stats_and_ratio(test_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 73 | F2-uw 85 | F2-w 88 | F2-noop 97 |
# F3 cr:    F2-wu 74 | F2-uw 84 | F2-w 70 | F2-noop 90 |
# F3 r:    F2-wu 87 | F2-uw 86 | F2-w 103 | F2-noop 103 |
# F3 noop:    F2-wu 94 | F2-uw 99 | F2-w 102 | F2-noop 121 |
#
# Positive samples count: 649
# Total samples count: 1456
# Positive class ratio: 0.44574175824175827

# %% [markdown]
# #### Peek at val data

# %%
val_original[:15]
# Out:
# [['.,_..,_,,,,,,___', ',.,.,.,,_,__,___', '.,..,..._cr.,_,,', 'V'],
#  ['..___.,,.___,_._', '_..,..,wu.,,.__.', '__,___.,.,_,.._.', 'V'],
#  ['_,_._,..,.,,_.,.', ',_,,,._,.._..,._', '_,__.,,_,_cr_,.,', 'V'],
#  ['_.._.,__........', ',..,__.,.._..w._', '.,_._.,_.._,dr._', 'D'],
#  ['...,,,,,,,__._,,', ',._,,.,__.___.wu', '.__....,__r,_,__', 'R'],
#  [',,,_,.._,___..._', ',..,_,,._,.__.._', '___,_,.,r,__.__,', 'R'],
#  [',,__,,,_.,._..,,', '_,.,_,,_,,_._,.,', ',_.,,.,,,cr.,,,_', 'V'],
#  ['._,._..,__,__.__', ',.,._uw,_.....,_', '.,.,__..._cr_.,.', 'V'],
#  [',___.,.._,._,.__', '.._.,wu_.__,__.,', '._.,._.,__,.,_,,', 'V'],
#  [',_,__,_,._._._..', ',_,.._.__.,__wu_', ',._,._,,r____._,', 'R'],
#  ['_...__,..,_,.___', '___,,._,w__,.__.', ',___,,_,,,_.,.cr', 'V'],
#  ['.,....,,_._,._..', ',__.,_,,uw_,,,_,', '._.,,___._,r._,.', 'R'],
#  ['.._,_.._,,,,.,..', '__.__.,,,w,,_.,_', '____.,_.__cr,._.', 'V'],
#  ['.,.__.._.,,_,.,,', ',___.,,_,,.,,__,', '.._,,,.,_,,.dr,.', 'D'],
#  ['.....,..,,._.._.', '__.,.__.,.,,,wu_', '_._,__,.,,,,____', 'V']]

# %%
pos_val_ratio = get_stats_and_ratio(val_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 27 | F2-uw 15 | F2-w 22 | F2-noop 23 |
# F3 cr:    F2-wu 26 | F2-uw 16 | F2-w 10 | F2-noop 30 |
# F3 r:    F2-wu 23 | F2-uw 24 | F2-w 18 | F2-noop 29 |
# F3 noop:    F2-wu 26 | F2-uw 21 | F2-w 30 | F2-noop 23 |
#
# Positive samples count: 154
# Total samples count: 363
# Positive class ratio: 0.42424242424242425

# %% [markdown]
# #### Send label arrays to device

# %%
from sklearn.preprocessing import LabelEncoder

# Codificar etiquetas categóricas a índices numéricos
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_val = label_encoder.transform(y_val)
y_test = label_encoder.transform(y_test)

# Convertir a tensores de PyTorch
y_train = torch.tensor(y_train, dtype=torch.long).to(device)
y_val = torch.tensor(y_val, dtype=torch.long).to(device)
y_test = torch.tensor(y_test, dtype=torch.long).to(device)

# Verificar clases codificadas
print("Clases codificadas:", label_encoder.classes_)
# Out:
# Clases codificadas: ['A' 'D' 'R' 'V']

# %% [markdown]
# #### Get data in normal format (same as CNN format)

# %%
x_train_normal = data.to_conv_format(x_train)
x_val_normal = data.to_conv_format(x_val)
x_test_normal = data.to_conv_format(x_test)
for i in range(len(x_train_normal)):
    x_train_normal[i] = x_train_normal[i].to(device)
    x_val_normal[i] = x_val_normal[i].to(device)
    x_test_normal[i] = x_test_normal[i].to(device)

# %%
x_train_normal[0].shape
# Out:
# torch.Size([400, 128])

# %% [markdown]
# #### Get data in convolutional format, send to device

# %%
x_train_cnn = data.to_conv_format(x_train)
x_val_cnn = data.to_conv_format(x_val)
x_test_cnn = data.to_conv_format(x_test)
for i in range(len(x_train_cnn)):
    x_train_cnn[i] = x_train_cnn[i].to(device)
    x_val_cnn[i] = x_val_cnn[i].to(device)
    x_test_cnn[i] = x_test_cnn[i].to(device)

# %%
x_train_cnn[0].shape
# Out:
# torch.Size([400, 128])

# %% [markdown]
# #### Get data in LSTM format, send to device

# %%
x_train_lstm = data.to_lstm_format(x_train, padding_left_size=2, padding_right_size=0)
x_val_lstm = data.to_lstm_format(x_val, padding_left_size=0, padding_right_size=2)
x_test_lstm = data.to_lstm_format(x_test, padding_left_size=0, padding_right_size=2)
for i in range(len(x_train_lstm)):
    x_train_lstm[i] = x_train_lstm[i].to(device)
    x_val_lstm[i] = x_val_lstm[i].to(device)
    x_test_lstm[i] = x_test_lstm[i].to(device)

# %%
x_train_lstm[0].shape
# Out:
# torch.Size([400, 18, 8])

# %% [markdown]
# ### Define training parameters

# %%
num_experiments = 20
epochs = 200
early_stopping_limit = 100

experiment_name = "2nd_interval"

# %% [markdown]
# ### Define training procedure for each model

# %%
def train_models(constructor, x_train, x_val, x_test, weight_decay, *argv):
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    wrong_preds = []
    best_accuracy = 0
    
    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []

    for i in range(num_experiments):
        model = constructor(*argv)
        model.to(device)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), weight_decay=weight_decay)

        train_losses.append([])
        val_losses.append([])
        train_accs.append([])
        val_accs.append([])
        
        best_acc = 0

        early_stopping_cnt = 0

        for epoch in range(1, epochs + 1):
            train_loss, train_acc = train_epoch(model, x_train, y_train, criterion, optimizer, epoch, 10, verbose=False)
            val_loss, val_acc = eval_epoch(model, x_val, y_val, criterion, 'Validation', verbose=False)

            
            train_losses[-1].append(train_loss)
            val_losses[-1].append(val_loss)
            train_accs[-1].append(train_acc)
            val_accs[-1].append(val_acc)
            
            model_name = constructor.__name__[:constructor.__name__.find('_')]
            if val_acc > best_acc:
                best_acc = val_acc
                torch.save(model.state_dict(), f'./{model_name}_model_TEMP_' + experiment_name)    
                early_stopping_cnt = 0
            else:
                early_stopping_cnt += 1

            if early_stopping_cnt >= early_stopping_limit:
                break


        model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
    
        accuracies.append(get_accuracy_by_cases(model, x_test, y_test, test_original))
        precisions.append(get_precision_by_cases(model, x_test, y_test, test_original))
        recalls.append(get_recall_by_cases(model, x_test, y_test, test_original))
        f1_scores.append(get_f1_by_cases(precisions[-1], recalls[-1]))
        
        wrong_preds.append((f"Experimento {i}", get_wrong_predictions(model, x_test, y_test, test_original)))

        if accuracies[-1]['Overall'] > best_accuracy:
            torch.save(model.state_dict(), f'./best_{model_name}_model_' + experiment_name)    
            best_accuracy = accuracies[-1]['Overall']

        print(i + 1, "/", num_experiments, "models trained | Current model test accuracy:", accuracies[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test precision:", precisions[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test recall:", recalls[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test f1:", f1_scores[-1]['Overall'])


    
    return accuracies, precisions, recalls, f1_scores, wrong_preds, [train_losses, val_losses, train_accs, val_accs], model
    #return accuracies, precisions, wrong_preds, [train_losses, val_losses, train_accs, val_accs]

# %% [markdown]
# # Train models

# %%
# %%time
cnn_accuracies, cnn_precisions, cnn_recall, cnn_f1, cnn_wrong_preds, cnn_epoch_stats, model = train_models(
    CNN_Model, x_train_cnn, x_val_cnn, x_test_cnn, 0.0001, data, 64, 128, 4, -1, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_19944\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 1.0
# 1 / 20 models trained | Current model test precision: 1.0
# 1 / 20 models trained | Current model test recall: 1.0
# 1 / 20 models trained | Current model test f1: 1.0
# 2 / 20 models trained | Current model test accuracy: 0.9608516483516484
# 2 / 20 models trained | Current model test precision: 0.9652422563228189
# 2 / 20 models trained | Current model test recall: 0.9457305341740134
# 2 / 20 models trained | Current model test f1: 0.9553867843844873
# 3 / 20 models trained | Current model test accuracy: 0.9787087912087912
# 3 / 20 models trained | Current model test precision: 0.9878235799288431
# 3 / 20 models trained | Current model test recall: 0.9708837540371662
# 3 / 20 models trained | Current model test f1: 0.9792804151765034
# 4 / 20 models trained | Current model test accuracy: 0.9601648351648352
# 4 / 20 models trained | Current model test precision: 0.9728759070450996
# 4 / 20 models trained | Current model test recall: 0.9255936675461741
# 4 / 20 models trained | Current model test f1: 0.9486459945643878
# 5 / 20 models trained | Current model test accuracy: 0.9938186813186813
# 5 / 20 models trained | Current model test precision: 0.9912149198400052
# 5 / 20 models trained | Current model test recall: 0.9885009843404102
# 5 / 20 models trained | Current model test f1: 0.9898560918622122
# 6 / 20 models trained | Current model test accuracy: 0.9938186813186813
# 6 / 20 models trained | Current model test precision: 0.9893248056994819
# 6 / 20 models trained | Current model test recall: 0.9889776750926217
# 6 / 20 models trained | Current model test f1: 0.9891512099407347
# 7 / 20 models trained | Current model test accuracy: 0.9601648351648352
# 7 / 20 models trained | Current model test precision: 0.9745241080588168
# 7 / 20 models trained | Current model test recall: 0.9449123746868736
# 7 / 20 models trained | Current model test f1: 0.9594898267414746
# 8 / 20 models trained | Current model test accuracy: 0.9931318681318682
# 8 / 20 models trained | Current model test precision: 0.9899514191573267
# 8 / 20 models trained | Current model test recall: 0.982061887254902
# 8 / 20 models trained | Current model test f1: 0.9859908711844015
# 9 / 20 models trained | Current model test accuracy: 0.9718406593406593
# 9 / 20 models trained | Current model test precision: 0.9879127358490566
# 9 / 20 models trained | Current model test recall: 0.9550597547726214
# 9 / 20 models trained | Current model test f1: 0.9712084960450057
# 10 / 20 models trained | Current model test accuracy: 0.9711538461538461
# 10 / 20 models trained | Current model test precision: 0.9832094184056135
# 10 / 20 models trained | Current model test recall: 0.9649307622379173
# 10 / 20 models trained | Current model test f1: 0.9739843394926884
# 11 / 20 models trained | Current model test accuracy: 0.9690934065934066
# 11 / 20 models trained | Current model test precision: 0.9867957746478873
# 11 / 20 models trained | Current model test recall: 0.9608877851932329
# 11 / 20 models trained | Current model test f1: 0.9736694665295601
# 12 / 20 models trained | Current model test accuracy: 0.9739010989010989
# 12 / 20 models trained | Current model test precision: 0.9861203067670832
# 12 / 20 models trained | Current model test recall: 0.9752838782029276
# 12 / 20 models trained | Current model test f1: 0.9806721577614727
# 13 / 20 models trained | Current model test accuracy: 0.9979395604395604
# 13 / 20 models trained | Current model test precision: 0.9980371020973064
# 13 / 20 models trained | Current model test recall: 0.9973366527647743
# 13 / 20 models trained | Current model test f1: 0.9976867544893444
# 14 / 20 models trained | Current model test accuracy: 0.9835164835164835
# 14 / 20 models trained | Current model test precision: 0.9905870249253443
# 14 / 20 models trained | Current model test recall: 0.9775572958960986
# 14 / 20 models trained | Current model test f1: 0.9840290299764389
# 15 / 20 models trained | Current model test accuracy: 0.9800824175824175
# 15 / 20 models trained | Current model test precision: 0.9839004002825524
# 15 / 20 models trained | Current model test recall: 0.9800373081396998
# 15 / 20 models trained | Current model test f1: 0.9819650548337732
# 16 / 20 models trained | Current model test accuracy: 0.9965659340659341
# 16 / 20 models trained | Current model test precision: 0.993260120585702
# 16 / 20 models trained | Current model test recall: 0.9944203011019711
# 16 / 20 models trained | Current model test f1: 0.9938398722534837
# 17 / 20 models trained | Current model test accuracy: 0.9690934065934066
# 17 / 20 models trained | Current model test precision: 0.979501180821952
# 17 / 20 models trained | Current model test recall: 0.9550236345626123
# 17 / 20 models trained | Current model test f1: 0.9671075504720198
# 18 / 20 models trained | Current model test accuracy: 0.9725274725274725
# 18 / 20 models trained | Current model test precision: 0.9881936245572609
# 18 / 20 models trained | Current model test recall: 0.9667701381344095
# 18 / 20 models trained | Current model test f1: 0.9773644966200236
# 19 / 20 models trained | Current model test accuracy: 0.9539835164835165
# 19 / 20 models trained | Current model test precision: 0.9808352402745996
# 19 / 20 models trained | Current model test recall: 0.9471441874902995
# 19 / 20 models trained | Current model test f1: 0.9636953416963753
# 20 / 20 models trained | Current model test accuracy: 0.9910714285714286
# 20 / 20 models trained | Current model test precision: 0.9890243744830438
# 20 / 20 models trained | Current model test recall: 0.9823645412980495
# 20 / 20 models trained | Current model test f1: 0.9856832086191074
# CPU times: total: 2h 31min 1s
# Wall time: 1h 31min 42s

# %%
# %%time
lstm_accuracies, lstm_precision, lstm_recall, lstm_f1, lstm_wrong_preds, lstm_epoch_stats, model = train_models(LSTM_Model, x_train_lstm, x_val_lstm, x_test_lstm, 0.0001, data, 16, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_19944\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.8131868131868132
# 1 / 20 models trained | Current model test precision: 0.7787683034655281
# 1 / 20 models trained | Current model test recall: 0.7314177937459767
# 1 / 20 models trained | Current model test f1: 0.7543507325511811
# 2 / 20 models trained | Current model test accuracy: 0.7637362637362637
# 2 / 20 models trained | Current model test precision: 0.752051294664931
# 2 / 20 models trained | Current model test recall: 0.6568366528878895
# 2 / 20 models trained | Current model test f1: 0.7012266036425833
# 3 / 20 models trained | Current model test accuracy: 0.8489010989010989
# 3 / 20 models trained | Current model test precision: 0.7814590011139149
# 3 / 20 models trained | Current model test recall: 0.6797315776090589
# 3 / 20 models trained | Current model test f1: 0.7270541808833647
# 4 / 20 models trained | Current model test accuracy: 0.7809065934065934
# 4 / 20 models trained | Current model test precision: 0.7257433428129364
# 4 / 20 models trained | Current model test recall: 0.6359081199984795
# 4 / 20 models trained | Current model test f1: 0.6778622831671035
# 5 / 20 models trained | Current model test accuracy: 0.8385989010989011
# 5 / 20 models trained | Current model test precision: 0.7440754059837159
# 5 / 20 models trained | Current model test recall: 0.6991120542680345
# 5 / 20 models trained | Current model test f1: 0.7208933003296116
# 6 / 20 models trained | Current model test accuracy: 0.8221153846153846
# 6 / 20 models trained | Current model test precision: 0.5766278568199223
# 6 / 20 models trained | Current model test recall: 0.6223221693104135
# 6 / 20 models trained | Current model test f1: 0.5986042635975202
# 7 / 20 models trained | Current model test accuracy: 0.8406593406593407
# 7 / 20 models trained | Current model test precision: 0.7948657691227835
# 7 / 20 models trained | Current model test recall: 0.717220123029501
# 7 / 20 models trained | Current model test f1: 0.7540493932004316
# 8 / 20 models trained | Current model test accuracy: 0.7211538461538461
# 8 / 20 models trained | Current model test precision: 0.691829861249871
# 8 / 20 models trained | Current model test recall: 0.6540785482635305
# 8 / 20 models trained | Current model test f1: 0.6724247624773751
# 9 / 20 models trained | Current model test accuracy: 0.8028846153846154
# 9 / 20 models trained | Current model test precision: 0.792262443438914
# 9 / 20 models trained | Current model test recall: 0.6784703666755714
# 9 / 20 models trained | Current model test f1: 0.7309643013423244
# 10 / 20 models trained | Current model test accuracy: 0.7802197802197802
# 10 / 20 models trained | Current model test precision: 0.6993886579830871
# 10 / 20 models trained | Current model test recall: 0.6157125327189072
# 10 / 20 models trained | Current model test f1: 0.6548885591560906
# 11 / 20 models trained | Current model test accuracy: 0.7108516483516484
# 11 / 20 models trained | Current model test precision: 0.7504569652548638
# 11 / 20 models trained | Current model test recall: 0.5668402228149101
# 11 / 20 models trained | Current model test f1: 0.6458515166518923
# 12 / 20 models trained | Current model test accuracy: 0.8173076923076923
# 12 / 20 models trained | Current model test precision: 0.7728431928245715
# 12 / 20 models trained | Current model test recall: 0.6880543885703585
# 12 / 20 models trained | Current model test f1: 0.7279882686805845
# 13 / 20 models trained | Current model test accuracy: 0.782967032967033
# 13 / 20 models trained | Current model test precision: 0.6851906663663383
# 13 / 20 models trained | Current model test recall: 0.6455891135650587
# 13 / 20 models trained | Current model test f1: 0.664800655365082
# 14 / 20 models trained | Current model test accuracy: 0.8804945054945055
# 14 / 20 models trained | Current model test precision: 0.7996551572658583
# 14 / 20 models trained | Current model test recall: 0.7210613831102453
# 14 / 20 models trained | Current model test f1: 0.7583273258364845
# 15 / 20 models trained | Current model test accuracy: 0.75
# 15 / 20 models trained | Current model test precision: 0.37072110797252744
# 15 / 20 models trained | Current model test recall: 0.46353313519893546
# 15 / 20 models trained | Current model test f1: 0.41196438344661895
# 16 / 20 models trained | Current model test accuracy: 0.7129120879120879
# 16 / 20 models trained | Current model test precision: 0.5695249626783104
# 16 / 20 models trained | Current model test recall: 0.6207088144577172
# 16 / 20 models trained | Current model test f1: 0.5940163540623975
# 17 / 20 models trained | Current model test accuracy: 0.8722527472527473
# 17 / 20 models trained | Current model test precision: 0.824843215826134
# 17 / 20 models trained | Current model test recall: 0.7777970173037633
# 17 / 20 models trained | Current model test f1: 0.8006295857927728
# 18 / 20 models trained | Current model test accuracy: 0.8935439560439561
# 18 / 20 models trained | Current model test precision: 0.8466806390201683
# 18 / 20 models trained | Current model test recall: 0.7954595828434837
# 18 / 20 models trained | Current model test f1: 0.8202712764105945
# 19 / 20 models trained | Current model test accuracy: 0.779532967032967
# 19 / 20 models trained | Current model test precision: 0.7569340862418532
# 19 / 20 models trained | Current model test recall: 0.6957516993923109
# 19 / 20 models trained | Current model test f1: 0.7250544915338778
# 20 / 20 models trained | Current model test accuracy: 0.7568681318681318
# 20 / 20 models trained | Current model test precision: 0.8797805385035601
# 20 / 20 models trained | Current model test recall: 0.6091749442476522
# 20 / 20 models trained | Current model test f1: 0.719887554331435
# CPU times: total: 1h 8min 26s
# Wall time: 29min 26s

# %%
# %%time
deepset_accuracies, deepset_procision, deepset_recall, deepset_f1, deepset_wrong_preds, deepset_epoch_stats, model = train_models(DEEPSET_Model, x_train_normal, x_val_normal, x_test_normal, 0.005, data, 128, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_19944\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.551510989010989
# 1 / 20 models trained | Current model test precision: 0.20659012268008808
# 1 / 20 models trained | Current model test recall: 0.24981036641785434
# 1 / 20 models trained | Current model test f1: 0.22615380779728858
# 2 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 2 / 20 models trained | Current model test precision: 0.13856456043956045
# 2 / 20 models trained | Current model test recall: 0.25
# 2 / 20 models trained | Current model test f1: 0.17830313742819268
# 3 / 20 models trained | Current model test accuracy: 0.5501373626373627
# 3 / 20 models trained | Current model test precision: 0.2603365384615385
# 3 / 20 models trained | Current model test recall: 0.29077771493212673
# 3 / 20 models trained | Current model test f1: 0.2747164069919735
# 4 / 20 models trained | Current model test accuracy: 0.5446428571428571
# 4 / 20 models trained | Current model test precision: 0.20373644507307875
# 4 / 20 models trained | Current model test recall: 0.24951120309429692
# 4 / 20 models trained | Current model test f1: 0.2243123631413386
# 5 / 20 models trained | Current model test accuracy: 0.5487637362637363
# 5 / 20 models trained | Current model test precision: 0.2159884493632651
# 5 / 20 models trained | Current model test recall: 0.25067025662654935
# 5 / 20 models trained | Current model test f1: 0.2320405869871068
# 6 / 20 models trained | Current model test accuracy: 0.551510989010989
# 6 / 20 models trained | Current model test precision: 0.2167629430159833
# 6 / 20 models trained | Current model test recall: 0.25051877421765895
# 6 / 20 models trained | Current model test f1: 0.23242161966728364
# 7 / 20 models trained | Current model test accuracy: 0.5494505494505495
# 7 / 20 models trained | Current model test precision: 0.2948084324702589
# 7 / 20 models trained | Current model test recall: 0.33362053120117635
# 7 / 20 models trained | Current model test f1: 0.3130159541619628
# 8 / 20 models trained | Current model test accuracy: 0.5480769230769231
# 8 / 20 models trained | Current model test precision: 0.20973389355742297
# 8 / 20 models trained | Current model test recall: 0.2500106260196892
# 8 / 20 models trained | Current model test f1: 0.22810800256660038
# 9 / 20 models trained | Current model test accuracy: 0.551510989010989
# 9 / 20 models trained | Current model test precision: 0.20100415512465375
# 9 / 20 models trained | Current model test recall: 0.24981036641785434
# 9 / 20 models trained | Current model test f1: 0.2227653247344044
# 10 / 20 models trained | Current model test accuracy: 0.5528846153846154
# 10 / 20 models trained | Current model test precision: 0.2217816091954023
# 10 / 20 models trained | Current model test recall: 0.2500801038407339
# 10 / 20 models trained | Current model test f1: 0.2350822977379552
# 11 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 11 / 20 models trained | Current model test precision: 0.13856456043956045
# 11 / 20 models trained | Current model test recall: 0.25
# 11 / 20 models trained | Current model test f1: 0.17830313742819268
# 12 / 20 models trained | Current model test accuracy: 0.5528846153846154
# 12 / 20 models trained | Current model test precision: 0.23848547717842325
# 12 / 20 models trained | Current model test recall: 0.25077978636796106
# 12 / 20 models trained | Current model test f1: 0.24447816542363734
# 13 / 20 models trained | Current model test accuracy: 0.5501373626373627
# 13 / 20 models trained | Current model test precision: 0.24546782127485142
# 13 / 20 models trained | Current model test recall: 0.29416210611790206
# 13 / 20 models trained | Current model test f1: 0.2676179641824391
# 14 / 20 models trained | Current model test accuracy: 0.554945054945055
# 14 / 20 models trained | Current model test precision: 0.2461276637726914
# 14 / 20 models trained | Current model test recall: 0.2513645482976338
# 14 / 20 models trained | Current model test f1: 0.24871854283029007
# 15 / 20 models trained | Current model test accuracy: 0.5377747252747253
# 15 / 20 models trained | Current model test precision: 0.2104743712193569
# 15 / 20 models trained | Current model test recall: 0.2649210194602055
# 15 / 20 models trained | Current model test f1: 0.2345798301240235
# 16 / 20 models trained | Current model test accuracy: 0.5528846153846154
# 16 / 20 models trained | Current model test precision: 0.18028735632183907
# 16 / 20 models trained | Current model test recall: 0.2497302625771204
# 16 / 20 models trained | Current model test f1: 0.2094016935811496
# 17 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 17 / 20 models trained | Current model test precision: 0.13856456043956045
# 17 / 20 models trained | Current model test recall: 0.25
# 17 / 20 models trained | Current model test f1: 0.17830313742819268
# 18 / 20 models trained | Current model test accuracy: 0.5446428571428571
# 18 / 20 models trained | Current model test precision: 0.18504213483146068
# 18 / 20 models trained | Current model test recall: 0.2477619967762291
# 18 / 20 models trained | Current model test f1: 0.21185753769622445
# 19 / 20 models trained | Current model test accuracy: 0.5302197802197802
# 19 / 20 models trained | Current model test precision: 0.20036630036630038
# 19 / 20 models trained | Current model test recall: 0.24720372204948127
# 19 / 20 models trained | Current model test f1: 0.22133428399197133
# 20 / 20 models trained | Current model test accuracy: 0.5535714285714286
# 20 / 20 models trained | Current model test precision: 0.20110192837465565
# 20 / 20 models trained | Current model test recall: 0.250040051920367
# 20 / 20 models trained | Current model test f1: 0.22291668170274065
# CPU times: total: 33min 17s
# Wall time: 11min 16s

# %%
# %%time
deepsetv2_accuracies, deepsetv2_procision, deepsetv2_recall, deepsetv2_f1, deepsetv2_wrong_preds, deepsetv2_epoch_stats, model = train_models(DEEPSETV2_Model, x_train_normal, x_val_normal, x_test_normal, 0.0001, data, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_19944\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.5789835164835165
# 1 / 20 models trained | Current model test precision: 0.3685172088637435
# 1 / 20 models trained | Current model test recall: 0.27444638437419283
# 1 / 20 models trained | Current model test f1: 0.3146001316901819
# 2 / 20 models trained | Current model test accuracy: 0.5638736263736264
# 2 / 20 models trained | Current model test precision: 0.29599737157876693
# 2 / 20 models trained | Current model test recall: 0.2623833998685643
# 2 / 20 models trained | Current model test f1: 0.2781786217519178
# 3 / 20 models trained | Current model test accuracy: 0.5528846153846154
# 3 / 20 models trained | Current model test precision: 0.27829058554528285
# 3 / 20 models trained | Current model test recall: 0.3014522958301069
# 3 / 20 models trained | Current model test f1: 0.2894087659050003
# 4 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 4 / 20 models trained | Current model test precision: 0.138659793814433
# 4 / 20 models trained | Current model test recall: 0.25
# 4 / 20 models trained | Current model test f1: 0.1783819628647215
# 5 / 20 models trained | Current model test accuracy: 0.2603021978021978
# 5 / 20 models trained | Current model test precision: 0.06507554945054946
# 5 / 20 models trained | Current model test recall: 0.25
# 5 / 20 models trained | Current model test f1: 0.10326975476839238
# 6 / 20 models trained | Current model test accuracy: 0.5535714285714286
# 6 / 20 models trained | Current model test precision: 0.221935261707989
# 6 / 20 models trained | Current model test recall: 0.3333333333333333
# 6 / 20 models trained | Current model test f1: 0.2664599483204134
# 7 / 20 models trained | Current model test accuracy: 0.5521978021978022
# 7 / 20 models trained | Current model test precision: 0.20676313306071092
# 7 / 20 models trained | Current model test recall: 0.2501201557611009
# 7 / 20 models trained | Current model test f1: 0.2263844106890404
# 8 / 20 models trained | Current model test accuracy: 0.5501373626373627
# 8 / 20 models trained | Current model test precision: 0.421875
# 8 / 20 models trained | Current model test recall: 0.498531157124501
# 8 / 20 models trained | Current model test f1: 0.4570109191119844
# 9 / 20 models trained | Current model test accuracy: 0.5487637362637363
# 9 / 20 models trained | Current model test precision: 0.19341275736624575
# 9 / 20 models trained | Current model test recall: 0.2503204153629358
# 9 / 20 models trained | Current model test f1: 0.2182174547042847
# 10 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 10 / 20 models trained | Current model test precision: 0.257251950335128
# 10 / 20 models trained | Current model test recall: 0.25314857137252206
# 10 / 20 models trained | Current model test f1: 0.2551837662400907
# 11 / 20 models trained | Current model test accuracy: 0.5528846153846154
# 11 / 20 models trained | Current model test precision: 0.17443064182194618
# 11 / 20 models trained | Current model test recall: 0.2520118084408485
# 11 / 20 models trained | Current model test f1: 0.2061641915149729
# 12 / 20 models trained | Current model test accuracy: 0.573489010989011
# 12 / 20 models trained | Current model test precision: 0.3748129967274427
# 12 / 20 models trained | Current model test recall: 0.2684696569920844
# 12 / 20 models trained | Current model test f1: 0.31285132930528226
# 13 / 20 models trained | Current model test accuracy: 0.551510989010989
# 13 / 20 models trained | Current model test precision: 0.20121527777777778
# 13 / 20 models trained | Current model test recall: 0.2501602076814679
# 13 / 20 models trained | Current model test f1: 0.2230340694127836
# 14 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 14 / 20 models trained | Current model test precision: 0.13856456043956045
# 14 / 20 models trained | Current model test recall: 0.25
# 14 / 20 models trained | Current model test f1: 0.17830313742819268
# 15 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 15 / 20 models trained | Current model test precision: 0.13856456043956045
# 15 / 20 models trained | Current model test recall: 0.25
# 15 / 20 models trained | Current model test f1: 0.17830313742819268
# 16 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 16 / 20 models trained | Current model test precision: 0.13856456043956045
# 16 / 20 models trained | Current model test recall: 0.25
# 16 / 20 models trained | Current model test f1: 0.17830313742819268
# 17 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 17 / 20 models trained | Current model test precision: 0.13856456043956045
# 17 / 20 models trained | Current model test recall: 0.25
# 17 / 20 models trained | Current model test f1: 0.17830313742819268
# 18 / 20 models trained | Current model test accuracy: 0.5508241758241759
# 18 / 20 models trained | Current model test precision: 0.2334050213855931
# 18 / 20 models trained | Current model test recall: 0.2522993071835163
# 18 / 20 models trained | Current model test f1: 0.242484662890378
# 19 / 20 models trained | Current model test accuracy: 0.551510989010989
# 19 / 20 models trained | Current model test precision: 0.13825757575757575
# 19 / 20 models trained | Current model test recall: 0.24876084262701362
# 19 / 20 models trained | Current model test f1: 0.17773351040283308
# 20 / 20 models trained | Current model test accuracy: 0.5535714285714286
# 20 / 20 models trained | Current model test precision: 0.24981617647058824
# 20 / 20 models trained | Current model test recall: 0.2643835437285232
# 20 / 20 models trained | Current model test f1: 0.25689351207903816
# CPU times: total: 25min 43s
# Wall time: 7min 59s

# %%
# %%time
feedforward_accuracies, feedforward_precision, feedforward_recall, feedforward_f1, feedforward_wrong_preds, feedforward_epoch_stats, model = train_models(FEEDFORWARD_Model, x_train_normal, x_val_normal, x_test_normal, 0.0001, data, 128, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_19944\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.5535714285714286
# 1 / 20 models trained | Current model test precision: 0.20150414937759337
# 1 / 20 models trained | Current model test recall: 0.25070240392821036
# 1 / 20 models trained | Current model test f1: 0.2234269905253206
# 2 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 2 / 20 models trained | Current model test precision: 0.13856456043956045
# 2 / 20 models trained | Current model test recall: 0.25
# 2 / 20 models trained | Current model test f1: 0.17830313742819268
# 3 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 3 / 20 models trained | Current model test precision: 0.13856456043956045
# 3 / 20 models trained | Current model test recall: 0.25
# 3 / 20 models trained | Current model test f1: 0.17830313742819268
# 4 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 4 / 20 models trained | Current model test precision: 0.13856456043956045
# 4 / 20 models trained | Current model test recall: 0.25
# 4 / 20 models trained | Current model test f1: 0.17830313742819268
# 5 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 5 / 20 models trained | Current model test precision: 0.13856456043956045
# 5 / 20 models trained | Current model test recall: 0.25
# 5 / 20 models trained | Current model test f1: 0.17830313742819268
# 6 / 20 models trained | Current model test accuracy: 0.5535714285714286
# 6 / 20 models trained | Current model test precision: 0.13848797250859107
# 6 / 20 models trained | Current model test recall: 0.2496902106567534
# 6 / 20 models trained | Current model test f1: 0.1781609195402299
# 7 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 7 / 20 models trained | Current model test precision: 0.22201192934159208
# 7 / 20 models trained | Current model test recall: 0.25034984126361354
# 7 / 20 models trained | Current model test f1: 0.2353308617591317
# 8 / 20 models trained | Current model test accuracy: 0.551510989010989
# 8 / 20 models trained | Current model test precision: 0.23853948287910554
# 8 / 20 models trained | Current model test recall: 0.2522592552631493
# 8 / 20 models trained | Current model test f1: 0.2452076080297457
# 9 / 20 models trained | Current model test accuracy: 0.551510989010989
# 9 / 20 models trained | Current model test precision: 0.18879250520471896
# 9 / 20 models trained | Current model test recall: 0.24981036641785434
# 9 / 20 models trained | Current model test f1: 0.21505707305409374
# 10 / 20 models trained | Current model test accuracy: 0.5521978021978022
# 10 / 20 models trained | Current model test precision: 0.2219523479065464
# 10 / 20 models trained | Current model test recall: 0.25081983828832805
# 10 / 20 models trained | Current model test f1: 0.23550476798433215
# 11 / 20 models trained | Current model test accuracy: 0.5254120879120879
# 11 / 20 models trained | Current model test precision: 0.1735586889349552
# 11 / 20 models trained | Current model test recall: 0.24083710148339235
# 11 / 20 models trained | Current model test f1: 0.2017364681149601
# 12 / 20 models trained | Current model test accuracy: 0.5446428571428571
# 12 / 20 models trained | Current model test precision: 0.1988691322901849
# 12 / 20 models trained | Current model test recall: 0.2498610443579105
# 12 / 20 models trained | Current model test f1: 0.2214678293122454
# 13 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 13 / 20 models trained | Current model test precision: 0.2464813511611541
# 13 / 20 models trained | Current model test recall: 0.2552476189542035
# 13 / 20 models trained | Current model test f1: 0.2507879024248265
# 14 / 20 models trained | Current model test accuracy: 0.5233516483516484
# 14 / 20 models trained | Current model test precision: 0.20209381276550364
# 14 / 20 models trained | Current model test recall: 0.24760424125315103
# 14 / 20 models trained | Current model test f1: 0.22254614946447213
# 15 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 15 / 20 models trained | Current model test precision: 0.13856456043956045
# 15 / 20 models trained | Current model test recall: 0.25
# 15 / 20 models trained | Current model test f1: 0.17830313742819268
# 16 / 20 models trained | Current model test accuracy: 0.5487637362637363
# 16 / 20 models trained | Current model test precision: 0.2506167477414871
# 16 / 20 models trained | Current model test recall: 0.2991856195214404
# 16 / 20 models trained | Current model test f1: 0.27275592612946264
# 17 / 20 models trained | Current model test accuracy: 0.5494505494505495
# 17 / 20 models trained | Current model test precision: 0.13831258644536654
# 17 / 20 models trained | Current model test recall: 0.24937655860349128
# 17 / 20 models trained | Current model test f1: 0.17793594306049823
# 18 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 18 / 20 models trained | Current model test precision: 0.13856456043956045
# 18 / 20 models trained | Current model test recall: 0.25
# 18 / 20 models trained | Current model test f1: 0.17830313742819268
# 19 / 20 models trained | Current model test accuracy: 0.5542582417582418
# 19 / 20 models trained | Current model test precision: 0.13856456043956045
# 19 / 20 models trained | Current model test recall: 0.25
# 19 / 20 models trained | Current model test f1: 0.17830313742819268
# 20 / 20 models trained | Current model test accuracy: 0.5494505494505495
# 20 / 20 models trained | Current model test precision: 0.20133053221288516
# 20 / 20 models trained | Current model test recall: 0.2502803634425688
# 20 / 20 models trained | Current model test f1: 0.22315262656005486
# CPU times: total: 36min 56s
# Wall time: 10min 59s

# %% [markdown]
# # Evaluation

# %% [markdown]
# # Evaluacion general de los modelos

# %%
import pandas as pd
# Lista de modelos y nombres
model_names = ['CNN', 'LSTM', 'DeepSet', 'DeepSetV2', 'Feedforward']
all_accuracies = [cnn_accuracies, lstm_accuracies, deepset_accuracies, deepsetv2_accuracies, feedforward_accuracies]
all_precisions = [cnn_precisions, lstm_precision, deepset_procision, deepsetv2_procision, feedforward_precision]
all_recalls = [cnn_recall, lstm_recall, deepset_recall, deepsetv2_recall, feedforward_recall]
all_f1_scores = [cnn_f1, lstm_f1, deepset_f1, deepsetv2_f1, feedforward_f1]

imprimirMetricas(model_names, all_accuracies, all_precisions, all_recalls, all_f1_scores)
# Out:
#         Modelo  Accuracy  Precision    Recall  F1-score  Precision clase A
# 0          CNN  1.000000   1.000000  1.000000  1.000000               1.00  \
# 1         LSTM  0.893544   0.846681  0.795460  0.820271               0.65
# 2      DeepSet  0.554945   0.246128  0.251365  0.248719               0.00
# 3    DeepSetV2  0.578984   0.368517  0.274446  0.314600               0.00
# 4  Feedforward  0.554258   0.138565  0.250000  0.178303               0.00
#
#    Recall clase A  Precision clase D  Recall clase D  Precision clase R
# 0        1.000000           1.000000        1.000000           1.000000  \
# 1        0.458824           0.868545        0.948718           0.983871
# 2        0.000000           0.000000        0.000000           0.428571
# 3        0.000000           0.000000        0.000000           0.904762
# 4        0.000000           0.000000        0.000000           0.000000
#
#    Recall clase R  Precision clase V  Recall clase V
# 0        1.000000           1.000000        1.000000
# 1        0.806878           0.884307        0.967419
# 2        0.007937           0.555939        0.997522
# 3        0.100264           0.569307        0.997522
# 4        0.000000           0.554258        1.000000

# %% [markdown]
# ### Get best 50% performing models

# %%
top_half = int(num_experiments / 2)
best_cnn_accs = filter_top_k_accuracies(cnn_accuracies, top_half)
best_lstm_accs = filter_top_k_accuracies(lstm_accuracies, top_half)
best_deepset_accs = filter_top_k_accuracies(deepset_accuracies, top_half)
best_deepsetv2_accs = filter_top_k_accuracies(deepsetv2_accuracies, top_half)
best_feedforward_accs = filter_top_k_accuracies(feedforward_accuracies, top_half)

# %% [markdown]
# ## Accuracy breakdown by cases for all the models

# %%
all_accuracies = [cnn_accuracies, lstm_accuracies, deepset_accuracies, deepsetv2_accuracies, feedforward_accuracies]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']

# %%
get_stats_df(all_accuracies, model_names, test_original)
# Out:
#                        Overall cr_noop   cr_uw    cr_w   cr_wu dr_noop  dr_uw
# CNN                      97.9%  100.0%  100.0%  100.0%  100.0%   98.9%  95.2%  \
# LSTM                     79.8%   99.9%  100.0%   99.9%  100.0%   70.9%  18.8%
# DeepSet(like in paper)   54.9%   98.1%   98.5%   97.9%   98.2%    0.3%   0.1%
# DeepSet(sum at start)    54.1%   93.8%   93.8%   94.1%   93.6%    0.1%   0.1%
# Feedforward              55.0%   98.4%   98.9%   98.1%   98.4%    0.1%   0.0%
# Sample count              1456      90      84      70      74      97     85
#
#                          dr_w  dr_wu noop_noop noop_uw  noop_w noop_wu r_noop
# CNN                     97.3%  94.9%    100.0%  100.0%  100.0%  100.0%  95.9%  \
# LSTM                    69.0%  30.4%     99.8%   99.9%   99.7%   99.6%  71.9%
# DeepSet(like in paper)   0.1%  98.6%     98.5%   98.3%   98.6%   99.5%   1.2%
# DeepSet(sum at start)    0.1%  93.6%     94.7%   94.4%   94.5%   94.5%   7.9%
# Feedforward              0.0%  98.6%     98.6%   98.5%   97.8%   99.3%   1.2%
# Sample count               88     73       121      99     102      94    103
#
#                          r_uw    r_w   r_wu
# CNN                     94.7%  95.0%  93.2%
# LSTM                    65.9%  69.3%  68.7%
# DeepSet(like in paper)   0.5%   2.6%   0.6%
# DeepSet(sum at start)    6.8%   7.1%   7.2%
# Feedforward              0.8%   2.2%   1.1%
# Sample count               86    103     87

# %% [markdown]
# ## Accuracy breakdown by cases for top 50% of models

# %%
best_accuracies = [best_cnn_accs, best_lstm_accs, best_deepset_accs, best_deepsetv2_accs, best_feedforward_accs]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']
collapsed_cases = ['dr', 'r', 'cr', 'noop']

# %%
get_stats_df(best_accuracies, model_names, test_original, collapsed_cases)
# Out:
#                        Overall   f3_cr  f3_dr f3_noop   f3_r
# CNN                      99.1%  100.0%  97.6%  100.0%  98.7%
# LSTM                     84.3%   99.9%  60.7%   99.7%  75.6%
# DeepSet(like in paper)   55.3%   99.5%  21.2%   99.6%   0.5%
# DeepSet(sum at start)    56.0%   99.6%  21.2%   99.9%   2.6%
# Feedforward              55.4%   99.8%  21.3%   99.7%   0.5%
# Sample count              1456     318    343     416    379

# %%
best_accuracies = [best_cnn_accs, best_lstm_accs, best_deepset_accs, best_deepsetv2_accs, best_feedforward_accs]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']
collapsed_cases = ['r', 'cr', 'noop']

# %%
get_stats_df(best_accuracies, model_names, test_original, collapsed_cases)
# Out:
#                        Overall dr_noop  dr_uw   dr_w  dr_wu   f3_cr f3_noop
# CNN                      99.1%   99.2%  97.8%  98.0%  94.8%  100.0%  100.0%  \
# LSTM                     84.3%   87.1%  23.6%  85.7%  38.8%   99.9%   99.7%
# DeepSet(like in paper)   55.3%    0.0%   0.0%   0.0%  99.6%   99.5%   99.6%
# DeepSet(sum at start)    56.0%    0.1%   0.0%   0.0%  99.5%   99.6%   99.9%
# Feedforward              55.4%    0.0%   0.0%   0.0%  99.9%   99.8%   99.7%
# Sample count              1456      97     85     88     73     318     416
#
#                          f3_r
# CNN                     98.7%
# LSTM                    75.6%
# DeepSet(like in paper)   0.5%
# DeepSet(sum at start)    2.6%
# Feedforward              0.5%
# Sample count              379

# %% [markdown]
# ## Accuracies per CNN model

# %%
get_stats_per_model(cnn_accuracies, ['CNN #' + str(i) for i in range(len(cnn_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#              Overall   f3_cr   f3_dr f3_noop    f3_r
# CNN #0        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #1         96.1%  100.0%   94.2%  100.0%   90.2%
# CNN #2         97.9%  100.0%   93.3%  100.0%   97.9%
# CNN #3         96.0%  100.0%   93.9%  100.0%   90.2%
# CNN #4         99.4%  100.0%   98.3%  100.0%   99.2%
# CNN #5         99.4%  100.0%   97.7%  100.0%   99.7%
# CNN #6         96.0%  100.0%   93.6%  100.0%   90.5%
# CNN #7         99.3%  100.0%   97.1%  100.0%  100.0%
# CNN #8         97.2%  100.0%   96.2%  100.0%   92.6%
# CNN #9         97.1%  100.0%   95.6%  100.0%   92.9%
# CNN #10        96.9%  100.0%   97.7%  100.0%   90.2%
# CNN #11        97.4%  100.0%   99.7%  100.0%   90.2%
# CNN #12        99.8%  100.0%   99.7%  100.0%   99.5%
# CNN #13        98.4%  100.0%   96.5%  100.0%   96.8%
# CNN #14        98.0%  100.0%   96.2%  100.0%   95.8%
# CNN #15        99.7%  100.0%   99.7%  100.0%   98.9%
# CNN #16        96.9%  100.0%   96.2%  100.0%   91.6%
# CNN #17        97.3%  100.0%   99.1%  100.0%   90.2%
# CNN #18        95.4%  100.0%   92.1%  100.0%   89.4%
# CNN #19        99.1%  100.0%   97.4%  100.0%   98.9%
# Sample count    1456     318     343     416     379

# %% [markdown]
# ## Accuracies per LSTM model

# %%
get_stats_per_model(best_lstm_accs, ['LSTM #' + str(i) for i in range(len(best_lstm_accs))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#              Overall   f3_cr  f3_dr f3_noop   f3_r
# LSTM #0        89.4%  100.0%  77.3%   99.3%  80.5%
# LSTM #1        88.0%  100.0%  63.3%  100.0%  87.3%
# LSTM #2        87.2%  100.0%  70.8%  100.0%  77.3%
# LSTM #3        84.9%  100.0%  61.5%   99.3%  77.6%
# LSTM #4        84.1%  100.0%  51.0%  100.0%  83.1%
# LSTM #5        83.9%   99.1%  47.2%   99.8%  86.8%
# LSTM #6        82.2%  100.0%  46.9%   99.5%  80.2%
# LSTM #7        81.7%  100.0%  65.6%  100.0%  60.9%
# LSTM #8        81.3%  100.0%  60.3%   99.5%  64.6%
# LSTM #9        80.3%  100.0%  63.3%  100.0%  57.5%
# Sample count    1456     318    343     416    379

# %% [markdown]
# ## Accuracies per DeepSets V1 model

# %%
get_stats_per_model(deepset_accuracies, ['DeepSet(like in paper) #' + str(i) for i in range(len(deepset_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                            Overall   f3_cr  f3_dr f3_noop  f3_r
# DeepSet(like in paper) #0    55.2%   99.4%  21.0%   99.0%  0.8%
# DeepSet(like in paper) #1    55.4%  100.0%  21.3%  100.0%  0.0%
# DeepSet(like in paper) #2    55.0%   98.7%  22.2%   98.8%  0.0%
# DeepSet(like in paper) #3    54.5%   95.3%  20.7%   98.1%  2.9%
# DeepSet(like in paper) #4    54.9%   97.8%  21.3%   97.6%  2.4%
# DeepSet(like in paper) #5    55.2%   98.4%  21.3%   99.0%  1.3%
# DeepSet(like in paper) #6    54.9%   97.5%  21.0%   98.8%  1.8%
# DeepSet(like in paper) #7    54.8%   96.9%  21.3%   98.3%  2.1%
# DeepSet(like in paper) #8    55.2%   99.1%  20.7%   99.5%  0.8%
# DeepSet(like in paper) #9    55.3%   99.7%  21.0%   99.5%  0.5%
# DeepSet(like in paper) #10   55.4%  100.0%  21.3%  100.0%  0.0%
# DeepSet(like in paper) #11   55.3%   99.4%  21.3%   99.0%  1.1%
# DeepSet(like in paper) #12   55.0%   98.7%  22.2%   98.6%  0.3%
# DeepSet(like in paper) #13   55.5%  100.0%  21.0%   99.8%  0.8%
# DeepSet(like in paper) #14   53.8%   95.9%  21.0%   95.2%  2.6%
# DeepSet(like in paper) #15   55.3%   99.1%  21.3%  100.0%  0.3%
# DeepSet(like in paper) #16   55.4%  100.0%  21.3%  100.0%  0.0%
# DeepSet(like in paper) #17   54.5%   97.8%  20.7%   97.4%  1.6%
# DeepSet(like in paper) #18   53.0%   90.6%  19.0%   95.2%  6.1%
# DeepSet(like in paper) #19   55.4%   99.4%  21.3%  100.0%  0.3%
# Sample count                  1456     318    343     416   379

# %% [markdown]
# ## Accuracies per DeepSets V2 model

# %%
get_stats_per_model(deepsetv2_accuracies, ['DeepSet(sum at start) #' + str(i) for i in range(len(deepsetv2_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                           Overall   f3_cr  f3_dr f3_noop    f3_r
# DeepSet(sum at start) #0    57.9%   99.7%  21.0%  100.0%   10.0%
# DeepSet(sum at start) #1    56.4%   97.8%  20.7%  100.0%    6.1%
# DeepSet(sum at start) #2    55.3%   98.1%  21.3%   99.8%    1.3%
# DeepSet(sum at start) #3    55.4%  100.0%  21.3%  100.0%    0.0%
# DeepSet(sum at start) #4    26.0%    0.0%   0.0%    0.0%  100.0%
# DeepSet(sum at start) #5    55.4%   99.7%  21.6%   99.8%    0.0%
# DeepSet(sum at start) #6    55.2%   99.7%  21.3%   98.8%    0.8%
# DeepSet(sum at start) #7    55.0%   99.1%  20.7%   99.3%    0.5%
# DeepSet(sum at start) #8    54.9%   97.5%  19.8%   99.3%    2.1%
# DeepSet(sum at start) #9    55.4%   98.4%  21.0%   99.3%    2.4%
# DeepSet(sum at start) #10   55.3%   99.4%  21.6%   99.8%    0.0%
# DeepSet(sum at start) #11   57.3%  100.0%  21.3%  100.0%    7.4%
# DeepSet(sum at start) #12   55.2%   98.1%  21.3%   99.5%    1.1%
# DeepSet(sum at start) #13   55.4%  100.0%  21.3%  100.0%    0.0%
# DeepSet(sum at start) #14   55.4%  100.0%  21.3%  100.0%    0.0%
# DeepSet(sum at start) #15   55.4%  100.0%  21.3%  100.0%    0.0%
# DeepSet(sum at start) #16   55.4%  100.0%  21.3%  100.0%    0.0%
# DeepSet(sum at start) #17   55.1%   97.5%  20.4%   98.8%    2.9%
# DeepSet(sum at start) #18   55.2%   99.1%  21.3%   99.8%    0.0%
# DeepSet(sum at start) #19   55.4%   92.8%  19.8%   96.4%   11.1%
# Sample count                 1456     318    343     416     379

# %% [markdown]
# ## Accuracies per FeedForward model

# %%
get_stats_per_model(feedforward_accuracies, ['Feedforward #' + str(i) for i in range(len(feedforward_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                 Overall   f3_cr  f3_dr f3_noop  f3_r
# Feedforward #0    55.4%  100.0%  21.3%   99.3%  0.5%
# Feedforward #1    55.4%  100.0%  21.3%  100.0%  0.0%
# Feedforward #2    55.4%  100.0%  21.3%  100.0%  0.0%
# Feedforward #3    55.4%  100.0%  21.3%  100.0%  0.0%
# Feedforward #4    55.4%  100.0%  21.3%  100.0%  0.0%
# Feedforward #5    55.4%  100.0%  21.3%   99.8%  0.0%
# Feedforward #6    55.4%   99.7%  21.3%  100.0%  0.3%
# Feedforward #7    55.2%   99.1%  21.0%   97.6%  2.6%
# Feedforward #8    55.2%  100.0%  20.7%   98.8%  0.8%
# Feedforward #9    55.2%   98.1%  21.3%   99.5%  1.3%
# Feedforward #10   52.5%   91.5%  19.8%   95.0%  2.9%
# Feedforward #11   54.5%   95.9%  20.4%   97.6%  3.2%
# Feedforward #12   55.4%   98.1%  21.0%   98.1%  4.0%
# Feedforward #13   52.3%   90.9%  19.8%   89.4%  8.7%
# Feedforward #14   55.4%  100.0%  21.3%  100.0%  0.0%
# Feedforward #15   54.9%   99.1%  21.3%   98.1%  0.8%
# Feedforward #16   54.9%   99.4%  21.3%   98.8%  0.0%
# Feedforward #17   55.4%  100.0%  21.3%  100.0%  0.0%
# Feedforward #18   55.4%  100.0%  21.3%  100.0%  0.0%
# Feedforward #19   54.9%   97.8%  20.7%   98.8%  1.8%
# Sample count       1456     318    343     416   379

# %% [markdown]
# # Training evolution

# %% [markdown]
# ### CNN

# %%
display_epochs_stats(cnn_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### LSTM

# %%
display_epochs_stats(lstm_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### DeepSets V1

# %%
display_epochs_stats(deepset_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### DeepSets V2

# %%
display_epochs_stats(deepsetv2_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### FeedForward

# %%
display_epochs_stats(feedforward_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# # Best performing models

# %%
best_cnn_model = CNN_Model(data, 64, 128, 4, -1,).to(device)
best_cnn_model.load_state_dict(torch.load('best_CNN_model_2nd_interval'))
best_deepset_model = DEEPSET_Model(data).to(device)
best_deepset_model.load_state_dict(torch.load('best_DEEPSET_model_2nd_interval'))
best_deepsetv2_model = DEEPSETV2_Model(data).to(device)
best_deepsetv2_model.load_state_dict(torch.load('best_DEEPSETV2_model_2nd_interval'))
best_feedforward_model = FEEDFORWARD_Model(data).to(device)
best_feedforward_model.load_state_dict(torch.load('best_FEEDFORWARD_model_2nd_interval'))
best_lstm_model = LSTM_Model(data, 16, 16, 8).to(device)
best_lstm_model.load_state_dict(torch.load('best_LSTM_model_2nd_interval'))
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_19944\2053327204.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_cnn_model.load_state_dict(torch.load('best_CNN_model_2nd_interval'))
# C:\Users\franm\AppData\Local\Temp\ipykernel_19944\2053327204.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_deepset_model.load_state_dict(torch.load('best_DEEPSET_model_2nd_interval'))
# C:\Users\franm\AppData\Local\Temp\ipykernel_19944\2053327204.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_deepsetv2_model.load_state_dict(torch.load('best_DEEPSETV2_model_2nd_interval'))
# C:\Users\franm\AppData\Local\Temp\ipykernel_19944\2053327204.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_feedforward_model.load_state_dict(torch.load('best_FEEDFORWARD_model_2nd_interval'))
# C:\Users\franm\AppData\Local\Temp\ipykernel_19944\2053327204.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_lstm_model.load_state_dict(torch.load('best_LSTM_model_2nd_interval'))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[63], line 10
#       8 best_feedforward_model.load_state_dict(torch.load('best_FEEDFORWARD_model_2nd_interval'))
#       9 best_lstm_model = LSTM_Model(data, 16, 16, 8).to(device)
# ---> 10 best_lstm_model.load_state_dict(torch.load('best_LSTM_model_2nd_interval'))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:2584, in Module.load_state_dict(self, state_dict, strict, assign)
#    2576         error_msgs.insert(
#    2577             0,
#    2578             "Missing key(s) in state_dict: {}. ".format(
#    2579                 ", ".join(f'"{k}"' for k in missing_keys)
#    2580             ),
#    2581         )
#    2583 if len(error_msgs) > 0:
# -> 2584     raise RuntimeError(
#    2585         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2586             self.__class__.__name__, "\n\t".join(error_msgs)
#    2587         )
#    2588     )
#    2589 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for LSTM_Model:
# 	size mismatch for densef1_1.weight: copying a param with shape torch.Size([32, 16]) from checkpoint, the shape in current model is torch.Size([16, 16]).
# 	size mismatch for densef1_1.bias: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([16]).
# 	size mismatch for densef2_1.weight: copying a param with shape torch.Size([32, 16]) from checkpoint, the shape in current model is torch.Size([16, 16]).
# 	size mismatch for densef2_1.bias: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([16]).
# 	size mismatch for densef3_1.weight: copying a param with shape torch.Size([32, 16]) from checkpoint, the shape in current model is torch.Size([16, 16]).
# 	size mismatch for densef3_1.bias: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([16]).
# 	size mismatch for densef1_2.weight: copying a param with shape torch.Size([8, 32]) from checkpoint, the shape in current model is torch.Size([8, 16]).
# 	size mismatch for densef2_2.weight: copying a param with shape torch.Size([8, 32]) from checkpoint, the shape in current model is torch.Size([8, 16]).
# 	size mismatch for densef3_2.weight: copying a param with shape torch.Size([8, 32]) from checkpoint, the shape in current model is torch.Size([8, 16]).

# %% [markdown]
# ## Top wrong predictions for best performing CNN model

# %%
print_wrong_preds([get_wrong_predictions(best_cnn_model, x_test_cnn, y_test, test_original)])
# Out:
# 4 false Atomicity violation:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 print_wrong_preds([get_wrong_predictions(best_cnn_model, x_test_cnn, y_test, test_original)])
#
# File ~\TFGNuestro\src\evaluate.py:405, in print_wrong_preds(wrong_preds_list, k)
#     403 print(f'{min(k,len(i))} false {cases[a]}:')
#     404 for j in range(min(k,len(i))):
# --> 405     print(f"Sample {i[j][0]} | Prediction {i[j][1]}")
#     406 a+=1
#     407 print("\n")
#
# IndexError: list index out of range

# %% [markdown]
# ## Top wrong predictions for best performing LSTM model

# %%
print_wrong_preds([get_wrong_predictions(best_lstm_model, x_test_lstm, y_test, test_original)])
# Out:
# 4 false Atomicity violation:
# Sample ([',_,._,__,,_,_,.,', '_,._._..,w.,_,.,', '.,..____,_.__.,,', 'V'], 'A') | Prediction (['._.,,,,..,_..,__', '._,_.._,_.,,_.__', ',__,,_,,_,._.cr,', 'V'], 'A')
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 print_wrong_preds([get_wrong_predictions(best_lstm_model, x_test_lstm, y_test, test_original)])
#
# File ~\TFGNuestro\src\evaluate.py:405, in print_wrong_preds(wrong_preds_list, k)
#     403 print(f'{min(k,len(i))} false {cases[a]}:')
#     404 for j in range(min(k,len(i))):
# --> 405     print(f"Sample {i[j][0]} | Prediction {i[j][1]}")
#     406 a+=1
#     407 print("\n")
#
# IndexError: list index out of range

# %% [markdown]
# ## Top wrong predictions for best performing DeepSets V1 model

# %%
print_wrong_preds([get_wrong_predictions(best_deepset_model, x_test_normal, y_test, test_original)])
# Out:
# 4 false Atomicity violation:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 print_wrong_preds([get_wrong_predictions(best_deepset_model, x_test_normal, y_test, test_original)])
#
# File ~\TFGNuestro\src\evaluate.py:405, in print_wrong_preds(wrong_preds_list, k)
#     403 print(f'{min(k,len(i))} false {cases[a]}:')
#     404 for j in range(min(k,len(i))):
# --> 405     print(f"Sample {i[j][0]} | Prediction {i[j][1]}")
#     406 a+=1
#     407 print("\n")
#
# IndexError: list index out of range

# %% [markdown]
# ## Top wrong predictions for best performing DeepSets V2 model

# %%
print_wrong_preds([get_wrong_predictions(best_deepsetv2_model, x_test_normal, y_test, test_original)])
# Out:
# 4 false Atomicity violation:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 print_wrong_preds([get_wrong_predictions(best_deepsetv2_model, x_test_normal, y_test, test_original)])
#
# File ~\TFGNuestro\src\evaluate.py:405, in print_wrong_preds(wrong_preds_list, k)
#     403 print(f'{min(k,len(i))} false {cases[a]}:')
#     404 for j in range(min(k,len(i))):
# --> 405     print(f"Sample {i[j][0]} | Prediction {i[j][1]}")
#     406 a+=1
#     407 print("\n")
#
# IndexError: list index out of range

# %% [markdown]
# ## Top wrong predictions for best performing Feedforward model

# %%
print_wrong_preds([get_wrong_predictions(best_feedforward_model, x_test_normal, y_test, test_original)])
# Out:
# 4 false Atomicity violation:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 print_wrong_preds([get_wrong_predictions(best_feedforward_model, x_test_normal, y_test, test_original)])
#
# File ~\TFGNuestro\src\evaluate.py:405, in print_wrong_preds(wrong_preds_list, k)
#     403 print(f'{min(k,len(i))} false {cases[a]}:')
#     404 for j in range(min(k,len(i))):
# --> 405     print(f"Sample {i[j][0]} | Prediction {i[j][1]}")
#     406 a+=1
#     407 print("\n")
#
# IndexError: list index out of range

# %% [markdown]
# # Saving Notebook State

# %%
import dill
dill.dump_session('notebook_env_first_third.db')

# %% [markdown]
# # Loading Notebook State

# %%
import dill
# dill.load_session('notebook_env_first_third.db')
