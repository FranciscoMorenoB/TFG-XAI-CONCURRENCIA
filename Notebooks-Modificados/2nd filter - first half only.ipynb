# %%
from src.generate_data import Data
from src.evaluate import *
from src.models import *

import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
# %autosave 120
# Out:
# Autosaving every 120 seconds

# %% [markdown]
# # Get the synthetic dataset

# %%
# %%time
data = Data(layer_size=16, permutation_intervals=2)
# Out:
# C:\Users\franm\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but OneHotEncoder was fitted without feature names
#   warnings.warn(
# CPU times: total: 672 ms
# Wall time: 668 ms

# %%
# %%time
train, val, test = data.get_splits(['1st_interval'], [])

train_unshuffled = train.copy()
np.random.shuffle(train)

x_train, y_train = data.get_x_y(train)
x_val, y_val = data.get_x_y(val)
x_test, y_test = data.get_x_y(test)

train_original = data.reverse_encoding(data.get_x_y(train_unshuffled)[0])
val_original = data.reverse_encoding(x_val)
test_original = data.reverse_encoding(x_test)
# Out:
# Number of samples: 900 train | 217 val | 872 test
# CPU times: total: 156 ms
# Wall time: 153 ms

# %% [markdown]
# #### Peek at unshuffled train data

# %%
train_original[:10]
# Out:
# [[',..._.._,.___._.', 'w,,_,.,_,__.._.,', 'cr__,._,._,._,__', 'V'],
#  [',___._.,_.,,..,_', 'w_.,.,._,_._..,,', ',cr,__,,._._.,,_', 'V'],
#  [',_..,__......___', 'w__.____,_,..___', '.,cr_.__._.,..._', 'V'],
#  ['_.,,.,....,__._,', 'w,.,.,.___,_,_,_', '.._cr_.___.,,,.,', 'V'],
#  [',.._.._,_...,.,_', 'w.__,,_,,_,__..,', '..,_cr_.,.,_.___', 'V'],
#  [',,.._.....,,,,,_', 'w_,.._.,...,_.,_', '...__cr..,__,_..', 'V'],
#  ['__....,,,._..,,.', 'w.._.,.,__.,.__.', '._..,_cr.,_,__.,', 'V'],
#  [',,,__..__.____,.', '_w__,_._,,.__,,.', 'cr...__,..,,__,.', 'V'],
#  ['..,._,.__.,__,,_', ',w,_,..__,_,_,..', '_cr,._,__.._,___', 'V'],
#  [',.,.,,__,,._.,__', ',w,,_,.__..__,,,', '_,cr_,.,._____.,', 'V']]

# %%
train_original[310:320]
# Out:
# [[',_,.__,.,.,..__.', '__.wu,.,...,_._,', 'dr,_,__,,.._,...', 'V'],
#  ['_,.,,_._,._,..__', ',._wu.,..,,__...', '_dr._...,..__,..', 'V'],
#  ['._____,..,.,....', '_..wu_,_._,,..,_', '__dr_,_,...___..', 'V'],
#  ['_.._...,,._____.', '...wu.,.,,_,,___', ',,_dr,.,_,__.,__', 'V'],
#  ['.._____._,_..,,_', '__.wu_..,,....,.', '_._,dr,._,_.,,_.', 'V'],
#  [',_,,,,_.,__._,,,', '.,.wu.,__.__,.,.', ',__,.dr.__.._,_.', 'V'],
#  ['_.._._.,.__...,,', '..,wu..____.,_,.', '__,,_.dr....,.,.', 'V'],
#  ['___._._,..__,.,.', '..,.wu..__._,...', 'dr,._.,,__..,,,,', 'V'],
#  [',.,,._...._.._._', '.._,wu,..,.,,_._', ',dr_...__..,_,._', 'V'],
#  [',.__,,.,_,..,,,.', '.,.,wu_,._,...__', '_.dr__.,,__,,__.', 'V']]

# %%
pos_train_ratio = get_stats_and_ratio(train_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 49 | F2-uw 49 | F2-w 56 | F2-noop 56 |
# F3 cr:    F2-wu 49 | F2-uw 49 | F2-w 56 | F2-noop 56 |
# F3 r:    F2-wu 56 | F2-uw 56 | F2-w 64 | F2-noop 64 |
# F3 noop:    F2-wu 56 | F2-uw 56 | F2-w 64 | F2-noop 64 |
#
# Positive samples count: 401
# Total samples count: 900
# Positive class ratio: 0.44555555555555554

# %% [markdown]
# #### Peek at test data

# %%
test_original[:15]
# Out:
# [['__...,_._,,_,,._', '...,,,____,__uw_', '.,,.,,,__,.,._,_', 'V'],
#  [',__._,._,,,_,,.,', ',,._._,_.__,..w_', '..,,,,.,.._,,cr.', 'V'],
#  ['___,___,,,.,,..,', '._,.,,,uw._...._', '__._.___,cr,_.,_', 'V'],
#  ['____,.,.,,_..,_.', '_,_.,...,,w__,,_', '__,._.,__dr,__,.', 'D'],
#  ['.,._.__,._.,....', '_..,,,.,,_.,w_..', ',,,.._.,dr,__,_,', 'D'],
#  [',,.,,_,,._,,..,_', ',,_,__.,,,___.uw', '_,._,,,..__,__cr', 'V'],
#  ['._.._,,_,,,_,_.,', ',,_,,__wu_,_.._.', '..._..,,r.,,.._,', 'R'],
#  ['____.__,_,.,,.,,', ',,,_,,.__w,._...', '_.,_,.,_,__._dr,', 'D'],
#  [',._.__.,,_....,_', '._.,___,__.,___,', '..,,,_.,.dr,,,..', 'D'],
#  ['__.,_,,.,,,..,,,', '.._,..,,,..,_uw.', '_,.,,.,.._.,.,._', 'V'],
#  [',,.,......,,_,,.', '_,,,,__,,._...,_', ',...,_.,.cr_,.,_', 'V'],
#  ['._._.,_,.,__,._.', '___,...,_,_,wu._', '._....,,,__,.,r_', 'R'],
#  ['_,,._.,..,_.,.,,', '.,.._.._w_.__,._', '__._,.,.,_,.._..', 'V'],
#  ['_,__._._._,__.,.', ',_.,.,,_._,,w.,,', ',,.._.__..___.cr', 'V'],
#  ['__.._.,_____...,', '...,,_._..uw....', ',.,,_..,dr,,_,,.', 'A']]

# %%
pos_test_ratio = get_stats_and_ratio(test_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 58 | F2-uw 48 | F2-w 54 | F2-noop 58 |
# F3 cr:    F2-wu 58 | F2-uw 53 | F2-w 49 | F2-noop 59 |
# F3 r:    F2-wu 51 | F2-uw 53 | F2-w 52 | F2-noop 57 |
# F3 noop:    F2-wu 56 | F2-uw 53 | F2-w 57 | F2-noop 56 |
#
# Positive samples count: 373
# Total samples count: 872
# Positive class ratio: 0.42775229357798167

# %% [markdown]
# #### Peek at val data

# %%
val_original[:15]
# Out:
# [['._...,._,_..._._', ',....__,_,_...w_', '___.._.,,._,._cr', 'V'],
#  ['.,,,,,___._.,___', '__,,.__,_._..wu_', '..,_,,__,.,,r.,.', 'R'],
#  ['_._._,___,,_,,..', ',,,__,_____.,,,_', '_.._._,,.._cr..,', 'V'],
#  ['_.,_,__,,,__,_.,', '_..._.,._,_,,,_w', '..___._cr,_,___.', 'V'],
#  ['....,,.,____..._', ',,__....._,,uw,,', '.,__,.,,.,,dr_._', 'A'],
#  [',____.,__.__,_.,', '._,..,._,.,.,.w.', ',_.._.,_,_._.__.', 'V'],
#  ['__..,_._....,_,_', ',_.,__.,.,.,.w,,', '_,_,__,.,.,cr_,,', 'V'],
#  ['.,,.._.,,,,,,._.', '_,__.,,,,,..uw,.', '_,...,,__.dr,.,.', 'A'],
#  ['_.,__.___.__.,__', '__,,,,.,,,__,,uw', '.__,.,_,___,r___', 'R'],
#  ['_._.._,__..,,,_,', '.__,,._____,..wu', ',,._._,,___._..,', 'V'],
#  [',.._..____,,,,.,', '.,,.,.__,.,_,,,_', '.__,_..__,,._.,r', 'R'],
#  [',,,,._,__._,.,_.', '.,._.___...wu,__', '__,,,,__.__,.r.,', 'R'],
#  ['.,_._._,,,,_,,_.', ',.,,_,_.._.___,w', ',__,._____._,,.,', 'V'],
#  [',.__,,___._,.__.', ',.,.,__..__,,wu.', ',_._.______,,__.', 'V'],
#  ['__,.._.,.._..,,_', '_,.,..,,_.._,,.w', '.._,_,,dr.__._,.', 'D']]

# %%
pos_val_ratio = get_stats_and_ratio(val_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 6 | F2-uw 16 | F2-w 10 | F2-noop 14 |
# F3 cr:    F2-wu 6 | F2-uw 11 | F2-w 15 | F2-noop 13 |
# F3 r:    F2-wu 13 | F2-uw 11 | F2-w 12 | F2-noop 15 |
# F3 noop:    F2-wu 16 | F2-uw 19 | F2-w 15 | F2-noop 25 |
#
# Positive samples count: 91
# Total samples count: 217
# Positive class ratio: 0.41935483870967744

# %% [markdown]
# #### Send label arrays to device

# %%
from sklearn.preprocessing import LabelEncoder
# Crear un codificador de etiquetas
label_encoder = LabelEncoder()

#input_tensor = input_tensor.requires_grad_()  # Esto habilita el cálculo de gradientes

#cambio de torch.float a torch.long

# Ajustar el codificador a las etiquetas y transformarlas a num enteros
y_train = label_encoder.fit_transform(y_train)
y_val = label_encoder.transform(y_val)
y_test = label_encoder.transform(y_test)

y_trainP = y_train

#Un tensor es una estructura de datos similar a matrices o arrays, pero con soporte para operaciones avanzadas en GPU.
# Convertir las etiquetas a tensores de PyTorch
y_train = torch.tensor(y_train, dtype=torch.long).to(device)
y_val = torch.tensor(y_val, dtype=torch.long).to(device)
y_test = torch.tensor(y_test, dtype=torch.long).to(device)

#se mueven los datos a la CPU o GPU para que puedan ser procesados por PyTorch durante el entrenamiento o la inferencia

# %% [markdown]
# #### Get data in normal format (same as CNN format)

# %%
x_train_normal = data.to_conv_format(x_train)
x_val_normal = data.to_conv_format(x_val)
x_test_normal = data.to_conv_format(x_test)
for i in range(len(x_train_normal)):
    x_train_normal[i] = x_train_normal[i].to(device)
    x_val_normal[i] = x_val_normal[i].to(device)
    x_test_normal[i] = x_test_normal[i].to(device)

# %%
x_train_normal[0].shape
# Out:
# torch.Size([900, 128])

# %% [markdown]
# #### Get data in convolutional format, send to device

# %%
x_train_cnn = data.to_conv_format(x_train)
x_val_cnn = data.to_conv_format(x_val)
x_test_cnn = data.to_conv_format(x_test)
for i in range(len(x_train_cnn)):
    x_train_cnn[i] = x_train_cnn[i].to(device)
    x_val_cnn[i] = x_val_cnn[i].to(device)
    x_test_cnn[i] = x_test_cnn[i].to(device)

# %%
x_train_cnn[0].shape
# Out:
# torch.Size([900, 128])

# %% [markdown]
# #### Get data in LSTM format, send to device

# %%
x_train_lstm = data.to_lstm_format(x_train, padding_left_size=2, padding_right_size=0)
x_val_lstm = data.to_lstm_format(x_val, padding_left_size=0, padding_right_size=2)
x_test_lstm = data.to_lstm_format(x_test, padding_left_size=0, padding_right_size=2)
for i in range(len(x_train_lstm)):
    x_train_lstm[i] = x_train_lstm[i].to(device)
    x_val_lstm[i] = x_val_lstm[i].to(device)
    x_test_lstm[i] = x_test_lstm[i].to(device)

# %%
x_train_lstm[0].shape
# Out:
# torch.Size([900, 18, 8])

# %% [markdown]
# ### Define training parameters

# %%
num_experiments = 20
epochs = 200
early_stopping_limit = 100
experiment_name="1st_interval"

# %% [markdown]
# ### Define training procedure for each model

# %%
def train_models(constructor, x_train, x_val, x_test, weight_decay, *argv):
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    wrong_preds = []
    best_accuracy = 0
    
    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []

    for i in range(num_experiments):
        model = constructor(*argv)
        model.to(device)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), weight_decay=weight_decay)

        train_losses.append([])
        val_losses.append([])
        train_accs.append([])
        val_accs.append([])
        
        best_acc = 0

        early_stopping_cnt = 0

        for epoch in range(1, epochs + 1):
            train_loss, train_acc = train_epoch(model, x_train, y_train, criterion, optimizer, epoch, 10, verbose=False)
            val_loss, val_acc = eval_epoch(model, x_val, y_val, criterion, 'Validation', verbose=False)

            
            train_losses[-1].append(train_loss)
            val_losses[-1].append(val_loss)
            train_accs[-1].append(train_acc)
            val_accs[-1].append(val_acc)
            
            model_name = constructor.__name__[:constructor.__name__.find('_')]
            if val_acc > best_acc:
                best_acc = val_acc
                torch.save(model.state_dict(), f'./{model_name}_model_TEMP_' + experiment_name)    
                early_stopping_cnt = 0
            else:
                early_stopping_cnt += 1

            if early_stopping_cnt >= early_stopping_limit:
                break


        model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
    
        accuracies.append(get_accuracy_by_cases(model, x_test, y_test, test_original))
        precisions.append(get_precision_by_cases(model, x_test, y_test, test_original))
        recalls.append(get_recall_by_cases(model, x_test, y_test, test_original))
        f1_scores.append(get_f1_by_cases(precisions[-1], recalls[-1]))
        
        wrong_preds.append((f"Experimento {i}", get_wrong_predictions(model, x_test, y_test, test_original)))

        if accuracies[-1]['Overall'] > best_accuracy:
            torch.save(model.state_dict(), f'./best_{model_name}_model_' + experiment_name)    
            best_accuracy = accuracies[-1]['Overall']

        print(i + 1, "/", num_experiments, "models trained | Current model test accuracy:", accuracies[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test precision:", precisions[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test recall:", recalls[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test f1:", f1_scores[-1]['Overall'])


    
    return accuracies, precisions, recalls, f1_scores, wrong_preds, [train_losses, val_losses, train_accs, val_accs], model
    #return accuracies, precisions, wrong_preds, [train_losses, val_losses, train_accs, val_accs]

# %% [markdown]
# # Train models

# %%
# %%time
cnn_accuracies, cnn_precisions, cnn_recall, cnn_f1, cnn_wrong_preds, cnn_epoch_stats, model = train_models(
    CNN_Model, x_train_cnn, x_val_cnn, x_test_cnn, 0.0001, data, 64, 128, 4, -1, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_4148\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.9724770642201835
# 1 / 20 models trained | Current model test precision: 0.9784818733623006
# 1 / 20 models trained | Current model test recall: 0.9661613750298401
# 1 / 20 models trained | Current model test f1: 0.9722825952689688
# 2 / 20 models trained | Current model test accuracy: 0.9931192660550459
# 2 / 20 models trained | Current model test precision: 0.9872881355932204
# 2 / 20 models trained | Current model test recall: 0.9872881355932204
# 2 / 20 models trained | Current model test f1: 0.9872881355932204
# 3 / 20 models trained | Current model test accuracy: 0.963302752293578
# 3 / 20 models trained | Current model test precision: 0.9747640508148003
# 3 / 20 models trained | Current model test recall: 0.9567717036683377
# 3 / 20 models trained | Current model test f1: 0.9656840774581358
# 4 / 20 models trained | Current model test accuracy: 0.9564220183486238
# 4 / 20 models trained | Current model test precision: 0.971941391941392
# 4 / 20 models trained | Current model test recall: 0.9306213885879379
# 4 / 20 models trained | Current model test f1: 0.950832694774928
# 5 / 20 models trained | Current model test accuracy: 0.9472477064220184
# 5 / 20 models trained | Current model test precision: 0.9747653220252981
# 5 / 20 models trained | Current model test recall: 0.9333316072908037
# 5 / 20 models trained | Current model test f1: 0.953598604724228
# 6 / 20 models trained | Current model test accuracy: 0.9655963302752294
# 6 / 20 models trained | Current model test precision: 0.9789033026672844
# 6 / 20 models trained | Current model test recall: 0.960862878419945
# 6 / 20 models trained | Current model test f1: 0.9697991997865232
# 7 / 20 models trained | Current model test accuracy: 0.981651376146789
# 7 / 20 models trained | Current model test precision: 0.9922330097087378
# 7 / 20 models trained | Current model test recall: 0.96875
# 7 / 20 models trained | Current model test f1: 0.9803508989076956
# 8 / 20 models trained | Current model test accuracy: 0.9770642201834863
# 8 / 20 models trained | Current model test precision: 0.9852258336850992
# 8 / 20 models trained | Current model test recall: 0.9432101458307366
# 8 / 20 models trained | Current model test f1: 0.9637602825680949
# 9 / 20 models trained | Current model test accuracy: 0.9610091743119266
# 9 / 20 models trained | Current model test precision: 0.9587865216464064
# 9 / 20 models trained | Current model test recall: 0.9641301382106937
# 9 / 20 models trained | Current model test f1: 0.9614509052079206
# 10 / 20 models trained | Current model test accuracy: 0.9839449541284404
# 10 / 20 models trained | Current model test precision: 0.986458050502308
# 10 / 20 models trained | Current model test recall: 0.9502523993518633
# 10 / 20 models trained | Current model test f1: 0.9680168033588727
# 11 / 20 models trained | Current model test accuracy: 0.9139908256880734
# 11 / 20 models trained | Current model test precision: 0.9554171609331752
# 11 / 20 models trained | Current model test recall: 0.892654538341158
# 11 / 20 models trained | Current model test f1: 0.9229701045158668
# 12 / 20 models trained | Current model test accuracy: 0.9850917431192661
# 12 / 20 models trained | Current model test precision: 0.9807211845278568
# 12 / 20 models trained | Current model test recall: 0.979926567954737
# 12 / 20 models trained | Current model test f1: 0.9803237152191302
# 13 / 20 models trained | Current model test accuracy: 0.963302752293578
# 13 / 20 models trained | Current model test precision: 0.984934086629002
# 13 / 20 models trained | Current model test recall: 0.9624413145539906
# 13 / 20 models trained | Current model test f1: 0.9735578014474198
# 14 / 20 models trained | Current model test accuracy: 0.9896788990825688
# 14 / 20 models trained | Current model test precision: 0.9857760388190269
# 14 / 20 models trained | Current model test recall: 0.983767008832657
# 14 / 20 models trained | Current model test f1: 0.984770499171547
# 15 / 20 models trained | Current model test accuracy: 0.9701834862385321
# 15 / 20 models trained | Current model test precision: 0.9730223156796584
# 15 / 20 models trained | Current model test recall: 0.9493480337950568
# 15 / 20 models trained | Current model test f1: 0.9610393985546087
# 16 / 20 models trained | Current model test accuracy: 0.9850917431192661
# 16 / 20 models trained | Current model test precision: 0.9822941176470589
# 16 / 20 models trained | Current model test recall: 0.9718573191284459
# 16 / 20 models trained | Current model test f1: 0.9770478477833386
# 17 / 20 models trained | Current model test accuracy: 0.9495412844036697
# 17 / 20 models trained | Current model test precision: 0.9797421731123388
# 17 / 20 models trained | Current model test recall: 0.9382335680751174
# 17 / 20 models trained | Current model test f1: 0.9585387084236505
# 18 / 20 models trained | Current model test accuracy: 0.9827981651376146
# 18 / 20 models trained | Current model test precision: 0.982806063880073
# 18 / 20 models trained | Current model test recall: 0.9646208820720936
# 18 / 20 models trained | Current model test f1: 0.97362856585336
# 19 / 20 models trained | Current model test accuracy: 0.9747706422018348
# 19 / 20 models trained | Current model test precision: 0.989443378119002
# 19 / 20 models trained | Current model test recall: 0.9580399061032864
# 19 / 20 models trained | Current model test f1: 0.973488449166529
# 20 / 20 models trained | Current model test accuracy: 0.9793577981651376
# 20 / 20 models trained | Current model test precision: 0.9912959381044487
# 20 / 20 models trained | Current model test recall: 0.9788732394366197
# 20 / 20 models trained | Current model test f1: 0.9850454237475629
# CPU times: total: 4h 3min 31s
# Wall time: 2h 21min 49s

# %%
# %%time
lstm_accuracies, lstm_precision, lstm_recall, lstm_f1, lstm_wrong_preds, lstm_epoch_stats, model = train_models(LSTM_Model, x_train_lstm, x_val_lstm, x_test_lstm, 0.0001, data, 16, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_4148\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.8646788990825688
# 1 / 20 models trained | Current model test precision: 0.6199335709950082
# 1 / 20 models trained | Current model test recall: 0.6514534914528556
# 1 / 20 models trained | Current model test f1: 0.635302814102839
# 2 / 20 models trained | Current model test accuracy: 0.9575688073394495
# 2 / 20 models trained | Current model test precision: 0.9223181818181818
# 2 / 20 models trained | Current model test recall: 0.9686814944442876
# 2 / 20 models trained | Current model test f1: 0.9449314729472927
# 3 / 20 models trained | Current model test accuracy: 0.9587155963302753
# 3 / 20 models trained | Current model test precision: 0.9074919637638807
# 3 / 20 models trained | Current model test recall: 0.9577279559118237
# 3 / 20 models trained | Current model test f1: 0.9319334565257048
# 4 / 20 models trained | Current model test accuracy: 0.8727064220183486
# 4 / 20 models trained | Current model test precision: 0.8601690814295764
# 4 / 20 models trained | Current model test recall: 0.8121163100849587
# 4 / 20 models trained | Current model test f1: 0.8354523025846623
# 5 / 20 models trained | Current model test accuracy: 0.8738532110091743
# 5 / 20 models trained | Current model test precision: 0.804029436746828
# 5 / 20 models trained | Current model test recall: 0.6823725654989865
# 5 / 20 models trained | Current model test f1: 0.7382224037113552
# 6 / 20 models trained | Current model test accuracy: 0.8256880733944955
# 6 / 20 models trained | Current model test precision: 0.8180564357278112
# 6 / 20 models trained | Current model test recall: 0.7082289579158316
# 6 / 20 models trained | Current model test f1: 0.7591912487725987
# 7 / 20 models trained | Current model test accuracy: 0.9323394495412844
# 7 / 20 models trained | Current model test precision: 0.9517058823529412
# 7 / 20 models trained | Current model test recall: 0.8479829377063988
# 7 / 20 models trained | Current model test f1: 0.8968554351785079
# 8 / 20 models trained | Current model test accuracy: 0.8302752293577982
# 8 / 20 models trained | Current model test precision: 0.5842162873036418
# 8 / 20 models trained | Current model test recall: 0.6263792235361262
# 8 / 20 models trained | Current model test f1: 0.6045635245492808
# 9 / 20 models trained | Current model test accuracy: 0.9621559633027523
# 9 / 20 models trained | Current model test precision: 0.9280249025758007
# 9 / 20 models trained | Current model test recall: 0.9684972938835418
# 9 / 20 models trained | Current model test f1: 0.9478292513308516
# 10 / 20 models trained | Current model test accuracy: 0.8543577981651376
# 10 / 20 models trained | Current model test precision: 0.6141041893608217
# 10 / 20 models trained | Current model test recall: 0.6424409129860824
# 10 / 20 models trained | Current model test f1: 0.6279530362175962
# 11 / 20 models trained | Current model test accuracy: 0.8967889908256881
# 11 / 20 models trained | Current model test precision: 0.7748208836567849
# 11 / 20 models trained | Current model test recall: 0.7524606288588576
# 11 / 20 models trained | Current model test f1: 0.7634770729451736
# 12 / 20 models trained | Current model test accuracy: 0.8532110091743119
# 12 / 20 models trained | Current model test precision: 0.7653028756367
# 12 / 20 models trained | Current model test recall: 0.8093965396779954
# 12 / 20 models trained | Current model test f1: 0.7867323672336206
# 13 / 20 models trained | Current model test accuracy: 0.8704128440366973
# 13 / 20 models trained | Current model test precision: 0.8242347592213115
# 13 / 20 models trained | Current model test recall: 0.8590978278018416
# 13 / 20 models trained | Current model test f1: 0.841305273484928
# 14 / 20 models trained | Current model test accuracy: 0.8715596330275229
# 14 / 20 models trained | Current model test precision: 0.900642205732412
# 14 / 20 models trained | Current model test recall: 0.8806267170491218
# 14 / 20 models trained | Current model test f1: 0.8905220079082784
# 15 / 20 models trained | Current model test accuracy: 0.8325688073394495
# 15 / 20 models trained | Current model test precision: 0.8607605211244451
# 15 / 20 models trained | Current model test recall: 0.8026766561291597
# 15 / 20 models trained | Current model test f1: 0.8307045030277416
# 16 / 20 models trained | Current model test accuracy: 0.9369266055045872
# 16 / 20 models trained | Current model test precision: 0.9461485239852399
# 16 / 20 models trained | Current model test recall: 0.919969340088628
# 16 / 20 models trained | Current model test f1: 0.9328753022451917
# 17 / 20 models trained | Current model test accuracy: 0.8371559633027523
# 17 / 20 models trained | Current model test precision: 0.8481734154262959
# 17 / 20 models trained | Current model test recall: 0.8035418206678371
# 17 / 20 models trained | Current model test f1: 0.8252546148152886
# 18 / 20 models trained | Current model test accuracy: 0.8600917431192661
# 18 / 20 models trained | Current model test precision: 0.7270015698587127
# 18 / 20 models trained | Current model test recall: 0.6898446321388245
# 18 / 20 models trained | Current model test f1: 0.7079358787375333
# 19 / 20 models trained | Current model test accuracy: 0.8646788990825688
# 19 / 20 models trained | Current model test precision: 0.6218178504161856
# 19 / 20 models trained | Current model test recall: 0.6506213753106876
# 19 / 20 models trained | Current model test f1: 0.6358936078843485
# 20 / 20 models trained | Current model test accuracy: 0.9036697247706422
# 20 / 20 models trained | Current model test precision: 0.847870182555781
# 20 / 20 models trained | Current model test recall: 0.899403266627151
# 20 / 20 models trained | Current model test f1: 0.8728767809332054
# CPU times: total: 2h 26min 19s
# Wall time: 9h 57min 11s

# %%
# %%time
deepset_accuracies, deepset_procision, deepset_recall, deepset_f1, deepset_wrong_preds, deepset_epoch_stats, model = train_models(DEEPSET_Model, x_train_normal, x_val_normal, x_test_normal, 0.005, data, 128, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_4148\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 1 / 20 models trained | Current model test precision: 0.1430619266055046
# 1 / 20 models trained | Current model test recall: 0.25
# 1 / 20 models trained | Current model test f1: 0.18198395331874545
# 2 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 2 / 20 models trained | Current model test precision: 0.1430619266055046
# 2 / 20 models trained | Current model test recall: 0.25
# 2 / 20 models trained | Current model test f1: 0.18198395331874545
# 3 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 3 / 20 models trained | Current model test precision: 0.1430619266055046
# 3 / 20 models trained | Current model test recall: 0.25
# 3 / 20 models trained | Current model test f1: 0.18198395331874545
# 4 / 20 models trained | Current model test accuracy: 0.5538990825688074
# 4 / 20 models trained | Current model test precision: 0.16263757861635222
# 4 / 20 models trained | Current model test recall: 0.2433293817682313
# 4 / 20 models trained | Current model test f1: 0.19496414890270433
# 5 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 5 / 20 models trained | Current model test precision: 0.1430619266055046
# 5 / 20 models trained | Current model test recall: 0.25
# 5 / 20 models trained | Current model test f1: 0.18198395331874545
# 6 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 6 / 20 models trained | Current model test precision: 0.1430619266055046
# 6 / 20 models trained | Current model test recall: 0.25
# 6 / 20 models trained | Current model test f1: 0.18198395331874545
# 7 / 20 models trained | Current model test accuracy: 0.5688073394495413
# 7 / 20 models trained | Current model test precision: 0.21420313790255988
# 7 / 20 models trained | Current model test recall: 0.2498424078203355
# 7 / 20 models trained | Current model test f1: 0.2306542029312123
# 8 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 8 / 20 models trained | Current model test precision: 0.1430619266055046
# 8 / 20 models trained | Current model test recall: 0.25
# 8 / 20 models trained | Current model test f1: 0.18198395331874545
# 9 / 20 models trained | Current model test accuracy: 0.5676605504587156
# 9 / 20 models trained | Current model test precision: 0.14322916666666666
# 9 / 20 models trained | Current model test recall: 0.24799599198396793
# 9 / 20 models trained | Current model test f1: 0.18158473954512108
# 10 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 10 / 20 models trained | Current model test precision: 0.14355581127733028
# 10 / 20 models trained | Current model test recall: 0.25
# 10 / 20 models trained | Current model test f1: 0.1823830409356725
# 11 / 20 models trained | Current model test accuracy: 0.5584862385321101
# 11 / 20 models trained | Current model test precision: 0.1991388899543554
# 11 / 20 models trained | Current model test recall: 0.24869692436516225
# 11 / 20 models trained | Current model test f1: 0.22117583216694633
# 12 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 12 / 20 models trained | Current model test precision: 0.1430619266055046
# 12 / 20 models trained | Current model test recall: 0.25
# 12 / 20 models trained | Current model test f1: 0.18198395331874545
# 13 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 13 / 20 models trained | Current model test precision: 0.1430619266055046
# 13 / 20 models trained | Current model test recall: 0.25
# 13 / 20 models trained | Current model test f1: 0.18198395331874545
# 14 / 20 models trained | Current model test accuracy: 0.5630733944954128
# 14 / 20 models trained | Current model test precision: 0.1781968031968032
# 14 / 20 models trained | Current model test recall: 0.24733739780029543
# 14 / 20 models trained | Current model test f1: 0.2071501350338192
# 15 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 15 / 20 models trained | Current model test precision: 0.14339080459770115
# 15 / 20 models trained | Current model test recall: 0.25
# 15 / 20 models trained | Current model test f1: 0.18224981738495252
# 16 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 16 / 20 models trained | Current model test precision: 0.1430619266055046
# 16 / 20 models trained | Current model test recall: 0.25
# 16 / 20 models trained | Current model test f1: 0.18198395331874545
# 17 / 20 models trained | Current model test accuracy: 0.5653669724770642
# 17 / 20 models trained | Current model test precision: 0.14314750290360045
# 17 / 20 models trained | Current model test recall: 0.2469939879759519
# 17 / 20 models trained | Current model test f1: 0.18125
# 18 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 18 / 20 models trained | Current model test precision: 0.1430619266055046
# 18 / 20 models trained | Current model test recall: 0.25
# 18 / 20 models trained | Current model test f1: 0.18198395331874545
# 19 / 20 models trained | Current model test accuracy: 0.5711009174311926
# 19 / 20 models trained | Current model test precision: 0.14293915040183697
# 19 / 20 models trained | Current model test recall: 0.24949899799599198
# 19 / 20 models trained | Current model test f1: 0.18175182481751825
# 20 / 20 models trained | Current model test accuracy: 0.5711009174311926
# 20 / 20 models trained | Current model test precision: 0.14293915040183697
# 20 / 20 models trained | Current model test recall: 0.24949899799599198
# 20 / 20 models trained | Current model test f1: 0.18175182481751825
# CPU times: total: 56min 29s
# Wall time: 4h 14min 45s

# %%
# %%time
deepsetv2_accuracies, deepsetv2_procision, deepsetv2_recall, deepsetv2_f1, deepsetv2_wrong_preds, deepsetv2_epoch_stats, model = train_models(DEEPSETV2_Model, x_train_normal, x_val_normal, x_test_normal, 0.0001, data, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_4148\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 1 / 20 models trained | Current model test precision: 0.1430619266055046
# 1 / 20 models trained | Current model test recall: 0.25
# 1 / 20 models trained | Current model test f1: 0.18198395331874545
# 2 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 2 / 20 models trained | Current model test precision: 0.1430619266055046
# 2 / 20 models trained | Current model test recall: 0.25
# 2 / 20 models trained | Current model test f1: 0.18198395331874545
# 3 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 3 / 20 models trained | Current model test precision: 0.1430619266055046
# 3 / 20 models trained | Current model test recall: 0.25
# 3 / 20 models trained | Current model test f1: 0.18198395331874545
# 4 / 20 models trained | Current model test accuracy: 0.5711009174311926
# 4 / 20 models trained | Current model test precision: 0.22714896927265654
# 4 / 20 models trained | Current model test recall: 0.25286253257689084
# 4 / 20 models trained | Current model test f1: 0.23931703061780896
# 5 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 5 / 20 models trained | Current model test precision: 0.1430619266055046
# 5 / 20 models trained | Current model test recall: 0.25
# 5 / 20 models trained | Current model test f1: 0.18198395331874545
# 6 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 6 / 20 models trained | Current model test precision: 0.1430619266055046
# 6 / 20 models trained | Current model test recall: 0.25
# 6 / 20 models trained | Current model test f1: 0.18198395331874545
# 7 / 20 models trained | Current model test accuracy: 0.5538990825688074
# 7 / 20 models trained | Current model test precision: 0.15186280955511727
# 7 / 20 models trained | Current model test recall: 0.24669129926519706
# 7 / 20 models trained | Current model test f1: 0.18799572238812437
# 8 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 8 / 20 models trained | Current model test precision: 0.1430619266055046
# 8 / 20 models trained | Current model test recall: 0.25
# 8 / 20 models trained | Current model test f1: 0.18198395331874545
# 9 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 9 / 20 models trained | Current model test precision: 0.1430619266055046
# 9 / 20 models trained | Current model test recall: 0.25
# 9 / 20 models trained | Current model test f1: 0.18198395331874545
# 10 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 10 / 20 models trained | Current model test precision: 0.1430619266055046
# 10 / 20 models trained | Current model test recall: 0.25
# 10 / 20 models trained | Current model test f1: 0.18198395331874545
# 11 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 11 / 20 models trained | Current model test precision: 0.1430619266055046
# 11 / 20 models trained | Current model test recall: 0.25
# 11 / 20 models trained | Current model test f1: 0.18198395331874545
# 12 / 20 models trained | Current model test accuracy: 0.5607798165137615
# 12 / 20 models trained | Current model test precision: 0.2030954184021204
# 12 / 20 models trained | Current model test recall: 0.25104434220553784
# 12 / 20 models trained | Current model test f1: 0.22453861185595125
# 13 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 13 / 20 models trained | Current model test precision: 0.1430619266055046
# 13 / 20 models trained | Current model test recall: 0.25
# 13 / 20 models trained | Current model test f1: 0.18198395331874545
# 14 / 20 models trained | Current model test accuracy: 0.24426605504587157
# 14 / 20 models trained | Current model test precision: 0.06106651376146789
# 14 / 20 models trained | Current model test recall: 0.25
# 14 / 20 models trained | Current model test f1: 0.09815668202764978
# 15 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 15 / 20 models trained | Current model test precision: 0.1430619266055046
# 15 / 20 models trained | Current model test recall: 0.25
# 15 / 20 models trained | Current model test f1: 0.18198395331874545
# 16 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 16 / 20 models trained | Current model test precision: 0.1430619266055046
# 16 / 20 models trained | Current model test recall: 0.25
# 16 / 20 models trained | Current model test f1: 0.18198395331874545
# 17 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 17 / 20 models trained | Current model test precision: 0.1430619266055046
# 17 / 20 models trained | Current model test recall: 0.25
# 17 / 20 models trained | Current model test f1: 0.18198395331874545
# 18 / 20 models trained | Current model test accuracy: 0.569954128440367
# 18 / 20 models trained | Current model test precision: 0.1434757505773672
# 18 / 20 models trained | Current model test recall: 0.24899799599198397
# 18 / 20 models trained | Current model test f1: 0.18205128205128204
# 19 / 20 models trained | Current model test accuracy: 0.5711009174311926
# 19 / 20 models trained | Current model test precision: 0.14293915040183697
# 19 / 20 models trained | Current model test recall: 0.24949899799599198
# 19 / 20 models trained | Current model test f1: 0.18175182481751825
# 20 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 20 / 20 models trained | Current model test precision: 0.1430619266055046
# 20 / 20 models trained | Current model test recall: 0.25
# 20 / 20 models trained | Current model test f1: 0.18198395331874545
# CPU times: total: 27min 45s
# Wall time: 6min 58s

# %%
# %%time
feedforward_accuracies, feedforward_precision, feedforward_recall, feedforward_f1, feedforward_wrong_preds, feedforward_epoch_stats, model = train_models(FEEDFORWARD_Model, x_train_normal, x_val_normal, x_test_normal, 0.0001, data, 128, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_4148\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 1 / 20 models trained | Current model test precision: 0.1430619266055046
# 1 / 20 models trained | Current model test recall: 0.25
# 1 / 20 models trained | Current model test f1: 0.18198395331874545
# 2 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 2 / 20 models trained | Current model test precision: 0.1430619266055046
# 2 / 20 models trained | Current model test recall: 0.25
# 2 / 20 models trained | Current model test f1: 0.18198395331874545
# 3 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 3 / 20 models trained | Current model test precision: 0.1430619266055046
# 3 / 20 models trained | Current model test recall: 0.25
# 3 / 20 models trained | Current model test f1: 0.18198395331874545
# 4 / 20 models trained | Current model test accuracy: 0.5711009174311926
# 4 / 20 models trained | Current model test precision: 0.14293915040183697
# 4 / 20 models trained | Current model test recall: 0.24949899799599198
# 4 / 20 models trained | Current model test f1: 0.18175182481751825
# 5 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 5 / 20 models trained | Current model test precision: 0.1430619266055046
# 5 / 20 models trained | Current model test recall: 0.25
# 5 / 20 models trained | Current model test f1: 0.18198395331874545
# 6 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 6 / 20 models trained | Current model test precision: 0.1430619266055046
# 6 / 20 models trained | Current model test recall: 0.25
# 6 / 20 models trained | Current model test f1: 0.18198395331874545
# 7 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 7 / 20 models trained | Current model test precision: 0.1430619266055046
# 7 / 20 models trained | Current model test recall: 0.25
# 7 / 20 models trained | Current model test f1: 0.18198395331874545
# 8 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 8 / 20 models trained | Current model test precision: 0.1430619266055046
# 8 / 20 models trained | Current model test recall: 0.25
# 8 / 20 models trained | Current model test f1: 0.18198395331874545
# 9 / 20 models trained | Current model test accuracy: 0.5711009174311926
# 9 / 20 models trained | Current model test precision: 0.14310344827586208
# 9 / 20 models trained | Current model test recall: 0.24949899799599198
# 9 / 20 models trained | Current model test f1: 0.1818845872899927
# 10 / 20 models trained | Current model test accuracy: 0.569954128440367
# 10 / 20 models trained | Current model test precision: 0.14331026528258362
# 10 / 20 models trained | Current model test recall: 0.25
# 10 / 20 models trained | Current model test f1: 0.18218475073313783
# 11 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 11 / 20 models trained | Current model test precision: 0.1430619266055046
# 11 / 20 models trained | Current model test recall: 0.25
# 11 / 20 models trained | Current model test f1: 0.18198395331874545
# 12 / 20 models trained | Current model test accuracy: 0.5619266055045872
# 12 / 20 models trained | Current model test precision: 0.21120880795986807
# 12 / 20 models trained | Current model test recall: 0.2793225700355982
# 12 / 20 models trained | Current model test f1: 0.2405366494375441
# 13 / 20 models trained | Current model test accuracy: 0.5573394495412844
# 13 / 20 models trained | Current model test precision: 0.1822668240850059
# 13 / 20 models trained | Current model test recall: 0.2461778016126149
# 13 / 20 models trained | Current model test f1: 0.20945552059195374
# 14 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 14 / 20 models trained | Current model test precision: 0.1430619266055046
# 14 / 20 models trained | Current model test recall: 0.25
# 14 / 20 models trained | Current model test f1: 0.18198395331874545
# 15 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 15 / 20 models trained | Current model test precision: 0.1430619266055046
# 15 / 20 models trained | Current model test recall: 0.25
# 15 / 20 models trained | Current model test f1: 0.18198395331874545
# 16 / 20 models trained | Current model test accuracy: 0.5711009174311926
# 16 / 20 models trained | Current model test precision: 0.1933102652825836
# 16 / 20 models trained | Current model test recall: 0.2501717049121718
# 16 / 20 models trained | Current model test f1: 0.21809571478872294
# 17 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 17 / 20 models trained | Current model test precision: 0.1430619266055046
# 17 / 20 models trained | Current model test recall: 0.25
# 17 / 20 models trained | Current model test f1: 0.18198395331874545
# 18 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 18 / 20 models trained | Current model test precision: 0.1430619266055046
# 18 / 20 models trained | Current model test recall: 0.25
# 18 / 20 models trained | Current model test f1: 0.18198395331874545
# 19 / 20 models trained | Current model test accuracy: 0.5745412844036697
# 19 / 20 models trained | Current model test precision: 0.293598615916955
# 19 / 20 models trained | Current model test recall: 0.2530201247565554
# 19 / 20 models trained | Current model test f1: 0.27180318895078065
# 20 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 20 / 20 models trained | Current model test precision: 0.1430619266055046
# 20 / 20 models trained | Current model test recall: 0.25
# 20 / 20 models trained | Current model test f1: 0.18198395331874545
# CPU times: total: 55min 16s
# Wall time: 14min 6s

# %% [markdown]
# # Evaluation

# %% [markdown]
# # Evaluacion general de los modelos

# %%
import pandas as pd
# Lista de modelos y nombres
model_names = ['CNN', 'LSTM', 'DeepSet', 'DeepSetV2', 'Feedforward']
all_accuracies = [cnn_accuracies, lstm_accuracies, deepset_accuracies, deepsetv2_accuracies, feedforward_accuracies]
all_precisions = [cnn_precisions, lstm_precision, deepset_procision, deepsetv2_procision, feedforward_precision]
all_recalls = [cnn_recall, lstm_recall, deepset_recall, deepsetv2_recall, feedforward_recall]
all_f1_scores = [cnn_f1, lstm_f1, deepset_f1, deepsetv2_f1, feedforward_f1]

imprimirMetricas(model_names, all_accuracies, all_precisions, all_recalls, all_f1_scores)
# Out:
#         Modelo  Accuracy  Precision    Recall  F1-score  Precision clase A
# 0          CNN  0.993119   0.987288  0.987288  0.987288           1.000000  \
# 1         LSTM  0.962156   0.928025  0.968497  0.947829           0.746032
# 2      DeepSet  0.572248   0.143062  0.250000  0.181984           0.000000
# 3    DeepSetV2  0.572248   0.143062  0.250000  0.181984           0.000000
# 4  Feedforward  0.574541   0.293599  0.253020  0.271803           0.000000
#
#    Recall clase A  Precision clase D  Recall clase D  Precision clase R
# 0        1.000000           0.949153        0.949153                1.0  \
# 1        0.979167           1.000000        1.000000                1.0
# 2        0.000000           0.000000        0.000000                0.0
# 3        0.000000           0.000000        0.000000                0.0
# 4        0.000000           0.000000        0.000000                0.6
#
#    Recall clase R  Precision clase V  Recall clase V
# 0        1.000000           1.000000        1.000000
# 1        0.924883           0.966068        0.969940
# 2        0.000000           0.572248        1.000000
# 3        0.000000           0.572248        1.000000
# 4        0.014085           0.574394        0.997996

# %% [markdown]
# ### Get best 50% performing models

# %%
top_half = int(num_experiments / 2)
best_cnn_accs = filter_top_k_accuracies(cnn_accuracies, top_half)
best_lstm_accs = filter_top_k_accuracies(lstm_accuracies, top_half)
best_deepset_accs = filter_top_k_accuracies(deepset_accuracies, top_half)
best_deepsetv2_accs = filter_top_k_accuracies(deepsetv2_accuracies, top_half)
best_feedforward_accs = filter_top_k_accuracies(feedforward_accuracies, top_half)

# %% [markdown]
# ## Accuracy breakdown by cases for all the models

# %%
all_accuracies = [cnn_accuracies, lstm_accuracies, deepset_accuracies, deepsetv2_accuracies, feedforward_accuracies]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']

# %%
get_stats_df(all_accuracies, model_names, test_original)
# Out:
#                        Overall cr_noop   cr_uw    cr_w   cr_wu dr_noop  dr_uw
# CNN                      97.0%  100.0%  100.0%  100.0%  100.0%   98.3%  94.1%  \
# LSTM                     88.3%  100.0%  100.0%  100.0%   99.9%   93.5%  50.4%
# DeepSet(like in paper)   56.9%   99.0%   99.7%   98.8%   99.4%    0.0%   0.0%
# DeepSet(sum at start)    55.4%   94.3%   94.5%   94.0%   94.1%    0.0%   0.1%
# Feedforward              57.1%   99.7%   99.5%   99.4%   99.9%    0.1%   0.0%
# Sample count               872      59      53      49      58      58     48
#
#                          dr_w  dr_wu noop_noop noop_uw  noop_w noop_wu r_noop
# CNN                     97.7%  93.5%    100.0%  100.0%  100.0%  100.0%  92.8%  \
# LSTM                    90.7%  38.4%    100.0%  100.0%  100.0%   99.9%  83.6%
# DeepSet(like in paper)   0.0%  99.1%     99.4%   99.4%   99.6%   99.8%   0.3%
# DeepSet(sum at start)    0.0%  94.6%     94.9%   94.9%   94.7%   94.8%   5.1%
# Feedforward              0.0%  99.3%     99.7%   99.6%   99.6%   99.9%   0.4%
# Sample count               54     58        56      53      57      56     57
#
#                          r_uw    r_w   r_wu
# CNN                     92.2%  94.0%  87.9%
# LSTM                    82.4%  87.0%  83.8%
# DeepSet(like in paper)   0.3%   0.3%   0.4%
# DeepSet(sum at start)    5.3%   5.4%   5.6%
# Feedforward              0.2%   0.1%   0.4%
# Sample count               53     52     51

# %% [markdown]
# ## Accuracy breakdown by cases for top 50% of models

# %%
best_accuracies = [best_cnn_accs, best_lstm_accs, best_deepset_accs, best_deepsetv2_accs, best_feedforward_accs]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']
collapsed_cases = ['dr', 'r', 'cr', 'noop']

# %%
get_stats_df(best_accuracies, model_names, test_original, collapsed_cases)
# Out:
#                        Overall   f3_cr  f3_dr f3_noop   f3_r
# CNN                      98.3%  100.0%  96.7%  100.0%  96.5%
# LSTM                     91.7%  100.0%  77.1%  100.0%  89.4%
# DeepSet(like in paper)   57.2%  100.0%  26.6%  100.0%   0.0%
# DeepSet(sum at start)    57.2%  100.0%  26.6%  100.0%   0.0%
# Feedforward              57.2%  100.0%  26.6%  100.0%   0.1%
# Sample count               872     219    218     222    213

# %%
best_accuracies = [best_cnn_accs, best_lstm_accs, best_deepset_accs, best_deepsetv2_accs, best_feedforward_accs]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']
collapsed_cases = ['r', 'cr', 'noop']

# %%
get_stats_df(best_accuracies, model_names, test_original, collapsed_cases)
# Out:
#                        Overall dr_noop  dr_uw   dr_w   dr_wu   f3_cr f3_noop
# CNN                      98.3%   99.3%  93.5%  98.9%   94.8%  100.0%  100.0%  \
# LSTM                     91.7%   93.6%  67.5%  92.2%   54.3%  100.0%  100.0%
# DeepSet(like in paper)   57.2%    0.0%   0.0%   0.0%  100.0%  100.0%  100.0%
# DeepSet(sum at start)    57.2%    0.0%   0.0%   0.0%  100.0%  100.0%  100.0%
# Feedforward              57.2%    0.0%   0.0%   0.0%  100.0%  100.0%  100.0%
# Sample count               872      58     48     54      58     219     222
#
#                          f3_r
# CNN                     96.5%
# LSTM                    89.4%
# DeepSet(like in paper)   0.0%
# DeepSet(sum at start)    0.0%
# Feedforward              0.1%
# Sample count              213

# %% [markdown]
# ## Accuracies per CNN model

# %%
get_stats_per_model(cnn_accuracies, ['CNN #' + str(i) for i in range(len(cnn_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#              Overall   f3_cr   f3_dr f3_noop    f3_r
# CNN #0         97.2%  100.0%   97.2%  100.0%   91.5%
# CNN #1         99.3%  100.0%   97.2%  100.0%  100.0%
# CNN #2         96.3%  100.0%   97.2%  100.0%   87.8%
# CNN #3         95.6%  100.0%   94.5%  100.0%   87.8%
# CNN #4         94.7%  100.0%   90.8%  100.0%   87.8%
# CNN #5         96.6%  100.0%   98.2%  100.0%   87.8%
# CNN #6         98.2%  100.0%   92.7%  100.0%  100.0%
# CNN #7         97.7%  100.0%   95.9%  100.0%   94.8%
# CNN #8         96.1%  100.0%   97.2%  100.0%   86.9%
# CNN #9         98.4%  100.0%   95.9%  100.0%   97.7%
# CNN #10        91.4%  100.0%   89.9%  100.0%   75.1%
# CNN #11        98.5%  100.0%   97.7%  100.0%   96.2%
# CNN #12        96.3%  100.0%  100.0%  100.0%   85.0%
# CNN #13        99.0%  100.0%   97.2%  100.0%   98.6%
# CNN #14        97.0%  100.0%   94.5%  100.0%   93.4%
# CNN #15        98.5%  100.0%   96.8%  100.0%   97.2%
# CNN #16        95.0%  100.0%   91.7%  100.0%   87.8%
# CNN #17        98.3%  100.0%   95.9%  100.0%   97.2%
# CNN #18        97.5%  100.0%   98.2%  100.0%   91.5%
# CNN #19        97.9%  100.0%  100.0%  100.0%   91.5%
# Sample count     872     219     218     222     213

# %% [markdown]
# ## Accuracies per LSTM model

# %%
get_stats_per_model(best_lstm_accs, ['LSTM #' + str(i) for i in range(len(best_lstm_accs))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#              Overall   f3_cr  f3_dr f3_noop    f3_r
# LSTM #0        96.2%  100.0%  92.2%  100.0%   92.5%
# LSTM #1        95.9%   99.5%  84.4%   99.5%  100.0%
# LSTM #2        95.8%  100.0%  91.7%  100.0%   91.1%
# LSTM #3        93.7%  100.0%  92.7%  100.0%   81.7%
# LSTM #4        93.2%  100.0%  73.4%  100.0%   99.5%
# LSTM #5        90.4%  100.0%  75.7%  100.0%   85.4%
# LSTM #6        89.7%  100.0%  59.6%  100.0%   99.1%
# LSTM #7        87.4%  100.0%  53.7%  100.0%   95.8%
# LSTM #8        87.3%  100.0%  56.0%  100.0%   93.0%
# LSTM #9        87.2%  100.0%  91.3%  100.0%   56.3%
# Sample count     872     219    218     222     213

# %% [markdown]
# ## Accuracies per DeepSets V1 model

# %%
get_stats_per_model(deepset_accuracies, ['DeepSet(like in paper) #' + str(i) for i in range(len(deepset_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                            Overall   f3_cr  f3_dr f3_noop  f3_r
# DeepSet(like in paper) #0    57.2%  100.0%  26.6%  100.0%  0.0%
# DeepSet(like in paper) #1    57.2%  100.0%  26.6%  100.0%  0.0%
# DeepSet(like in paper) #2    57.2%  100.0%  26.6%  100.0%  0.0%
# DeepSet(like in paper) #3    55.4%   95.4%  26.1%   96.8%  0.9%
# DeepSet(like in paper) #4    57.2%  100.0%  26.6%  100.0%  0.0%
# DeepSet(like in paper) #5    57.2%  100.0%  26.6%  100.0%  0.0%
# DeepSet(like in paper) #6    56.9%   98.6%  26.1%   99.5%  0.9%
# DeepSet(like in paper) #7    57.2%  100.0%  26.6%  100.0%  0.0%
# DeepSet(like in paper) #8    56.8%   99.1%  25.7%  100.0%  0.0%
# DeepSet(like in paper) #9    57.2%  100.0%  26.6%  100.0%  0.0%
# DeepSet(like in paper) #10   55.8%   96.8%  25.7%   95.5%  3.3%
# DeepSet(like in paper) #11   57.2%  100.0%  26.6%  100.0%  0.0%
# DeepSet(like in paper) #12   57.2%  100.0%  26.6%  100.0%  0.0%
# DeepSet(like in paper) #13   56.3%   96.8%  26.1%   99.1%  0.9%
# DeepSet(like in paper) #14   57.2%  100.0%  26.6%  100.0%  0.0%
# DeepSet(like in paper) #15   57.2%  100.0%  26.6%  100.0%  0.0%
# DeepSet(like in paper) #16   56.5%   98.2%  25.7%  100.0%  0.0%
# DeepSet(like in paper) #17   57.2%  100.0%  26.6%  100.0%  0.0%
# DeepSet(like in paper) #18   57.1%  100.0%  26.1%  100.0%  0.0%
# DeepSet(like in paper) #19   57.1%   99.5%  26.6%  100.0%  0.0%
# Sample count                   872     219    218     222   213

# %% [markdown]
# ## Accuracies per DeepSets V2 model

# %%
get_stats_per_model(deepsetv2_accuracies, ['DeepSet(sum at start) #' + str(i) for i in range(len(deepsetv2_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                           Overall   f3_cr  f3_dr f3_noop    f3_r
# DeepSet(sum at start) #0    57.2%  100.0%  26.6%  100.0%    0.0%
# DeepSet(sum at start) #1    57.2%  100.0%  26.6%  100.0%    0.0%
# DeepSet(sum at start) #2    57.2%  100.0%  26.6%  100.0%    0.0%
# DeepSet(sum at start) #3    57.1%   97.3%  26.6%  100.0%    2.3%
# DeepSet(sum at start) #4    57.2%  100.0%  26.6%  100.0%    0.0%
# DeepSet(sum at start) #5    57.2%  100.0%  26.6%  100.0%    0.0%
# DeepSet(sum at start) #6    55.4%   93.2%  26.1%  100.0%    0.0%
# DeepSet(sum at start) #7    57.2%  100.0%  26.6%  100.0%    0.0%
# DeepSet(sum at start) #8    57.2%  100.0%  26.6%  100.0%    0.0%
# DeepSet(sum at start) #9    57.2%  100.0%  26.6%  100.0%    0.0%
# DeepSet(sum at start) #10   57.2%  100.0%  26.6%  100.0%    0.0%
# DeepSet(sum at start) #11   56.1%   95.4%  25.2%   97.3%    4.2%
# DeepSet(sum at start) #12   57.2%  100.0%  26.6%  100.0%    0.0%
# DeepSet(sum at start) #13   24.4%    0.0%   0.0%    0.0%  100.0%
# DeepSet(sum at start) #14   57.2%  100.0%  26.6%  100.0%    0.0%
# DeepSet(sum at start) #15   57.2%  100.0%  26.6%  100.0%    0.0%
# DeepSet(sum at start) #16   57.2%  100.0%  26.6%  100.0%    0.0%
# DeepSet(sum at start) #17   57.0%   99.5%  26.6%   99.5%    0.0%
# DeepSet(sum at start) #18   57.1%   99.5%  26.6%  100.0%    0.0%
# DeepSet(sum at start) #19   57.2%  100.0%  26.6%  100.0%    0.0%
# Sample count                  872     219    218     222     213

# %% [markdown]
# ## Accuracies per FeedForward model

# %%
get_stats_per_model(feedforward_accuracies, ['Feedforward #' + str(i) for i in range(len(feedforward_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                 Overall   f3_cr  f3_dr f3_noop  f3_r
# Feedforward #0    57.2%  100.0%  26.6%  100.0%  0.0%
# Feedforward #1    57.2%  100.0%  26.6%  100.0%  0.0%
# Feedforward #2    57.2%  100.0%  26.6%  100.0%  0.0%
# Feedforward #3    57.1%  100.0%  26.6%   99.5%  0.0%
# Feedforward #4    57.2%  100.0%  26.6%  100.0%  0.0%
# Feedforward #5    57.2%  100.0%  26.6%  100.0%  0.0%
# Feedforward #6    57.2%  100.0%  26.6%  100.0%  0.0%
# Feedforward #7    57.2%  100.0%  26.6%  100.0%  0.0%
# Feedforward #8    57.1%  100.0%  26.1%  100.0%  0.0%
# Feedforward #9    57.0%   99.5%  26.6%   99.5%  0.0%
# Feedforward #10   57.2%  100.0%  26.6%  100.0%  0.0%
# Feedforward #11   56.2%   97.7%  25.2%   98.2%  1.4%
# Feedforward #12   55.7%   96.3%  25.2%   97.3%  1.9%
# Feedforward #13   57.2%  100.0%  26.6%  100.0%  0.0%
# Feedforward #14   57.2%  100.0%  26.6%  100.0%  0.0%
# Feedforward #15   57.1%   99.1%  26.6%  100.0%  0.5%
# Feedforward #16   57.2%  100.0%  26.6%  100.0%  0.0%
# Feedforward #17   57.2%  100.0%  26.6%  100.0%  0.0%
# Feedforward #18   57.5%  100.0%  26.6%   99.5%  1.4%
# Feedforward #19   57.2%  100.0%  26.6%  100.0%  0.0%
# Sample count        872     219    218     222   213

# %% [markdown]
# # Training evolution

# %% [markdown]
# ### CNN

# %%
display_epochs_stats(cnn_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### LSTM

# %%
display_epochs_stats(lstm_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### DeepSets V1

# %%
display_epochs_stats(deepset_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### DeepSets V2

# %%
display_epochs_stats(deepsetv2_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### FeedForward

# %%
display_epochs_stats(feedforward_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# # Best performing models

# %%
best_cnn_model = CNN_Model(data, 64, 128, 4, -1,).to(device)
best_cnn_model.load_state_dict(torch.load('best_CNN_model_1st_interval'))
best_deepset_model = DEEPSET_Model(data).to(device)
best_deepset_model.load_state_dict(torch.load('best_DEEPSET_model_1st_interval'))
best_deepsetv2_model = DEEPSETV2_Model(data).to(device)
best_deepsetv2_model.load_state_dict(torch.load('best_DEEPSETV2_model_1st_interval'))
best_feedforward_model = FEEDFORWARD_Model(data).to(device)
best_feedforward_model.load_state_dict(torch.load('best_FEEDFORWARD_model_1st_interval'))
best_lstm_model = LSTM_Model(data, 16, 16, 8).to(device)
best_lstm_model.load_state_dict(torch.load('best_LSTM_model_1st_interval'))
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_4148\369090151.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_cnn_model.load_state_dict(torch.load('best_CNN_model_1st_interval'))
# C:\Users\franm\AppData\Local\Temp\ipykernel_4148\369090151.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_deepset_model.load_state_dict(torch.load('best_DEEPSET_model_1st_interval'))
# C:\Users\franm\AppData\Local\Temp\ipykernel_4148\369090151.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_deepsetv2_model.load_state_dict(torch.load('best_DEEPSETV2_model_1st_interval'))
# C:\Users\franm\AppData\Local\Temp\ipykernel_4148\369090151.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_feedforward_model.load_state_dict(torch.load('best_FEEDFORWARD_model_1st_interval'))
# C:\Users\franm\AppData\Local\Temp\ipykernel_4148\369090151.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_lstm_model.load_state_dict(torch.load('best_LSTM_model_1st_interval'))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[53], line 10
#       8 best_feedforward_model.load_state_dict(torch.load('best_FEEDFORWARD_model_1st_interval'))
#       9 best_lstm_model = LSTM_Model(data, 16, 16, 8).to(device)
# ---> 10 best_lstm_model.load_state_dict(torch.load('best_LSTM_model_1st_interval'))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:2584, in Module.load_state_dict(self, state_dict, strict, assign)
#    2576         error_msgs.insert(
#    2577             0,
#    2578             "Missing key(s) in state_dict: {}. ".format(
#    2579                 ", ".join(f'"{k}"' for k in missing_keys)
#    2580             ),
#    2581         )
#    2583 if len(error_msgs) > 0:
# -> 2584     raise RuntimeError(
#    2585         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2586             self.__class__.__name__, "\n\t".join(error_msgs)
#    2587         )
#    2588     )
#    2589 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for LSTM_Model:
# 	size mismatch for densef1_1.weight: copying a param with shape torch.Size([32, 16]) from checkpoint, the shape in current model is torch.Size([16, 16]).
# 	size mismatch for densef1_1.bias: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([16]).
# 	size mismatch for densef2_1.weight: copying a param with shape torch.Size([32, 16]) from checkpoint, the shape in current model is torch.Size([16, 16]).
# 	size mismatch for densef2_1.bias: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([16]).
# 	size mismatch for densef3_1.weight: copying a param with shape torch.Size([32, 16]) from checkpoint, the shape in current model is torch.Size([16, 16]).
# 	size mismatch for densef3_1.bias: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([16]).
# 	size mismatch for densef1_2.weight: copying a param with shape torch.Size([8, 32]) from checkpoint, the shape in current model is torch.Size([8, 16]).
# 	size mismatch for densef2_2.weight: copying a param with shape torch.Size([8, 32]) from checkpoint, the shape in current model is torch.Size([8, 16]).
# 	size mismatch for densef3_2.weight: copying a param with shape torch.Size([8, 32]) from checkpoint, the shape in current model is torch.Size([8, 16]).

# %% [markdown]
# ## Top wrong predictions for best performing CNN model

# %%
print_wrong_preds([get_wrong_predictions(best_cnn_model, x_test_cnn, y_test, test_original)])
# Out:
# 4 false Atomicity violation:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 print_wrong_preds([get_wrong_predictions(best_cnn_model, x_test_cnn, y_test, test_original)])
#
# File ~\TFGNuestro\src\evaluate.py:405, in print_wrong_preds(wrong_preds_list, k)
#     403 print(f'{min(k,len(i))} false {cases[a]}:')
#     404 for j in range(min(k,len(i))):
# --> 405     print(f"Sample {i[j][0]} | Prediction {i[j][1]}")
#     406 a+=1
#     407 print("\n")
#
# IndexError: list index out of range

# %% [markdown]
# ## Top wrong predictions for best performing LSTM model

# %%
print_wrong_preds([get_wrong_predictions(best_lstm_model, x_test_lstm, y_test, test_original)])
# Out:
# 4 false Atomicity violation:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 print_wrong_preds([get_wrong_predictions(best_lstm_model, x_test_lstm, y_test, test_original)])
#
# File ~\TFGNuestro\src\evaluate.py:405, in print_wrong_preds(wrong_preds_list, k)
#     403 print(f'{min(k,len(i))} false {cases[a]}:')
#     404 for j in range(min(k,len(i))):
# --> 405     print(f"Sample {i[j][0]} | Prediction {i[j][1]}")
#     406 a+=1
#     407 print("\n")
#
# IndexError: list index out of range

# %% [markdown]
# ## Top wrong predictions for best performing DeepSets V1 model

# %%
print_wrong_preds([get_wrong_predictions(best_deepset_model, x_test_normal, y_test, test_original)])
# Out:
# 4 false Atomicity violation:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 print_wrong_preds([get_wrong_predictions(best_deepset_model, x_test_normal, y_test, test_original)])
#
# File ~\TFGNuestro\src\evaluate.py:405, in print_wrong_preds(wrong_preds_list, k)
#     403 print(f'{min(k,len(i))} false {cases[a]}:')
#     404 for j in range(min(k,len(i))):
# --> 405     print(f"Sample {i[j][0]} | Prediction {i[j][1]}")
#     406 a+=1
#     407 print("\n")
#
# IndexError: list index out of range

# %% [markdown]
# ## Top wrong predictions for best performing DeepSets V2 model

# %%
print_wrong_preds([get_wrong_predictions(best_deepsetv2_model, x_test_normal, y_test, test_original)])
# Out:
# 4 false Atomicity violation:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 print_wrong_preds([get_wrong_predictions(best_deepsetv2_model, x_test_normal, y_test, test_original)])
#
# File ~\TFGNuestro\src\evaluate.py:405, in print_wrong_preds(wrong_preds_list, k)
#     403 print(f'{min(k,len(i))} false {cases[a]}:')
#     404 for j in range(min(k,len(i))):
# --> 405     print(f"Sample {i[j][0]} | Prediction {i[j][1]}")
#     406 a+=1
#     407 print("\n")
#
# IndexError: list index out of range

# %% [markdown]
# ## Top wrong predictions for best performing Feedforward model

# %%
print_wrong_preds([get_wrong_predictions(best_feedforward_model, x_test_normal, y_test, test_original)])
# Out:
# 4 false Atomicity violation:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 print_wrong_preds([get_wrong_predictions(best_feedforward_model, x_test_normal, y_test, test_original)])
#
# File ~\TFGNuestro\src\evaluate.py:405, in print_wrong_preds(wrong_preds_list, k)
#     403 print(f'{min(k,len(i))} false {cases[a]}:')
#     404 for j in range(min(k,len(i))):
# --> 405     print(f"Sample {i[j][0]} | Prediction {i[j][1]}")
#     406 a+=1
#     407 print("\n")
#
# IndexError: list index out of range

# %% [markdown]
# # Saving Notebook State

# %%
import dill
dill.dump_session('notebook_env_first_half.db')

# %% [markdown]
# # Loading Notebook State

# %%
import dill
# dill.load_session('notebook_env_first_half.db')
