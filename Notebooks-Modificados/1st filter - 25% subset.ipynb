# %%
from generate_data import Data
from evaluate import *
from models import *

import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
# %autosave 120
# Out:
# Autosaving every 120 seconds

# %% [markdown]
# # Get the synthetic dataset

# %%
# %%time
data = Data(layer_size=16)
# Out:
# CPU times: total: 656 ms
# Wall time: 658 ms
# c:\Users\franm\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but OneHotEncoder was fitted without feature names
#   warnings.warn(

# %%
# %%time
train, val, test = data.get_splits(['random_subsample'], [[0.25, 0.75]])

train_unshuffled = train.copy()
np.random.shuffle(train)

x_train, y_train = data.get_x_y(train)
x_val, y_val = data.get_x_y(val)
x_test, y_test = data.get_x_y(test)

train_original = data.reverse_encoding(data.get_x_y(train_unshuffled)[0])
val_original = data.reverse_encoding(x_val)
test_original = data.reverse_encoding(x_test)
# Out:
# Number of samples: 992 train | 595 val | 2382 test
# CPU times: total: 266 ms
# Wall time: 304 ms

# %% [markdown]
# #### Peek at unshuffled train data

# %%
train_original[:20]
# Out:
# [[',,..,__._,.,._.,', '______.,_.uw._.,', '___..,__.__dr_._', 'A'],
#  [',___,,._,,.__.,.', '__._,__w__._,,,,', '_,.,,,.,_.dr_...', 'D'],
#  [',...__..,.,,,_..', '.,___.__.wu___.,', '._cr._..__,,,.,.', 'V'],
#  ['.,,._.._.,_,,,..', '_..__,,,.,.__.,,', ',_,._._,_,.r,,__', 'R'],
#  ['.__.,,.,,_.,___,', '_._,,,._..._,_,,', '._.,_dr.,,.._,__', 'D'],
#  [',,__,,_.___...,_', '_,__,_,_,,_._..,', '_,.,,cr.._,.._,.', 'V'],
#  ['.._...,.,._,,.,,', ',._,,.,,,.w_._.,', ',,.,,__.,.__,__,', 'V'],
#  ['._.,..._.._...._', '_,_...__.,,.wu,_', '_.._.,.._._,_,._', 'V'],
#  ['.._._,,_._,....,', '_....__,.,uw,_._', ',.,_,,.._,__r,,,', 'R'],
#  ['.,_..,,._,__.,,.', ',___,_.._,_,w.,_', ',,._,,..__,cr__.', 'V'],
#  [',..._.____.__,_,', '.,,,_wu_...,_,_,', '_..__,.__,.r....', 'R'],
#  [',,.,_,__.,.__.,_', '...,__.,.__._..,', '_,_....,,.cr,__,', 'V'],
#  ['._._..,,_,...._.', '_._._,wu_.,___..', '__,.._,_.,.,....', 'V'],
#  [',__,,_._.,.,.,,.', 'w._.,,_.._,_..._', '_...__.__..._._.', 'V'],
#  ['.,._.,._.,,__,..', '__._wu.,..,,__.,', '__,__._cr,.._,_.', 'V'],
#  ['__,,.,,,__.._,..', ',_.,.._,._.,uw._', '_.,__,,.,..,..__', 'V'],
#  [',_,,_.,__,,.__..', '_.,,.,_,uw,__...', '._...,_,.____..,', 'V'],
#  [',._...,,._,._,_.', ',.__,w_,_,__.,,,', ',,,.___,,_,__,__', 'V'],
#  ['._,,.._..,_.,..,', '_.,..,.__.,...wu', '.dr,_...__.,,_,,', 'V'],
#  ['...__.,..__._.._', '.....,_.,_,w_._,', ',..._.,_,,.cr,_,', 'V']]

# %%
pos_train_ratio = get_stats_and_ratio(train_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 56 | F2-uw 59 | F2-w 64 | F2-noop 65 |
# F3 cr:    F2-wu 56 | F2-uw 52 | F2-w 63 | F2-noop 51 |
# F3 r:    F2-wu 69 | F2-uw 49 | F2-w 67 | F2-noop 71 |
# F3 noop:    F2-wu 69 | F2-uw 54 | F2-w 75 | F2-noop 72 |
#
# Positive samples count: 444
# Total samples count: 992
# Positive class ratio: 0.4475806451612903

# %% [markdown]
# #### Peek at test data

# %%
test_original[:15]
# Out:
# [['.,_,__,,._..,.,.', ',_uw__.,,___,...', ',,_,,_.__,._____', 'V'],
#  ['_..,.____.,,.,,_', ',.,......,.,_.,.', ',,,..._,_dr,_,,,', 'D'],
#  ['.,_,,__.,..___._', '__.,_,..,_,.._,,', ',.,..._,..,,,,,.', 'V'],
#  ['__,._.,..,,__...', '_._.w..,..__,...', '_____,..,.,...dr', 'D'],
#  ['.___,,,_,_.._,..', ',____,.,._w____.', '_.cr,....,,.__,.', 'V'],
#  ['.,,..,__._..,_._', '__wu.,._,.,__.._', '_cr...,__.,,,,..', 'V'],
#  [',.__,.,_..._,.,,', ',_,.,,_,_.,_,wu_', ',,._,._,_r,,,,._', 'R'],
#  [',.,.._..,,,.,.__', '_,._uw____,_,__.', '_._...,_,_,r._._', 'R'],
#  [',_,,,,,.__...___', ',_._.,,uw_,_,,,_', '.r,_..__,..,,._.', 'R'],
#  ['.,_.,__..___._..', ',._._,uw___..,__', '__...,.__.r_._..', 'R'],
#  ['_,,,,,_._,,,,..,', ',_,_,_..,..wu__,', '_,..__cr..,,._.,', 'V'],
#  ['._,_,_,._,__,_..', '__...,_._..__,wu', '..,_,__...,__,_.', 'V'],
#  ['_._,,,.....,.,._', ',_.,uw.,__,,...,', ',..,.,_..__..,.r', 'R'],
#  [',.,,..,,__,._._.', '.,wu._,_____..._', '.,r.___,..._,,..', 'R'],
#  ['__.,_._,,.,_.._.', ',_.__,__.,,wu,_.', '.,_.,.dr.._.,,._', 'V']]

# %%
pos_test_ratio = get_stats_and_ratio(test_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 140 | F2-uw 133 | F2-w 138 | F2-noop 160 |
# F3 cr:    F2-wu 139 | F2-uw 142 | F2-w 145 | F2-noop 151 |
# F3 r:    F2-wu 132 | F2-uw 149 | F2-w 151 | F2-noop 154 |
# F3 noop:    F2-wu 148 | F2-uw 173 | F2-w 162 | F2-noop 165 |
#
# Positive samples count: 1017
# Total samples count: 2382
# Positive class ratio: 0.4269521410579345

# %% [markdown]
# #### Peek at val data

# %%
val_original[:15]
# Out:
# [[',,,__..__.____,.', 'w___,_._,,.__,,.', '...__,.cr.,,__,.', 'V'],
#  [',_..._,_._._,,,.', '_.._._.uw..,,_,_', '_.,,_._.,,.,_cr_', 'V'],
#  ['.___.,_.__,.,_.,', '_,,.._.,._..w_.,', '..,_..__.,__.r,.', 'R'],
#  ['._,.,,.._,_,.,_,', '.,,uw_.._.....,.', ',.,,,,.r.,,_..._', 'R'],
#  ['_..,_.,_,_._,,,,', '__.,,_.uw,,,,..,', '.__.,cr,.,.__..,', 'V'],
#  ['_,,._._....,,,_,', ',,_._w._._.__,_,', '_._.r,_..,,.,__,', 'R'],
#  ['..__.,_,____,._,', '.,_.w,,,_._,_,__', ',.,.,.,..__._cr,', 'V'],
#  ['.,._.,_..,_,,,_,', ',_.._._.____wu__', '.,_,r_.,,_,_.__.', 'R'],
#  ['._,._,_,,,___,.,', '..___,___uw.,__.', ',.,....,,_dr,_,_', 'A'],
#  ['..,.__.__,,_,___', '____,__._.,uw__.', ',__.,_cr___._,_.', 'V'],
#  ['___...,____,,__.', '_,,..._,___,__,.', '.,_,,._._,.,..cr', 'V'],
#  [',,._,.,.,_...,_,', 'wu__,._.,____,,,', ',.__,.._.,__,,,r', 'R'],
#  ['__.,._,,.______,', '.w..._.._.,_..__', ',.,_dr,._,_,.,._', 'D'],
#  [',..,,,__...,,,,,', ',,__._,,,._,,.,_', '_.___..__....,__', 'V'],
#  ['_,.._,_,_,.,,,,,', '..,_.._,..,._,,,', 'r._,.__._,..,,,.', 'R']]

# %%
pos_val_ratio = get_stats_and_ratio(val_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 29 | F2-uw 33 | F2-w 38 | F2-noop 30 |
# F3 cr:    F2-wu 30 | F2-uw 31 | F2-w 32 | F2-noop 53 |
# F3 r:    F2-wu 39 | F2-uw 42 | F2-w 38 | F2-noop 47 |
# F3 noop:    F2-wu 38 | F2-uw 28 | F2-w 35 | F2-noop 52 |
#
# Positive samples count: 267
# Total samples count: 595
# Positive class ratio: 0.44873949579831934

# %% [markdown]
# #### Send label arrays to device

# %%
from sklearn.preprocessing import LabelEncoder

# Codificar etiquetas categóricas a índices numéricos
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_val = label_encoder.transform(y_val)
y_test = label_encoder.transform(y_test)

# Convertir a tensores de PyTorch
y_train = torch.tensor(y_train, dtype=torch.long).to(device)
y_val = torch.tensor(y_val, dtype=torch.long).to(device)
y_test = torch.tensor(y_test, dtype=torch.long).to(device)

# Verificar clases codificadas
print("Clases codificadas:", label_encoder.classes_)
# Out:
# Clases codificadas: ['A' 'D' 'R' 'V']

# %% [markdown]
# #### Get data in normal format (same as CNN format)

# %%
x_train_normal = data.to_conv_format(x_train)
x_val_normal = data.to_conv_format(x_val)
x_test_normal = data.to_conv_format(x_test)
for i in range(len(x_train_normal)):
    x_train_normal[i] = x_train_normal[i].to(device)
    x_val_normal[i] = x_val_normal[i].to(device)
    x_test_normal[i] = x_test_normal[i].to(device)

# %%
x_train_normal[0].shape
# Out:
# torch.Size([992, 128])

# %% [markdown]
# #### Get data in convolutional format, send to device

# %%
x_train_cnn = data.to_conv_format(x_train)
x_val_cnn = data.to_conv_format(x_val)
x_test_cnn = data.to_conv_format(x_test)
for i in range(len(x_train_cnn)):
    x_train_cnn[i] = x_train_cnn[i].to(device)
    x_val_cnn[i] = x_val_cnn[i].to(device)
    x_test_cnn[i] = x_test_cnn[i].to(device)

# %%
x_train_cnn[0].shape
# Out:
# torch.Size([992, 128])

# %% [markdown]
# #### Get data in LSTM format, send to device

# %%
x_train_lstm = data.to_lstm_format(x_train)
x_val_lstm = data.to_lstm_format(x_val)
x_test_lstm = data.to_lstm_format(x_test)
for i in range(len(x_train_lstm)):
    x_train_lstm[i] = x_train_lstm[i].to(device)
    x_val_lstm[i] = x_val_lstm[i].to(device)
    x_test_lstm[i] = x_test_lstm[i].to(device)

# %%
x_train_lstm[0].shape
# Out:
# torch.Size([992, 16, 8])

# %% [markdown]
# ### Define training parameters

# %%
num_experiments = 20
epochs = 200
early_stopping_limit = 100

experiment_name = "25per"

# %% [markdown]
# ### Define training procedure for each model

# %%
def train_models(constructor, x_train, x_val, x_test, weight_decay, *argv):
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    wrong_preds = []
    best_accuracy = 0
    
    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []

    for i in range(num_experiments):
        model = constructor(*argv)
        model.to(device)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), weight_decay=weight_decay)

        train_losses.append([])
        val_losses.append([])
        train_accs.append([])
        val_accs.append([])
        
        best_acc = 0

        early_stopping_cnt = 0

        for epoch in range(1, epochs + 1):
            train_loss, train_acc = train_epoch(model, x_train, y_train, criterion, optimizer, epoch, 10, verbose=False)
            val_loss, val_acc = eval_epoch(model, x_val, y_val, criterion, 'Validation', verbose=False)

            
            train_losses[-1].append(train_loss)
            val_losses[-1].append(val_loss)
            train_accs[-1].append(train_acc)
            val_accs[-1].append(val_acc)
            
            model_name = constructor.__name__[:constructor.__name__.find('_')]
            if val_acc > best_acc:
                best_acc = val_acc
                torch.save(model.state_dict(), f'./temp/{model_name}_model_TEMP_' + experiment_name)    
                early_stopping_cnt = 0
            else:
                early_stopping_cnt += 1

            if early_stopping_cnt >= early_stopping_limit:
                break


        model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
        
        accuracies.append(get_accuracy_by_cases(model, x_test, y_test, test_original))
        precisions.append(get_precision(model, x_test, y_test, test_original))
        recalls.append(get_recall(model, x_test, y_test, test_original))
        f1_scores.append(get_f1(precisions[-1], recalls[-1]))
        
        wrong_preds.append((f"Experimento {i}", get_wrong_predictions(model, x_test, y_test, test_original)))

        if accuracies[-1]['Overall'] > best_accuracy:
            torch.save(model.state_dict(), f'./bestmodels/best_{model_name}_model_' + experiment_name)    
            best_accuracy = accuracies[-1]['Overall']

        print(i + 1, "/", num_experiments, "models trained | Current model test accuracy:", accuracies[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test precision:", precisions[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test recall:", recalls[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test f1:", f1_scores[-1]['Overall'])


    
    return accuracies, precisions, recalls, f1_scores, wrong_preds, [train_losses, val_losses, train_accs, val_accs], model
    #return accuracies, precisions, wrong_preds, [train_losses, val_losses, train_accs, val_accs]

# %% [markdown]
# # Train models

# %%
# %%time
cnn_accuracies, cnn_precisions, cnn_recalls, cnn_f1_scores, cnn_wrong_preds, cnn_epoch_stats, model = train_models(
    CNN_Model, x_train_cnn, x_val_cnn, x_test_cnn, 0.0001, data, 64, 128, 4, -1, 'keras')
    
#cnn_accuracies, cnn_precisions, cnn_wrong_preds, cnn_epoch_stats = train_models(CNN_Model, x_train_cnn, x_val_cnn, x_test_cnn, 0.0001, data, 64, 128, 4, -1, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_7128\2177076457.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 1.0
# 1 / 20 models trained | Current model test precision: 1.0
# 1 / 20 models trained | Current model test recall: 1.0
# 1 / 20 models trained | Current model test f1: 1.0
# 2 / 20 models trained | Current model test accuracy: 1.0
# 2 / 20 models trained | Current model test precision: 1.0
# 2 / 20 models trained | Current model test recall: 1.0
# 2 / 20 models trained | Current model test f1: 1.0
# 3 / 20 models trained | Current model test accuracy: 1.0
# 3 / 20 models trained | Current model test precision: 1.0
# 3 / 20 models trained | Current model test recall: 1.0
# 3 / 20 models trained | Current model test f1: 1.0
# 4 / 20 models trained | Current model test accuracy: 1.0
# 4 / 20 models trained | Current model test precision: 1.0
# 4 / 20 models trained | Current model test recall: 1.0
# 4 / 20 models trained | Current model test f1: 1.0
# 5 / 20 models trained | Current model test accuracy: 1.0
# 5 / 20 models trained | Current model test precision: 1.0
# 5 / 20 models trained | Current model test recall: 1.0
# 5 / 20 models trained | Current model test f1: 1.0
# 6 / 20 models trained | Current model test accuracy: 1.0
# 6 / 20 models trained | Current model test precision: 1.0
# 6 / 20 models trained | Current model test recall: 1.0
# 6 / 20 models trained | Current model test f1: 1.0
# 7 / 20 models trained | Current model test accuracy: 1.0
# 7 / 20 models trained | Current model test precision: 1.0
# 7 / 20 models trained | Current model test recall: 1.0
# 7 / 20 models trained | Current model test f1: 1.0
# 8 / 20 models trained | Current model test accuracy: 1.0
# 8 / 20 models trained | Current model test precision: 1.0
# 8 / 20 models trained | Current model test recall: 1.0
# 8 / 20 models trained | Current model test f1: 1.0
# 9 / 20 models trained | Current model test accuracy: 0.9995801847187238
# 9 / 20 models trained | Current model test precision: 0.9998169838945827
# 9 / 20 models trained | Current model test recall: 0.9995733788395904
# 9 / 20 models trained | Current model test f1: 0.9996951665267073
# 10 / 20 models trained | Current model test accuracy: 0.9995801847187238
# 10 / 20 models trained | Current model test precision: 0.9998169838945827
# 10 / 20 models trained | Current model test recall: 0.9995733788395904
# 10 / 20 models trained | Current model test f1: 0.9996951665267073
# 11 / 20 models trained | Current model test accuracy: 0.9979009235936188
# 11 / 20 models trained | Current model test precision: 0.9990875912408759
# 11 / 20 models trained | Current model test recall: 0.9920545818471093
# 11 / 20 models trained | Current model test f1: 0.9955586657279901
# 12 / 20 models trained | Current model test accuracy: 0.9995801847187238
# 12 / 20 models trained | Current model test precision: 0.9998169838945827
# 12 / 20 models trained | Current model test recall: 0.9995733788395904
# 12 / 20 models trained | Current model test f1: 0.9996951665267073
# 13 / 20 models trained | Current model test accuracy: 1.0
# 13 / 20 models trained | Current model test precision: 1.0
# 13 / 20 models trained | Current model test recall: 1.0
# 13 / 20 models trained | Current model test f1: 1.0
# 14 / 20 models trained | Current model test accuracy: 1.0
# 14 / 20 models trained | Current model test precision: 1.0
# 14 / 20 models trained | Current model test recall: 1.0
# 14 / 20 models trained | Current model test f1: 1.0
# 15 / 20 models trained | Current model test accuracy: 1.0
# 15 / 20 models trained | Current model test precision: 1.0
# 15 / 20 models trained | Current model test recall: 1.0
# 15 / 20 models trained | Current model test f1: 1.0
# 16 / 20 models trained | Current model test accuracy: 1.0
# 16 / 20 models trained | Current model test precision: 1.0
# 16 / 20 models trained | Current model test recall: 1.0
# 16 / 20 models trained | Current model test f1: 1.0
# 17 / 20 models trained | Current model test accuracy: 0.9991603694374476
# 17 / 20 models trained | Current model test precision: 0.9996342355523044
# 17 / 20 models trained | Current model test recall: 0.9991467576791808
# 17 / 20 models trained | Current model test f1: 0.9993904371708416
# 18 / 20 models trained | Current model test accuracy: 1.0
# 18 / 20 models trained | Current model test precision: 1.0
# 18 / 20 models trained | Current model test recall: 1.0
# 18 / 20 models trained | Current model test f1: 1.0
# 19 / 20 models trained | Current model test accuracy: 0.998320738874895
# 19 / 20 models trained | Current model test precision: 0.9992695398100804
# 19 / 20 models trained | Current model test recall: 0.9982935153583617
# 19 / 20 models trained | Current model test f1: 0.9987812891377479
# 20 / 20 models trained | Current model test accuracy: 1.0
# 20 / 20 models trained | Current model test precision: 1.0
# 20 / 20 models trained | Current model test recall: 1.0
# 20 / 20 models trained | Current model test f1: 1.0
# CPU times: total: 3h 48min 12s
# Wall time: 1h 48min 32s

# %%
# %%time
lstm_accuracies, lstm_precisions, lstm_recalls, lstm_f1Scores, lstm_wrong_preds, lstm_epoch_stats, model = train_models(LSTM_Model, x_train_lstm, x_val_lstm, x_test_lstm, 0.0001, data, 16, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_7128\2177076457.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.9987405541561712
# 1 / 20 models trained | Current model test precision: 0.9944852941176471
# 1 / 20 models trained | Current model test recall: 0.9994505494505495
# 1 / 20 models trained | Current model test f1: 0.9969617395990995
# 2 / 20 models trained | Current model test accuracy: 1.0
# 2 / 20 models trained | Current model test precision: 1.0
# 2 / 20 models trained | Current model test recall: 1.0
# 2 / 20 models trained | Current model test f1: 1.0
# 3 / 20 models trained | Current model test accuracy: 1.0
# 3 / 20 models trained | Current model test precision: 1.0
# 3 / 20 models trained | Current model test recall: 1.0
# 3 / 20 models trained | Current model test f1: 1.0
# 4 / 20 models trained | Current model test accuracy: 0.8849706129303107
# 4 / 20 models trained | Current model test precision: 0.6296417512523462
# 4 / 20 models trained | Current model test recall: 0.669908466819222
# 4 / 20 models trained | Current model test f1: 0.649151274589067
# 5 / 20 models trained | Current model test accuracy: 0.9995801847187238
# 5 / 20 models trained | Current model test precision: 0.9981343283582089
# 5 / 20 models trained | Current model test recall: 0.9998168498168498
# 5 / 20 models trained | Current model test f1: 0.9989748806421755
# 6 / 20 models trained | Current model test accuracy: 0.9991603694374476
# 6 / 20 models trained | Current model test precision: 0.9979371505687296
# 6 / 20 models trained | Current model test recall: 0.9979371505687296
# 6 / 20 models trained | Current model test f1: 0.9979371505687296
# 7 / 20 models trained | Current model test accuracy: 1.0
# 7 / 20 models trained | Current model test precision: 1.0
# 7 / 20 models trained | Current model test recall: 1.0
# 7 / 20 models trained | Current model test f1: 1.0
# 8 / 20 models trained | Current model test accuracy: 1.0
# 8 / 20 models trained | Current model test precision: 1.0
# 8 / 20 models trained | Current model test recall: 1.0
# 8 / 20 models trained | Current model test f1: 1.0
# 9 / 20 models trained | Current model test accuracy: 1.0
# 9 / 20 models trained | Current model test precision: 1.0
# 9 / 20 models trained | Current model test recall: 1.0
# 9 / 20 models trained | Current model test f1: 1.0
# 10 / 20 models trained | Current model test accuracy: 0.8837111670864819
# 10 / 20 models trained | Current model test precision: 0.6271836183026236
# 10 / 20 models trained | Current model test recall: 0.6697313909263787
# 10 / 20 models trained | Current model test f1: 0.6477595741632532
# 11 / 20 models trained | Current model test accuracy: 1.0
# 11 / 20 models trained | Current model test precision: 1.0
# 11 / 20 models trained | Current model test recall: 1.0
# 11 / 20 models trained | Current model test f1: 1.0
# 12 / 20 models trained | Current model test accuracy: 0.9987405541561712
# 12 / 20 models trained | Current model test precision: 0.9987981151509665
# 12 / 20 models trained | Current model test recall: 0.9943609022556391
# 12 / 20 models trained | Current model test f1: 0.9965745695945547
# 13 / 20 models trained | Current model test accuracy: 0.9974811083123426
# 13 / 20 models trained | Current model test precision: 0.9989059080962801
# 13 / 20 models trained | Current model test recall: 0.9887218045112782
# 13 / 20 models trained | Current model test f1: 0.9937877659134178
# 14 / 20 models trained | Current model test accuracy: 1.0
# 14 / 20 models trained | Current model test precision: 1.0
# 14 / 20 models trained | Current model test recall: 1.0
# 14 / 20 models trained | Current model test f1: 1.0
# 15 / 20 models trained | Current model test accuracy: 1.0
# 15 / 20 models trained | Current model test precision: 1.0
# 15 / 20 models trained | Current model test recall: 1.0
# 15 / 20 models trained | Current model test f1: 1.0
# 16 / 20 models trained | Current model test accuracy: 1.0
# 16 / 20 models trained | Current model test precision: 1.0
# 16 / 20 models trained | Current model test recall: 1.0
# 16 / 20 models trained | Current model test f1: 1.0
# 17 / 20 models trained | Current model test accuracy: 1.0
# 17 / 20 models trained | Current model test precision: 1.0
# 17 / 20 models trained | Current model test recall: 1.0
# 17 / 20 models trained | Current model test f1: 1.0
# 18 / 20 models trained | Current model test accuracy: 0.9991603694374476
# 18 / 20 models trained | Current model test precision: 0.9962962962962962
# 18 / 20 models trained | Current model test recall: 0.9996336996336996
# 18 / 20 models trained | Current model test f1: 0.9979622077215878
# 19 / 20 models trained | Current model test accuracy: 1.0
# 19 / 20 models trained | Current model test precision: 1.0
# 19 / 20 models trained | Current model test recall: 1.0
# 19 / 20 models trained | Current model test f1: 1.0
# 20 / 20 models trained | Current model test accuracy: 0.9995801847187238
# 20 / 20 models trained | Current model test precision: 0.9981343283582089
# 20 / 20 models trained | Current model test recall: 0.9998168498168498
# 20 / 20 models trained | Current model test f1: 0.9989748806421755
# CPU times: total: 1h 56min 43s
# Wall time: 1h 37min 9s

# %%
# %%time
deepset_accuracies, deepset_precisions, deepset_recalls, deepset_f1Scores, deepset_wrong_preds, deepset_epoch_stats, model = train_models(DEEPSET_Model, x_train_normal, x_val_normal, x_test_normal, 0.005, data, 128, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_7128\2177076457.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.9172963895885811
# 1 / 20 models trained | Current model test precision: 0.8215721552960996
# 1 / 20 models trained | Current model test recall: 0.8609366077787991
# 1 / 20 models trained | Current model test f1: 0.8407938905868908
# 2 / 20 models trained | Current model test accuracy: 0.9231738035264484
# 2 / 20 models trained | Current model test precision: 0.8328737879217061
# 2 / 20 models trained | Current model test recall: 0.8609530687391127
# 2 / 20 models trained | Current model test f1: 0.8466806873013832
# 3 / 20 models trained | Current model test accuracy: 0.9231738035264484
# 3 / 20 models trained | Current model test precision: 0.8293120081851569
# 3 / 20 models trained | Current model test recall: 0.8690643805433688
# 3 / 20 models trained | Current model test f1: 0.8487229703071595
# 4 / 20 models trained | Current model test accuracy: 0.9298908480268682
# 4 / 20 models trained | Current model test precision: 0.8393782605066566
# 4 / 20 models trained | Current model test recall: 0.8779160410819652
# 4 / 20 models trained | Current model test f1: 0.8582147378612753
# 5 / 20 models trained | Current model test accuracy: 0.9214945424013434
# 5 / 20 models trained | Current model test precision: 0.825359507146
# 5 / 20 models trained | Current model test recall: 0.8476891991460478
# 5 / 20 models trained | Current model test f1: 0.8363753392102844

# %%
# %%time
deepsetv2_accuracies, deepsetv2_precisions, deepsetv2_recalls, deepsetv2_f1Scores, deepsetv2_wrong_preds, deepsetv2_epoch_stats, model = train_models(DEEPSETV2_Model, x_train_normal, x_val_normal, x_test_normal, 0.0001, data, 16, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_4820\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.8832913518052057
# 1 / 20 models trained | Current model test precision: 0.6278420058110002
# 1 / 20 models trained | Current model test recall: 0.6699286673244585
# 1 / 20 models trained | Current model test f1: 0.6482029020228537
# 2 / 20 models trained | Current model test accuracy: 0.8140218303946264
# 2 / 20 models trained | Current model test precision: 0.5483789260385006
# 2 / 20 models trained | Current model test recall: 0.7149604781183728
# 2 / 20 models trained | Current model test f1: 0.6206871373764916
# 3 / 20 models trained | Current model test accuracy: 0.8001679261125105
# 3 / 20 models trained | Current model test precision: 0.5414110970964273
# 3 / 20 models trained | Current model test recall: 0.6921557635227475
# 3 / 20 models trained | Current model test f1: 0.6075727603485865
# 4 / 20 models trained | Current model test accuracy: 0.815281276238455
# 4 / 20 models trained | Current model test precision: 0.5551162797651084
# 4 / 20 models trained | Current model test recall: 0.7205995758627337
# 4 / 20 models trained | Current model test f1: 0.627124847572531
# 5 / 20 models trained | Current model test accuracy: 0.9000839630562553
# 5 / 20 models trained | Current model test precision: 0.7624131916904161
# 5 / 20 models trained | Current model test recall: 0.7624223939542786
# 5 / 20 models trained | Current model test f1: 0.7624177927945799
# 6 / 20 models trained | Current model test accuracy: 0.9445843828715366
# 6 / 20 models trained | Current model test precision: 0.8564875646033375
# 6 / 20 models trained | Current model test recall: 0.8290596677854384
# 6 / 20 models trained | Current model test f1: 0.8425504573562974
# 7 / 20 models trained | Current model test accuracy: 0.8127623845507976
# 7 / 20 models trained | Current model test precision: 0.5450327527303949
# 7 / 20 models trained | Current model test recall: 0.7093213803740119
# 7 / 20 models trained | Current model test f1: 0.6164182415678174
# 8 / 20 models trained | Current model test accuracy: 0.9378673383711167
# 8 / 20 models trained | Current model test precision: 0.8591886056901789
# 8 / 20 models trained | Current model test recall: 0.9547401650145305
# 8 / 20 models trained | Current model test f1: 0.9044477207961803
# 9 / 20 models trained | Current model test accuracy: 0.8530646515533166
# 9 / 20 models trained | Current model test precision: 0.7199460695099976
# 9 / 20 models trained | Current model test recall: 0.7572031950967232
# 9 / 20 models trained | Current model test f1: 0.7381047768052585
# 10 / 20 models trained | Current model test accuracy: 0.9382871536523929
# 10 / 20 models trained | Current model test precision: 0.8604036729036729
# 10 / 20 models trained | Current model test recall: 0.9566198642626508
# 10 / 20 models trained | Current model test f1: 0.905964317961233
# 11 / 20 models trained | Current model test accuracy: 0.9403862300587741
# 11 / 20 models trained | Current model test precision: 0.8675027733267595
# 11 / 20 models trained | Current model test recall: 0.967879185722037
# 11 / 20 models trained | Current model test f1: 0.9149462036711561
# 12 / 20 models trained | Current model test accuracy: 0.9391267842149454
# 12 / 20 models trained | Current model test precision: 0.8615079365079366
# 12 / 20 models trained | Current model test recall: 0.9572729388021947
# 12 / 20 models trained | Current model test f1: 0.9068692610282069
# 13 / 20 models trained | Current model test accuracy: 0.8505457598656591
# 13 / 20 models trained | Current model test precision: 0.777125822967204
# 13 / 20 models trained | Current model test recall: 0.8045511589545034
# 13 / 20 models trained | Current model test f1: 0.7906007214723256
# 14 / 20 models trained | Current model test accuracy: 0.9382871536523929
# 14 / 20 models trained | Current model test precision: 0.8635608889959923
# 14 / 20 models trained | Current model test recall: 0.9623706468008717
# 14 / 20 models trained | Current model test f1: 0.9102922371427462
# 15 / 20 models trained | Current model test accuracy: 0.9433249370277078
# 15 / 20 models trained | Current model test precision: 0.8599514439175856
# 15 / 20 models trained | Current model test recall: 0.8939617288694071
# 15 / 20 models trained | Current model test f1: 0.8766268381766374
# 16 / 20 models trained | Current model test accuracy: 0.9256926952141058
# 16 / 20 models trained | Current model test precision: 0.8211689874978677
# 16 / 20 models trained | Current model test recall: 0.8072495623120899
# 16 / 20 models trained | Current model test f1: 0.8141497845492822
# 17 / 20 models trained | Current model test accuracy: 0.9151973131821999
# 17 / 20 models trained | Current model test precision: 0.804256496110491
# 17 / 20 models trained | Current model test recall: 0.7479777199447135
# 17 / 20 models trained | Current model test f1: 0.7750968687447809
# 18 / 20 models trained | Current model test accuracy: 0.8127623845507976
# 18 / 20 models trained | Current model test precision: 0.5470052996648742
# 18 / 20 models trained | Current model test recall: 0.7093213803740119
# 18 / 20 models trained | Current model test f1: 0.6176778068872645
# 19 / 20 models trained | Current model test accuracy: 0.9340890008396305
# 19 / 20 models trained | Current model test precision: 0.8516640796803131
# 19 / 20 models trained | Current model test recall: 0.9469027414907514
# 19 / 20 models trained | Current model test f1: 0.8967618465833849
# 20 / 20 models trained | Current model test accuracy: 0.9475230898404702
# 20 / 20 models trained | Current model test precision: 0.8692137312189121
# 20 / 20 models trained | Current model test recall: 0.8595859361038557
# 20 / 20 models trained | Current model test f1: 0.8643730247602344
# CPU times: total: 54min 25s
# Wall time: 26min 39s

# %%
# %%time
feedforward_accuracies, feedforward_precisions, feedforward_recalls, feedforward_f1Scores, feedforward_wrong_preds, feedforward_epoch_stats, model = train_models(FEEDFORWARD_Model, x_train_normal, x_val_normal, x_test_normal, 0.0001, data, 128, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_4820\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.8681780016792612
# 1 / 20 models trained | Current model test precision: 0.7438120828292394
# 1 / 20 models trained | Current model test recall: 0.7437519421596834
# 1 / 20 models trained | Current model test f1: 0.743782011278749
# 2 / 20 models trained | Current model test accuracy: 0.8140218303946264
# 2 / 20 models trained | Current model test precision: 0.7004049720212601
# 2 / 20 models trained | Current model test recall: 0.7633081746437864
# 2 / 20 models trained | Current model test f1: 0.7305049379696839
# 3 / 20 models trained | Current model test accuracy: 0.9080604534005038
# 3 / 20 models trained | Current model test precision: 0.7932436522535189
# 3 / 20 models trained | Current model test recall: 0.8079879708748845
# 3 / 20 models trained | Current model test f1: 0.800547927902504
# 4 / 20 models trained | Current model test accuracy: 0.9089000839630562
# 4 / 20 models trained | Current model test precision: 0.8088500520340549
# 4 / 20 models trained | Current model test recall: 0.8251306052193927
# 4 / 20 models trained | Current model test f1: 0.816909221053374
# 5 / 20 models trained | Current model test accuracy: 0.9193954659949622
# 5 / 20 models trained | Current model test precision: 0.827879595704283
# 5 / 20 models trained | Current model test recall: 0.8746009298999706
# 5 / 20 models trained | Current model test f1: 0.8505991738039869
# 6 / 20 models trained | Current model test accuracy: 0.9063811922753988
# 6 / 20 models trained | Current model test precision: 0.7663357955617813
# 6 / 20 models trained | Current model test recall: 0.7575382230687164
# 6 / 20 models trained | Current model test f1: 0.7619116144070004
# 7 / 20 models trained | Current model test accuracy: 0.9109991603694374
# 7 / 20 models trained | Current model test precision: 0.8211119333012492
# 7 / 20 models trained | Current model test recall: 0.8515011369745431
# 7 / 20 models trained | Current model test f1: 0.8360304689883757
# 8 / 20 models trained | Current model test accuracy: 0.9156171284634761
# 8 / 20 models trained | Current model test precision: 0.8210212171261706
# 8 / 20 models trained | Current model test recall: 0.8537295652021011
# 8 / 20 models trained | Current model test f1: 0.837055989601484
# 9 / 20 models trained | Current model test accuracy: 0.9030226700251889
# 9 / 20 models trained | Current model test precision: 0.8052708769704504
# 9 / 20 models trained | Current model test recall: 0.8388440941041508
# 9 / 20 models trained | Current model test f1: 0.8217146990142968
# 10 / 20 models trained | Current model test accuracy: 0.9130982367758187
# 10 / 20 models trained | Current model test precision: 0.8129631604434742
# 10 / 20 models trained | Current model test recall: 0.8382227856370688
# 10 / 20 models trained | Current model test f1: 0.825399763830117
# 11 / 20 models trained | Current model test accuracy: 0.9151973131821999
# 11 / 20 models trained | Current model test precision: 0.8187741949410354
# 11 / 20 models trained | Current model test recall: 0.862664239615303
# 11 / 20 models trained | Current model test f1: 0.8401463934441472
# 12 / 20 models trained | Current model test accuracy: 0.8669185558354324
# 12 / 20 models trained | Current model test precision: 0.7240388515334159
# 12 / 20 models trained | Current model test recall: 0.7792768801155082
# 12 / 20 models trained | Current model test f1: 0.7506430291745824
# 13 / 20 models trained | Current model test accuracy: 0.9319899244332494
# 13 / 20 models trained | Current model test precision: 0.8404202042710702
# 13 / 20 models trained | Current model test recall: 0.8778663808599367
# 13 / 20 models trained | Current model test f1: 0.8587352651289691
# 14 / 20 models trained | Current model test accuracy: 0.9151973131821999
# 14 / 20 models trained | Current model test precision: 0.7898757192224344
# 14 / 20 models trained | Current model test recall: 0.8026786065314616
# 14 / 20 models trained | Current model test f1: 0.796225700292345
# 15 / 20 models trained | Current model test accuracy: 0.9076406381192276
# 15 / 20 models trained | Current model test precision: 0.8156524675049457
# 15 / 20 models trained | Current model test recall: 0.8382594795247729
# 15 / 20 models trained | Current model test f1: 0.826801468012501
# 16 / 20 models trained | Current model test accuracy: 0.9047019311502938
# 16 / 20 models trained | Current model test precision: 0.8205856244906969
# 16 / 20 models trained | Current model test recall: 0.8783902445593252
# 16 / 20 models trained | Current model test f1: 0.8485045850371968
# 17 / 20 models trained | Current model test accuracy: 0.892527287993283
# 17 / 20 models trained | Current model test precision: 0.7676416857051896
# 17 / 20 models trained | Current model test recall: 0.7909442906888738
# 17 / 20 models trained | Current model test f1: 0.7791187881826437
# 18 / 20 models trained | Current model test accuracy: 0.9130982367758187
# 18 / 20 models trained | Current model test precision: 0.8212555069302993
# 18 / 20 models trained | Current model test recall: 0.8553892297535575
# 18 / 20 models trained | Current model test f1: 0.8379749151789885
# 19 / 20 models trained | Current model test accuracy: 0.8627204030226701
# 19 / 20 models trained | Current model test precision: 0.7134577984114228
# 19 / 20 models trained | Current model test recall: 0.6939237912097103
# 19 / 20 models trained | Current model test f1: 0.7035552319183948
# 20 / 20 models trained | Current model test accuracy: 0.8518052057094878
# 20 / 20 models trained | Current model test precision: 0.7456103485941807
# 20 / 20 models trained | Current model test recall: 0.773281305203524
# 20 / 20 models trained | Current model test f1: 0.7591937740819967
# CPU times: total: 1h 49min 20s
# Wall time: 46min 42s

# %% [markdown]
# # Evaluation

# %% [markdown]
# # Evaluacion general de los modelos

# %%
import pandas as pd
# Lista de modelos y nombres
model_names = ['CNN', 'LSTM', 'DeepSet', 'DeepSetV2', 'Feedforward']
all_accuracies = [cnn_accuracies, lstm_accuracies, deepset_accuracies, deepsetv2_accuracies, feedforward_accuracies]
all_precisions = [cnn_precisions, lstm_precisions, deepset_precisions, deepsetv2_precisions, feedforward_precisions]
all_recalls = [cnn_recalls, lstm_recalls, deepset_recalls, deepsetv2_recalls, feedforward_recalls]
all_f1_scores = [cnn_f1_scores, lstm_f1Scores, deepset_f1Scores, deepsetv2_f1Scores, feedforward_f1Scores]

get_summary_df(model_names, all_accuracies, all_precisions, all_recalls, all_f1_scores)
# Out:
#         Modelo  Accuracy  Precision    Recall  F1-score  Precision clase A
# 0          CNN  1.000000   1.000000  1.000000  1.000000           1.000000  \
# 1         LSTM  1.000000   1.000000  1.000000  1.000000           1.000000
# 2      DeepSet  0.945004   0.865360  0.924355  0.893885           0.512438
# 3    DeepSetV2  0.947523   0.869214  0.859586  0.864373           0.591304
# 4  Feedforward  0.931990   0.840420  0.877866  0.858735           0.497076
#
#    Recall clase A  Precision clase D  Recall clase D  Precision clase R
# 0        1.000000           1.000000        1.000000           1.000000  \
# 1        1.000000           1.000000        1.000000           1.000000
# 2        0.774436           0.966777        0.989796           1.000000
# 3        0.511278           0.927900        0.961039           0.996593
# 4        0.639098           0.904459        0.931148           0.991540
#
#    Recall clase R  Precision clase V  Recall clase V
# 0             1.0           1.000000        1.000000
# 1             1.0           1.000000        1.000000
# 2             1.0           0.982226        0.933186
# 3             1.0           0.961058        0.966027
# 4             1.0           0.968606        0.941220

# %% [markdown]
# ### Get best 50% performing models

# %%
top_half = int(num_experiments / 2)
best_cnn_accs = filter_top_k_accuracies(cnn_accuracies, top_half)
best_lstm_accs = filter_top_k_accuracies(lstm_accuracies, top_half)
best_deepset_accs = filter_top_k_accuracies(deepset_accuracies, top_half)
best_deepsetv2_accs = filter_top_k_accuracies(deepsetv2_accuracies, top_half)
best_feedforward_accs = filter_top_k_accuracies(feedforward_accuracies, top_half)

# %% [markdown]
# ## Accuracy breakdown by cases for all the models

# %%
all_accuracies = [cnn_accuracies, lstm_accuracies, deepset_accuracies, deepsetv2_accuracies, feedforward_accuracies]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']

# %%
get_stats_df(all_accuracies, model_names, test_original)
# Out:
#                        Overall cr_noop   cr_uw    cr_w   cr_wu dr_noop
# CNN                     100.0%  100.0%  100.0%  100.0%  100.0%  100.0%  \
# LSTM                     99.9%  100.0%  100.0%  100.0%  100.0%  100.0%
# DeepSet(like in paper)   92.1%   99.9%  100.0%  100.0%  100.0%   94.8%
# DeepSet(sum at start)    89.2%   99.9%  100.0%   99.8%  100.0%   70.7%
# Feedforward              89.6%   99.4%   99.9%   99.7%   99.9%   91.0%
# Sample count              2382     151     142     145     139     160
#
#                          dr_uw    dr_w   dr_wu noop_noop noop_uw  noop_w
# CNN                     100.0%  100.0%  100.0%    100.0%  100.0%  100.0%  \
# LSTM                     99.6%  100.0%   99.3%    100.0%  100.0%  100.0%
# DeepSet(like in paper)   59.6%   85.9%   26.1%    100.0%  100.0%  100.0%
# DeepSet(sum at start)    68.2%   68.7%   17.4%     99.8%  100.0%   99.9%
# Feedforward              50.0%   82.5%   21.1%     99.1%   99.9%   99.4%
# Sample count               133     138     140       165     173     162
#
#                        noop_wu  r_noop    r_uw     r_w    r_wu
# CNN                     100.0%  100.0%  100.0%  100.0%   99.5%
# LSTM                    100.0%  100.0%  100.0%  100.0%  100.0%
# DeepSet(like in paper)  100.0%   99.8%   99.3%   99.9%   98.4%
# DeepSet(sum at start)   100.0%   99.1%   98.5%   99.2%   98.0%
# Feedforward              99.9%   97.7%   94.4%   96.8%   92.6%
# Sample count               148     154     149     151     132

# %% [markdown]
# ## Accuracy breakdown by cases for top 50% of models

# %%
best_accuracies = [best_cnn_accs, best_lstm_accs, best_deepset_accs, best_deepsetv2_accs, best_feedforward_accs]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']
collapsed_cases = ['dr', 'r', 'cr', 'noop']

# %%
get_stats_df(best_accuracies, model_names, test_original, collapsed_cases)
# Out:
#                        Overall   f3_cr   f3_dr f3_noop    f3_r
# CNN                     100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM                    100.0%  100.0%  100.0%  100.0%  100.0%
# DeepSet(like in paper)   92.6%  100.0%   69.6%  100.0%   99.7%
# DeepSet(sum at start)    93.9%  100.0%   74.7%  100.0%   99.9%
# Feedforward              91.5%   99.8%   66.4%  100.0%   98.4%
# Sample count              2382     577     571     648     586

# %%
best_accuracies = [best_cnn_accs, best_lstm_accs, best_deepset_accs, best_deepsetv2_accs, best_feedforward_accs]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']
collapsed_cases = ['r', 'cr', 'noop']

# %%
get_stats_df(best_accuracies, model_names, test_original, collapsed_cases)
# Out:
#                        Overall dr_noop   dr_uw    dr_w   dr_wu   f3_cr
# CNN                     100.0%  100.0%  100.0%  100.0%  100.0%  100.0%  \
# LSTM                    100.0%  100.0%  100.0%  100.0%  100.0%  100.0%
# DeepSet(like in paper)   92.6%   96.8%   60.9%   89.6%   27.2%  100.0%
# DeepSet(sum at start)    93.9%   99.6%   76.8%   97.5%   21.6%  100.0%
# Feedforward              91.5%   95.2%   55.4%   85.4%   25.4%   99.8%
# Sample count              2382     160     133     138     140     577
#
#                        f3_noop    f3_r
# CNN                     100.0%  100.0%
# LSTM                    100.0%  100.0%
# DeepSet(like in paper)  100.0%   99.7%
# DeepSet(sum at start)   100.0%   99.9%
# Feedforward             100.0%   98.4%
# Sample count               648     586

# %% [markdown]
# ## Accuracies per CNN model

# %%
get_stats_per_model(cnn_accuracies, ['CNN #' + str(i) for i in range(len(cnn_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#              Overall   f3_cr   f3_dr f3_noop    f3_r
# CNN #0        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #1        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #2        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #3        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #4        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #5         99.9%  100.0%  100.0%  100.0%   99.7%
# CNN #6        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #7         99.9%  100.0%  100.0%  100.0%   99.7%
# CNN #8         99.9%  100.0%  100.0%  100.0%   99.5%
# CNN #9        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #10       100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #11       100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #12       100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #13       100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #14       100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #15        99.8%  100.0%  100.0%  100.0%   99.3%
# CNN #16       100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #17       100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #18       100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #19        99.9%  100.0%  100.0%  100.0%   99.7%
# Sample count    2382     577     571     648     586

# %%
get_stats_per_model_multiclass(cnn_accuracies, cnn_precisions, cnn_recalls, cnn_f1s, "CNN")

# %% [markdown]
# ## Accuracies per LSTM model

# %%
get_stats_per_model(lstm_accuracies, ['LSTM #' + str(i) for i in range(len(lstm_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#              Overall   f3_cr   f3_dr f3_noop    f3_r
# LSTM #0       100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #1       100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #2        99.9%  100.0%   99.5%  100.0%  100.0%
# LSTM #3       100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #4        99.9%  100.0%   99.5%  100.0%  100.0%
# LSTM #5        99.9%  100.0%   99.6%  100.0%  100.0%
# LSTM #6        99.7%  100.0%   98.9%  100.0%  100.0%
# LSTM #7       100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #8       100.0%  100.0%   99.8%  100.0%  100.0%
# LSTM #9       100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #10       99.6%  100.0%   98.2%  100.0%  100.0%
# LSTM #11      100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #12      100.0%  100.0%   99.8%  100.0%  100.0%
# LSTM #13      100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #14      100.0%  100.0%   99.8%  100.0%  100.0%
# LSTM #15      100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #16      100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #17      100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #18      100.0%  100.0%   99.8%  100.0%  100.0%
# LSTM #19       99.9%  100.0%   99.6%  100.0%  100.0%
# Sample count    2382     577     571     648     586

# %%
get_stats_per_model_multiclass(lstm_accuracies, lstm_precisions, lstm_recalls, lstm_f1s, "LSTM")

# %% [markdown]
# ## Accuracies per DeepSets V1 model

# %%
get_stats_per_model(deepset_accuracies, ['DeepSet(like in paper) #' + str(i) for i in range(len(deepset_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                            Overall   f3_cr  f3_dr f3_noop    f3_r
# DeepSet(like in paper) #0    92.6%  100.0%  69.0%  100.0%  100.0%
# DeepSet(like in paper) #1    91.4%   99.8%  64.3%  100.0%  100.0%
# DeepSet(like in paper) #2    93.0%  100.0%  70.8%  100.0%  100.0%
# DeepSet(like in paper) #3    92.1%  100.0%  67.6%  100.0%   99.5%
# DeepSet(like in paper) #4    89.8%  100.0%  64.3%  100.0%   93.2%
# DeepSet(like in paper) #5    91.7%   99.8%  65.7%  100.0%  100.0%
# DeepSet(like in paper) #6    92.0%  100.0%  66.9%  100.0%   99.8%
# DeepSet(like in paper) #7    92.1%   99.8%  69.5%  100.0%   98.0%
# DeepSet(like in paper) #8    90.9%   99.8%  64.6%  100.0%   97.8%
# DeepSet(like in paper) #9    91.9%  100.0%  66.2%  100.0%   99.8%
# DeepSet(like in paper) #10   91.7%  100.0%  65.3%  100.0%  100.0%
# DeepSet(like in paper) #11   92.4%  100.0%  68.1%  100.0%  100.0%
# DeepSet(like in paper) #12   92.5%  100.0%  68.7%  100.0%  100.0%
# DeepSet(like in paper) #13   91.7%  100.0%  65.5%  100.0%   99.8%
# DeepSet(like in paper) #14   91.9%  100.0%  66.4%  100.0%  100.0%
# DeepSet(like in paper) #15   92.4%  100.0%  68.3%  100.0%  100.0%
# DeepSet(like in paper) #16   92.4%  100.0%  68.7%  100.0%   99.8%
# DeepSet(like in paper) #17   92.5%  100.0%  68.7%  100.0%  100.0%
# DeepSet(like in paper) #18   94.5%  100.0%  77.1%  100.0%  100.0%
# DeepSet(like in paper) #19   91.9%  100.0%  66.4%  100.0%  100.0%
# Sample count                  2382     577    571     648     586

# %%
get_stats_per_model_multiclass(deepset_accuracies, deepset_precisions, deepset_recalls, deepset_f1s, "DEEPSET")

# %% [markdown]
# ## Accuracies per DeepSets V2 model

# %%
get_stats_per_model(deepsetv2_accuracies, ['DeepSet(sum at start) #' + str(i) for i in range(len(deepsetv2_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                           Overall   f3_cr  f3_dr f3_noop    f3_r
# DeepSet(sum at start) #0    88.3%  100.0%  51.8%  100.0%   99.5%
# DeepSet(sum at start) #1    81.4%  100.0%  22.4%  100.0%  100.0%
# DeepSet(sum at start) #2    80.0%  100.0%  22.6%  100.0%   94.2%
# DeepSet(sum at start) #3    81.5%  100.0%  22.9%  100.0%  100.0%
# DeepSet(sum at start) #4    90.0%  100.0%  58.7%  100.0%   99.7%
# DeepSet(sum at start) #5    94.5%  100.0%  76.9%  100.0%  100.0%
# DeepSet(sum at start) #6    81.3%  100.0%  21.9%  100.0%  100.0%
# DeepSet(sum at start) #7    93.8%  100.0%  74.1%  100.0%  100.0%
# DeepSet(sum at start) #8    85.3%   99.7%  48.0%   99.7%   91.6%
# DeepSet(sum at start) #9    93.8%  100.0%  74.3%  100.0%  100.0%
# DeepSet(sum at start) #10   94.0%  100.0%  75.1%  100.0%  100.0%
# DeepSet(sum at start) #11   93.9%  100.0%  74.6%  100.0%  100.0%
# DeepSet(sum at start) #12   85.1%   99.7%  46.2%   99.8%   92.2%
# DeepSet(sum at start) #13   93.8%  100.0%  74.6%  100.0%   99.7%
# DeepSet(sum at start) #14   94.3%  100.0%  76.7%   99.8%   99.8%
# DeepSet(sum at start) #15   92.6%  100.0%  69.4%  100.0%   99.7%
# DeepSet(sum at start) #16   91.5%   99.1%  68.1%   99.1%   98.5%
# DeepSet(sum at start) #17   81.3%  100.0%  21.9%  100.0%  100.0%
# DeepSet(sum at start) #18   93.4%  100.0%  72.7%   99.8%  100.0%
# DeepSet(sum at start) #19   94.8%  100.0%  78.3%  100.0%   99.8%
# Sample count                 2382     577    571     648     586

# %%
get_stats_per_model_multiclass(deepsetv2_accuracies, deepsetv2_precisions, deepsetv2_recalls, deepsetv2_f1s, "DEEPSETv2")

# %% [markdown]
# ## Accuracies per FeedForward model

# %%
get_stats_per_model(feedforward_accuracies, ['Feedforward #' + str(i) for i in range(len(feedforward_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                 Overall   f3_cr  f3_dr f3_noop    f3_r
# Feedforward #0    86.8%  100.0%  59.5%   99.4%   86.5%
# Feedforward #1    81.4%   99.0%  47.1%   96.3%   81.1%
# Feedforward #2    90.8%  100.0%  65.0%  100.0%   96.8%
# Feedforward #3    90.9%  100.0%  63.2%  100.0%   98.8%
# Feedforward #4    91.9%   99.7%  67.4%  100.0%   99.3%
# Feedforward #5    90.6%  100.0%  61.5%  100.0%   99.5%
# Feedforward #6    91.1%   99.8%  66.9%  100.0%   96.2%
# Feedforward #7    91.6%   99.3%  68.3%  100.0%   97.3%
# Feedforward #8    90.3%   99.5%  64.4%  100.0%   95.7%
# Feedforward #9    91.3%   99.8%  65.3%   99.8%   98.8%
# Feedforward #10   91.5%   99.8%  65.7%  100.0%   99.1%
# Feedforward #11   86.7%   99.7%  48.3%   99.5%   97.1%
# Feedforward #12   93.2%  100.0%  71.8%   99.8%  100.0%
# Feedforward #13   91.5%  100.0%  64.8%  100.0%   99.8%
# Feedforward #14   90.8%  100.0%  66.0%   99.5%   96.1%
# Feedforward #15   90.5%   99.1%  65.0%  100.0%   96.2%
# Feedforward #16   89.3%   99.7%  60.8%   99.1%   95.9%
# Feedforward #17   91.3%   99.7%  66.0%  100.0%   98.1%
# Feedforward #18   86.3%   99.7%  49.9%   99.8%   93.5%
# Feedforward #19   85.2%   99.5%  58.1%   98.1%   83.1%
# Sample count       2382     577    571     648     586

# %%
get_stats_per_model_multiclass(feedforward_accuracies, feedforward_precisions, feedforward_recalls, feedforward_f1s, "FEEDFORWARD")

# %% [markdown]
# # Training evolution

# %% [markdown]
# ### CNN

# %%
display_epochs_stats(cnn_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### LSTM

# %%
display_epochs_stats(lstm_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### DeepSets V1

# %%
display_epochs_stats(deepset_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### DeepSets V2

# %%
display_epochs_stats(deepsetv2_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### FeedForward

# %%
display_epochs_stats(feedforward_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# # Best performing models

# %%
best_lstm_model = LSTM_Model(data, 16, 32, 8).to(device)
best_lstm_model.load_state_dict(torch.load('./bestmodels/best_LSTM_model_' + experiment_name))
best_cnn_model = CNN_Model(data, 64, 128, 4, -1,).to(device)
best_cnn_model.load_state_dict(torch.load('./bestmodels/best_CNN_model_' + experiment_name))
best_deepset_model = DEEPSET_Model(data).to(device)
best_deepset_model.load_state_dict(torch.load('./bestmodels/best_DEEPSET_model_' + experiment_name))
best_deepsetv2_model = DEEPSETV2_Model(data, 16, 8).to(device)
best_deepsetv2_model.load_state_dict(torch.load('./bestmodels/best_DEEPSETV2_model_' + experiment_name))
best_feedforward_model = FEEDFORWARD_Model(data).to(device)
best_feedforward_model.load_state_dict(torch.load('./bestmodels/best_FEEDFORWARD_model_' + experiment_name))
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_4820\971391106.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_lstm_model.load_state_dict(torch.load('best_LSTM_model_' + experiment_name))
# C:\Users\franm\AppData\Local\Temp\ipykernel_4820\971391106.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_cnn_model.load_state_dict(torch.load('best_CNN_model_' + experiment_name))
# C:\Users\franm\AppData\Local\Temp\ipykernel_4820\971391106.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_deepset_model.load_state_dict(torch.load('best_DEEPSET_model_' + experiment_name))
# C:\Users\franm\AppData\Local\Temp\ipykernel_4820\971391106.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_deepsetv2_model.load_state_dict(torch.load('best_DEEPSETV2_model_' + experiment_name))
# C:\Users\franm\AppData\Local\Temp\ipykernel_4820\971391106.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_feedforward_model.load_state_dict(torch.load('best_FEEDFORWARD_model_' + experiment_name))
# <All keys matched successfully>

# %% [markdown]
# ## Top wrong predictions for best performing CNN model

# %%
print_wrong_preds_bycases(get_wrong_predictions_bycases(best_cnn_model, x_test_cnn, y_test, test_original), k=10)
# Out:
# 4 false Atomicity violation:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 print_wrong_preds([get_wrong_predictions(best_cnn_model, x_test_cnn, y_test, test_original)])
#
# File ~\TFGNuestro\src\evaluate.py:405, in print_wrong_preds(wrong_preds_list, k)
#     403 print(f'{min(k,len(i))} false {cases[a]}:')
#     404 for j in range(min(k,len(i))):
# --> 405     print(f"Sample {i[j][0]} | Prediction {i[j][1]}")
#     406 a+=1
#     407 print("\n")
#
# IndexError: list index out of range

# %%
print_wrong_preds(get_wrong_predictions(best_cnn_model, x_test_cnn, y_test, test_original), k=10)

# %% [markdown]
# ## Top wrong predictions for best performing LSTM model

# %%
print_wrong_preds_bycases(get_wrong_predictions_bycases(best_lstm_model, x_test_lstm, y_test, test_original), k=10)
# Out:
# 4 false Atomicity violation:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 print_wrong_preds([get_wrong_predictions(best_lstm_model, x_test_lstm, y_test, test_original)])
#
# File ~\TFGNuestro\src\evaluate.py:405, in print_wrong_preds(wrong_preds_list, k)
#     403 print(f'{min(k,len(i))} false {cases[a]}:')
#     404 for j in range(min(k,len(i))):
# --> 405     print(f"Sample {i[j][0]} | Prediction {i[j][1]}")
#     406 a+=1
#     407 print("\n")
#
# IndexError: list index out of range

# %%
print_wrong_preds(get_wrong_predictions(best_lstm_model, x_test_lstm, y_test, test_original), k=10)

# %% [markdown]
# ## Top wrong predictions for best performing DeepSets V1 model

# %%
print_wrong_preds_bycases(get_wrong_predictions_bycases(best_deepset_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 4 false Atomicity violation:
# Sample ([',__.._,._...__.,', '_.__wu._,,....,.', '_,..__,..dr...._', 'V'], 'A') | Prediction (['_,_,__.,._,,,.,.', ',.__.,,,w_,._.,.', 'dr,,_.,.,__,.___', 'D'], 'A')
# Sample (['.,_.,,,,.,__....', '.,uw.,.__,.,_.,,', '.,dr,.__._.,,,_.', 'A'], 'D') | Prediction (['_.._,.,,_._.__,.', '_wu_,,_,_,,____,', 'dr.,,.,..,_,_,__', 'V'], 'D')
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 print_wrong_preds([get_wrong_predictions(best_deepset_model, x_test_normal, y_test, test_original)])
#
# File ~\TFGNuestro\src\evaluate.py:405, in print_wrong_preds(wrong_preds_list, k)
#     403 print(f'{min(k,len(i))} false {cases[a]}:')
#     404 for j in range(min(k,len(i))):
# --> 405     print(f"Sample {i[j][0]} | Prediction {i[j][1]}")
#     406 a+=1
#     407 print("\n")
#
# IndexError: list index out of range

# %%
print_wrong_preds(get_wrong_predictions(best_deepset_model, x_test_normal, y_test, test_original), k=10)

# %% [markdown]
# ## Top wrong predictions for best performing DeepSets V2 model

# %%
print_wrong_preds_bycases(get_wrong_predictions_bycases(best_deepsetv2_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 4 false Atomicity violation:
# Sample ([',__.._,._...__.,', '_.__wu._,,....,.', '_,..__,..dr...._', 'V'], 'A') | Prediction ([',___,,,,__.,.,,.', '_,.,wu__..,._,..', '.__....,,_.__dr_', 'V'], 'A')
# Sample ([',._,,___,,,._,_,', ',.,uw__,_,._._..', 'dr______,,,,.__,', 'A'], 'D') | Prediction (['.._.,.,.._.,.,_.', ',.,uw.,,,,,_,_._', '__,.._.,,_dr_.._', 'A'], 'D')
# Sample (['_.,.,_..,__.___,', ',__,.__,___uw_._', '__,,,.,.,,,dr._,', 'A'], 'R') | Prediction (['_.,_._.,._,.__..', '__.._..wu..___._', '._......,..dr_,,', 'V'], 'R')
# Sample (['...,.._...,__.,,', ',uw.._,,._.__,_.', '___._.__,__dr.,.', 'A'], 'V') | Prediction (['.,_.___.,..,,..,', ',_.._.uw._._.__.', '_.,dr_.._,,..,..', 'A'], 'V')

# %%
print_wrong_preds(get_wrong_predictions(best_deepsetv2_model, x_test_normal, y_test, test_original), k=10)

# %% [markdown]
# ## Top wrong predictions for best performing Feedforward model

# %%
print_wrong_preds_bycases(get_wrong_predictions_bycases(best_feedforward_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 4 false Atomicity violation:
# Sample (['__.,_._,,.,_.._.', ',_.__,__.,,wu,_.', '.,_.,.dr.._.,,._', 'V'], 'A') | Prediction ([',__.._,._...__.,', '_.__wu._,,....,.', '_,..__,..dr...._', 'V'], 'A')
# Sample (['...,.._...,__.,,', ',uw.._,,._.__,_.', '___._.__,__dr.,.', 'A'], 'D') | Prediction ([',._,,___,,,._,_,', ',.,uw__,_,._._..', 'dr______,,,,.__,', 'A'], 'D')
# Sample (['___.__,___.._,..', '_.,._..,__,,,_.,', '_,_,_..._,__._..', 'V'], 'R') | Prediction (['___._.,_.,,,,.,,', '_,___w._,_,,.._.', '__.__,.,.dr_.,,.', 'D'], 'R')
# Sample (['_,_._..,_,.__.,_', ',_,.,__,,_.uw,,.', ',.,,,_____._,dr,', 'A'], 'V') | Prediction (['.,,,.,.._.,_.,_.', '______,,.__uw_..', ',______,_dr,,.._', 'A'], 'V')

# %%
print_wrong_preds(get_wrong_predictions(best_feedforward_model, x_test_normal, y_test, test_original), k=10)

# %% [markdown]
# # Saving Notebook State

# %%
import dill
dill.dump_session('notebook_env_' + experiment_name + '.db')

# %% [markdown]
# # Loading Notebook State

# %%
import dill
experiment_name = "25per"
# dill.load_session('notebook_env_' + experiment_name + '.db')
