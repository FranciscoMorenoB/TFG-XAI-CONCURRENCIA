# %%
from generate_data import Data
from evaluate import *
from models import *

import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# %autosave 120
# Out:
# Autosaving every 120 seconds

# %% [markdown]
# # Get the synthetic dataset

# %%
# %%time
data = Data(layer_size=16)
num_experiments = 20
epochs = 200
early_stopping_limit = 100

experiment_name = "25per"
# Out:
# c:\Users\juand\anaconda3\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but OneHotEncoder was fitted without feature names
#   warnings.warn(
# Wall time: 847 ms

# %%
# %%time
train, val, test = data.get_splits(['random_subsample'], [[0.25, 0.75]])

train_unshuffled = train.copy()
np.random.shuffle(train)

x_train, y_train = data.get_x_y(train)
x_val, y_val = data.get_x_y(val)
x_test, y_test = data.get_x_y(test)

train_original = data.reverse_encoding(data.get_x_y(train_unshuffled)[0])
val_original = data.reverse_encoding(x_val)
test_original = data.reverse_encoding(x_test)
# Out:
# Number of samples: 992 train | 595 val | 2382 test
# Wall time: 310 ms

# %% [markdown]
# #### Peek at unshuffled train data

# %%
train_original[:20]
# Out:
# [[',,..,__._,.,._.,', '______.,_.uw._.,', '___..,__.__dr_._', 'A'],
#  [',___,,._,,.__.,.', '__._,__w__._,,,,', '_,.,,,.,_.dr_...', 'D'],
#  [',...__..,.,,,_..', '.,___.__.wu___.,', '._cr._..__,,,.,.', 'V'],
#  ['.,,._.._.,_,,,..', '_..__,,,.,.__.,,', ',_,._._,_,.r,,__', 'R'],
#  ['.__.,,.,,_.,___,', '_._,,,._..._,_,,', '._.,_dr.,,.._,__', 'D'],
#  [',,__,,_.___...,_', '_,__,_,_,,_._..,', '_,.,,cr.._,.._,.', 'V'],
#  ['.._...,.,._,,.,,', ',._,,.,,,.w_._.,', ',,.,,__.,.__,__,', 'V'],
#  ['._.,..._.._...._', '_,_...__.,,.wu,_', '_.._.,.._._,_,._', 'V'],
#  ['.._._,,_._,....,', '_....__,.,uw,_._', ',.,_,,.._,__r,,,', 'R'],
#  ['.,_..,,._,__.,,.', ',___,_.._,_,w.,_', ',,._,,..__,cr__.', 'V'],
#  [',..._.____.__,_,', '.,,,_wu_...,_,_,', '_..__,.__,.r....', 'R'],
#  [',,.,_,__.,.__.,_', '...,__.,.__._..,', '_,_....,,.cr,__,', 'V'],
#  ['._._..,,_,...._.', '_._._,wu_.,___..', '__,.._,_.,.,....', 'V'],
#  [',__,,_._.,.,.,,.', 'w._.,,_.._,_..._', '_...__.__..._._.', 'V'],
#  ['.,._.,._.,,__,..', '__._wu.,..,,__.,', '__,__._cr,.._,_.', 'V'],
#  ['__,,.,,,__.._,..', ',_.,.._,._.,uw._', '_.,__,,.,..,..__', 'V'],
#  [',_,,_.,__,,.__..', '_.,,.,_,uw,__...', '._...,_,.____..,', 'V'],
#  [',._...,,._,._,_.', ',.__,w_,_,__.,,,', ',,,.___,,_,__,__', 'V'],
#  ['._,,.._..,_.,..,', '_.,..,.__.,...wu', '.dr,_...__.,,_,,', 'V'],
#  ['...__.,..__._.._', '.....,_.,_,w_._,', ',..._.,_,,.cr,_,', 'V']]

# %%
pos_train_ratio = get_stats_and_ratio(train_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 56 | F2-uw 59 | F2-w 64 | F2-noop 65 |
# F3 cr:    F2-wu 56 | F2-uw 52 | F2-w 63 | F2-noop 51 |
# F3 r:    F2-wu 69 | F2-uw 49 | F2-w 67 | F2-noop 71 |
# F3 noop:    F2-wu 69 | F2-uw 54 | F2-w 75 | F2-noop 72 |
#
# Positive samples count: 444
# Total samples count: 992
# Positive class ratio: 0.4475806451612903

# %% [markdown]
# #### Peek at test data

# %%
test_original[:15]
# Out:
# [['.,_,__,,._..,.,.', ',_uw__.,,___,...', ',,_,,_.__,._____', 'V'],
#  ['_..,.____.,,.,,_', ',.,......,.,_.,.', ',,,..._,_dr,_,,,', 'D'],
#  ['.,_,,__.,..___._', '__.,_,..,_,.._,,', ',.,..._,..,,,,,.', 'V'],
#  ['__,._.,..,,__...', '_._.w..,..__,...', '_____,..,.,...dr', 'D'],
#  ['.___,,,_,_.._,..', ',____,.,._w____.', '_.cr,....,,.__,.', 'V'],
#  ['.,,..,__._..,_._', '__wu.,._,.,__.._', '_cr...,__.,,,,..', 'V'],
#  [',.__,.,_..._,.,,', ',_,.,,_,_.,_,wu_', ',,._,._,_r,,,,._', 'R'],
#  [',.,.._..,,,.,.__', '_,._uw____,_,__.', '_._...,_,_,r._._', 'R'],
#  [',_,,,,,.__...___', ',_._.,,uw_,_,,,_', '.r,_..__,..,,._.', 'R'],
#  ['.,_.,__..___._..', ',._._,uw___..,__', '__...,.__.r_._..', 'R'],
#  ['_,,,,,_._,,,,..,', ',_,_,_..,..wu__,', '_,..__cr..,,._.,', 'V'],
#  ['._,_,_,._,__,_..', '__...,_._..__,wu', '..,_,__...,__,_.', 'V'],
#  ['_._,,,.....,.,._', ',_.,uw.,__,,...,', ',..,.,_..__..,.r', 'R'],
#  [',.,,..,,__,._._.', '.,wu._,_____..._', '.,r.___,..._,,..', 'R'],
#  ['__.,_._,,.,_.._.', ',_.__,__.,,wu,_.', '.,_.,.dr.._.,,._', 'V']]

# %%
pos_test_ratio = get_stats_and_ratio(test_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 140 | F2-uw 133 | F2-w 138 | F2-noop 160 |
# F3 cr:    F2-wu 139 | F2-uw 142 | F2-w 145 | F2-noop 151 |
# F3 r:    F2-wu 132 | F2-uw 149 | F2-w 151 | F2-noop 154 |
# F3 noop:    F2-wu 148 | F2-uw 173 | F2-w 162 | F2-noop 165 |
#
# Positive samples count: 1017
# Total samples count: 2382
# Positive class ratio: 0.4269521410579345

# %% [markdown]
# #### Peek at val data

# %%
val_original[:15]
# Out:
# [[',,,__..__.____,.', 'w___,_._,,.__,,.', '...__,.cr.,,__,.', 'V'],
#  [',_..._,_._._,,,.', '_.._._.uw..,,_,_', '_.,,_._.,,.,_cr_', 'V'],
#  ['.___.,_.__,.,_.,', '_,,.._.,._..w_.,', '..,_..__.,__.r,.', 'R'],
#  ['._,.,,.._,_,.,_,', '.,,uw_.._.....,.', ',.,,,,.r.,,_..._', 'R'],
#  ['_..,_.,_,_._,,,,', '__.,,_.uw,,,,..,', '.__.,cr,.,.__..,', 'V'],
#  ['_,,._._....,,,_,', ',,_._w._._.__,_,', '_._.r,_..,,.,__,', 'R'],
#  ['..__.,_,____,._,', '.,_.w,,,_._,_,__', ',.,.,.,..__._cr,', 'V'],
#  ['.,._.,_..,_,,,_,', ',_.._._.____wu__', '.,_,r_.,,_,_.__.', 'R'],
#  ['._,._,_,,,___,.,', '..___,___uw.,__.', ',.,....,,_dr,_,_', 'A'],
#  ['..,.__.__,,_,___', '____,__._.,uw__.', ',__.,_cr___._,_.', 'V'],
#  ['___...,____,,__.', '_,,..._,___,__,.', '.,_,,._._,.,..cr', 'V'],
#  [',,._,.,.,_...,_,', 'wu__,._.,____,,,', ',.__,.._.,__,,,r', 'R'],
#  ['__.,._,,.______,', '.w..._.._.,_..__', ',.,_dr,._,_,.,._', 'D'],
#  [',..,,,__...,,,,,', ',,__._,,,._,,.,_', '_.___..__....,__', 'V'],
#  ['_,.._,_,_,.,,,,,', '..,_.._,..,._,,,', 'r._,.__._,..,,,.', 'R']]

# %%
pos_val_ratio = get_stats_and_ratio(val_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 29 | F2-uw 33 | F2-w 38 | F2-noop 30 |
# F3 cr:    F2-wu 30 | F2-uw 31 | F2-w 32 | F2-noop 53 |
# F3 r:    F2-wu 39 | F2-uw 42 | F2-w 38 | F2-noop 47 |
# F3 noop:    F2-wu 38 | F2-uw 28 | F2-w 35 | F2-noop 52 |
#
# Positive samples count: 267
# Total samples count: 595
# Positive class ratio: 0.44873949579831934

# %% [markdown]
# #### Send label arrays to device

# %%
from sklearn.preprocessing import LabelEncoder

# Codificar etiquetas categóricas a índices numéricos
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_val = label_encoder.transform(y_val)
y_test = label_encoder.transform(y_test)

# Convertir a tensores de PyTorch
y_train = torch.tensor(y_train, dtype=torch.long).to(device)
y_val = torch.tensor(y_val, dtype=torch.long).to(device)
y_test = torch.tensor(y_test, dtype=torch.long).to(device)

# Verificar clases codificadas
print("Clases codificadas:", label_encoder.classes_)
# Out:
# Clases codificadas: ['A' 'D' 'R' 'V']

# %% [markdown]
# #### Get data in normal format (same as CNN format)

# %%
x_train_normal = data.to_conv_format(x_train)
x_val_normal = data.to_conv_format(x_val)
x_test_normal = data.to_conv_format(x_test)
for i in range(len(x_train_normal)):
    x_train_normal[i] = x_train_normal[i].to(device)
    x_val_normal[i] = x_val_normal[i].to(device)
    x_test_normal[i] = x_test_normal[i].to(device)

# %%
x_train_normal[0].shape
# Out:
# torch.Size([992, 128])

# %% [markdown]
# #### Get data in convolutional format, send to device

# %%
x_train_cnn = data.to_conv_format(x_train)
x_val_cnn = data.to_conv_format(x_val)
x_test_cnn = data.to_conv_format(x_test)
for i in range(len(x_train_cnn)):
    x_train_cnn[i] = x_train_cnn[i].to(device)
    x_val_cnn[i] = x_val_cnn[i].to(device)
    x_test_cnn[i] = x_test_cnn[i].to(device)

# %%
x_train_cnn[0].shape
# Out:
# torch.Size([992, 128])

# %% [markdown]
# #### Get data in LSTM format, send to device

# %%
x_train_lstm = data.to_lstm_format(x_train)
x_val_lstm = data.to_lstm_format(x_val)
x_test_lstm = data.to_lstm_format(x_test)
for i in range(len(x_train_lstm)):
    x_train_lstm[i] = x_train_lstm[i].to(device)
    x_val_lstm[i] = x_val_lstm[i].to(device)
    x_test_lstm[i] = x_test_lstm[i].to(device)

# %%
x_train_lstm[0].shape
# Out:
# torch.Size([992, 16, 8])

# %% [markdown]
# ### Define training procedure for each model

# %%
def train_models(constructor, x_train, x_val, x_test, weight_decay, *argv):
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    wrong_preds = []
    best_accuracy = 0
    
    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []

    for i in range(num_experiments):
        model = constructor(*argv)
        model.to(device)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), weight_decay=weight_decay)

        train_losses.append([])
        val_losses.append([])
        train_accs.append([])
        val_accs.append([])
        
        best_acc = 0

        early_stopping_cnt = 0

        for epoch in range(1, epochs + 1):
            train_loss, train_acc = train_epoch(model, x_train, y_train, criterion, optimizer, epoch, 10, verbose=False)
            val_loss, val_acc = eval_epoch(model, x_val, y_val, criterion, 'Validation', verbose=False)

            
            train_losses[-1].append(train_loss)
            val_losses[-1].append(val_loss)
            train_accs[-1].append(train_acc)
            val_accs[-1].append(val_acc)
            
            model_name = constructor.__name__[:constructor.__name__.find('_')]
            if val_acc > best_acc:
                best_acc = val_acc
                torch.save(model.state_dict(), f'./temp/{model_name}_model_TEMP_' + experiment_name)    
                early_stopping_cnt = 0
            else:
                early_stopping_cnt += 1

            if early_stopping_cnt >= early_stopping_limit:
                break


        model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
        
        accuracies.append(get_accuracy_by_cases(model, x_test, y_test, test_original))
        precisions.append(get_precision(model, x_test, y_test, test_original))
        recalls.append(get_recall(model, x_test, y_test, test_original))
        f1_scores.append(get_f1(precisions[-1], recalls[-1]))
        
        wrong_preds.append((f"Experimento {i}", get_wrong_predictions(model, x_test, y_test, test_original)))

        if accuracies[-1]['Overall'] > best_accuracy:
            torch.save(model.state_dict(), f'./bestmodels/best_{model_name}_model_' + experiment_name)    
            best_accuracy = accuracies[-1]['Overall']

        print(i + 1, "/", num_experiments, "models trained | Current model test accuracy:", accuracies[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test precision:", precisions[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test recall:", recalls[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test f1:", f1_scores[-1]['Overall'])


    
    return accuracies, precisions, recalls, f1_scores, wrong_preds, [train_losses, val_losses, train_accs, val_accs], model
    #return accuracies, precisions, wrong_preds, [train_losses, val_losses, train_accs, val_accs]

# %% [markdown]
# # Train models

# %%
# %%time
cnn_accuracies, cnn_precisions, cnn_recalls, cnn_f1_scores, cnn_wrong_preds, cnn_epoch_stats, model = train_models(
    CNN_Model, x_train_cnn, x_val_cnn, x_test_cnn, 0.0001, data, 64, 128, 4, -1, 'keras')
    
#cnn_accuracies, cnn_precisions, cnn_wrong_preds, cnn_epoch_stats = train_models(CNN_Model, x_train_cnn, x_val_cnn, x_test_cnn, 0.0001, data, 64, 128, 4, -1, 'keras')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\AppData\Local\Temp\ipykernel_19984\2177076457.py in train_models(constructor, x_train, x_val, x_test, weight_decay, *argv)
#      17
#      18         criterion = nn.CrossEntropyLoss()
# ---> 19         optimizer = optim.Adam(model.parameters(), weight_decay=weight_decay)
#      20
#      21         train_losses.append([])
#
# c:\Users\juand\anaconda3\lib\site-packages\torch\optim\adam.py in __init__(self, params, lr, betas, eps, weight_decay, amsgrad, foreach, maximize, capturable, differentiable, fused)
#      97             fused=fused,
#      98         )
# ---> 99         super().__init__(params, defaults)
#     100
#     101         if fused:
#
# c:\Users\juand\anaconda3\lib\site-packages\torch\optim\optimizer.py in __init__(self, params, defaults)
#     375
#     376         for param_group in param_groups:
# --> 377             self.add_param_group(cast(dict, param_group))
#     378
#     379         # Allows _cuda_graph_capture_health_check to rig a poor man's TORCH_WARN_ONCE in python,
#
# c:\Users\juand\anaconda3\lib\site-packages\torch\_compile.py in inner(*args, **kwargs)
#      25             disable_fn = getattr(fn, "__dynamo_disable", None)
#      26             if disable_fn is None:
# ---> 27                 import torch._dynamo
#      28
#      29                 disable_fn = torch._dynamo.disable(fn, recursive)
#
# c:\Users\juand\anaconda3\lib\site-packages\torch\_dynamo\__init__.py in <module>
#       1 import torch
#       2
# ----> 3 from . import convert_frame, eval_frame, resume_execution
#       4 from .backends.registry import list_backends, lookup_backend, register_backend
#       5 from .callback import callback_handler, on_compile_end, on_compile_start
#
# c:\Users\juand\anaconda3\lib\site-packages\torch\_dynamo\convert_frame.py in <module>
#      31 from torch._C._dynamo.guards import GlobalStateGuard
#      32 from torch._dynamo.distributed import get_compile_pg
# ---> 33 from torch._dynamo.symbolic_convert import TensorifyState
#      34 from torch._guards import compile_context, CompileContext, CompileId, tracing
#      35 from torch._logging import structured
#
# c:\Users\juand\anaconda3\lib\site-packages\torch\_dynamo\symbolic_convert.py in <module>
#      28 from torch._guards import tracing, TracingContext
#      29
# ---> 30 from . import config, exc, logging as torchdynamo_logging, trace_rules, variables
#      31 from .bytecode_analysis import (
#      32     get_indexof,
#
# c:\Users\juand\anaconda3\lib\site-packages\torch\_dynamo\trace_rules.py in <module>
#      44 from .resume_execution import TORCH_DYNAMO_RESUME_IN_PREFIX
#      45 from .utils import getfile, hashable, NP_SUPPORTED_MODULES, unwrap_if_wrapper
# ---> 46 from .variables import (
#      47     BuiltinVariable,
#      48     FunctionalCallVariable,
#
# c:\Users\juand\anaconda3\lib\site-packages\torch\_dynamo\variables\__init__.py in <module>
#     107     UntypedStorageVariable,
#     108 )
# --> 109 from .torch import TorchCtxManagerClassVariable, TorchInGraphFunctionVariable
#     110 from .user_defined import (
#     111     MutableMappingVariable,
#
# c:\Users\juand\anaconda3\lib\site-packages\torch\_dynamo\variables\torch.py in <module>
#     143     torch._C._get_tracing_state: None,
#     144     torch.fx._symbolic_trace.is_fx_tracing: False,
# --> 145     torch.onnx.is_in_onnx_export: False,
#     146     torch._dynamo.external_utils.is_compiling: True,
#     147     torch._utils.is_compiling: True,
#
# c:\Users\juand\anaconda3\lib\site-packages\torch\__init__.py in __getattr__(name)
#    2677         # Lazy modules
#    2678         if name in _lazy_modules:
# -> 2679             return importlib.import_module(f".{name}", __name__)
#    2680
#    2681         raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# c:\Users\juand\anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# c:\Users\juand\anaconda3\lib\site-packages\torch\onnx\__init__.py in <module>
#      65 from ._type_utils import JitScalarType
#      66 from .errors import OnnxExporterError
# ---> 67 from .utils import (
#      68     _run_symbolic_function,
#      69     _run_symbolic_method,
#
# c:\Users\juand\anaconda3\lib\site-packages\torch\onnx\utils.py in <module>
#      21 import torch.serialization
#      22 from torch import _C
# ---> 23 from torch.onnx import _constants, _deprecation, errors, symbolic_helper  # noqa: F401
#      24 from torch.onnx._globals import GLOBALS
#      25 from torch.onnx._internal import diagnostics, jit_utils, onnx_proto_utils, registration
#
# c:\Users\juand\anaconda3\lib\site-packages\torch\onnx\symbolic_helper.py in <module>
#      17 # Monkey-patch graph manipulation methods on Graph, used for the ONNX symbolics
#      18 from torch.onnx import _constants, _type_utils, errors, utils
# ---> 19 from torch.onnx._globals import GLOBALS
#      20 from torch.onnx._internal import jit_utils
#      21
#
# c:\Users\juand\anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# c:\Users\juand\anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# c:\Users\juand\anaconda3\lib\importlib\_bootstrap.py in _find_spec(name, path, target)
#
# c:\Users\juand\anaconda3\lib\importlib\_bootstrap_external.py in find_spec(cls, fullname, path, target)
#
# c:\Users\juand\anaconda3\lib\importlib\_bootstrap_external.py in _get_spec(cls, fullname, path, target)
#
# c:\Users\juand\anaconda3\lib\importlib\_bootstrap_external.py in find_spec(self, fullname, target)
#
# c:\Users\juand\anaconda3\lib\importlib\_bootstrap_external.py in _path_isfile(path)
#
# c:\Users\juand\anaconda3\lib\importlib\_bootstrap_external.py in _path_is_mode_type(path, mode)
#
# c:\Users\juand\anaconda3\lib\importlib\_bootstrap_external.py in _path_stat(path)
#
# KeyboardInterrupt:

# %%
# %%time
lstm_accuracies, lstm_precisions, lstm_recalls, lstm_f1Scores, lstm_wrong_preds, lstm_epoch_stats, model = train_models(LSTM_Model, x_train_lstm, x_val_lstm, x_test_lstm, 0.0001, data, 16, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_7128\2177076457.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.9987405541561712
# 1 / 20 models trained | Current model test precision: 0.9944852941176471
# 1 / 20 models trained | Current model test recall: 0.9994505494505495
# 1 / 20 models trained | Current model test f1: 0.9969617395990995
# 2 / 20 models trained | Current model test accuracy: 1.0
# 2 / 20 models trained | Current model test precision: 1.0
# 2 / 20 models trained | Current model test recall: 1.0
# 2 / 20 models trained | Current model test f1: 1.0
# 3 / 20 models trained | Current model test accuracy: 1.0
# 3 / 20 models trained | Current model test precision: 1.0
# 3 / 20 models trained | Current model test recall: 1.0
# 3 / 20 models trained | Current model test f1: 1.0
# 4 / 20 models trained | Current model test accuracy: 0.8849706129303107
# 4 / 20 models trained | Current model test precision: 0.6296417512523462
# 4 / 20 models trained | Current model test recall: 0.669908466819222
# 4 / 20 models trained | Current model test f1: 0.649151274589067
# 5 / 20 models trained | Current model test accuracy: 0.9995801847187238
# 5 / 20 models trained | Current model test precision: 0.9981343283582089
# 5 / 20 models trained | Current model test recall: 0.9998168498168498
# 5 / 20 models trained | Current model test f1: 0.9989748806421755
# 6 / 20 models trained | Current model test accuracy: 0.9991603694374476
# 6 / 20 models trained | Current model test precision: 0.9979371505687296
# 6 / 20 models trained | Current model test recall: 0.9979371505687296
# 6 / 20 models trained | Current model test f1: 0.9979371505687296
# 7 / 20 models trained | Current model test accuracy: 1.0
# 7 / 20 models trained | Current model test precision: 1.0
# 7 / 20 models trained | Current model test recall: 1.0
# 7 / 20 models trained | Current model test f1: 1.0
# 8 / 20 models trained | Current model test accuracy: 1.0
# 8 / 20 models trained | Current model test precision: 1.0
# 8 / 20 models trained | Current model test recall: 1.0
# 8 / 20 models trained | Current model test f1: 1.0
# 9 / 20 models trained | Current model test accuracy: 1.0
# 9 / 20 models trained | Current model test precision: 1.0
# 9 / 20 models trained | Current model test recall: 1.0
# 9 / 20 models trained | Current model test f1: 1.0
# 10 / 20 models trained | Current model test accuracy: 0.8837111670864819
# 10 / 20 models trained | Current model test precision: 0.6271836183026236
# 10 / 20 models trained | Current model test recall: 0.6697313909263787
# 10 / 20 models trained | Current model test f1: 0.6477595741632532
# 11 / 20 models trained | Current model test accuracy: 1.0
# 11 / 20 models trained | Current model test precision: 1.0
# 11 / 20 models trained | Current model test recall: 1.0
# 11 / 20 models trained | Current model test f1: 1.0
# 12 / 20 models trained | Current model test accuracy: 0.9987405541561712
# 12 / 20 models trained | Current model test precision: 0.9987981151509665
# 12 / 20 models trained | Current model test recall: 0.9943609022556391
# 12 / 20 models trained | Current model test f1: 0.9965745695945547
# 13 / 20 models trained | Current model test accuracy: 0.9974811083123426
# 13 / 20 models trained | Current model test precision: 0.9989059080962801
# 13 / 20 models trained | Current model test recall: 0.9887218045112782
# 13 / 20 models trained | Current model test f1: 0.9937877659134178
# 14 / 20 models trained | Current model test accuracy: 1.0
# 14 / 20 models trained | Current model test precision: 1.0
# 14 / 20 models trained | Current model test recall: 1.0
# 14 / 20 models trained | Current model test f1: 1.0
# 15 / 20 models trained | Current model test accuracy: 1.0
# 15 / 20 models trained | Current model test precision: 1.0
# 15 / 20 models trained | Current model test recall: 1.0
# 15 / 20 models trained | Current model test f1: 1.0
# 16 / 20 models trained | Current model test accuracy: 1.0
# 16 / 20 models trained | Current model test precision: 1.0
# 16 / 20 models trained | Current model test recall: 1.0
# 16 / 20 models trained | Current model test f1: 1.0
# 17 / 20 models trained | Current model test accuracy: 1.0
# 17 / 20 models trained | Current model test precision: 1.0
# 17 / 20 models trained | Current model test recall: 1.0
# 17 / 20 models trained | Current model test f1: 1.0
# 18 / 20 models trained | Current model test accuracy: 0.9991603694374476
# 18 / 20 models trained | Current model test precision: 0.9962962962962962
# 18 / 20 models trained | Current model test recall: 0.9996336996336996
# 18 / 20 models trained | Current model test f1: 0.9979622077215878
# 19 / 20 models trained | Current model test accuracy: 1.0
# 19 / 20 models trained | Current model test precision: 1.0
# 19 / 20 models trained | Current model test recall: 1.0
# 19 / 20 models trained | Current model test f1: 1.0
# 20 / 20 models trained | Current model test accuracy: 0.9995801847187238
# 20 / 20 models trained | Current model test precision: 0.9981343283582089
# 20 / 20 models trained | Current model test recall: 0.9998168498168498
# 20 / 20 models trained | Current model test f1: 0.9989748806421755
# CPU times: total: 1h 56min 43s
# Wall time: 1h 37min 9s

# %%
# %%time
deepset_accuracies, deepset_precisions, deepset_recalls, deepset_f1Scores, deepset_wrong_preds, deepset_epoch_stats, model = train_models(DEEPSET_Model, x_train_normal, x_val_normal, x_test_normal, 0.005, data, 128, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_7128\2177076457.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.9172963895885811
# 1 / 20 models trained | Current model test precision: 0.8215721552960996
# 1 / 20 models trained | Current model test recall: 0.8609366077787991
# 1 / 20 models trained | Current model test f1: 0.8407938905868908
# 2 / 20 models trained | Current model test accuracy: 0.9231738035264484
# 2 / 20 models trained | Current model test precision: 0.8328737879217061
# 2 / 20 models trained | Current model test recall: 0.8609530687391127
# 2 / 20 models trained | Current model test f1: 0.8466806873013832
# 3 / 20 models trained | Current model test accuracy: 0.9231738035264484
# 3 / 20 models trained | Current model test precision: 0.8293120081851569
# 3 / 20 models trained | Current model test recall: 0.8690643805433688
# 3 / 20 models trained | Current model test f1: 0.8487229703071595
# 4 / 20 models trained | Current model test accuracy: 0.9298908480268682
# 4 / 20 models trained | Current model test precision: 0.8393782605066566
# 4 / 20 models trained | Current model test recall: 0.8779160410819652
# 4 / 20 models trained | Current model test f1: 0.8582147378612753
# 5 / 20 models trained | Current model test accuracy: 0.9214945424013434
# 5 / 20 models trained | Current model test precision: 0.825359507146
# 5 / 20 models trained | Current model test recall: 0.8476891991460478
# 5 / 20 models trained | Current model test f1: 0.8363753392102844
# 6 / 20 models trained | Current model test accuracy: 0.9185558354324097
# 6 / 20 models trained | Current model test precision: 0.8187920653151258
# 6 / 20 models trained | Current model test recall: 0.8552101501516226
# 6 / 20 models trained | Current model test f1: 0.836604968202941
# 7 / 20 models trained | Current model test accuracy: 0.9219143576826196
# 7 / 20 models trained | Current model test precision: 0.8374343631185384
# 7 / 20 models trained | Current model test recall: 0.8917094141942492
# 7 / 20 models trained | Current model test f1: 0.8637200852355559
# 8 / 20 models trained | Current model test accuracy: 0.9214945424013434
# 8 / 20 models trained | Current model test precision: 0.8335617537162555
# 8 / 20 models trained | Current model test recall: 0.870975381595792
# 8 / 20 models trained | Current model test f1: 0.8518579636503644
# 9 / 20 models trained | Current model test accuracy: 0.9227539882451721
# 9 / 20 models trained | Current model test precision: 0.8345066444355089
# 9 / 20 models trained | Current model test recall: 0.8808425254131148
# 9 / 20 models trained | Current model test f1: 0.8570487607761704
# 10 / 20 models trained | Current model test accuracy: 0.8560033585222502
# 10 / 20 models trained | Current model test precision: 0.7209277493684563
# 10 / 20 models trained | Current model test recall: 0.6631806926488116
# 10 / 20 models trained | Current model test f1: 0.6908495745884005
# 11 / 20 models trained | Current model test accuracy: 0.9160369437447523
# 11 / 20 models trained | Current model test precision: 0.8206775311563844
# 11 / 20 models trained | Current model test recall: 0.8586330893556116
# 11 / 20 models trained | Current model test f1: 0.8392263769840295
# 12 / 20 models trained | Current model test accuracy: 0.9206549118387909
# 12 / 20 models trained | Current model test precision: 0.8242368668309662
# 12 / 20 models trained | Current model test recall: 0.8639419339901799
# 12 / 20 models trained | Current model test f1: 0.8436224793837983
# 13 / 20 models trained | Current model test accuracy: 0.9286314021830394
# 13 / 20 models trained | Current model test precision: 0.8275960405387569
# 13 / 20 models trained | Current model test recall: 0.8845894032416041
# 13 / 20 models trained | Current model test f1: 0.8551441554238618
# 14 / 20 models trained | Current model test accuracy: 0.9114189756507137
# 14 / 20 models trained | Current model test precision: 0.8080200087391937
# 14 / 20 models trained | Current model test recall: 0.8345733112354952
# 14 / 20 models trained | Current model test f1: 0.8210820366034288
# 15 / 20 models trained | Current model test accuracy: 0.9231738035264484
# 15 / 20 models trained | Current model test precision: 0.8295600377447512
# 15 / 20 models trained | Current model test recall: 0.8402377658939008
# 15 / 20 models trained | Current model test f1: 0.834864761794055
# 16 / 20 models trained | Current model test accuracy: 0.9374475230898405
# 16 / 20 models trained | Current model test precision: 0.8491810626987305
# 16 / 20 models trained | Current model test recall: 0.9232698934837092
# 16 / 20 models trained | Current model test f1: 0.884677013568707
# 17 / 20 models trained | Current model test accuracy: 0.9160369437447523
# 17 / 20 models trained | Current model test precision: 0.8183107599699022
# 17 / 20 models trained | Current model test recall: 0.8448642732842715
# 17 / 20 models trained | Current model test f1: 0.8313755458316989
# 18 / 20 models trained | Current model test accuracy: 0.9185558354324097
# 18 / 20 models trained | Current model test precision: 0.8224062380025683
# 18 / 20 models trained | Current model test recall: 0.8712939310893097
# 18 / 20 models trained | Current model test f1: 0.8461445268035007
# 19 / 20 models trained | Current model test accuracy: 0.9130982367758187
# 19 / 20 models trained | Current model test precision: 0.8160017434114402
# 19 / 20 models trained | Current model test recall: 0.8499065899996674
# 19 / 20 models trained | Current model test f1: 0.8326091481354692
# 20 / 20 models trained | Current model test accuracy: 0.9290512174643157
# 20 / 20 models trained | Current model test precision: 0.8370915586535883
# 20 / 20 models trained | Current model test recall: 0.8767022439704351
# 20 / 20 models trained | Current model test f1: 0.8564391430948715
# CPU times: total: 2h 11min 6s
# Wall time: 36min 4s

# %%
# %%time
deepsetv2_accuracies, deepsetv2_precisions, deepsetv2_recalls, deepsetv2_f1Scores, deepsetv2_wrong_preds, deepsetv2_epoch_stats, model = train_models(DEEPSETV2_Model, x_train_normal, x_val_normal, x_test_normal, 0.0001, data, 16, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_7128\2177076457.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.9361880772460117
# 1 / 20 models trained | Current model test precision: 0.8498914728909395
# 1 / 20 models trained | Current model test recall: 0.900319544861596
# 1 / 20 models trained | Current model test f1: 0.8743790277785932
# 2 / 20 models trained | Current model test accuracy: 0.9492023509655751
# 2 / 20 models trained | Current model test precision: 0.8769838977598676
# 2 / 20 models trained | Current model test recall: 0.9154513264933887
# 2 / 20 models trained | Current model test f1: 0.8958048376359949
# 3 / 20 models trained | Current model test accuracy: 0.9387069689336692
# 3 / 20 models trained | Current model test precision: 0.8597708007059934
# 3 / 20 models trained | Current model test recall: 0.9541877936171638
# 3 / 20 models trained | Current model test f1: 0.9045220832598152
# 4 / 20 models trained | Current model test accuracy: 0.815281276238455
# 4 / 20 models trained | Current model test precision: 0.5544925087472712
# 4 / 20 models trained | Current model test recall: 0.7205995758627337
# 4 / 20 models trained | Current model test f1: 0.6267266049958374
# 5 / 20 models trained | Current model test accuracy: 0.573887489504618
# 5 / 20 models trained | Current model test precision: 0.24806132267005632
# 5 / 20 models trained | Current model test recall: 0.43529014844804315
# 5 / 20 models trained | Current model test f1: 0.31602668475299284
# 6 / 20 models trained | Current model test accuracy: 0.9378673383711167
# 6 / 20 models trained | Current model test precision: 0.8575502562571529
# 6 / 20 models trained | Current model test recall: 0.9510285174326826
# 6 / 20 models trained | Current model test f1: 0.9018736266249265
# 7 / 20 models trained | Current model test accuracy: 0.9357682619647355
# 7 / 20 models trained | Current model test precision: 0.8596586715867158
# 7 / 20 models trained | Current model test recall: 0.9610239412249945
# 7 / 20 models trained | Current model test f1: 0.9075195850864612
# 8 / 20 models trained | Current model test accuracy: 0.892527287993283
# 8 / 20 models trained | Current model test precision: 0.7936255132814729
# 8 / 20 models trained | Current model test recall: 0.8397054375960364
# 8 / 20 models trained | Current model test f1: 0.8160154665034268
# 9 / 20 models trained | Current model test accuracy: 0.9408060453400504
# 9 / 20 models trained | Current model test precision: 0.8701937269372694
# 9 / 20 models trained | Current model test recall: 0.9723531571218796
# 9 / 20 models trained | Current model test f1: 0.9184413433551971
# 10 / 20 models trained | Current model test accuracy: 0.9408060453400504
# 10 / 20 models trained | Current model test precision: 0.8694668751077081
# 10 / 20 models trained | Current model test recall: 0.9710447506817297
# 10 / 20 models trained | Current model test f1: 0.9174527703435191
# 11 / 20 models trained | Current model test accuracy: 0.9248530646515534
# 11 / 20 models trained | Current model test precision: 0.8513684583041845
# 11 / 20 models trained | Current model test recall: 0.898879221460089
# 11 / 20 models trained | Current model test f1: 0.8744789961146647
# 12 / 20 models trained | Current model test accuracy: 0.9021830394626364
# 12 / 20 models trained | Current model test precision: 0.796711635686401
# 12 / 20 models trained | Current model test recall: 0.8627634169966404
# 12 / 20 models trained | Current model test f1: 0.8284230028700162
# 13 / 20 models trained | Current model test accuracy: 0.9450041981528128
# 13 / 20 models trained | Current model test precision: 0.8917060503798384
# 13 / 20 models trained | Current model test recall: 0.8560284027869359
# 13 / 20 models trained | Current model test f1: 0.8735030709945741
# 14 / 20 models trained | Current model test accuracy: 0.8337531486146096
# 14 / 20 models trained | Current model test precision: 0.6919723512711318
# 14 / 20 models trained | Current model test recall: 0.6497145728217943
# 14 / 20 models trained | Current model test f1: 0.6701779864398194
# 15 / 20 models trained | Current model test accuracy: 0.8140218303946264
# 15 / 20 models trained | Current model test precision: 0.54615160559963
# 15 / 20 models trained | Current model test recall: 0.7149604781183728
# 15 / 20 models trained | Current model test f1: 0.619257904362358
# 16 / 20 models trained | Current model test accuracy: 0.780016792611251
# 16 / 20 models trained | Current model test precision: 0.462582667737787
# 16 / 20 models trained | Current model test recall: 0.5580478993493184
# 16 / 20 models trained | Current model test f1: 0.5058505875308448
# 17 / 20 models trained | Current model test accuracy: 0.9391267842149454
# 17 / 20 models trained | Current model test precision: 0.8628690291982848
# 17 / 20 models trained | Current model test recall: 0.9583798966334495
# 17 / 20 models trained | Current model test f1: 0.9081200480418676
# 18 / 20 models trained | Current model test accuracy: 0.8144416456759026
# 18 / 20 models trained | Current model test precision: 0.5539154122635472
# 18 / 20 models trained | Current model test recall: 0.7168401773664932
# 18 / 20 models trained | Current model test f1: 0.6249334264012728
# 19 / 20 models trained | Current model test accuracy: 0.936607892527288
# 19 / 20 models trained | Current model test precision: 0.8563081400539219
# 19 / 20 models trained | Current model test recall: 0.9515392734419884
# 19 / 20 models trained | Current model test f1: 0.9014154837921143
# 20 / 20 models trained | Current model test accuracy: 0.9332493702770781
# 20 / 20 models trained | Current model test precision: 0.8329704661090295
# 20 / 20 models trained | Current model test recall: 0.8433866265081337
# 20 / 20 models trained | Current model test f1: 0.8381461855431045
# CPU times: total: 1h 9min 27s
# Wall time: 4h 58min 44s

# %%
# %%time
feedforward_accuracies, feedforward_precisions, feedforward_recalls, feedforward_f1Scores, feedforward_wrong_preds, feedforward_epoch_stats, model = train_models(FEEDFORWARD_Model, x_train_normal, x_val_normal, x_test_normal, 0.0001, data, 128, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_7128\2177076457.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.9235936188077246
# 1 / 20 models trained | Current model test precision: 0.8285760077437689
# 1 / 20 models trained | Current model test recall: 0.8770667879410206
# 1 / 20 models trained | Current model test f1: 0.85213211056311
# 2 / 20 models trained | Current model test accuracy: 0.8807724601175483
# 2 / 20 models trained | Current model test precision: 0.7780462814791833
# 2 / 20 models trained | Current model test recall: 0.7829313300945621
# 2 / 20 models trained | Current model test f1: 0.7804811619552772
# 3 / 20 models trained | Current model test accuracy: 0.9122586062132662
# 3 / 20 models trained | Current model test precision: 0.8103642681543116
# 3 / 20 models trained | Current model test recall: 0.8478060719098203
# 3 / 20 models trained | Current model test f1: 0.828662448483322
# 4 / 20 models trained | Current model test accuracy: 0.9202350965575147
# 4 / 20 models trained | Current model test precision: 0.8298737716643895
# 4 / 20 models trained | Current model test recall: 0.8631315286169146
# 4 / 20 models trained | Current model test f1: 0.8461759889077162
# 5 / 20 models trained | Current model test accuracy: 0.9009235936188077
# 5 / 20 models trained | Current model test precision: 0.7964649486241204
# 5 / 20 models trained | Current model test recall: 0.8198871382831272
# 5 / 20 models trained | Current model test f1: 0.8080063406478842
# 6 / 20 models trained | Current model test accuracy: 0.8396305625524769
# 6 / 20 models trained | Current model test precision: 0.6725371749893918
# 6 / 20 models trained | Current model test recall: 0.6851673819903363
# 6 / 20 models trained | Current model test f1: 0.6787935314936687
# 7 / 20 models trained | Current model test accuracy: 0.9118387909319899
# 7 / 20 models trained | Current model test precision: 0.8077111832362741
# 7 / 20 models trained | Current model test recall: 0.8215693315914253
# 7 / 20 models trained | Current model test f1: 0.8145813208850919
# 8 / 20 models trained | Current model test accuracy: 0.8706968933669186
# 8 / 20 models trained | Current model test precision: 0.7429435396207382
# 8 / 20 models trained | Current model test recall: 0.765231337093428
# 8 / 20 models trained | Current model test f1: 0.7539227539017678
# 9 / 20 models trained | Current model test accuracy: 0.9219143576826196
# 9 / 20 models trained | Current model test precision: 0.8257592278706799
# 9 / 20 models trained | Current model test recall: 0.861536838236304
# 9 / 20 models trained | Current model test f1: 0.8432687168714695
# 10 / 20 models trained | Current model test accuracy: 0.9147774979009236
# 10 / 20 models trained | Current model test precision: 0.8269183635958568
# 10 / 20 models trained | Current model test recall: 0.8676896610298802
# 10 / 20 models trained | Current model test f1: 0.8468135452932695
# 11 / 20 models trained | Current model test accuracy: 0.9198152812762385
# 11 / 20 models trained | Current model test precision: 0.8281461917249628
# 11 / 20 models trained | Current model test recall: 0.8827162115460964
# 11 / 20 models trained | Current model test f1: 0.8545609133360189
# 12 / 20 models trained | Current model test accuracy: 0.8589420654911839
# 12 / 20 models trained | Current model test precision: 0.7365771644981196
# 12 / 20 models trained | Current model test recall: 0.7849166737542466
# 12 / 20 models trained | Current model test f1: 0.7599790198102689
# 13 / 20 models trained | Current model test accuracy: 0.9076406381192276
# 13 / 20 models trained | Current model test precision: 0.7968595824165046
# 13 / 20 models trained | Current model test recall: 0.8110286597969861
# 13 / 20 models trained | Current model test f1: 0.8038816905383317
# 14 / 20 models trained | Current model test accuracy: 0.8979848866498741
# 14 / 20 models trained | Current model test precision: 0.8025343322815583
# 14 / 20 models trained | Current model test recall: 0.8374289659032533
# 14 / 20 models trained | Current model test f1: 0.8196104104625719
# 15 / 20 models trained | Current model test accuracy: 0.8194794290512175
# 15 / 20 models trained | Current model test precision: 0.6873407394642379
# 15 / 20 models trained | Current model test recall: 0.7415241912296692
# 15 / 20 models trained | Current model test f1: 0.7134051301586684
# 16 / 20 models trained | Current model test accuracy: 0.8669185558354324
# 16 / 20 models trained | Current model test precision: 0.7372436701599016
# 16 / 20 models trained | Current model test recall: 0.7606698221439362
# 16 / 20 models trained | Current model test f1: 0.7487735631444893
# 17 / 20 models trained | Current model test accuracy: 0.8551637279596978
# 17 / 20 models trained | Current model test precision: 0.7648239688069232
# 17 / 20 models trained | Current model test recall: 0.7304544761343755
# 17 / 20 models trained | Current model test f1: 0.7472442251273235
# 18 / 20 models trained | Current model test accuracy: 0.8765743073047859
# 18 / 20 models trained | Current model test precision: 0.7656548485510649
# 18 / 20 models trained | Current model test recall: 0.7736565614352323
# 18 / 20 models trained | Current model test f1: 0.7696349075740347
# 19 / 20 models trained | Current model test accuracy: 0.9193954659949622
# 19 / 20 models trained | Current model test precision: 0.8164255365673887
# 19 / 20 models trained | Current model test recall: 0.8267017150880214
# 19 / 20 models trained | Current model test f1: 0.821531492027696
# 20 / 20 models trained | Current model test accuracy: 0.9059613769941226
# 20 / 20 models trained | Current model test precision: 0.8117502557604855
# 20 / 20 models trained | Current model test recall: 0.8306544080986745
# 20 / 20 models trained | Current model test f1: 0.82109353810322
# CPU times: total: 1h 46min 19s
# Wall time: 1d 18h 18min 42s

# %% [markdown]
# # Evaluation

# %% [markdown]
# # Evaluacion general de los modelos

# %%
import pandas as pd
# Lista de modelos y nombres
model_names = ['CNN', 'LSTM', 'DeepSet', 'DeepSetV2', 'Feedforward']
all_accuracies = [cnn_accuracies, lstm_accuracies, deepset_accuracies, deepsetv2_accuracies, feedforward_accuracies]
all_precisions = [cnn_precisions, lstm_precisions, deepset_precisions, deepsetv2_precisions, feedforward_precisions]
all_recalls = [cnn_recalls, lstm_recalls, deepset_recalls, deepsetv2_recalls, feedforward_recalls]
all_f1_scores = [cnn_f1_scores, lstm_f1Scores, deepset_f1Scores, deepsetv2_f1Scores, feedforward_f1Scores]

get_summary_df(model_names, all_accuracies, all_precisions, all_recalls, all_f1_scores)
# Out:
#         Modelo  Accuracy  Precision    Recall  F1-score  Precision clase A
# 0          CNN  1.000000   1.000000  1.000000  1.000000           1.000000  \
# 1         LSTM  1.000000   1.000000  1.000000  1.000000           1.000000
# 2      DeepSet  0.937448   0.849181  0.923270  0.884677           0.514019
# 3    DeepSetV2  0.949202   0.876984  0.915451  0.895805           0.571429
# 4  Feedforward  0.923594   0.828576  0.877067  0.852132           0.494505
#
#    Recall clase A  Precision clase D  Recall clase D  Precision clase R
# 0        1.000000           1.000000        1.000000           1.000000  \
# 1        1.000000           1.000000        1.000000           1.000000
# 2        0.827068           0.891374        0.930000           1.000000
# 3        0.751880           0.964052        0.967213           0.998291
# 4        0.676692           0.854938        0.902280           0.996569
#
#    Recall clase R  Precision clase V  Recall clase V
# 0        1.000000           1.000000        1.000000
# 1        1.000000           1.000000        1.000000
# 2        1.000000           0.991332        0.936012
# 3        0.996587           0.974164        0.946125
# 4        0.991468           0.968291        0.937828

# %% [markdown]
# ### Get best 50% performing models

# %%
top_half = int(num_experiments / 2)
best_cnn_accs = filter_top_k_accuracies(cnn_accuracies, top_half)
best_lstm_accs = filter_top_k_accuracies(lstm_accuracies, top_half)
best_deepset_accs = filter_top_k_accuracies(deepset_accuracies, top_half)
best_deepsetv2_accs = filter_top_k_accuracies(deepsetv2_accuracies, top_half)
best_feedforward_accs = filter_top_k_accuracies(feedforward_accuracies, top_half)

# %% [markdown]
# ## Accuracy breakdown by cases for all the models

# %%
all_accuracies = [cnn_accuracies, lstm_accuracies, deepset_accuracies, deepsetv2_accuracies, feedforward_accuracies]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']

# %%
get_stats_df(all_accuracies, model_names, test_original)
# Out:
#                        Overall cr_noop   cr_uw    cr_w   cr_wu dr_noop  dr_uw
# CNN                     100.0%  100.0%  100.0%  100.0%  100.0%  100.0%  99.8%  \
# LSTM                     98.8%  100.0%  100.0%  100.0%  100.0%   99.9%  89.6%
# DeepSet(like in paper)   91.8%   99.7%   99.9%   99.9%  100.0%   94.4%  59.0%
# DeepSet(sum at start)    88.4%   99.8%   99.9%   99.8%   99.9%   72.8%  77.8%
# Feedforward              89.1%   98.8%   99.8%   99.7%   99.9%   85.5%  48.6%
# Sample count              2382     151     142     145     139     160    133
#
#                           dr_w   dr_wu noop_noop noop_uw  noop_w noop_wu
# CNN                     100.0%  100.0%    100.0%  100.0%  100.0%  100.0%  \
# LSTM                     99.9%   89.7%    100.0%  100.0%  100.0%  100.0%
# DeepSet(like in paper)   85.5%   24.0%    100.0%   99.9%   99.9%  100.0%
# DeepSet(sum at start)    70.4%   15.1%     99.8%  100.0%   99.9%  100.0%
# Feedforward              78.4%   23.8%     99.6%   99.7%   99.8%   99.7%
# Sample count               138     140       165     173     162     148
#
#                         r_noop    r_uw     r_w    r_wu
# CNN                     100.0%  100.0%  100.0%   99.6%
# LSTM                    100.0%  100.0%  100.0%  100.0%
# DeepSet(like in paper)   99.8%   99.4%   99.5%   99.1%
# DeepSet(sum at start)    93.2%   93.1%   93.3%   92.0%
# Feedforward              95.6%   95.5%   95.9%   95.0%
# Sample count               154     149     151     132

# %% [markdown]
# ## Accuracy breakdown by cases for top 50% of models

# %%
best_accuracies = [best_cnn_accs, best_lstm_accs, best_deepset_accs, best_deepsetv2_accs, best_feedforward_accs]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']
collapsed_cases = ['dr', 'r', 'cr', 'noop']

# %%
get_stats_df(best_accuracies, model_names, test_original, collapsed_cases)
# Out:
#                        Overall   f3_cr   f3_dr f3_noop    f3_r
# CNN                     100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM                    100.0%  100.0%  100.0%  100.0%  100.0%
# DeepSet(like in paper)   92.6%  100.0%   69.4%  100.0%   99.8%
# DeepSet(sum at start)    94.0%  100.0%   75.2%   99.9%   99.9%
# Feedforward              91.6%   99.7%   66.4%  100.0%   98.8%
# Sample count              2382     577     571     648     586

# %%
best_accuracies = [best_cnn_accs, best_lstm_accs, best_deepset_accs, best_deepsetv2_accs, best_feedforward_accs]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']
collapsed_cases = ['r', 'cr', 'noop']

# %%
get_stats_df(best_accuracies, model_names, test_original, collapsed_cases)
# Out:
#                        Overall dr_noop   dr_uw    dr_w   dr_wu   f3_cr
# CNN                     100.0%  100.0%  100.0%  100.0%  100.0%  100.0%  \
# LSTM                    100.0%  100.0%  100.0%  100.0%  100.0%  100.0%
# DeepSet(like in paper)   92.6%   97.0%   64.1%   87.2%   25.3%  100.0%
# DeepSet(sum at start)    94.0%   99.4%   88.0%   98.0%   12.8%  100.0%
# Feedforward              91.6%   93.6%   57.1%   85.1%   25.6%   99.7%
# Sample count              2382     160     133     138     140     577
#
#                        f3_noop    f3_r
# CNN                     100.0%  100.0%
# LSTM                    100.0%  100.0%
# DeepSet(like in paper)  100.0%   99.8%
# DeepSet(sum at start)    99.9%   99.9%
# Feedforward             100.0%   98.8%
# Sample count               648     586

# %% [markdown]
# ## Accuracies per CNN model

# %%
get_stats_per_model(cnn_accuracies, ['CNN #' + str(i) for i in range(len(cnn_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#              Overall   f3_cr   f3_dr f3_noop    f3_r
# CNN #0        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #1        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #2        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #3        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #4        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #5        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #6        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #7        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #8        100.0%  100.0%  100.0%  100.0%   99.8%
# CNN #9        100.0%  100.0%  100.0%  100.0%   99.8%
# CNN #10        99.8%  100.0%   99.3%  100.0%   99.8%
# CNN #11       100.0%  100.0%  100.0%  100.0%   99.8%
# CNN #12       100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #13       100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #14       100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #15       100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #16        99.9%  100.0%  100.0%  100.0%   99.7%
# CNN #17       100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #18        99.8%  100.0%  100.0%  100.0%   99.3%
# CNN #19       100.0%  100.0%  100.0%  100.0%  100.0%
# Sample count    2382     577     571     648     586

# %%
get_stats_per_model_multiclass(cnn_accuracies, cnn_precisions, cnn_recalls, cnn_f1_scores, "CNN")
# Out:
#    Modelo  Accuracy  F1-score  Precision_Overall  Recall_Overall  Precision_A
# 0     CNN  1.000000  1.000000           1.000000        1.000000          1.0  \
# 1     CNN  1.000000  1.000000           1.000000        1.000000          1.0
# 2     CNN  1.000000  1.000000           1.000000        1.000000          1.0
# 3     CNN  1.000000  1.000000           1.000000        1.000000          1.0
# 4     CNN  1.000000  1.000000           1.000000        1.000000          1.0
# 5     CNN  1.000000  1.000000           1.000000        1.000000          1.0
# 6     CNN  1.000000  1.000000           1.000000        1.000000          1.0
# 7     CNN  1.000000  1.000000           1.000000        1.000000          1.0
# 8     CNN  0.999580  0.999695           0.999817        0.999573          1.0
# 9     CNN  0.999580  0.999695           0.999817        0.999573          1.0
# 10    CNN  0.997901  0.995559           0.999088        0.992055          1.0
# 11    CNN  0.999580  0.999695           0.999817        0.999573          1.0
# 12    CNN  1.000000  1.000000           1.000000        1.000000          1.0
# 13    CNN  1.000000  1.000000           1.000000        1.000000          1.0
# 14    CNN  1.000000  1.000000           1.000000        1.000000          1.0
# 15    CNN  1.000000  1.000000           1.000000        1.000000          1.0
# 16    CNN  0.999160  0.999390           0.999634        0.999147          1.0
# 17    CNN  1.000000  1.000000           1.000000        1.000000          1.0
# 18    CNN  0.998321  0.998781           0.999270        0.998294          1.0
# 19    CNN  1.000000  1.000000           1.000000        1.000000          1.0
#
#     Precision_D  Precision_R  Precision_V  Recall_A  Recall_D  Recall_R
# 0           1.0          1.0     1.000000  1.000000       1.0  1.000000  \
# 1           1.0          1.0     1.000000  1.000000       1.0  1.000000
# 2           1.0          1.0     1.000000  1.000000       1.0  1.000000
# 3           1.0          1.0     1.000000  1.000000       1.0  1.000000
# 4           1.0          1.0     1.000000  1.000000       1.0  1.000000
# 5           1.0          1.0     1.000000  1.000000       1.0  1.000000
# 6           1.0          1.0     1.000000  1.000000       1.0  1.000000
# 7           1.0          1.0     1.000000  1.000000       1.0  1.000000
# 8           1.0          1.0     0.999268  1.000000       1.0  0.998294
# 9           1.0          1.0     0.999268  1.000000       1.0  0.998294
# 10          1.0          1.0     0.996350  0.969925       1.0  0.998294
# 11          1.0          1.0     0.999268  1.000000       1.0  0.998294
# 12          1.0          1.0     1.000000  1.000000       1.0  1.000000
# 13          1.0          1.0     1.000000  1.000000       1.0  1.000000
# 14          1.0          1.0     1.000000  1.000000       1.0  1.000000
# 15          1.0          1.0     1.000000  1.000000       1.0  1.000000
# 16          1.0          1.0     0.998537  1.000000       1.0  0.996587
# 17          1.0          1.0     1.000000  1.000000       1.0  1.000000
# 18          1.0          1.0     0.997078  1.000000       1.0  0.993174
# 19          1.0          1.0     1.000000  1.000000       1.0  1.000000
#
#     Recall_V
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
# 5        1.0
# 6        1.0
# 7        1.0
# 8        1.0
# 9        1.0
# 10       1.0
# 11       1.0
# 12       1.0
# 13       1.0
# 14       1.0
# 15       1.0
# 16       1.0
# 17       1.0
# 18       1.0
# 19       1.0

# %% [markdown]
# ## Accuracies per LSTM model

# %%
get_stats_per_model(lstm_accuracies, ['LSTM #' + str(i) for i in range(len(lstm_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#              Overall   f3_cr   f3_dr f3_noop    f3_r
# LSTM #0        99.9%  100.0%   99.5%  100.0%  100.0%
# LSTM #1       100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #2       100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #3        88.5%  100.0%   52.0%  100.0%  100.0%
# LSTM #4       100.0%  100.0%   99.8%  100.0%  100.0%
# LSTM #5        99.9%  100.0%   99.6%  100.0%  100.0%
# LSTM #6       100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #7       100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #8       100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #9        88.4%  100.0%   51.5%  100.0%  100.0%
# LSTM #10      100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #11       99.9%  100.0%   99.5%  100.0%  100.0%
# LSTM #12       99.7%  100.0%   98.9%  100.0%  100.0%
# LSTM #13      100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #14      100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #15      100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #16      100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #17       99.9%  100.0%   99.6%  100.0%  100.0%
# LSTM #18      100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #19      100.0%  100.0%   99.8%  100.0%  100.0%
# Sample count    2382     577     571     648     586

# %%
get_stats_per_model_multiclass(lstm_accuracies, lstm_precisions, lstm_recalls, lstm_f1Scores, "LSTM")
# Out:
#    Modelo  Accuracy  F1-score  Precision_Overall  Recall_Overall  Precision_A
# 0    LSTM  0.998741  0.996962           0.994485        0.999451     0.977941  \
# 1    LSTM  1.000000  1.000000           1.000000        1.000000     1.000000
# 2    LSTM  1.000000  1.000000           1.000000        1.000000     1.000000
# 3    LSTM  0.884971  0.649151           0.629642        0.669908     0.000000
# 4    LSTM  0.999580  0.998975           0.998134        0.999817     0.992537
# 5    LSTM  0.999160  0.997937           0.997937        0.997937     0.992481
# 6    LSTM  1.000000  1.000000           1.000000        1.000000     1.000000
# 7    LSTM  1.000000  1.000000           1.000000        1.000000     1.000000
# 8    LSTM  1.000000  1.000000           1.000000        1.000000     1.000000
# 9    LSTM  0.883711  0.647760           0.627184        0.669731     0.000000
# 10   LSTM  1.000000  1.000000           1.000000        1.000000     1.000000
# 11   LSTM  0.998741  0.996575           0.998798        0.994361     1.000000
# 12   LSTM  0.997481  0.993788           0.998906        0.988722     1.000000
# 13   LSTM  1.000000  1.000000           1.000000        1.000000     1.000000
# 14   LSTM  1.000000  1.000000           1.000000        1.000000     1.000000
# 15   LSTM  1.000000  1.000000           1.000000        1.000000     1.000000
# 16   LSTM  1.000000  1.000000           1.000000        1.000000     1.000000
# 17   LSTM  0.999160  0.997962           0.996296        0.999634     0.985185
# 18   LSTM  1.000000  1.000000           1.000000        1.000000     1.000000
# 19   LSTM  0.999580  0.998975           0.998134        0.999817     0.992537
#
#     Precision_D  Precision_R  Precision_V  Recall_A  Recall_D  Recall_R
# 0      1.000000     1.000000     1.000000  1.000000  1.000000       1.0  \
# 1      1.000000     1.000000     1.000000  1.000000  1.000000       1.0
# 2      1.000000     1.000000     1.000000  1.000000  1.000000       1.0
# 3      0.521968     0.996599     1.000000  0.000000  0.679634       1.0
# 4      1.000000     1.000000     1.000000  1.000000  1.000000       1.0
# 5      1.000000     1.000000     0.999267  0.992481  1.000000       1.0
# 6      1.000000     1.000000     1.000000  1.000000  1.000000       1.0
# 7      1.000000     1.000000     1.000000  1.000000  1.000000       1.0
# 8      1.000000     1.000000     1.000000  1.000000  1.000000       1.0
# 9      0.522202     0.986532     1.000000  0.000000  0.680556       1.0
# 10     1.000000     1.000000     1.000000  1.000000  1.000000       1.0
# 11     0.996656     1.000000     0.998537  0.977444  1.000000       1.0
# 12     1.000000     1.000000     0.995624  0.954887  1.000000       1.0
# 13     1.000000     1.000000     1.000000  1.000000  1.000000       1.0
# 14     1.000000     1.000000     1.000000  1.000000  1.000000       1.0
# 15     1.000000     1.000000     1.000000  1.000000  1.000000       1.0
# 16     1.000000     1.000000     1.000000  1.000000  1.000000       1.0
# 17     1.000000     1.000000     1.000000  1.000000  1.000000       1.0
# 18     1.000000     1.000000     1.000000  1.000000  1.000000       1.0
# 19     1.000000     1.000000     1.000000  1.000000  1.000000       1.0
#
#     Recall_V
# 0   0.997802
# 1   1.000000
# 2   1.000000
# 3   1.000000
# 4   0.999267
# 5   0.999267
# 6   1.000000
# 7   1.000000
# 8   1.000000
# 9   0.998370
# 10  1.000000
# 11  1.000000
# 12  1.000000
# 13  1.000000
# 14  1.000000
# 15  1.000000
# 16  1.000000
# 17  0.998535
# 18  1.000000
# 19  0.999267

# %% [markdown]
# ## Accuracies per DeepSets V1 model

# %%
get_stats_per_model(deepset_accuracies, ['DeepSet(like in paper) #' + str(i) for i in range(len(deepset_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                            Overall   f3_cr  f3_dr f3_noop    f3_r
# DeepSet(like in paper) #0    91.7%   99.7%  69.7%  100.0%   96.2%
# DeepSet(like in paper) #1    92.3%  100.0%  68.0%  100.0%  100.0%
# DeepSet(like in paper) #2    92.3%  100.0%  68.3%  100.0%   99.7%
# DeepSet(like in paper) #3    93.0%  100.0%  70.8%  100.0%  100.0%
# DeepSet(like in paper) #4    92.1%  100.0%  68.0%  100.0%   99.3%
# DeepSet(like in paper) #5    91.9%  100.0%  66.0%  100.0%  100.0%
# DeepSet(like in paper) #6    92.2%  100.0%  67.6%  100.0%   99.8%
# DeepSet(like in paper) #7    92.1%  100.0%  67.4%  100.0%   99.8%
# DeepSet(like in paper) #8    92.3%  100.0%  67.8%  100.0%  100.0%
# DeepSet(like in paper) #9    85.6%   98.4%  44.7%   98.9%   98.1%
# DeepSet(like in paper) #10   91.6%   99.8%  65.3%  100.0%   99.8%
# DeepSet(like in paper) #11   92.1%  100.0%  66.9%  100.0%  100.0%
# DeepSet(like in paper) #12   92.9%  100.0%  70.8%  100.0%   99.5%
# DeepSet(like in paper) #13   91.1%   99.8%  64.4%  100.0%   98.8%
# DeepSet(like in paper) #14   92.3%  100.0%  68.5%  100.0%   99.5%
# DeepSet(like in paper) #15   93.7%  100.0%  73.9%  100.0%  100.0%
# DeepSet(like in paper) #16   91.6%   99.7%  65.5%  100.0%   99.8%
# DeepSet(like in paper) #17   91.9%  100.0%  66.0%  100.0%  100.0%
# DeepSet(like in paper) #18   91.3%  100.0%  64.8%  100.0%   99.0%
# DeepSet(like in paper) #19   92.9%  100.0%  70.6%  100.0%   99.8%
# Sample count                  2382     577    571     648     586

# %%
get_stats_per_model_multiclass(deepset_accuracies, deepset_precisions, deepset_recalls, deepset_f1Scores, "DEEPSET")
# Out:
#      Modelo  Accuracy  F1-score  Precision_Overall  Recall_Overall
# 0   DEEPSET  0.917296  0.840794           0.821572        0.860937  \
# 1   DEEPSET  0.923174  0.846681           0.832874        0.860953
# 2   DEEPSET  0.923174  0.848723           0.829312        0.869064
# 3   DEEPSET  0.929891  0.858215           0.839378        0.877916
# 4   DEEPSET  0.921495  0.836375           0.825360        0.847689
# 5   DEEPSET  0.918556  0.836605           0.818792        0.855210
# 6   DEEPSET  0.921914  0.863720           0.837434        0.891709
# 7   DEEPSET  0.921495  0.851858           0.833562        0.870975
# 8   DEEPSET  0.922754  0.857049           0.834507        0.880843
# 9   DEEPSET  0.856003  0.690850           0.720928        0.663181
# 10  DEEPSET  0.916037  0.839226           0.820678        0.858633
# 11  DEEPSET  0.920655  0.843622           0.824237        0.863942
# 12  DEEPSET  0.928631  0.855144           0.827596        0.884589
# 13  DEEPSET  0.911419  0.821082           0.808020        0.834573
# 14  DEEPSET  0.923174  0.834865           0.829560        0.840238
# 15  DEEPSET  0.937448  0.884677           0.849181        0.923270
# 16  DEEPSET  0.916037  0.831376           0.818311        0.844864
# 17  DEEPSET  0.918556  0.846145           0.822406        0.871294
# 18  DEEPSET  0.913098  0.832609           0.816002        0.849907
# 19  DEEPSET  0.929051  0.856439           0.837092        0.876702
#
#     Precision_A  Precision_D  Precision_R  Precision_V  Recall_A  Recall_D
# 0      0.511628     0.827684     0.977470     0.969507  0.661654  0.885196  \
# 1      0.509804     0.873377     1.000000     0.948315  0.586466  0.911864
# 2      0.479532     0.881029     1.000000     0.956687  0.616541  0.925676
# 3      0.491429     0.904762     0.996599     0.964724  0.646617  0.928339
# 4      0.517483     0.831288     1.000000     0.952667  0.556391  0.888525
# 5      0.469880     0.849530     1.000000     0.955759  0.586466  0.894389
# 6      0.457286     0.938628     1.000000     0.953823  0.684211  0.952381
# 7      0.521472     0.863787     1.000000     0.948987  0.639098  0.899654
# 8      0.485876     0.900344     1.000000     0.951807  0.646617  0.939068
# 9      0.500000     0.514874     0.938010     0.930827  0.007519  0.679758
# 10     0.472727     0.872054     0.989848     0.948081  0.586466  0.908772
# 11     0.487952     0.853035     1.000000     0.955961  0.609023  0.905085
# 12     0.492147     0.828571     1.000000     0.989666  0.706767  0.903427
# 13     0.469388     0.833333     0.981356     0.948003  0.518797  0.886288
# 14     0.496296     0.878981     1.000000     0.942963  0.503759  0.910891
# 15     0.514019     0.891374     1.000000     0.991332  0.827068  0.930000
# 16     0.493333     0.833333     1.000000     0.946576  0.556391  0.877483
# 17     0.477778     0.853896     1.000000     0.957951  0.646617  0.900685
# 18     0.493590     0.825806     1.000000     0.944611  0.578947  0.882759
# 19     0.477528     0.906250     1.000000     0.964588  0.639098  0.938511
#
#     Recall_R  Recall_V
# 0   0.962457  0.934439
# 1   1.000000  0.945482
# 2   0.996587  0.937453
# 3   1.000000  0.936709
# 4   0.993174  0.952667
# 5   1.000000  0.939985
# 6   0.998294  0.931953
# 7   0.998294  0.946856
# 8   1.000000  0.937685
# 9   0.982906  0.982540
# 10  0.998294  0.941001
# 11  1.000000  0.941660
# 12  0.994881  0.933283
# 13  0.988055  0.945154
# 14  0.994881  0.951420
# 15  1.000000  0.936012
# 16  0.998294  0.947289
# 17  1.000000  0.937874
# 18  0.989761  0.948159
# 19  0.998294  0.930906

# %% [markdown]
# ## Accuracies per DeepSets V2 model

# %%
get_stats_per_model(deepsetv2_accuracies, ['DeepSet(sum at start) #' + str(i) for i in range(len(deepsetv2_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                           Overall   f3_cr  f3_dr f3_noop    f3_r
# DeepSet(sum at start) #0    93.6%   99.8%  74.6%   99.1%  100.0%
# DeepSet(sum at start) #1    94.9%  100.0%  79.2%  100.0%   99.7%
# DeepSet(sum at start) #2    93.9%  100.0%  74.4%  100.0%  100.0%
# DeepSet(sum at start) #3    81.5%  100.0%  22.9%  100.0%  100.0%
# DeepSet(sum at start) #4    57.4%  100.0%  24.9%  100.0%    0.0%
# DeepSet(sum at start) #5    93.8%  100.0%  74.1%  100.0%  100.0%
# DeepSet(sum at start) #6    93.6%  100.0%  73.2%  100.0%  100.0%
# DeepSet(sum at start) #7    89.3%  100.0%  64.3%   99.7%   91.5%
# DeepSet(sum at start) #8    94.1%  100.0%  75.3%  100.0%  100.0%
# DeepSet(sum at start) #9    94.1%  100.0%  75.3%  100.0%  100.0%
# DeepSet(sum at start) #10   92.5%   99.7%  69.4%  100.0%   99.7%
# DeepSet(sum at start) #11   90.2%  100.0%  65.0%   99.8%   94.5%
# DeepSet(sum at start) #12   94.5%  100.0%  77.2%  100.0%   99.8%
# DeepSet(sum at start) #13   83.4%   97.1%  53.1%   99.5%   81.6%
# DeepSet(sum at start) #14   81.4%  100.0%  22.4%  100.0%  100.0%
# DeepSet(sum at start) #15   78.0%  100.0%  16.5%  100.0%   92.0%
# DeepSet(sum at start) #16   93.9%  100.0%  74.8%  100.0%   99.8%
# DeepSet(sum at start) #17   81.4%  100.0%  22.6%  100.0%  100.0%
# DeepSet(sum at start) #18   93.7%  100.0%  73.6%  100.0%  100.0%
# DeepSet(sum at start) #19   93.3%  100.0%  72.2%  100.0%  100.0%
# Sample count                 2382     577    571     648     586

# %%
get_stats_per_model_multiclass(deepsetv2_accuracies, deepsetv2_precisions, deepsetv2_recalls, deepsetv2_f1Scores, "DEEPSETv2")
# Out:
#        Modelo  Accuracy  F1-score  Precision_Overall  Recall_Overall
# 0   DEEPSETv2  0.936188  0.874379           0.849891        0.900320  \
# 1   DEEPSETv2  0.949202  0.895805           0.876984        0.915451
# 2   DEEPSETv2  0.938707  0.904522           0.859771        0.954188
# 3   DEEPSETv2  0.815281  0.626727           0.554493        0.720600
# 4   DEEPSETv2  0.573887  0.316027           0.248061        0.435290
# 5   DEEPSETv2  0.937867  0.901874           0.857550        0.951029
# 6   DEEPSETv2  0.935768  0.907520           0.859659        0.961024
# 7   DEEPSETv2  0.892527  0.816015           0.793626        0.839705
# 8   DEEPSETv2  0.940806  0.918441           0.870194        0.972353
# 9   DEEPSETv2  0.940806  0.917453           0.869467        0.971045
# 10  DEEPSETv2  0.924853  0.874479           0.851368        0.898879
# 11  DEEPSETv2  0.902183  0.828423           0.796712        0.862763
# 12  DEEPSETv2  0.945004  0.873503           0.891706        0.856028
# 13  DEEPSETv2  0.833753  0.670178           0.691972        0.649715
# 14  DEEPSETv2  0.814022  0.619258           0.546152        0.714960
# 15  DEEPSETv2  0.780017  0.505851           0.462583        0.558048
# 16  DEEPSETv2  0.939127  0.908120           0.862869        0.958380
# 17  DEEPSETv2  0.814442  0.624933           0.553915        0.716840
# 18  DEEPSETv2  0.936608  0.901415           0.856308        0.951539
# 19  DEEPSETv2  0.933249  0.838146           0.832970        0.843387
#
#     Precision_A  Precision_D  Precision_R  Precision_V  Recall_A  Recall_D
# 0      0.543478     0.892638     0.979933     0.983516  0.751880  0.912226  \
# 1      0.571429     0.964052     0.998291     0.974164  0.751880  0.967213
# 2      0.501976     0.937107     1.000000     1.000000  0.954887  0.955128
# 3      0.233096     0.000000     0.984874     1.000000  0.984962  0.000000
# 4      0.114979     0.000000     0.000000     0.877266  0.819549  0.000000
# 5      0.496032     0.934169     1.000000     1.000000  0.939850  0.958199
# 6      0.468635     0.970000     1.000000     1.000000  0.954887  0.989796
# 7      0.438503     0.829721     0.964029     0.942249  0.616541  0.884488
# 8      0.490775     0.990000     1.000000     1.000000  1.000000  0.990000
# 9      0.494424     0.983444     1.000000     1.000000  1.000000  0.983444
# 10     0.536313     0.927798     0.996587     0.944776  0.721805  0.937956
# 11     0.462687     0.798851     0.942177     0.983133  0.699248  0.871473
# 12     0.757895     0.851964     1.000000     0.956966  0.541353  0.900958
# 13     0.342857     0.553241     0.995833     0.875958  0.090226  0.667598
# 14     0.237918     0.000000     0.946688     1.000000  0.962406  0.000000
# 15     0.220779     0.000000     0.735334     0.894217  0.383459  0.000000
# 16     0.507874     0.952077     0.991525     1.000000  0.969925  0.958199
# 17     0.229130     0.000000     0.986532     1.000000  0.969925  0.000000
# 18     0.492126     0.936508     0.996599     1.000000  0.939850  0.960912
# 19     0.531746     0.832853     0.998296     0.968986  0.503759  0.911672
#
#     Recall_R  Recall_V
# 0   1.000000  0.937173
# 1   0.996587  0.946125
# 2   1.000000  0.906736
# 3   1.000000  0.897436
# 4   0.000000  0.921612
# 5   1.000000  0.906065
# 6   1.000000  0.899413
# 7   0.933798  0.923994
# 8   1.000000  0.899413
# 9   1.000000  0.900735
# 10  0.996587  0.939169
# 11  0.963478  0.916854
# 12  0.998294  0.983508
# 13  0.852050  0.988985
# 14  1.000000  0.897436
# 15  0.919795  0.928938
# 16  1.000000  0.905395
# 17  1.000000  0.897436
# 18  1.000000  0.905395
# 19  1.000000  0.958115

# %% [markdown]
# ## Accuracies per FeedForward model

# %%
get_stats_per_model(feedforward_accuracies, ['Feedforward #' + str(i) for i in range(len(feedforward_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                 Overall   f3_cr  f3_dr f3_noop    f3_r
# Feedforward #0    92.4%   99.8%  69.2%  100.0%   99.1%
# Feedforward #1    88.1%   99.8%  54.1%  100.0%   96.4%
# Feedforward #2    91.2%   99.7%  64.8%  100.0%   99.0%
# Feedforward #3    92.0%  100.0%  67.8%  100.0%   99.0%
# Feedforward #4    90.1%   99.7%  59.9%  100.0%   99.1%
# Feedforward #5    84.0%   99.3%  46.1%   98.0%   90.3%
# Feedforward #6    91.2%   99.8%  64.8%  100.0%   98.6%
# Feedforward #7    87.1%   99.8%  52.2%   99.8%   94.4%
# Feedforward #8    92.2%   99.8%  68.5%  100.0%   99.1%
# Feedforward #9    91.5%   99.7%  66.2%  100.0%   98.6%
# Feedforward #10   92.0%   99.5%  67.1%  100.0%  100.0%
# Feedforward #11   85.9%   99.3%  50.3%   99.5%   92.3%
# Feedforward #12   90.8%   99.8%  63.2%  100.0%   98.5%
# Feedforward #13   89.8%   96.4%  67.1%   99.8%   94.4%
# Feedforward #14   81.9%   99.3%  39.4%   99.2%   87.2%
# Feedforward #15   86.7%  100.0%  51.3%   99.2%   94.2%
# Feedforward #16   85.5%   99.5%  58.1%   99.8%   82.6%
# Feedforward #17   87.7%  100.0%  58.8%   98.5%   91.6%
# Feedforward #18   91.9%   99.1%  68.1%  100.0%   99.1%
# Feedforward #19   90.6%   99.8%  64.1%  100.0%   96.9%
# Sample count       2382     577    571     648     586

# %%
get_stats_per_model_multiclass(feedforward_accuracies, feedforward_precisions, feedforward_recalls, feedforward_f1Scores, "FEEDFORWARD")
# Out:
#          Modelo  Accuracy  F1-score  Precision_Overall  Recall_Overall
# 0   FEEDFORWARD  0.923594  0.852132           0.828576        0.877067  \
# 1   FEEDFORWARD  0.880772  0.780481           0.778046        0.782931
# 2   FEEDFORWARD  0.912259  0.828662           0.810364        0.847806
# 3   FEEDFORWARD  0.920235  0.846176           0.829874        0.863132
# 4   FEEDFORWARD  0.900924  0.808006           0.796465        0.819887
# 5   FEEDFORWARD  0.839631  0.678794           0.672537        0.685167
# 6   FEEDFORWARD  0.911839  0.814581           0.807711        0.821569
# 7   FEEDFORWARD  0.870697  0.753923           0.742944        0.765231
# 8   FEEDFORWARD  0.921914  0.843269           0.825759        0.861537
# 9   FEEDFORWARD  0.914777  0.846814           0.826918        0.867690
# 10  FEEDFORWARD  0.919815  0.854561           0.828146        0.882716
# 11  FEEDFORWARD  0.858942  0.759979           0.736577        0.784917
# 12  FEEDFORWARD  0.907641  0.803882           0.796860        0.811029
# 13  FEEDFORWARD  0.897985  0.819610           0.802534        0.837429
# 14  FEEDFORWARD  0.819479  0.713405           0.687341        0.741524
# 15  FEEDFORWARD  0.866919  0.748774           0.737244        0.760670
# 16  FEEDFORWARD  0.855164  0.747244           0.764824        0.730454
# 17  FEEDFORWARD  0.876574  0.769635           0.765655        0.773657
# 18  FEEDFORWARD  0.919395  0.821531           0.816426        0.826702
# 19  FEEDFORWARD  0.905961  0.821094           0.811750        0.830654
#
#     Precision_A  Precision_D  Precision_R  Precision_V  Recall_A  Recall_D
# 0      0.494505     0.854938     0.996569     0.968291  0.676692  0.902280  \
# 1      0.504854     0.712838     0.998233     0.896260  0.390977  0.811538
# 2      0.481250     0.809375     1.000000     0.950832  0.578947  0.875000
# 3      0.464286     0.916388     0.991453     0.947368  0.586466  0.941581
# 4      0.507692     0.757962     0.984746     0.935460  0.496241  0.835088
# 5      0.269663     0.531616     0.961818     0.927052  0.180451  0.689970
# 6      0.500000     0.789941     0.994836     0.946067  0.481203  0.864078
# 7      0.430894     0.646377     0.966783     0.927720  0.398496  0.753378
# 8      0.487952     0.858025     0.998282     0.958779  0.609023  0.905537
# 9      0.517647     0.847896     0.996552     0.945578  0.661654  0.882155
# 10     0.510989     0.850163     0.989865     0.961568  0.699248  0.893836
# 11     0.387500     0.711268     0.934370     0.913171  0.466165  0.808000
# 12     0.452381     0.801242     0.996546     0.937269  0.428571  0.874576
# 13     0.512346     0.791549     0.956747     0.949495  0.624060  0.854103
# 14     0.433071     0.648515     0.757037     0.910740  0.413534  0.675258
# 15     0.407080     0.703470     0.916944     0.921481  0.345865  0.805054
# 16     0.409639     0.814433     0.991803     0.843421  0.255639  0.877778
# 17     0.504348     0.679045     0.942105     0.937121  0.436090  0.785276
# 18     0.488372     0.834808     0.991468     0.951054  0.473684  0.892744
# 19     0.492857     0.828947     0.998243     0.926954  0.518797  0.881119
#
#     Recall_R  Recall_V
# 0   0.991468  0.937828
# 1   0.964164  0.965046
# 2   0.991453  0.945824
# 3   0.989761  0.934718
# 4   0.991468  0.956753
# 5   0.905822  0.964427
# 6   0.986348  0.954649
# 7   0.946918  0.962133
# 8   0.991468  0.940120
# 9   0.986348  0.940602
# 10  1.000000  0.937781
# 11  0.923208  0.942293
# 12  0.984642  0.956325
# 13  0.943686  0.927866
# 14  0.946296  0.931009
# 15  0.943590  0.948171
# 16  0.825939  0.962462
# 17  0.919521  0.953739
# 18  0.991468  0.948911
# 19  0.969283  0.953418

# %% [markdown]
# # Training evolution

# %% [markdown]
# ### CNN

# %%
display_epochs_stats(cnn_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### LSTM

# %%
display_epochs_stats(lstm_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### DeepSets V1

# %%
display_epochs_stats(deepset_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### DeepSets V2

# %%
display_epochs_stats(deepsetv2_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### FeedForward

# %%
display_epochs_stats(feedforward_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# # Best performing models

# %%
# %%time
data = Data(layer_size=16)
num_experiments = 20
epochs = 200
early_stopping_limit = 100

experiment_name = "25per"

train, val, test = data.get_splits(['random_subsample'], [[0.25, 0.75]])
train_unshuffled = train.copy()
np.random.shuffle(train)

x_train, y_train = data.get_x_y(train)
x_val, y_val = data.get_x_y(val)
x_test, y_test = data.get_x_y(test)

train_original = data.reverse_encoding(data.get_x_y(train_unshuffled)[0])
val_original = data.reverse_encoding(x_val)
test_original = data.reverse_encoding(x_test)

x_train_normal = data.to_conv_format(x_train)
x_val_normal = data.to_conv_format(x_val)
x_test_normal = data.to_conv_format(x_test)
for i in range(len(x_train_normal)):
    x_train_normal[i] = x_train_normal[i].to(device)
    x_val_normal[i] = x_val_normal[i].to(device)
    x_test_normal[i] = x_test_normal[i].to(device)

x_train_cnn = data.to_conv_format(x_train)
x_val_cnn = data.to_conv_format(x_val)
x_test_cnn = data.to_conv_format(x_test)
for i in range(len(x_train_cnn)):
    x_train_cnn[i] = x_train_cnn[i].to(device)
    x_val_cnn[i] = x_val_cnn[i].to(device)
    x_test_cnn[i] = x_test_cnn[i].to(device)

x_train_lstm = data.to_lstm_format(x_train)
x_val_lstm = data.to_lstm_format(x_val)
x_test_lstm = data.to_lstm_format(x_test)
for i in range(len(x_train_lstm)):
    x_train_lstm[i] = x_train_lstm[i].to(device)
    x_val_lstm[i] = x_val_lstm[i].to(device)
    x_test_lstm[i] = x_test_lstm[i].to(device)
# Out:
# c:\Users\juand\anaconda3\lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but OneHotEncoder was fitted without feature names
#   warnings.warn(
# Number of samples: 992 train | 595 val | 2382 test
# Wall time: 2.26 s

# %%
best_lstm_model = LSTM_Model(data, 16, 32, 8).to(device)
best_lstm_model.load_state_dict(torch.load('./bestmodels/best_LSTM_model_' + experiment_name))
best_cnn_model = CNN_Model(data, 64, 128, 4, -1,).to(device)
best_cnn_model.load_state_dict(torch.load('./bestmodels/best_CNN_model_' + experiment_name))
best_deepset_model = DEEPSET_Model(data).to(device)
best_deepset_model.load_state_dict(torch.load('./bestmodels/best_DEEPSET_model_' + experiment_name))
best_deepsetv2_model = DEEPSETV2_Model(data, 16, 8).to(device)
best_deepsetv2_model.load_state_dict(torch.load('./bestmodels/best_DEEPSETV2_model_' + experiment_name))
best_feedforward_model = FEEDFORWARD_Model(data).to(device)
best_feedforward_model.load_state_dict(torch.load('./bestmodels/best_FEEDFORWARD_model_' + experiment_name))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Top wrong predictions for best performing CNN model

# %%
print_wrong_preds_bycases(get_wrong_predictions_bycases(best_cnn_model, x_test_cnn, y_test, test_original), k=10)
# Out:
# 0 Atomicity violation cases wrong predicted:
#
#
# 0 DeadLock cases wrong predicted:
#
#
# 0 Data race cases wrong predicted:
#
#
# 0 Valid cases wrong predicted:

# %%
print_wrong_preds(get_wrong_predictions(best_cnn_model, x_test_cnn, y_test, test_original), k=10)
# Out:
# 0 false Atomicity violation:
#
#
# 0 false DeadLock:
#
#
# 0 false Data race :
#
#
# 0 false Valid:

# %% [markdown]
# ## Top wrong predictions for best performing LSTM model

# %%
print_wrong_preds_bycases(get_wrong_predictions_bycases(best_lstm_model, x_test_lstm, y_test, test_original), k=10)
# Out:
# 0 Atomicity violation cases wrong predicted:
#
#
# 0 DeadLock cases wrong predicted:
#
#
# 0 Data race cases wrong predicted:
#
#
# 0 Valid cases wrong predicted:

# %%
print_wrong_preds(get_wrong_predictions(best_lstm_model, x_test_lstm, y_test, test_original), k=10)
# Out:
# 0 false Atomicity violation:
#
#
# 0 false DeadLock:
#
#
# 0 false Data race :
#
#
# 0 false Valid:

# %% [markdown]
# ## Top wrong predictions for best performing DeepSets V1 model

# %%
print_wrong_preds_bycases(get_wrong_predictions_bycases(best_deepset_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 10 Atomicity violation cases wrong predicted:
# Sample ['...,.._...,__.,,', ',uw.._,,._.__,_.', '___._.__,__dr.,.', 'A'] | Prediction D
# Sample ['_..___,.,._.,_,_', '_,,,,_._.uw_,_._', ',,_,,dr,...,.,,_', 'A'] | Prediction V
# Sample [',,___,,,_._,,_._', '.,...,_..,_uw_.,', '___..,...,,_,.dr', 'A'] | Prediction D
# Sample ['.,_.___.__,_,_..', '.__,,,_uw,,_.,_,', '_.dr.,....,.,.._', 'A'] | Prediction V
# Sample ['____.,,,_._._.._', '..,...._,uw,,,._', ',,dr,_,.,,,....,', 'A'] | Prediction D
# Sample [',___.._,.,_.___,', ',._,,,,._,_.uw_,', '_,_._.__.___..dr', 'A'] | Prediction D
# Sample [',,,_.....,...___', '..uw_,_.,,__.___', '..__,__._dr_,_,.', 'A'] | Prediction D
# Sample ['..,._,_,..,,.__,', '._.._uw_.,,,_,.,', ',,__,dr._,__,,,_', 'A'] | Prediction V
# Sample ['_,,,,....,..,,..', ',_,.,__,,uw.,_.,', ',_._...____,,_dr', 'A'] | Prediction D
# Sample ['.,.__.,_,...._,,', '_,._____..uw.,._', '.,,,.._...._.dr_', 'A'] | Prediction V
#
#
# 10 DeadLock cases wrong predicted:
# Sample ['_,_,__.,._,,,.,.', ',.__.,,,w_,._.,.', 'dr,,_.,.,__,.___', 'D'] | Prediction A
# Sample ['_,___,,,_,,_,._.', '__..,,,_,_,.__w_', ',.._._,_.dr.,,.,', 'D'] | Prediction A
# Sample ['..__,,.._,,.,___', '...w_...,_..__.,', '.,.,__,,,,dr.,,,', 'D'] | Prediction A
# Sample ['__.,...,,_,,_,,.', '_..,.__.,_....w.', 'dr,.,,,__.,_,__,', 'D'] | Prediction A
# Sample ['_,._,,,_,._..,,,', '__.._.__,__.,w,.', '.,_.,__,..._dr_,', 'D'] | Prediction A
# Sample [',,_._,_...,,,._,', ',_.__,_.__.__w_.', '._____._.,,,,_dr', 'D'] | Prediction A
# Sample ['.....__,.....__.', '__.w.._,._,._,,.', '.dr.__,_,_,_..,.', 'D'] | Prediction A
# Sample ['._._.._.__,..,,,', '_,_,_.,.__.w___.', '_,_,dr,__._.....', 'D'] | Prediction A
# Sample ['..._,._,_...,,._', '_,..,,,w._,.,_,.', '__,_,.dr___,.__.', 'D'] | Prediction A
# Sample ['..,,__,_,,._,,,,', ',,_,._,,___._.,w', '._,._,__dr..,,_,', 'D'] | Prediction A
#
#
# 0 Data race cases wrong predicted:
#
#
# 10 Valid cases wrong predicted:
# Sample ['__.,_._,,.,_.._.', ',_.__,__.,,wu,_.', '.,_.,.dr.._.,,._', 'V'] | Prediction D
# Sample [',__.._,._...__.,', '_.__wu._,,....,.', '_,..__,..dr...._', 'V'] | Prediction A
# Sample [',___,,,,__.,.,,.', '_,.,wu__..,._,..', '.__....,,_.__dr_', 'V'] | Prediction A
# Sample ['__._.._,_.__,,_.', ',..,..__,wu_._..', '_,..._.,,_,,dr,.', 'V'] | Prediction A
# Sample [',,...,,_.___.,._', '_.,_,.__wu_,_.,.', '__,.,_dr,,__._,.', 'V'] | Prediction A
# Sample ['_,,,.,.,_,.__,__', ',_.._wu._,_.___,', '.dr___..._._.,._', 'V'] | Prediction A
# Sample ['.,.._,,._,,,_,,,', ',wu.__..,.__.,,,', '.,,dr.__._,__,,.', 'V'] | Prediction A
# Sample ['.._.,,_,_._,__,_', '.___,_,,._.wu,_,', 'dr._._,.._.____,', 'V'] | Prediction D
# Sample ['...,,.,._,_,_..,', '_,._.wu___._.,,_', '.._,,....,,_dr,.', 'V'] | Prediction A
# Sample ['_,__,,._.,,__,_,', '__,._wu._.,___..', '._dr,..__.__,_..', 'V'] | Prediction A

# %%
print_wrong_preds(get_wrong_predictions(best_deepset_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 10 false Atomicity violation:
# Sample [',__.._,._...__.,', '_.__wu._,,....,.', '_,..__,..dr...._', 'V'] | Prediction A
# Sample ['_,_,__.,._,,,.,.', ',.__.,,,w_,._.,.', 'dr,,_.,.,__,.___', 'D'] | Prediction A
# Sample [',___,,,,__.,.,,.', '_,.,wu__..,._,..', '.__....,,_.__dr_', 'V'] | Prediction A
# Sample ['__._.._,_.__,,_.', ',..,..__,wu_._..', '_,..._.,,_,,dr,.', 'V'] | Prediction A
# Sample [',,...,,_.___.,._', '_.,_,.__wu_,_.,.', '__,.,_dr,,__._,.', 'V'] | Prediction A
# Sample ['_,___,,,_,,_,._.', '__..,,,_,_,.__w_', ',.._._,_.dr.,,.,', 'D'] | Prediction A
# Sample ['_,,,.,.,_,.__,__', ',_.._wu._,_.___,', '.dr___..._._.,._', 'V'] | Prediction A
# Sample ['.,.._,,._,,,_,,,', ',wu.__..,.__.,,,', '.,,dr.__._,__,,.', 'V'] | Prediction A
# Sample ['...,,.,._,_,_..,', '_,._.wu___._.,,_', '.._,,....,,_dr,.', 'V'] | Prediction A
# Sample ['_,__,,._.,,__,_,', '__,._wu._.,___..', '._dr,..__.__,_..', 'V'] | Prediction A
#
#
# 10 false DeadLock:
# Sample ['__.,_._,,.,_.._.', ',_.__,__.,,wu,_.', '.,_.,.dr.._.,,._', 'V'] | Prediction D
# Sample ['...,.._...,__.,,', ',uw.._,,._.__,_.', '___._.__,__dr.,.', 'A'] | Prediction D
# Sample [',,___,,,_._,,_._', '.,...,_..,_uw_.,', '___..,...,,_,.dr', 'A'] | Prediction D
# Sample ['.._.,,_,_._,__,_', '.___,_,,._.wu,_,', 'dr._._,.._.____,', 'V'] | Prediction D
# Sample ['_.._,.,,_._.__,.', '_wu_,,_,_,,____,', 'dr.,,.,..,_,_,__', 'V'] | Prediction D
# Sample ['__,___.____,,.._', ',._.,,,wu._,.,.,', '.,,..._dr_,,.,..', 'V'] | Prediction D
# Sample [',,_.__.__,,,_,,,', ',_..,.,.,,,wu,.,', '_.,_,.,_dr_,..__', 'V'] | Prediction D
# Sample [',_,__,.._,....,,', '.wu_.,.,.__,.,_.', '_.__.dr__,,..___', 'V'] | Prediction D
# Sample ['_.,_.__,__.,.._.', 'wu__,,...,_,._._', ',_dr,_._,,___,_.', 'V'] | Prediction D
# Sample ['____.,,,_._._.._', '..,...._,uw,,,._', ',,dr,_,.,,,....,', 'A'] | Prediction D
#
#
# 0 false Data race :
#
#
# 10 false Valid:
# Sample ['_..___,.,._.,_,_', '_,,,,_._.uw_,_._', ',,_,,dr,...,.,,_', 'A'] | Prediction V
# Sample ['.,_.___.__,_,_..', '.__,,,_uw,,_.,_,', '_.dr.,....,.,.._', 'A'] | Prediction V
# Sample ['..,._,_,..,,.__,', '._.._uw_.,,,_,.,', ',,__,dr._,__,,,_', 'A'] | Prediction V
# Sample ['.,.__.,_,...._,,', '_,._____..uw.,._', '.,,,.._...._.dr_', 'A'] | Prediction V
# Sample ['__..,.,,._,..__.', ',,_..,,_..__,uw,', '_.._.__,_dr,_...', 'A'] | Prediction V
# Sample ['_.._,_,,_._,_.,.', '.uw._,._.._..._,', ',.__.,,_dr_.,...', 'A'] | Prediction V
# Sample ['...,__,,,._,.,,_', '_..,.uw_.,,,.,_.', '_dr,.,__,_._._.,', 'A'] | Prediction V
# Sample ['_,,__,,_,,_,_...', '.___.._...,uw,_.', '_..,,,dr_._.,.,_', 'A'] | Prediction V
# Sample ['.,._._._,.,_,_.,', '.__._.uw._,,,,_,', '...__dr.,__..,_.', 'A'] | Prediction V
# Sample [',.._,.___.,.__,.', '.,.,,_..,_.uw..,', ',._..,.,__dr._,,', 'A'] | Prediction V

# %% [markdown]
# ## Top wrong predictions for best performing DeepSets V2 model

# %%
print_wrong_preds_bycases(get_wrong_predictions_bycases(best_deepsetv2_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 10 Atomicity violation cases wrong predicted:
# Sample [',._._.,.,._,,_,,', '___._._,__uw_,__', ',_.,.._dr,,,_,,,', 'A'] | Prediction V
# Sample [',,___,,,_._,,_._', '.,...,_..,_uw_.,', '___..,...,,_,.dr', 'A'] | Prediction V
# Sample ['.,,__._._,.,..,_', '_.___,,_.___uw..', '__.,_dr,,.,,,_.,', 'A'] | Prediction V
# Sample ['_,,_.__,.__._.,,', ',__....,._uw,__.', ',_,._dr,__,...,_', 'A'] | Prediction V
# Sample ['.,_.___.__,_,_..', '.__,,,_uw,,_.,_,', '_.dr.,....,.,.._', 'A'] | Prediction V
# Sample ['__,,,_..,.__,._,', '_,_,..uw,,__.,__', '.,_,._._,,,_dr.,', 'A'] | Prediction V
# Sample [',_.,_.,.,_.._,.,', '.__.,,,uw,_,,._.', '..,dr..__,__,._,', 'A'] | Prediction V
# Sample ['.,,_,,..._.__,,.', '__._,uw_,,_,,___', '._,,_.__,dr,,__.', 'A'] | Prediction V
# Sample ['.,.____,,_.._,_,', '_,_,_,,,_._uw__,', ',,.,..___,..dr__', 'A'] | Prediction V
# Sample ['...._.,_,_,.,,_.', '._,uw_..,.____..', '._dr.,..,.__.,_,', 'A'] | Prediction D
#
#
# 3 DeadLock cases wrong predicted:
# Sample ['_.,_.,.,._.,_._.', ',__w_,,..,_.,.._', ',_,,_,dr,.__....', 'D'] | Prediction A
# Sample ['._,__,,._.._..,.', ',_,w,,_._,,_.._,', '._,_..._,.,,,dr,', 'D'] | Prediction V
# Sample ['.,,,____,,,..__.', 'w_,._._..._...._', ',,..,,_..dr,_,_.', 'D'] | Prediction A
#
#
# 2 Data race cases wrong predicted:
# Sample ['._,.,.,...,_.._.', 'wu__.,,,,,_._.._', '___r_..__,.,,_,.', 'R'] | Prediction V
# Sample ['.,._,.,_,..___..', ',.,,..,,_.,,.wu.', '.___._.,,,.,,_.r', 'R'] | Prediction V
#
#
# 10 Valid cases wrong predicted:
# Sample ['__.,_._,,.,_.._.', ',_.__,__.,,wu,_.', '.,_.,.dr.._.,,._', 'V'] | Prediction A
# Sample [',__.._,._...__.,', '_.__wu._,,....,.', '_,..__,..dr...._', 'V'] | Prediction A
# Sample ['__._.._,_.__,,_.', ',..,..__,wu_._..', '_,..._.,,_,,dr,.', 'V'] | Prediction A
# Sample [',,...,,_.___.,._', '_.,_,.__wu_,_.,.', '__,.,_dr,,__._,.', 'V'] | Prediction A
# Sample ['_,,,.,.,_,.__,__', ',_.._wu._,_.___,', '.dr___..._._.,._', 'V'] | Prediction A
# Sample ['.,.._,,._,,,_,,,', ',wu.__..,.__.,,,', '.,,dr.__._,__,,.', 'V'] | Prediction A
# Sample ['.._.,,_,_._,__,_', '.___,_,,._.wu,_,', 'dr._._,.._.____,', 'V'] | Prediction A
# Sample ['...,,.,._,_,_..,', '_,._.wu___._.,,_', '.._,,....,,_dr,.', 'V'] | Prediction A
# Sample ['_,__,,._.,,__,_,', '__,._wu._.,___..', '._dr,..__.__,_..', 'V'] | Prediction A
# Sample [',,_.,,..._.__.,_', '_,,,,._,,._wu___', '._,,.,,_,,dr___.', 'V'] | Prediction A

# %%
print_wrong_preds(get_wrong_predictions(best_deepsetv2_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 10 false Atomicity violation:
# Sample ['__.,_._,,.,_.._.', ',_.__,__.,,wu,_.', '.,_.,.dr.._.,,._', 'V'] | Prediction A
# Sample [',__.._,._...__.,', '_.__wu._,,....,.', '_,..__,..dr...._', 'V'] | Prediction A
# Sample ['__._.._,_.__,,_.', ',..,..__,wu_._..', '_,..._.,,_,,dr,.', 'V'] | Prediction A
# Sample [',,...,,_.___.,._', '_.,_,.__wu_,_.,.', '__,.,_dr,,__._,.', 'V'] | Prediction A
# Sample ['_,,,.,.,_,.__,__', ',_.._wu._,_.___,', '.dr___..._._.,._', 'V'] | Prediction A
# Sample ['.,.._,,._,,,_,,,', ',wu.__..,.__.,,,', '.,,dr.__._,__,,.', 'V'] | Prediction A
# Sample ['.._.,,_,_._,__,_', '.___,_,,._.wu,_,', 'dr._._,.._.____,', 'V'] | Prediction A
# Sample ['...,,.,._,_,_..,', '_,._.wu___._.,,_', '.._,,....,,_dr,.', 'V'] | Prediction A
# Sample ['_,__,,._.,,__,_,', '__,._wu._.,___..', '._dr,..__.__,_..', 'V'] | Prediction A
# Sample [',,_.,,..._.__.,_', '_,,,,._,,._wu___', '._,,.,,_,,dr___.', 'V'] | Prediction A
#
#
# 10 false DeadLock:
# Sample ['__,_..,_._,_..,.', '.,wu,.,__...._._', '.__,.._,dr..,__,', 'V'] | Prediction D
# Sample ['...._.,_,_,.,,_.', '._,uw_..,.____..', '._dr.,..,.__.,_,', 'A'] | Prediction D
# Sample ['_,.,,__.___.__,,', '._wu,,,,__,_.,.,', '_,,._,_,.,,dr._,', 'V'] | Prediction D
# Sample ['_..____...,__,,.', '__wu.__,_._...,.', '_,_.,..__dr.,,._', 'V'] | Prediction D
# Sample [',.,_._.,,,.,.,,,', '..wu_,,,_.._,,_.', '.dr___.,,,,,_,..', 'V'] | Prediction D
# Sample [',_,.._._.,.,.,__', '._wu.,,.,____._,', '..,.._dr.,_.._..', 'V'] | Prediction D
# Sample ['_..,_,,_..._,,_,', '_,wu_...,____.,_', '_,,dr,,.,,__..__', 'V'] | Prediction D
# Sample [',._,_.._.._.,_..', '.,wu.__.,.._,.._', ',_.,_,__.._,dr,.', 'V'] | Prediction D
# Sample ['..,_._,__._.,,.,', '_,wu___,._._.,_.', '._.,dr,_,___....', 'V'] | Prediction D
# Sample ['._._,.,,,.,.._..', ',.wu.,,.__.._,,.', '___,_..__..,,.dr', 'V'] | Prediction D
#
#
# 1 false Data race :
# Sample ['_._,,,_,,.__.,,_', 'uw_,__,_____.,_,', '.....dr,.,..,,._', 'A'] | Prediction R
#
#
# 10 false Valid:
# Sample [',._._.,.,._,,_,,', '___._._,__uw_,__', ',_.,.._dr,,,_,,,', 'A'] | Prediction V
# Sample [',,___,,,_._,,_._', '.,...,_..,_uw_.,', '___..,...,,_,.dr', 'A'] | Prediction V
# Sample ['.,,__._._,.,..,_', '_.___,,_.___uw..', '__.,_dr,,.,,,_.,', 'A'] | Prediction V
# Sample ['_,,_.__,.__._.,,', ',__....,._uw,__.', ',_,._dr,__,...,_', 'A'] | Prediction V
# Sample ['.,_.___.__,_,_..', '.__,,,_uw,,_.,_,', '_.dr.,....,.,.._', 'A'] | Prediction V
# Sample ['__,,,_..,.__,._,', '_,_,..uw,,__.,__', '.,_,._._,,,_dr.,', 'A'] | Prediction V
# Sample [',_.,_.,.,_.._,.,', '.__.,,,uw,_,,._.', '..,dr..__,__,._,', 'A'] | Prediction V
# Sample ['._,.,.,...,_.._.', 'wu__.,,,,,_._.._', '___r_..__,.,,_,.', 'R'] | Prediction V
# Sample ['.,,_,,..._.__,,.', '__._,uw_,,_,,___', '._,,_.__,dr,,__.', 'A'] | Prediction V
# Sample ['.,.____,,_.._,_,', '_,_,_,,,_._uw__,', ',,.,..___,..dr__', 'A'] | Prediction V

# %% [markdown]
# ## Top wrong predictions for best performing Feedforward model

# %%
print_wrong_preds_bycases(get_wrong_predictions_bycases(best_feedforward_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 10 Atomicity violation cases wrong predicted:
# Sample ['.,_.,,,,.,__....', '.,uw.,.__,.,_.,,', '.,dr,.__._.,,,_.', 'A'] | Prediction D
# Sample ['_..___,.,._.,_,_', '_,,,,_._.uw_,_._', ',,_,,dr,...,.,,_', 'A'] | Prediction V
# Sample ['_,_,___.,.,.,,._', '.,uw._,..,,,_..,', '.____,,____.,,dr', 'A'] | Prediction D
# Sample ['.,,__._._,.,..,_', '_.___,,_.___uw..', '__.,_dr,,.,,,_.,', 'A'] | Prediction V
# Sample [',,.,._,,,.._,...', 'uw_,,,,___,_..._', '__.,_.._dr,...._', 'A'] | Prediction V
# Sample ['...,...__,__.,,.', '.__,...,,__,uw,_', '_.__,,_.,.__.dr_', 'A'] | Prediction V
# Sample ['.,...._._.___,..', ',,uw,__.,,_,,,_.', '...._.._dr..__.,', 'A'] | Prediction V
# Sample ['.,,_,,..._.__,,.', '__._,uw_,,_,,___', '._,,_.__,dr,,__.', 'A'] | Prediction V
# Sample ['._,,.,,_,_,.,.__', ',,__uw,._.__,,,.', '..,_,,_,dr.,_,,,', 'A'] | Prediction V
# Sample ['._.._.,,_.___,.,', ',_.._..,_.,uw,,_', ',dr._,__,_.,_.,.', 'A'] | Prediction D
#
#
# 10 DeadLock cases wrong predicted:
# Sample ['..__,,.._,,.,___', '...w_...,_..__.,', '.,.,__,,,,dr.,,,', 'D'] | Prediction A
# Sample ['__.,...,,_,,_,,.', '_..,.__.,_....w.', 'dr,.,,,__.,_,__,', 'D'] | Prediction A
# Sample ['_,..,.__.,,..._,', '__._w._,..,.....', ',_,_.._,dr,_,.,_', 'D'] | Prediction A
# Sample ['_,._,,,_,._..,,,', '__.._.__,__.,w,.', '.,_.,__,..._dr_,', 'D'] | Prediction A
# Sample [',_,__..,,.,__..,', '.,,...__.._,.,__', '.dr_,,,,___,,,,.', 'D'] | Prediction V
# Sample [',_.,_.,,...._.,_', '___.,,w.,.,,_,..', '.,_...,dr_,_....', 'D'] | Prediction A
# Sample ['_._._,,._.___..,', ',,.,__w,_.,,.__.', '.dr,,..,,_..,_._', 'D'] | Prediction V
# Sample ['__.__.,.,...,_._', ',,_,w__,,.._,...', '_,.,,_._,._,.dr.', 'D'] | Prediction V
# Sample ['__._.,__.,..,.,_', '.._,.w_.,..,_.,,', ',_...,_,_,,dr,.,', 'D'] | Prediction R
# Sample [',____,_..,.,,.,,', '_..,_,__w_,,,.,_', ',....dr,__,.,_..', 'D'] | Prediction V
#
#
# 5 Data race cases wrong predicted:
# Sample [',...,,_,__.,._.,', ',_.,._,.wu,_,,_.', ',,r,_..,_,_,,_._', 'R'] | Prediction V
# Sample [',.___,..,._._,_.', '_,,__,_,..wu.__,', '..r,,__,,,..,._.', 'R'] | Prediction V
# Sample ['__.,_..._.......', '._,,.,..uw_.,,,,', '.r,._...._,..,..', 'R'] | Prediction V
# Sample ['_,,,___,._,,_.,.', '_.._,.uw___,.__.', '._r,_,._.,_.,_..', 'R'] | Prediction V
# Sample ['.,,.,,,.___.,_..', ',,.__,,.,.,.__.,', '_.r_.,__._,_,,,,', 'R'] | Prediction V
#
#
# 10 Valid cases wrong predicted:
# Sample ['__.,_._,,.,_.._.', ',_.__,__.,,wu,_.', '.,_.,.dr.._.,,._', 'V'] | Prediction A
# Sample [',__.._,._...__.,', '_.__wu._,,....,.', '_,..__,..dr...._', 'V'] | Prediction A
# Sample [',___,,,,__.,.,,.', '_,.,wu__..,._,..', '.__....,,_.__dr_', 'V'] | Prediction A
# Sample ['__._.._,_.__,,_.', ',..,..__,wu_._..', '_,..._.,,_,,dr,.', 'V'] | Prediction A
# Sample [',,...,,_.___.,._', '_.,_,.__wu_,_.,.', '__,.,_dr,,__._,.', 'V'] | Prediction A
# Sample ['.,.._,,._,,,_,,,', ',wu.__..,.__.,,,', '.,,dr.__._,__,,.', 'V'] | Prediction A
# Sample ['_.,_.,,_.,,,,__.', '.___._.__._.wu._', '.,,..____.__,,dr', 'V'] | Prediction A
# Sample ['.._.,,_,_._,__,_', '.___,_,,._.wu,_,', 'dr._._,.._.____,', 'V'] | Prediction A
# Sample ['_,__,,._.,,__,_,', '__,._wu._.,___..', '._dr,..__.__,_..', 'V'] | Prediction A
# Sample ['.,,_,___,_._,_.,', ',,,,,.___wu..,..', '._,.,,,_.,____dr', 'V'] | Prediction A

# %%
print_wrong_preds(get_wrong_predictions(best_feedforward_model, x_test_normal, y_test, test_original), k=10)
# Out:
# 10 false Atomicity violation:
# Sample ['__.,_._,,.,_.._.', ',_.__,__.,,wu,_.', '.,_.,.dr.._.,,._', 'V'] | Prediction A
# Sample [',__.._,._...__.,', '_.__wu._,,....,.', '_,..__,..dr...._', 'V'] | Prediction A
# Sample [',___,,,,__.,.,,.', '_,.,wu__..,._,..', '.__....,,_.__dr_', 'V'] | Prediction A
# Sample ['__._.._,_.__,,_.', ',..,..__,wu_._..', '_,..._.,,_,,dr,.', 'V'] | Prediction A
# Sample [',,...,,_.___.,._', '_.,_,.__wu_,_.,.', '__,.,_dr,,__._,.', 'V'] | Prediction A
# Sample ['.,.._,,._,,,_,,,', ',wu.__..,.__.,,,', '.,,dr.__._,__,,.', 'V'] | Prediction A
# Sample ['_.,_.,,_.,,,,__.', '.___._.__._.wu._', '.,,..____.__,,dr', 'V'] | Prediction A
# Sample ['.._.,,_,_._,__,_', '.___,_,,._.wu,_,', 'dr._._,.._.____,', 'V'] | Prediction A
# Sample ['_,__,,._.,,__,_,', '__,._wu._.,___..', '._dr,..__.__,_..', 'V'] | Prediction A
# Sample ['.,,_,___,_._,_.,', ',,,,,.___wu..,..', '._,.,,,_.,____dr', 'V'] | Prediction A
#
#
# 10 false DeadLock:
# Sample ['.,_.,,,,.,__....', '.,uw.,.__,.,_.,,', '.,dr,.__._.,,,_.', 'A'] | Prediction D
# Sample ['_,_,___.,.,.,,._', '.,uw._,..,,,_..,', '.____,,____.,,dr', 'A'] | Prediction D
# Sample ['_.._,.,,_._.__,.', '_wu_,,_,_,,____,', 'dr.,,.,..,_,_,__', 'V'] | Prediction D
# Sample ['__,_..,_._,_..,.', '.,wu,.,__...._._', '.__,.._,dr..,__,', 'V'] | Prediction D
# Sample ['_.._,,,_,_,._._.', '__..._,,_,,wu_,_', ',,.___,.__._.dr,', 'V'] | Prediction D
# Sample [',,_.__.__,,,_,,,', ',_..,.,.,,,wu,.,', '_.,_,.,_dr_,..__', 'V'] | Prediction D
# Sample [',_,__,.._,....,,', '.wu_.,.,.__,.,_.', '_.__.dr__,,..___', 'V'] | Prediction D
# Sample ['_.,_.__,__.,.._.', 'wu__,,...,_,._._', ',_dr,_._,,___,_.', 'V'] | Prediction D
# Sample ['._.._.,,_.___,.,', ',_.._..,_.,uw,,_', ',dr._,__,_.,_.,.', 'A'] | Prediction D
# Sample ['____.,,,_._._.._', '..,...._,uw,,,._', ',,dr,_,.,,,....,', 'A'] | Prediction D
#
#
# 2 false Data race :
# Sample [',,._,,,,....,,__', '....wu_._,.,,_,.', '_,.,_,.,_.,dr,._', 'V'] | Prediction R
# Sample ['__._.,__.,..,.,_', '.._,.w_.,..,_.,,', ',_...,_,_,,dr,.,', 'D'] | Prediction R
#
#
# 10 false Valid:
# Sample ['_..___,.,._.,_,_', '_,,,,_._.uw_,_._', ',,_,,dr,...,.,,_', 'A'] | Prediction V
# Sample ['.,,__._._,.,..,_', '_.___,,_.___uw..', '__.,_dr,,.,,,_.,', 'A'] | Prediction V
# Sample [',,.,._,,,.._,...', 'uw_,,,,___,_..._', '__.,_.._dr,...._', 'A'] | Prediction V
# Sample ['...,...__,__.,,.', '.__,...,,__,uw,_', '_.__,,_.,.__.dr_', 'A'] | Prediction V
# Sample ['.,...._._.___,..', ',,uw,__.,,_,,,_.', '...._.._dr..__.,', 'A'] | Prediction V
# Sample ['.,,_,,..._.__,,.', '__._,uw_,,_,,___', '._,,_.__,dr,,__.', 'A'] | Prediction V
# Sample ['._,,.,,_,_,.,.__', ',,__uw,._.__,,,.', '..,_,,_,dr.,_,,,', 'A'] | Prediction V
# Sample [',...,,_,__.,._.,', ',_.,._,.wu,_,,_.', ',,r,_..,_,_,,_._', 'R'] | Prediction V
# Sample [',_,__..,,.,__..,', '.,,...__.._,.,__', '.dr_,,,,___,,,,.', 'D'] | Prediction V
# Sample [',,_,,___..___,__', '_uw,..,.,_..,_,_', ',.___._.,dr.,_..', 'A'] | Prediction V

# %%
confusionMatrix(best_lstm_model, x_test_lstm, y_test)

# %%
models=[best_cnn_model, best_lstm_model, best_deepset_model, best_deepsetv2_model, best_feedforward_model]
Xs=[x_test_cnn, x_test_lstm, x_test_normal, x_test_normal, x_test_normal]
confusionMatrixs(models, Xs, y_test, experiment_name)
# Out:
#      y_true
# 0         V
# 1         D
# 2         V
# 3         D
# 4         V
# ...     ...
# 2377      D
# 2378      R
# 2379      R
# 2380      V
# 2381      A
#
# [2382 rows x 1 columns]
#      y_pred
# 0         V
# 1         D
# 2         V
# 3         D
# 4         V
# ...     ...
# 2377      D
# 2378      R
# 2379      R
# 2380      V
# 2381      A
#
# [2382 rows x 1 columns]
#      y_true
# 0         V
# 1         D
# 2         V
# 3         D
# 4         V
# ...     ...
# 2377      D
# 2378      R
# 2379      R
# 2380      V
# 2381      A
#
# [2382 rows x 1 columns]
#      y_pred
# 0         V
# 1         D
# 2         V
# 3         D
# 4         V
# ...     ...
# 2377      D
# 2378      R
# 2379      R
# 2380      V
# 2381      A
#
# [2382 rows x 1 columns]
#      y_true
# 0         V
# 1         D
# 2         V
# 3         D
# 4         V
# ...     ...
# 2377      D
# 2378      R
# 2379      R
# 2380      V
# 2381      A
#
# [2382 rows x 1 columns]
#      y_pred
# 0         V
# 1         D
# 2         V
# 3         D
# 4         V
# ...     ...
# 2377      D
# 2378      R
# 2379      R
# 2380      V
# 2381      D
#
# [2382 rows x 1 columns]
#      y_true
# 0         V
# 1         D
# 2         V
# 3         D
# 4         V
# ...     ...
# 2377      D
# 2378      R
# 2379      R
# 2380      V
# 2381      A
#
# [2382 rows x 1 columns]
#      y_pred
# 0         V
# 1         D
# 2         V
# 3         D
# 4         V
# ...     ...
# 2377      D
# 2378      R
# 2379      R
# 2380      V
# 2381      V
#
# [2382 rows x 1 columns]
#      y_true
# 0         V
# 1         D
# 2         V
# 3         D
# 4         V
# ...     ...
# 2377      D
# 2378      R
# 2379      R
# 2380      V
# 2381      A
#
# [2382 rows x 1 columns]
#      y_pred
# 0         V
# 1         D
# 2         V
# 3         D
# 4         V
# ...     ...
# 2377      D
# 2378      R
# 2379      R
# 2380      V
# 2381      D
#
# [2382 rows x 1 columns]

# %% [markdown]
# # Saving Notebook State

# %%
import dill
dill.dump_session('notebook_env_' + experiment_name + '.db')

# %% [markdown]
# # Loading Notebook State

# %%
import dill
experiment_name = "25per"
# dill.load_session('notebook_env_' + experiment_name + '.db')
