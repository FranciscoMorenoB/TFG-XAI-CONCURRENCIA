# %%
from src.generate_data import Data
from src.evaluate import *
from src.models import *

import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
# %autosave 120
# Out:
# Autosaving every 120 seconds

# %% [markdown]
# # Get the synthetic dataset

# %%
# %%time
data = Data(layer_size=16, permutation_intervals=2)
# Out:
# CPU times: total: 609 ms
# Wall time: 607 ms
# C:\Users\franm\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but OneHotEncoder was fitted without feature names
#   warnings.warn(

# %%
# %%time
train, val, test = data.get_splits(['1st_interval'], [])

train_unshuffled = train.copy()
np.random.shuffle(train)

x_train, y_train = data.get_x_y(train)
x_val, y_val = data.get_x_y(val)
x_test, y_test = data.get_x_y(test)

train_original = data.reverse_encoding(data.get_x_y(train_unshuffled)[0])
val_original = data.reverse_encoding(x_val)
test_original = data.reverse_encoding(x_test)
# Out:
# Number of samples: 900 train | 217 val | 872 test
# CPU times: total: 109 ms
# Wall time: 123 ms

# %% [markdown]
# #### Peek at unshuffled train data

# %%
train_original[:10]
# Out:
# [[',..._.._,.___._.', 'w,,_,.,_,__.._.,', 'cr__,._,._,._,__', False],
#  [',___._.,_.,,..,_', 'w_.,.,._,_._..,,', ',cr,__,,._._.,,_', False],
#  [',_..,__......___', 'w__.____,_,..___', '.,cr_.__._.,..._', False],
#  ['_.,,.,....,__._,', 'w,.,.,.___,_,_,_', '.._cr_.___.,,,.,', False],
#  [',.._.._,_...,.,_', 'w.__,,_,,_,__..,', '..,_cr_.,.,_.___', False],
#  [',,.._.....,,,,,_', 'w_,.._.,...,_.,_', '...__cr..,__,_..', False],
#  ['__....,,,._..,,.', 'w.._.,.,__.,.__.', '._..,_cr.,_,__.,', False],
#  [',,,__..__.____,.', '_w__,_._,,.__,,.', 'cr...__,..,,__,.', False],
#  ['..,._,.__.,__,,_', ',w,_,..__,_,_,..', '_cr,._,__.._,___', False],
#  [',.,.,,__,,._.,__', ',w,,_,.__..__,,,', '_,cr_,.,._____.,', False]]

# %%
train_original[310:320]
# Out:
# [[',_,.__,.,.,..__.', '__.wu,.,...,_._,', 'dr,_,__,,.._,...', False],
#  ['_,.,,_._,._,..__', ',._wu.,..,,__...', '_dr._...,..__,..', False],
#  ['._____,..,.,....', '_..wu_,_._,,..,_', '__dr_,_,...___..', False],
#  ['_.._...,,._____.', '...wu.,.,,_,,___', ',,_dr,.,_,__.,__', False],
#  ['.._____._,_..,,_', '__.wu_..,,....,.', '_._,dr,._,_.,,_.', False],
#  [',_,,,,_.,__._,,,', '.,.wu.,__.__,.,.', ',__,.dr.__.._,_.', False],
#  ['_.._._.,.__...,,', '..,wu..____.,_,.', '__,,_.dr....,.,.', False],
#  ['___._._,..__,.,.', '..,.wu..__._,...', 'dr,._.,,__..,,,,', False],
#  [',.,,._...._.._._', '.._,wu,..,.,,_._', ',dr_...__..,_,._', False],
#  [',.__,,.,_,..,,,.', '.,.,wu_,._,...__', '_.dr__.,,__,,__.', False]]

# %%
pos_train_ratio = get_stats_and_ratio(train_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 49 | F2-uw 49 | F2-w 56 | F2-noop 56 |
# F3 cr:    F2-wu 49 | F2-uw 49 | F2-w 56 | F2-noop 56 |
# F3 r:    F2-wu 56 | F2-uw 56 | F2-w 64 | F2-noop 64 |
# F3 noop:    F2-wu 56 | F2-uw 56 | F2-w 64 | F2-noop 64 |
#
# Positive samples count: 401
# Total samples count: 900
# Positive class ratio: 0.44555555555555554

# %% [markdown]
# #### Peek at test data

# %%
test_original[:15]
# Out:
# [['__...,_._,,_,,._', '...,,,____,__uw_', '.,,.,,,__,.,._,_', False],
#  [',__._,._,,,_,,.,', ',,._._,_.__,..w_', '..,,,,.,.._,,cr.', False],
#  ['___,___,,,.,,..,', '._,.,,,uw._...._', '__._.___,cr,_.,_', False],
#  ['____,.,.,,_..,_.', '_,_.,...,,w__,,_', '__,._.,__dr,__,.', True],
#  ['.,._.__,._.,....', '_..,,,.,,_.,w_..', ',,,.._.,dr,__,_,', True],
#  [',,.,,_,,._,,..,_', ',,_,__.,,,___.uw', '_,._,,,..__,__cr', False],
#  ['._.._,,_,,,_,_.,', ',,_,,__wu_,_.._.', '..._..,,r.,,.._,', True],
#  ['____.__,_,.,,.,,', ',,,_,,.__w,._...', '_.,_,.,_,__._dr,', True],
#  [',._.__.,,_....,_', '._.,___,__.,___,', '..,,,_.,.dr,,,..', True],
#  ['__.,_,,.,,,..,,,', '.._,..,,,..,_uw.', '_,.,,.,.._.,.,._', False],
#  [',,.,......,,_,,.', '_,,,,__,,._...,_', ',...,_.,.cr_,.,_', False],
#  ['._._.,_,.,__,._.', '___,...,_,_,wu._', '._....,,,__,.,r_', True],
#  ['_,,._.,..,_.,.,,', '.,.._.._w_.__,._', '__._,.,.,_,.._..', False],
#  ['_,__._._._,__.,.', ',_.,.,,_._,,w.,,', ',,.._.__..___.cr', False],
#  ['__.._.,_____...,', '...,,_._..uw....', ',.,,_..,dr,,_,,.', True]]

# %%
pos_test_ratio = get_stats_and_ratio(test_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 58 | F2-uw 48 | F2-w 54 | F2-noop 58 |
# F3 cr:    F2-wu 58 | F2-uw 53 | F2-w 49 | F2-noop 59 |
# F3 r:    F2-wu 51 | F2-uw 53 | F2-w 52 | F2-noop 57 |
# F3 noop:    F2-wu 56 | F2-uw 53 | F2-w 57 | F2-noop 56 |
#
# Positive samples count: 373
# Total samples count: 872
# Positive class ratio: 0.42775229357798167

# %% [markdown]
# #### Peek at val data

# %%
val_original[:15]
# Out:
# [['._...,._,_..._._', ',....__,_,_...w_', '___.._.,,._,._cr', False],
#  ['.,,,,,___._.,___', '__,,.__,_._..wu_', '..,_,,__,.,,r.,.', True],
#  ['_._._,___,,_,,..', ',,,__,_____.,,,_', '_.._._,,.._cr..,', False],
#  ['_.,_,__,,,__,_.,', '_..._.,._,_,,,_w', '..___._cr,_,___.', False],
#  ['....,,.,____..._', ',,__....._,,uw,,', '.,__,.,,.,,dr_._', True],
#  [',____.,__.__,_.,', '._,..,._,.,.,.w.', ',_.._.,_,_._.__.', False],
#  ['__..,_._....,_,_', ',_.,__.,.,.,.w,,', '_,_,__,.,.,cr_,,', False],
#  ['.,,.._.,,,,,,._.', '_,__.,,,,,..uw,.', '_,...,,__.dr,.,.', True],
#  ['_.,__.___.__.,__', '__,,,,.,,,__,,uw', '.__,.,_,___,r___', True],
#  ['_._.._,__..,,,_,', '.__,,._____,..wu', ',,._._,,___._..,', False],
#  [',.._..____,,,,.,', '.,,.,.__,.,_,,,_', '.__,_..__,,._.,r', True],
#  [',,,,._,__._,.,_.', '.,._.___...wu,__', '__,,,,__.__,.r.,', True],
#  ['.,_._._,,,,_,,_.', ',.,,_,_.._.___,w', ',__,._____._,,.,', False],
#  [',.__,,___._,.__.', ',.,.,__..__,,wu.', ',_._.______,,__.', False],
#  ['__,.._.,.._..,,_', '_,.,..,,_.._,,.w', '.._,_,,dr.__._,.', True]]

# %%
pos_val_ratio = get_stats_and_ratio(val_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 6 | F2-uw 16 | F2-w 10 | F2-noop 14 |
# F3 cr:    F2-wu 6 | F2-uw 11 | F2-w 15 | F2-noop 13 |
# F3 r:    F2-wu 13 | F2-uw 11 | F2-w 12 | F2-noop 15 |
# F3 noop:    F2-wu 16 | F2-uw 19 | F2-w 15 | F2-noop 25 |
#
# Positive samples count: 91
# Total samples count: 217
# Positive class ratio: 0.41935483870967744

# %% [markdown]
# #### Send label arrays to device

# %%
y_train = torch.from_numpy(y_train.astype(float)).float().to(device)
y_val = torch.from_numpy(y_val.astype(float)).float().to(device)
y_test = torch.from_numpy(y_test.astype(float)).float().to(device)

# %% [markdown]
# #### Get data in normal format (same as CNN format)

# %%
x_train_normal = data.to_conv_format(x_train)
x_val_normal = data.to_conv_format(x_val)
x_test_normal = data.to_conv_format(x_test)
for i in range(len(x_train_normal)):
    x_train_normal[i] = x_train_normal[i].to(device)
    x_val_normal[i] = x_val_normal[i].to(device)
    x_test_normal[i] = x_test_normal[i].to(device)

# %%
x_train_normal[0].shape
# Out:
# torch.Size([900, 128])

# %% [markdown]
# #### Get data in convolutional format, send to device

# %%
x_train_cnn = data.to_conv_format(x_train)
x_val_cnn = data.to_conv_format(x_val)
x_test_cnn = data.to_conv_format(x_test)
for i in range(len(x_train_cnn)):
    x_train_cnn[i] = x_train_cnn[i].to(device)
    x_val_cnn[i] = x_val_cnn[i].to(device)
    x_test_cnn[i] = x_test_cnn[i].to(device)

# %%
x_train_cnn[0].shape
# Out:
# torch.Size([900, 128])

# %% [markdown]
# #### Get data in LSTM format, send to device

# %%
x_train_lstm = data.to_lstm_format(x_train, padding_left_size=2, padding_right_size=0)
x_val_lstm = data.to_lstm_format(x_val, padding_left_size=0, padding_right_size=2)
x_test_lstm = data.to_lstm_format(x_test, padding_left_size=0, padding_right_size=2)
for i in range(len(x_train_lstm)):
    x_train_lstm[i] = x_train_lstm[i].to(device)
    x_val_lstm[i] = x_val_lstm[i].to(device)
    x_test_lstm[i] = x_test_lstm[i].to(device)

# %%
x_train_lstm[0].shape
# Out:
# torch.Size([900, 18, 8])

# %% [markdown]
# ### Define training parameters

# %%
num_experiments = 20
epochs = 200
early_stopping_limit = 100

experiment_name = "1st_interval"

# %% [markdown]
# ### Define training procedure for each model

# %%
def train_models(constructor, x_train, x_val, x_test, weight_decay, *argv):
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    wrong_preds = []
    best_accuracy = 0
    
    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []

    for i in range(num_experiments):
        model = constructor(*argv)
        model.to(device)

        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), weight_decay=weight_decay)

        train_losses.append([])
        val_losses.append([])
        train_accs.append([])
        val_accs.append([])
        
        best_acc = 0

        early_stopping_cnt = 0

        for epoch in range(1, epochs + 1):
            train_loss, train_acc = train_epoch(model, x_train, y_train, criterion, optimizer, epoch, 10, verbose=False)
            val_loss, val_acc = eval_epoch(model, x_val, y_val, criterion, 'Validation', verbose=False)

            
            train_losses[-1].append(train_loss)
            val_losses[-1].append(val_loss)
            train_accs[-1].append(train_acc)
            val_accs[-1].append(val_acc)
            
            model_name = constructor.__name__[:constructor.__name__.find('_')]
            if val_acc > best_acc:
                best_acc = val_acc
                torch.save(model.state_dict(), f'./{model_name}_model_TEMP_' + experiment_name)    
                early_stopping_cnt = 0
            else:
                early_stopping_cnt += 1

            if early_stopping_cnt >= early_stopping_limit:
                break


        model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
    
        accuracies.append(get_accuracy_by_cases(model, x_test, y_test, test_original))
        precisions.append(get_precision_by_cases(model, x_test, y_test, test_original))
        recalls.append(get_recall_by_cases(model, x_test, y_test, test_original))
        f1_scores.append(get_f1_by_cases(precisions[-1], recalls[-1]))
        
        wrong_preds.append((f"Experimento {i}", get_wrong_predictions(model, x_test, y_test, test_original)))

        if accuracies[-1]['Overall'] > best_accuracy:
            torch.save(model.state_dict(), f'./best_{model_name}_model_' + experiment_name)    
            best_accuracy = accuracies[-1]['Overall']

        print(i + 1, "/", num_experiments, "models trained | Current model test accuracy:", accuracies[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test precision:", precisions[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test recall:", recalls[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test f1:", f1_scores[-1]['Overall'])


    
    return accuracies, precisions, recalls, f1_scores, wrong_preds, [train_losses, val_losses, train_accs, val_accs], model
    #return accuracies, precisions, wrong_preds, [train_losses, val_losses, train_accs, val_accs]

# %% [markdown]
# # Train models

# %%
# %%time
cnn_accuracies, cnn_precisions, cnn_recall, cnn_f1, cnn_wrong_preds, cnn_epoch_stats, model = train_models(
    CNN_Model, x_train_cnn, x_val_cnn, x_test_cnn, 0.0001, data, 64, 128, 4, -1, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_20124\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.911697247706422
# 1 / 20 models trained | Current model test precision: 0.8457943925233645
# 1 / 20 models trained | Current model test recall: 0.9705093833780161
# 1 / 20 models trained | Current model test f1: 0.9038701622971286
# 2 / 20 models trained | Current model test accuracy: 0.9139908256880734
# 2 / 20 models trained | Current model test precision: 0.8514150943396226
# 2 / 20 models trained | Current model test recall: 0.967828418230563
# 2 / 20 models trained | Current model test f1: 0.9058971141781681
# 3 / 20 models trained | Current model test accuracy: 0.8956422018348624
# 3 / 20 models trained | Current model test precision: 0.8671875
# 3 / 20 models trained | Current model test recall: 0.8927613941018767
# 3 / 20 models trained | Current model test f1: 0.8797886393659181
# 4 / 20 models trained | Current model test accuracy: 0.9025229357798165
# 4 / 20 models trained | Current model test precision: 0.8711340206185567
# 4 / 20 models trained | Current model test recall: 0.9061662198391421
# 4 / 20 models trained | Current model test f1: 0.8883048620236531
# 5 / 20 models trained | Current model test accuracy: 0.9243119266055045
# 5 / 20 models trained | Current model test precision: 0.8611764705882353
# 5 / 20 models trained | Current model test recall: 0.9812332439678284
# 5 / 20 models trained | Current model test f1: 0.9172932330827068
# 6 / 20 models trained | Current model test accuracy: 0.9334862385321101
# 6 / 20 models trained | Current model test precision: 0.8671328671328671
# 6 / 20 models trained | Current model test recall: 0.9973190348525469
# 6 / 20 models trained | Current model test f1: 0.9276807980049876
# 7 / 20 models trained | Current model test accuracy: 0.9288990825688074
# 7 / 20 models trained | Current model test precision: 0.859122401847575
# 7 / 20 models trained | Current model test recall: 0.9973190348525469
# 7 / 20 models trained | Current model test f1: 0.923076923076923
# 8 / 20 models trained | Current model test accuracy: 0.9323394495412844
# 8 / 20 models trained | Current model test precision: 0.866822429906542
# 8 / 20 models trained | Current model test recall: 0.9946380697050938
# 8 / 20 models trained | Current model test f1: 0.9263420724094882
# 9 / 20 models trained | Current model test accuracy: 0.9151376146788991
# 9 / 20 models trained | Current model test precision: 0.8691358024691358
# 9 / 20 models trained | Current model test recall: 0.9436997319034852
# 9 / 20 models trained | Current model test f1: 0.9048843187660668
# 10 / 20 models trained | Current model test accuracy: 0.9380733944954128
# 10 / 20 models trained | Current model test precision: 0.8788598574821853
# 10 / 20 models trained | Current model test recall: 0.9919571045576407
# 10 / 20 models trained | Current model test f1: 0.9319899244332495
# 11 / 20 models trained | Current model test accuracy: 0.9323394495412844
# 11 / 20 models trained | Current model test precision: 0.8685446009389671
# 11 / 20 models trained | Current model test recall: 0.9919571045576407
# 11 / 20 models trained | Current model test f1: 0.9261576971214016
# 12 / 20 models trained | Current model test accuracy: 0.930045871559633
# 12 / 20 models trained | Current model test precision: 0.8696682464454977
# 12 / 20 models trained | Current model test recall: 0.9839142091152815
# 12 / 20 models trained | Current model test f1: 0.9232704402515723
# 13 / 20 models trained | Current model test accuracy: 0.9357798165137615
# 13 / 20 models trained | Current model test precision: 0.8747044917257684
# 13 / 20 models trained | Current model test recall: 0.9919571045576407
# 13 / 20 models trained | Current model test f1: 0.9296482412060302
# 14 / 20 models trained | Current model test accuracy: 0.8979357798165137
# 14 / 20 models trained | Current model test precision: 0.8796791443850267
# 14 / 20 models trained | Current model test recall: 0.8820375335120644
# 14 / 20 models trained | Current model test f1: 0.8808567603748326
# 15 / 20 models trained | Current model test accuracy: 0.8922018348623854
# 15 / 20 models trained | Current model test precision: 0.8680738786279684
# 15 / 20 models trained | Current model test recall: 0.8820375335120644
# 15 / 20 models trained | Current model test f1: 0.875
# 16 / 20 models trained | Current model test accuracy: 0.9002293577981652
# 16 / 20 models trained | Current model test precision: 0.8783068783068783
# 16 / 20 models trained | Current model test recall: 0.8900804289544236
# 16 / 20 models trained | Current model test f1: 0.8841544607190414
# 17 / 20 models trained | Current model test accuracy: 0.9288990825688074
# 17 / 20 models trained | Current model test precision: 0.8641686182669789
# 17 / 20 models trained | Current model test recall: 0.9892761394101877
# 17 / 20 models trained | Current model test f1: 0.9225
# 18 / 20 models trained | Current model test accuracy: 0.9334862385321101
# 18 / 20 models trained | Current model test precision: 0.8654292343387471
# 18 / 20 models trained | Current model test recall: 1.0
# 18 / 20 models trained | Current model test f1: 0.9278606965174129
# 19 / 20 models trained | Current model test accuracy: 0.9380733944954128
# 19 / 20 models trained | Current model test precision: 0.8977556109725686
# 19 / 20 models trained | Current model test recall: 0.9651474530831099
# 19 / 20 models trained | Current model test f1: 0.9302325581395349
# 20 / 20 models trained | Current model test accuracy: 0.9048165137614679
# 20 / 20 models trained | Current model test precision: 0.868020304568528
# 20 / 20 models trained | Current model test recall: 0.9168900804289544
# 20 / 20 models trained | Current model test f1: 0.8917861799217731
# CPU times: total: 2h 43min 43s
# Wall time: 41min 31s

# %%
# %%time
lstm_accuracies, lstm_precision, lstm_recall, lstm_f1, lstm_wrong_preds, lstm_epoch_stats, model = train_models(LSTM_Model, x_train_lstm, x_val_lstm, x_test_lstm, 0.0001, data, 16, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_20124\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.9873853211009175
# 1 / 20 models trained | Current model test precision: 0.9972527472527473
# 1 / 20 models trained | Current model test recall: 0.9731903485254692
# 1 / 20 models trained | Current model test f1: 0.9850746268656717
# 2 / 20 models trained | Current model test accuracy: 0.9323394495412844
# 2 / 20 models trained | Current model test precision: 0.8651162790697674
# 2 / 20 models trained | Current model test recall: 0.9973190348525469
# 2 / 20 models trained | Current model test f1: 0.9265255292652552
# 3 / 20 models trained | Current model test accuracy: 0.9323394495412844
# 3 / 20 models trained | Current model test precision: 0.8634259259259259
# 3 / 20 models trained | Current model test recall: 1.0
# 3 / 20 models trained | Current model test f1: 0.9267080745341615
# 4 / 20 models trained | Current model test accuracy: 0.9323394495412844
# 4 / 20 models trained | Current model test precision: 0.8651162790697674
# 4 / 20 models trained | Current model test recall: 0.9973190348525469
# 4 / 20 models trained | Current model test f1: 0.9265255292652552
# 5 / 20 models trained | Current model test accuracy: 0.8681192660550459
# 5 / 20 models trained | Current model test precision: 0.764344262295082
# 5 / 20 models trained | Current model test recall: 1.0
# 5 / 20 models trained | Current model test f1: 0.8664343786295006
# 6 / 20 models trained | Current model test accuracy: 0.7740825688073395
# 6 / 20 models trained | Current model test precision: 0.6543859649122807
# 6 / 20 models trained | Current model test recall: 1.0
# 6 / 20 models trained | Current model test f1: 0.7910922587486745
# 7 / 20 models trained | Current model test accuracy: 0.9311926605504587
# 7 / 20 models trained | Current model test precision: 0.8648018648018648
# 7 / 20 models trained | Current model test recall: 0.9946380697050938
# 7 / 20 models trained | Current model test f1: 0.9251870324189527
# 8 / 20 models trained | Current model test accuracy: 0.930045871559633
# 8 / 20 models trained | Current model test precision: 0.8594470046082949
# 8 / 20 models trained | Current model test recall: 1.0
# 8 / 20 models trained | Current model test f1: 0.9244114002478315
# 9 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 9 / 20 models trained | Current model test precision: 0.42775229357798167
# 9 / 20 models trained | Current model test recall: 1.0
# 9 / 20 models trained | Current model test f1: 0.5991967871485944
# 10 / 20 models trained | Current model test accuracy: 0.9610091743119266
# 10 / 20 models trained | Current model test precision: 0.9312977099236641
# 10 / 20 models trained | Current model test recall: 0.9812332439678284
# 10 / 20 models trained | Current model test f1: 0.9556135770234987
# 11 / 20 models trained | Current model test accuracy: 0.9323394495412844
# 11 / 20 models trained | Current model test precision: 0.8634259259259259
# 11 / 20 models trained | Current model test recall: 1.0
# 11 / 20 models trained | Current model test f1: 0.9267080745341615
# 12 / 20 models trained | Current model test accuracy: 0.8279816513761468
# 12 / 20 models trained | Current model test precision: 0.8539682539682539
# 12 / 20 models trained | Current model test recall: 0.7211796246648794
# 12 / 20 models trained | Current model test f1: 0.7819767441860466
# 13 / 20 models trained | Current model test accuracy: 0.48509174311926606
# 13 / 20 models trained | Current model test precision: 0.4537712895377129
# 13 / 20 models trained | Current model test recall: 1.0
# 13 / 20 models trained | Current model test f1: 0.6242677824267783
# 14 / 20 models trained | Current model test accuracy: 0.9208715596330275
# 14 / 20 models trained | Current model test precision: 0.861904761904762
# 14 / 20 models trained | Current model test recall: 0.9705093833780161
# 14 / 20 models trained | Current model test f1: 0.9129886506935687
# 15 / 20 models trained | Current model test accuracy: 0.9805045871559633
# 15 / 20 models trained | Current model test precision: 0.961139896373057
# 15 / 20 models trained | Current model test recall: 0.9946380697050938
# 15 / 20 models trained | Current model test f1: 0.9776021080368906
# 16 / 20 models trained | Current model test accuracy: 0.9334862385321101
# 16 / 20 models trained | Current model test precision: 0.8654292343387471
# 16 / 20 models trained | Current model test recall: 1.0
# 16 / 20 models trained | Current model test f1: 0.9278606965174129
# 17 / 20 models trained | Current model test accuracy: 0.5665137614678899
# 17 / 20 models trained | Current model test precision: 0.4966711051930759
# 17 / 20 models trained | Current model test recall: 1.0
# 17 / 20 models trained | Current model test f1: 0.6637010676156584
# 18 / 20 models trained | Current model test accuracy: 0.9380733944954128
# 18 / 20 models trained | Current model test precision: 0.8735362997658079
# 18 / 20 models trained | Current model test recall: 1.0
# 18 / 20 models trained | Current model test f1: 0.9325
# 19 / 20 models trained | Current model test accuracy: 0.9311926605504587
# 19 / 20 models trained | Current model test precision: 0.8614318706697459
# 19 / 20 models trained | Current model test recall: 1.0
# 19 / 20 models trained | Current model test f1: 0.9255583126550868
# 20 / 20 models trained | Current model test accuracy: 0.9759174311926605
# 20 / 20 models trained | Current model test precision: 0.9731182795698925
# 20 / 20 models trained | Current model test recall: 0.9705093833780161
# 20 / 20 models trained | Current model test f1: 0.9718120805369127
# CPU times: total: 1h 34min 18s
# Wall time: 16h 19min 35s

# %%
# %%time
deepset_accuracies, deepset_procision, deepset_recall, deepset_f1, deepset_wrong_preds, deepset_epoch_stats, model = train_models(DEEPSET_Model, x_train_normal, x_val_normal, x_test_normal, 0.005, data, 128, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_20124\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.5527522935779816
# 1 / 20 models trained | Current model test precision: 0.36923076923076925
# 1 / 20 models trained | Current model test recall: 0.064343163538874
# 1 / 20 models trained | Current model test f1: 0.1095890410958904
# 2 / 20 models trained | Current model test accuracy: 0.518348623853211
# 2 / 20 models trained | Current model test precision: 0.3657142857142857
# 2 / 20 models trained | Current model test recall: 0.17158176943699732
# 2 / 20 models trained | Current model test f1: 0.2335766423357664
# 3 / 20 models trained | Current model test accuracy: 0.5653669724770642
# 3 / 20 models trained | Current model test precision: 0.42857142857142855
# 3 / 20 models trained | Current model test recall: 0.04825737265415549
# 3 / 20 models trained | Current model test f1: 0.08674698795180723
# 4 / 20 models trained | Current model test accuracy: 0.573394495412844
# 4 / 20 models trained | Current model test precision: 0.5333333333333333
# 4 / 20 models trained | Current model test recall: 0.021447721179624665
# 4 / 20 models trained | Current model test f1: 0.041237113402061855
# 5 / 20 models trained | Current model test accuracy: 0.5688073394495413
# 5 / 20 models trained | Current model test precision: 0.4845360824742268
# 5 / 20 models trained | Current model test recall: 0.1260053619302949
# 5 / 20 models trained | Current model test f1: 0.19999999999999998
# 6 / 20 models trained | Current model test accuracy: 0.5470183486238532
# 6 / 20 models trained | Current model test precision: 0.36904761904761907
# 6 / 20 models trained | Current model test recall: 0.08310991957104558
# 6 / 20 models trained | Current model test f1: 0.13566739606126915
# 7 / 20 models trained | Current model test accuracy: 0.573394495412844
# 7 / 20 models trained | Current model test precision: 0.5714285714285714
# 7 / 20 models trained | Current model test recall: 0.010723860589812333
# 7 / 20 models trained | Current model test f1: 0.021052631578947368
# 8 / 20 models trained | Current model test accuracy: 0.5653669724770642
# 8 / 20 models trained | Current model test precision: 0.2
# 8 / 20 models trained | Current model test recall: 0.005361930294906166
# 8 / 20 models trained | Current model test f1: 0.010443864229765013
# 9 / 20 models trained | Current model test accuracy: 0.5561926605504587
# 9 / 20 models trained | Current model test precision: 0.3333333333333333
# 9 / 20 models trained | Current model test recall: 0.03753351206434316
# 9 / 20 models trained | Current model test f1: 0.06746987951807229
# 10 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 10 / 20 models trained | Current model test precision: 0.5
# 10 / 20 models trained | Current model test recall: 0.024128686327077747
# 10 / 20 models trained | Current model test f1: 0.04603580562659846
# 11 / 20 models trained | Current model test accuracy: 0.569954128440367
# 11 / 20 models trained | Current model test precision: 0.47368421052631576
# 11 / 20 models trained | Current model test recall: 0.04825737265415549
# 11 / 20 models trained | Current model test f1: 0.08759124087591241
# 12 / 20 models trained | Current model test accuracy: 0.5619266055045872
# 12 / 20 models trained | Current model test precision: 0.3902439024390244
# 12 / 20 models trained | Current model test recall: 0.04289544235924933
# 12 / 20 models trained | Current model test f1: 0.07729468599033816
# 13 / 20 models trained | Current model test accuracy: 0.5756880733944955
# 13 / 20 models trained | Current model test precision: 0.6153846153846154
# 13 / 20 models trained | Current model test recall: 0.021447721179624665
# 13 / 20 models trained | Current model test f1: 0.04145077720207254
# 14 / 20 models trained | Current model test accuracy: 0.5676605504587156
# 14 / 20 models trained | Current model test precision: 0.3888888888888889
# 14 / 20 models trained | Current model test recall: 0.01876675603217158
# 14 / 20 models trained | Current model test f1: 0.03580562659846547
# 15 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 15 / 20 models trained | Current model test precision: 0.5
# 15 / 20 models trained | Current model test recall: 0.00804289544235925
# 15 / 20 models trained | Current model test f1: 0.0158311345646438
# 16 / 20 models trained | Current model test accuracy: 0.5538990825688074
# 16 / 20 models trained | Current model test precision: 0.41836734693877553
# 16 / 20 models trained | Current model test recall: 0.10991957104557641
# 16 / 20 models trained | Current model test f1: 0.17409766454352443
# 17 / 20 models trained | Current model test accuracy: 0.5458715596330275
# 17 / 20 models trained | Current model test precision: 0.4581818181818182
# 17 / 20 models trained | Current model test recall: 0.3378016085790885
# 17 / 20 models trained | Current model test f1: 0.3888888888888889
# 18 / 20 models trained | Current model test accuracy: 0.5642201834862385
# 18 / 20 models trained | Current model test precision: 0.425531914893617
# 18 / 20 models trained | Current model test recall: 0.05361930294906166
# 18 / 20 models trained | Current model test f1: 0.09523809523809525
# 19 / 20 models trained | Current model test accuracy: 0.5711009174311926
# 19 / 20 models trained | Current model test precision: 0.0
# 19 / 20 models trained | Current model test recall: 0.0
# 19 / 20 models trained | Current model test f1: 0.0
# 20 / 20 models trained | Current model test accuracy: 0.5665137614678899
# 20 / 20 models trained | Current model test precision: 0.2727272727272727
# 20 / 20 models trained | Current model test recall: 0.00804289544235925
# 20 / 20 models trained | Current model test f1: 0.015625
# CPU times: total: 1h 4min 40s
# Wall time: 16min 14s

# %%
# %%time
deepsetv2_accuracies, deepsetv2_procision, deepsetv2_recall, deepsetv2_f1, deepsetv2_wrong_preds, deepsetv2_epoch_stats, model = train_models(DEEPSETV2_Model, x_train_normal, x_val_normal, x_test_normal, 0.0001, data, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_20124\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 1 / 20 models trained | Current model test precision: 0.42775229357798167
# 1 / 20 models trained | Current model test recall: 1.0
# 1 / 20 models trained | Current model test f1: 0.5991967871485944
# 2 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 2 / 20 models trained | Current model test precision: 0.42775229357798167
# 2 / 20 models trained | Current model test recall: 1.0
# 2 / 20 models trained | Current model test f1: 0.5991967871485944
# 3 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 3 / 20 models trained | Current model test precision: 0.42775229357798167
# 3 / 20 models trained | Current model test recall: 1.0
# 3 / 20 models trained | Current model test f1: 0.5991967871485944
# 4 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 4 / 20 models trained | Current model test precision: 0.42775229357798167
# 4 / 20 models trained | Current model test recall: 1.0
# 4 / 20 models trained | Current model test f1: 0.5991967871485944
# 5 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 5 / 20 models trained | Current model test precision: 0.42775229357798167
# 5 / 20 models trained | Current model test recall: 1.0
# 5 / 20 models trained | Current model test f1: 0.5991967871485944
# 6 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 6 / 20 models trained | Current model test precision: 0.42775229357798167
# 6 / 20 models trained | Current model test recall: 1.0
# 6 / 20 models trained | Current model test f1: 0.5991967871485944
# 7 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 7 / 20 models trained | Current model test precision: 0.42775229357798167
# 7 / 20 models trained | Current model test recall: 1.0
# 7 / 20 models trained | Current model test f1: 0.5991967871485944
# 8 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 8 / 20 models trained | Current model test precision: 0.42775229357798167
# 8 / 20 models trained | Current model test recall: 1.0
# 8 / 20 models trained | Current model test f1: 0.5991967871485944
# 9 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 9 / 20 models trained | Current model test precision: 0.42775229357798167
# 9 / 20 models trained | Current model test recall: 1.0
# 9 / 20 models trained | Current model test f1: 0.5991967871485944
# 10 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 10 / 20 models trained | Current model test precision: 0.42775229357798167
# 10 / 20 models trained | Current model test recall: 1.0
# 10 / 20 models trained | Current model test f1: 0.5991967871485944
# 11 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 11 / 20 models trained | Current model test precision: 0.42775229357798167
# 11 / 20 models trained | Current model test recall: 1.0
# 11 / 20 models trained | Current model test f1: 0.5991967871485944
# 12 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 12 / 20 models trained | Current model test precision: 0.42775229357798167
# 12 / 20 models trained | Current model test recall: 1.0
# 12 / 20 models trained | Current model test f1: 0.5991967871485944
# 13 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 13 / 20 models trained | Current model test precision: 0.42775229357798167
# 13 / 20 models trained | Current model test recall: 1.0
# 13 / 20 models trained | Current model test f1: 0.5991967871485944
# 14 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 14 / 20 models trained | Current model test precision: 0.42775229357798167
# 14 / 20 models trained | Current model test recall: 1.0
# 14 / 20 models trained | Current model test f1: 0.5991967871485944
# 15 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 15 / 20 models trained | Current model test precision: 0.42775229357798167
# 15 / 20 models trained | Current model test recall: 1.0
# 15 / 20 models trained | Current model test f1: 0.5991967871485944
# 16 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 16 / 20 models trained | Current model test precision: 0.42775229357798167
# 16 / 20 models trained | Current model test recall: 1.0
# 16 / 20 models trained | Current model test f1: 0.5991967871485944
# 17 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 17 / 20 models trained | Current model test precision: 0.42775229357798167
# 17 / 20 models trained | Current model test recall: 1.0
# 17 / 20 models trained | Current model test f1: 0.5991967871485944
# 18 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 18 / 20 models trained | Current model test precision: 0.42775229357798167
# 18 / 20 models trained | Current model test recall: 1.0
# 18 / 20 models trained | Current model test f1: 0.5991967871485944
# 19 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 19 / 20 models trained | Current model test precision: 0.42775229357798167
# 19 / 20 models trained | Current model test recall: 1.0
# 19 / 20 models trained | Current model test f1: 0.5991967871485944
# 20 / 20 models trained | Current model test accuracy: 0.42775229357798167
# 20 / 20 models trained | Current model test precision: 0.42775229357798167
# 20 / 20 models trained | Current model test recall: 1.0
# 20 / 20 models trained | Current model test f1: 0.5991967871485944
# CPU times: total: 27min 24s
# Wall time: 7min 13s

# %%
# %%time
feedforward_accuracies, feedforward_precision, feedforward_recall, feedforward_f1, feedforward_wrong_preds, feedforward_epoch_stats, model = train_models(FEEDFORWARD_Model, x_train_normal, x_val_normal, x_test_normal, 0.0001, data, 128, 32, 8, 'keras')
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_20124\1162859194.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_' + experiment_name))
# 1 / 20 models trained | Current model test accuracy: 0.5676605504587156
# 1 / 20 models trained | Current model test precision: 0.3333333333333333
# 1 / 20 models trained | Current model test recall: 0.010723860589812333
# 1 / 20 models trained | Current model test f1: 0.02077922077922078
# 2 / 20 models trained | Current model test accuracy: 0.555045871559633
# 2 / 20 models trained | Current model test precision: 0.3728813559322034
# 2 / 20 models trained | Current model test recall: 0.058981233243967826
# 2 / 20 models trained | Current model test f1: 0.10185185185185186
# 3 / 20 models trained | Current model test accuracy: 0.5240825688073395
# 3 / 20 models trained | Current model test precision: 0.36875
# 3 / 20 models trained | Current model test recall: 0.1581769436997319
# 3 / 20 models trained | Current model test f1: 0.22138836772983114
# 4 / 20 models trained | Current model test accuracy: 0.5642201834862385
# 4 / 20 models trained | Current model test precision: 0.41025641025641024
# 4 / 20 models trained | Current model test recall: 0.04289544235924933
# 4 / 20 models trained | Current model test f1: 0.07766990291262137
# 5 / 20 models trained | Current model test accuracy: 0.5607798165137615
# 5 / 20 models trained | Current model test precision: 0.4166666666666667
# 5 / 20 models trained | Current model test recall: 0.06702412868632708
# 5 / 20 models trained | Current model test f1: 0.11547344110854504
# 6 / 20 models trained | Current model test accuracy: 0.5688073394495413
# 6 / 20 models trained | Current model test precision: 0.42105263157894735
# 6 / 20 models trained | Current model test recall: 0.021447721179624665
# 6 / 20 models trained | Current model test f1: 0.04081632653061224
# 7 / 20 models trained | Current model test accuracy: 0.5435779816513762
# 7 / 20 models trained | Current model test precision: 0.37373737373737376
# 7 / 20 models trained | Current model test recall: 0.09919571045576407
# 7 / 20 models trained | Current model test f1: 0.15677966101694915
# 8 / 20 models trained | Current model test accuracy: 0.5642201834862385
# 8 / 20 models trained | Current model test precision: 0.42857142857142855
# 8 / 20 models trained | Current model test recall: 0.05630026809651475
# 8 / 20 models trained | Current model test f1: 0.0995260663507109
# 9 / 20 models trained | Current model test accuracy: 0.5688073394495413
# 9 / 20 models trained | Current model test precision: 0.2857142857142857
# 9 / 20 models trained | Current model test recall: 0.005361930294906166
# 9 / 20 models trained | Current model test f1: 0.010526315789473684
# 10 / 20 models trained | Current model test accuracy: 0.5665137614678899
# 10 / 20 models trained | Current model test precision: 0.3076923076923077
# 10 / 20 models trained | Current model test recall: 0.010723860589812333
# 10 / 20 models trained | Current model test f1: 0.02072538860103627
# 11 / 20 models trained | Current model test accuracy: 0.5676605504587156
# 11 / 20 models trained | Current model test precision: 0.4230769230769231
# 11 / 20 models trained | Current model test recall: 0.029490616621983913
# 11 / 20 models trained | Current model test f1: 0.05513784461152881
# 12 / 20 models trained | Current model test accuracy: 0.5412844036697247
# 12 / 20 models trained | Current model test precision: 0.4228571428571429
# 12 / 20 models trained | Current model test recall: 0.19839142091152814
# 12 / 20 models trained | Current model test f1: 0.27007299270072993
# 13 / 20 models trained | Current model test accuracy: 0.555045871559633
# 13 / 20 models trained | Current model test precision: 0.39436619718309857
# 13 / 20 models trained | Current model test recall: 0.07506702412868632
# 13 / 20 models trained | Current model test f1: 0.12612612612612611
# 14 / 20 models trained | Current model test accuracy: 0.5252293577981652
# 14 / 20 models trained | Current model test precision: 0.43234323432343236
# 14 / 20 models trained | Current model test recall: 0.3512064343163539
# 14 / 20 models trained | Current model test f1: 0.3875739644970414
# 15 / 20 models trained | Current model test accuracy: 0.5722477064220184
# 15 / 20 models trained | Current model test precision: 0.5
# 15 / 20 models trained | Current model test recall: 0.002680965147453083
# 15 / 20 models trained | Current model test f1: 0.005333333333333333
# 16 / 20 models trained | Current model test accuracy: 0.573394495412844
# 16 / 20 models trained | Current model test precision: 0.5714285714285714
# 16 / 20 models trained | Current model test recall: 0.010723860589812333
# 16 / 20 models trained | Current model test f1: 0.021052631578947368
# 17 / 20 models trained | Current model test accuracy: 0.5676605504587156
# 17 / 20 models trained | Current model test precision: 0.4
# 17 / 20 models trained | Current model test recall: 0.021447721179624665
# 17 / 20 models trained | Current model test f1: 0.04071246819338423
# 18 / 20 models trained | Current model test accuracy: 0.555045871559633
# 18 / 20 models trained | Current model test precision: 0.4157303370786517
# 18 / 20 models trained | Current model test recall: 0.09919571045576407
# 18 / 20 models trained | Current model test f1: 0.16017316017316016
# 19 / 20 models trained | Current model test accuracy: 0.5711009174311926
# 19 / 20 models trained | Current model test precision: 0.4444444444444444
# 19 / 20 models trained | Current model test recall: 0.010723860589812333
# 19 / 20 models trained | Current model test f1: 0.020942408376963352
# 20 / 20 models trained | Current model test accuracy: 0.5470183486238532
# 20 / 20 models trained | Current model test precision: 0.417910447761194
# 20 / 20 models trained | Current model test recall: 0.15013404825737264
# 20 / 20 models trained | Current model test f1: 0.22090729783037474
# CPU times: total: 1h 1min 47s
# Wall time: 15min 32s

# %% [markdown]
# # Evaluation

# %%
import pandas as pd
# Lista de modelos y nombres
model_names = ['CNN', 'LSTM', 'DeepSet', 'DeepSetV2', 'Feedforward']
all_accuracies = [cnn_accuracies, lstm_accuracies, deepset_accuracies, deepsetv2_accuracies, feedforward_accuracies]
all_precisions = [cnn_precisions, lstm_precision, deepset_procision, deepsetv2_procision, feedforward_precision]
all_recalls = [cnn_recall, lstm_recall, deepset_recall, deepsetv2_recall, feedforward_recall]
all_f1_scores = [cnn_f1, lstm_f1, deepset_f1, deepsetv2_f1, feedforward_f1]

imprimirMetricas(model_names, all_accuracies, all_precisions, all_recalls, all_f1_scores)
# Out:
#         Modelo  Accuracy  Precision    Recall  F1-score
# 0          CNN  0.938073   0.878860  0.991957  0.931990
# 1         LSTM  0.987385   0.997253  0.973190  0.985075
# 2      DeepSet  0.575688   0.615385  0.021448  0.041451
# 3    DeepSetV2  0.427752   0.427752  1.000000  0.599197
# 4  Feedforward  0.573394   0.571429  0.010724  0.021053

# %% [markdown]
# ### Get best 50% performing models

# %%
top_half = int(num_experiments / 2)
best_cnn_accs = filter_top_k_accuracies(cnn_accuracies, top_half)
best_lstm_accs = filter_top_k_accuracies(lstm_accuracies, top_half)
best_deepset_accs = filter_top_k_accuracies(deepset_accuracies, top_half)
best_deepsetv2_accs = filter_top_k_accuracies(deepsetv2_accuracies, top_half)
best_feedforward_accs = filter_top_k_accuracies(feedforward_accuracies, top_half)

# %% [markdown]
# ## Accuracy breakdown by cases for all the models

# %%
all_accuracies = [cnn_accuracies, lstm_accuracies, deepset_accuracies, deepsetv2_accuracies, feedforward_accuracies]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']

# %%
get_stats_df(all_accuracies, model_names, test_original)
# Out:
#                        Overall cr_noop   cr_uw    cr_w   cr_wu dr_noop
# CNN                      91.9%   99.9%  100.0%  100.0%  100.0%   97.2%  \
# LSTM                     85.8%   86.6%   87.3%   86.6%   87.6%   99.3%
# DeepSet(like in paper)   56.2%   93.9%   93.3%   92.1%   94.3%    5.9%
# DeepSet(sum at start)    42.8%    0.0%    0.0%    0.0%    0.0%  100.0%
# Feedforward              55.8%   92.5%   92.8%   89.4%   92.8%    5.8%
# Sample count               872      59      53      49      58      58
#
#                          dr_uw    dr_w  dr_wu noop_noop noop_uw noop_w
# CNN                      95.8%   97.1%   9.1%     98.8%   99.4%  99.4%  \
# LSTM                     98.4%   99.2%  16.8%     82.1%   82.6%  81.8%
# DeepSet(like in paper)    6.5%    7.2%  93.4%     93.7%   94.2%  93.3%
# DeepSet(sum at start)   100.0%  100.0%   0.0%      0.0%    0.0%   0.0%
# Feedforward               8.9%    8.4%  90.2%     92.7%   92.2%  92.5%
# Sample count                48      54     58        56      53     57
#
#                        noop_wu  r_noop    r_uw     r_w    r_wu
# CNN                     100.0%   95.6%   95.3%   97.1%   91.3%
# LSTM                     82.6%   97.3%   97.5%   97.9%   96.3%
# DeepSet(like in paper)   93.9%    5.0%    5.6%    6.2%    7.2%
# DeepSet(sum at start)     0.0%  100.0%  100.0%  100.0%  100.0%
# Feedforward              92.5%    6.4%    7.1%    7.3%    8.3%
# Sample count                56      57      53      52      51

# %% [markdown]
# ## Accuracy breakdown by cases for top 50% of models

# %%
best_accuracies = [best_cnn_accs, best_lstm_accs, best_deepset_accs, best_deepsetv2_accs, best_feedforward_accs]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']
collapsed_cases = ['dr', 'r', 'cr', 'noop']

# %%
get_stats_df(best_accuracies, model_names, test_original, collapsed_cases)
# Out:
#                        Overall   f3_cr  f3_dr f3_noop    f3_r
# CNN                      93.3%  100.0%  75.1%   99.8%   98.3%
# LSTM                     95.1%  100.0%  81.4%  100.0%   98.9%
# DeepSet(like in paper)   57.1%   97.6%  28.2%   97.8%    2.7%
# DeepSet(sum at start)    42.8%    0.0%  73.4%    0.0%  100.0%
# Feedforward              56.9%   97.9%  27.2%   98.8%    1.4%
# Sample count               872     219    218     222     213

# %%
best_accuracies = [best_cnn_accs, best_lstm_accs, best_deepset_accs, best_deepsetv2_accs, best_feedforward_accs]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']
collapsed_cases = ['r', 'cr', 'noop']

# %%
get_stats_df(best_accuracies, model_names, test_original, collapsed_cases)
# Out:
#                        Overall dr_noop   dr_uw    dr_w  dr_wu   f3_cr f3_noop
# CNN                      93.3%  100.0%  100.0%  100.0%   6.6%  100.0%   99.8%  \
# LSTM                     95.1%  100.0%   98.3%  100.0%  31.6%  100.0%  100.0%
# DeepSet(like in paper)   57.1%    2.6%    2.9%    3.9%  97.4%   97.6%   97.8%
# DeepSet(sum at start)    42.8%  100.0%  100.0%  100.0%   0.0%    0.0%    0.0%
# Feedforward              56.9%    1.6%    2.3%    2.2%  96.7%   97.9%   98.8%
# Sample count               872      58      48      54     58     219     222
#
#                           f3_r
# CNN                      98.3%
# LSTM                     98.9%
# DeepSet(like in paper)    2.7%
# DeepSet(sum at start)   100.0%
# Feedforward               1.4%
# Sample count               213

# %% [markdown]
# ## Accuracies per CNN model

# %%
get_stats_per_model(cnn_accuracies, ['CNN #' + str(i) for i in range(len(cnn_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#              Overall   f3_cr  f3_dr f3_noop    f3_r
# CNN #0         91.2%  100.0%  73.9%   95.9%   94.8%
# CNN #1         91.4%  100.0%  73.9%   96.4%   95.3%
# CNN #2         89.6%  100.0%  70.2%  100.0%   87.8%
# CNN #3         90.3%  100.0%  69.7%  100.0%   91.1%
# CNN #4         92.4%   99.5%  73.9%   98.2%   98.1%
# CNN #5         93.3%  100.0%  73.9%  100.0%   99.5%
# CNN #6         92.9%  100.0%  73.9%   98.2%   99.5%
# CNN #7         93.2%  100.0%  74.3%   99.5%   99.1%
# CNN #8         91.5%  100.0%  73.4%  100.0%   92.5%
# CNN #9         93.8%  100.0%  76.6%  100.0%   98.6%
# CNN #10        93.2%  100.0%  74.3%  100.0%   98.6%
# CNN #11        93.0%  100.0%  74.8%  100.0%   97.2%
# CNN #12        93.6%  100.0%  75.7%  100.0%   98.6%
# CNN #13        89.8%  100.0%  71.1%  100.0%   87.8%
# CNN #14        89.2%  100.0%  68.8%  100.0%   87.8%
# CNN #15        90.0%  100.0%  70.6%  100.0%   89.2%
# CNN #16        92.9%  100.0%  73.4%  100.0%   98.1%
# CNN #17        93.3%  100.0%  73.4%  100.0%  100.0%
# CNN #18        93.8%  100.0%  81.2%  100.0%   93.9%
# CNN #19        90.5%  100.0%  72.0%  100.0%   89.7%
# Sample count     872     219    218     222     213

# %% [markdown]
# ## Accuracies per LSTM model

# %%
get_stats_per_model(best_lstm_accs, ['LSTM #' + str(i) for i in range(len(best_lstm_accs))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#              Overall   f3_cr  f3_dr f3_noop    f3_r
# LSTM #0        98.7%  100.0%  99.1%  100.0%   95.8%
# LSTM #1        98.1%  100.0%  93.1%  100.0%   99.1%
# LSTM #2        97.6%  100.0%  92.2%  100.0%   98.1%
# LSTM #3        96.1%  100.0%  87.6%  100.0%   96.7%
# LSTM #4        93.8%  100.0%  75.2%  100.0%  100.0%
# LSTM #5        93.3%  100.0%  73.4%  100.0%  100.0%
# LSTM #6        93.2%  100.0%  73.4%  100.0%   99.5%
# LSTM #7        93.2%   99.5%  73.4%  100.0%  100.0%
# LSTM #8        93.2%  100.0%  73.4%  100.0%   99.5%
# LSTM #9        93.2%  100.0%  73.4%   99.5%  100.0%
# Sample count     872     219    218     222     213

# %% [markdown]
# ## Accuracies per DeepSets V1 model

# %%
get_stats_per_model(best_deepset_accs, ['DeepSet(like in paper) #' + str(i) for i in range(len(best_deepset_accs))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                           Overall   f3_cr  f3_dr f3_noop   f3_r
# DeepSet(like in paper) #0   57.6%   98.2%  28.4%   99.5%   1.9%
# DeepSet(like in paper) #1   57.3%   98.6%  28.0%   99.1%   1.4%
# DeepSet(like in paper) #2   57.3%   99.1%  28.0%   99.5%   0.5%
# DeepSet(like in paper) #3   57.2%   97.7%  27.5%   98.2%   3.3%
# DeepSet(like in paper) #4   57.2%   99.5%  27.1%   99.5%   0.5%
# DeepSet(like in paper) #5   57.1%  100.0%  26.6%   99.5%   0.0%
# DeepSet(like in paper) #6   57.0%   95.9%  28.9%   96.4%   4.7%
# DeepSet(like in paper) #7   56.9%   90.9%  33.5%   89.2%  12.2%
# DeepSet(like in paper) #8   56.8%   97.3%  27.5%   98.6%   1.4%
# DeepSet(like in paper) #9   56.7%   98.6%  26.6%   98.2%   0.9%
# Sample count                  872     219    218     222    213

# %% [markdown]
# ## Accuracies per DeepSets V2 model

# %%
get_stats_per_model(best_deepsetv2_accs, ['DeepSet(sum at start) #' + str(i) for i in range(len(best_deepsetv2_accs))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                          Overall f3_cr  f3_dr f3_noop    f3_r
# DeepSet(sum at start) #0   42.8%  0.0%  73.4%    0.0%  100.0%
# DeepSet(sum at start) #1   42.8%  0.0%  73.4%    0.0%  100.0%
# DeepSet(sum at start) #2   42.8%  0.0%  73.4%    0.0%  100.0%
# DeepSet(sum at start) #3   42.8%  0.0%  73.4%    0.0%  100.0%
# DeepSet(sum at start) #4   42.8%  0.0%  73.4%    0.0%  100.0%
# DeepSet(sum at start) #5   42.8%  0.0%  73.4%    0.0%  100.0%
# DeepSet(sum at start) #6   42.8%  0.0%  73.4%    0.0%  100.0%
# DeepSet(sum at start) #7   42.8%  0.0%  73.4%    0.0%  100.0%
# DeepSet(sum at start) #8   42.8%  0.0%  73.4%    0.0%  100.0%
# DeepSet(sum at start) #9   42.8%  0.0%  73.4%    0.0%  100.0%
# Sample count                 872   219    218     222     213

# %% [markdown]
# ## Accuracies per FeedForward model

# %%
get_stats_per_model(best_feedforward_accs, ['Feedforward #' + str(i) for i in range(len(best_feedforward_accs))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                Overall   f3_cr  f3_dr f3_noop  f3_r
# Feedforward #0   57.3%   99.5%  26.1%   99.5%  1.9%
# Feedforward #1   57.2%  100.0%  26.6%  100.0%  0.0%
# Feedforward #2   57.1%   99.1%  27.5%   99.1%  0.5%
# Feedforward #3   56.9%   95.9%  28.9%   99.5%  0.9%
# Feedforward #4   56.9%   99.1%  26.1%  100.0%  0.0%
# Feedforward #5   56.8%   97.7%  27.1%   99.5%  0.5%
# Feedforward #6   56.8%   97.7%  26.6%   97.7%  2.8%
# Feedforward #7   56.8%   97.7%  27.1%   97.7%  2.3%
# Feedforward #8   56.7%   97.3%  28.0%   98.6%  0.5%
# Feedforward #9   56.4%   94.5%  28.0%   96.4%  4.7%
# Sample count       872     219    218     222   213

# %% [markdown]
# # Training evolution

# %% [markdown]
# ### CNN

# %%
display_epochs_stats(cnn_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### LSTM

# %%
display_epochs_stats(lstm_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### DeepSets V1

# %%
display_epochs_stats(deepset_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### DeepSets V2

# %%
display_epochs_stats(deepsetv2_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### FeedForward

# %%
display_epochs_stats(feedforward_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# # Best performing models

# %%
best_cnn_model = CNN_Model(data, 64, 128, 4, -1,).to(device)
best_cnn_model.load_state_dict(torch.load('best_CNN_model_1st_interval'))
best_deepset_model = DEEPSET_Model(data).to(device)
best_deepset_model.load_state_dict(torch.load('best_DEEPSET_model_1st_interval'))
best_deepsetv2_model = DEEPSETV2_Model(data).to(device)
best_deepsetv2_model.load_state_dict(torch.load('best_DEEPSETV2_model_1st_interval'))
best_feedforward_model = FEEDFORWARD_Model(data).to(device)
best_feedforward_model.load_state_dict(torch.load('best_FEEDFORWARD_model_1st_interval'))
best_lstm_model = LSTM_Model(data, 16, 16, 8).to(device)
best_lstm_model.load_state_dict(torch.load('best_LSTM_model_1st_interval'))
# Out:
# C:\Users\franm\AppData\Local\Temp\ipykernel_20124\369090151.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_cnn_model.load_state_dict(torch.load('best_CNN_model_1st_interval'))
# C:\Users\franm\AppData\Local\Temp\ipykernel_20124\369090151.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_deepset_model.load_state_dict(torch.load('best_DEEPSET_model_1st_interval'))
# C:\Users\franm\AppData\Local\Temp\ipykernel_20124\369090151.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_deepsetv2_model.load_state_dict(torch.load('best_DEEPSETV2_model_1st_interval'))
# C:\Users\franm\AppData\Local\Temp\ipykernel_20124\369090151.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_feedforward_model.load_state_dict(torch.load('best_FEEDFORWARD_model_1st_interval'))
# C:\Users\franm\AppData\Local\Temp\ipykernel_20124\369090151.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_lstm_model.load_state_dict(torch.load('best_LSTM_model_1st_interval'))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[80], line 10
#       8 best_feedforward_model.load_state_dict(torch.load('best_FEEDFORWARD_model_1st_interval'))
#       9 best_lstm_model = LSTM_Model(data, 16, 16, 8).to(device)
# ---> 10 best_lstm_model.load_state_dict(torch.load('best_LSTM_model_1st_interval'))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:2584, in Module.load_state_dict(self, state_dict, strict, assign)
#    2576         error_msgs.insert(
#    2577             0,
#    2578             "Missing key(s) in state_dict: {}. ".format(
#    2579                 ", ".join(f'"{k}"' for k in missing_keys)
#    2580             ),
#    2581         )
#    2583 if len(error_msgs) > 0:
# -> 2584     raise RuntimeError(
#    2585         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2586             self.__class__.__name__, "\n\t".join(error_msgs)
#    2587         )
#    2588     )
#    2589 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for LSTM_Model:
# 	size mismatch for densef1_1.weight: copying a param with shape torch.Size([32, 16]) from checkpoint, the shape in current model is torch.Size([16, 16]).
# 	size mismatch for densef1_1.bias: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([16]).
# 	size mismatch for densef2_1.weight: copying a param with shape torch.Size([32, 16]) from checkpoint, the shape in current model is torch.Size([16, 16]).
# 	size mismatch for densef2_1.bias: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([16]).
# 	size mismatch for densef3_1.weight: copying a param with shape torch.Size([32, 16]) from checkpoint, the shape in current model is torch.Size([16, 16]).
# 	size mismatch for densef3_1.bias: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([16]).
# 	size mismatch for densef1_2.weight: copying a param with shape torch.Size([8, 32]) from checkpoint, the shape in current model is torch.Size([8, 16]).
# 	size mismatch for densef2_2.weight: copying a param with shape torch.Size([8, 32]) from checkpoint, the shape in current model is torch.Size([8, 16]).
# 	size mismatch for densef3_2.weight: copying a param with shape torch.Size([8, 32]) from checkpoint, the shape in current model is torch.Size([8, 16]).

# %% [markdown]
# ## Top wrong predictions for best performing CNN model

# %%
print_wrong_preds([get_wrong_predictions(best_cnn_model, x_test_cnn, y_test, test_original)], top_k=10)
# Out:
# Top 10 false positives:
#
# ...,,.,.__.,._wu ..,___,dr.,_.,_, | label: False | actual prediction: 0.9746782183647156
# ,..,,..._,_wu,,_ ..,,,..,dr.,,_,. | label: False | actual prediction: 0.9629095196723938
# __..,,.._,_.,wu. _,,_,___.dr,.,,. | label: False | actual prediction: 0.9616774916648865
# .__.._.._,,_.,wu ,,_.__,.dr,__.,, | label: False | actual prediction: 0.9576624631881714
# ..,.._.___._wu__ _,.._,_dr,,,_,__ | label: False | actual prediction: 0.9544782638549805
# ._.___,.,wu____. _,,.,__.._dr.,_. | label: False | actual prediction: 0.9522860646247864
# ,,_,.,___,__wu_, __,_,,..dr....,, | label: False | actual prediction: 0.9510489106178284
# ,___,._,wu._,,__ __._,.,dr.__.,__ | label: False | actual prediction: 0.9468495845794678
# _..,.__..._..wu_ __,_._,dr.,,__., | label: False | actual prediction: 0.9380245208740234
# ._,_.,__wu,.._,_ _,.,__.,_dr,_... | label: False | actual prediction: 0.9158380031585693
#
# Top 10 false negatives:
#
# _,.,_..wu.,__,,, ,_,,...._.,.,..r | label: True | actual prediction: 0.15711276233196259
# _.._,_,._..wu.,. ,_.__.,.__._,,r, | label: True | actual prediction: 0.319489449262619
# _,__.,.,,,,wu.,_ ._._.,,_._,,.__r | label: True | actual prediction: 0.45358890295028687
# _.,.._.wu,_,__._ .,,_..___,,_.r,. | label: True | actual prediction: 0.5044059753417969
# .,__,,.,_.,.wu., ._,.__,,_._r,.__ | label: True | actual prediction: 0.6223628520965576

# %% [markdown]
# ## Top wrong predictions for best performing LSTM model

# %%
print_wrong_preds([get_wrong_predictions(best_lstm_model, x_test_lstm, y_test, test_original)], top_k=10)
# Out:
# Top 10 false positives:
#
#
# Top 10 false negatives:
#
# _..._._.,_uw,_,_ _,,,_.,._._,dr,_ | label: True | actual prediction: 0.5277970433235168
# _,.._,__.._.,uw, _.,_,,__.,_dr,,_ | label: True | actual prediction: 0.5278647541999817
# ,._....,__,_..w_ ,.,__,,,._,_._dr | label: True | actual prediction: 0.5280031561851501
# ..__,.___,__,,uw _,,.___.,_.dr.,, | label: True | actual prediction: 0.5280900597572327
# ,,.._,_uw,.___,_ ._._,__,__,_,_dr | label: True | actual prediction: 0.5281792879104614
# ,__,.___.,,,w... __,_,,,.._,,,dr. | label: True | actual prediction: 0.5282987952232361
# ..__,.___w_..__, ,...__.,,.dr_,,, | label: True | actual prediction: 0.528303325176239
# ,.,___.._,.,_uw. ,._...,,__...dr_ | label: True | actual prediction: 0.5283138751983643
# ,.,._.._,,_.__uw _.,,__...,.,,dr. | label: True | actual prediction: 0.5284551978111267
# __,,,.,.,_,,_._w ____,.._,dr__,,. | label: True | actual prediction: 0.5284627676010132

# %% [markdown]
# ## Top wrong predictions for best performing DeepSets V1 model

# %%
print_wrong_preds([get_wrong_predictions(best_deepset_model, x_test_normal, y_test, test_original)], top_k=10)
# Out:
# Top 10 false positives:
#
# ,.,_,_,,___uw,__ _,.___,cr,,,,.,_ | label: False | actual prediction: 0.6517797112464905
# ,._.._.,,_,..._w ,,___,,_.,_,_cr_ | label: False | actual prediction: 0.6512275338172913
#
# Top 10 false negatives:
#
# ,..,_,_..,.uw... ..,,,__.dr,_.,,. | label: True | actual prediction: 1.4181148799252696e-05
# ..,_._.uw,__.,,. __,,_.,.,.,dr,., | label: True | actual prediction: 2.4083998141577467e-05
# ,_,.,._.._,_._._ ,_,,.,_.,,,r.,.. | label: True | actual prediction: 3.0039174816920422e-05
# __,,_.,,.__.,.,_ ,__,.__,_.,.._,r | label: True | actual prediction: 3.564030703273602e-05
# ,.._,.__.,_.._.. _._,.,_._dr,___. | label: True | actual prediction: 3.704077971633524e-05
# ...,,_._..uw.... ,.,,_..,dr,,_,,. | label: True | actual prediction: 4.3770127376774326e-05
# ,.,,....,uw,___. ,__,_,__.r,..__. | label: True | actual prediction: 5.5784930736990646e-05
# _,.._..,..,w____ ._,,._.,,_dr,,,. | label: True | actual prediction: 5.652649633702822e-05
# _,_,_,_,,,.__,,. __.,._,,.dr,,__. | label: True | actual prediction: 5.72803764953278e-05
# ._,_,,..,....,w, ._...__,,.r.,_,, | label: True | actual prediction: 6.241243681870401e-05

# %% [markdown]
# ## Top wrong predictions for best performing DeepSets V2 model

# %%
print_wrong_preds([get_wrong_predictions(best_deepsetv2_model, x_test_normal, y_test, test_original)], top_k=10)
# Out:
# Top 10 false positives:
#
#
# Top 10 false negatives:
#
# ,_.,,,_,.,_,.wu, .__.._.,,,,r_,_, | label: True | actual prediction: 0.5015067458152771
# ,_..._,_.,__,.w. .,_,_.,__r_.._.. | label: True | actual prediction: 0.5018436312675476
# ,_..,__,.,,,.._, ,,,_,,.,.____r.. | label: True | actual prediction: 0.5018741488456726
# .,,,,,,,.,,..w,_ __,,,_,..r___,,. | label: True | actual prediction: 0.5020285844802856
# __.,._,...,,..wu _,,..,,,_,,r__._ | label: True | actual prediction: 0.5025511384010315
# _,.,,,,_.__._.,, _.,_._,,dr.__.,, | label: True | actual prediction: 0.5026781558990479
# ,.._,__.._,._.., __,,_.,,dr__,.., | label: True | actual prediction: 0.5030827522277832
# ,,..,__.._wu_._, ,,._.__,r..___,, | label: True | actual prediction: 0.5030840635299683
# ,,.,..._,___.,w, .,,__.,,.,._,r,. | label: True | actual prediction: 0.5037592053413391
# ,_.__..,,,,,..,. .__....___dr_.,, | label: True | actual prediction: 0.503781259059906

# %% [markdown]
# ## Top wrong predictions for best performing Feedforward model

# %%
print_wrong_preds([get_wrong_predictions(best_feedforward_model, x_test_normal, y_test, test_original)], top_k=10)
# Out:
# Top 10 false positives:
#
#
# Top 10 false negatives:
#
# ,..,,,,_.,.__.uw _.,,_,,,,..,...r | label: True | actual prediction: 0.3464698791503906
# ,...,__.,.._.._, _,,_,,,,,dr,,_._ | label: True | actual prediction: 0.3680580258369446
# .__,,_,,___.w.,. _.,..,.,,.r_..__ | label: True | actual prediction: 0.3708556592464447
# ...._,_,_.,.,,__ __,._...,..,._dr | label: True | actual prediction: 0.37168949842453003
# ..,___.._w.,,_., ,,.,,,_,,dr_..., | label: True | actual prediction: 0.3742199242115021
# ..,_._.uw,__.,,. __,,_.,.,.,dr,., | label: True | actual prediction: 0.37609168887138367
# ,_,_...__uw,_,., ..,..,..,,._r_,, | label: True | actual prediction: 0.3773583769798279
# ....,,,_..,....w _..,_,_,..,,,_.r | label: True | actual prediction: 0.3783039450645447
# _._,__,__,.w,__, .._,.,._.,._,_r_ | label: True | actual prediction: 0.37918704748153687
# _...._.,uw.,__.. _,._,_.,,_...._r | label: True | actual prediction: 0.38118183612823486

# %% [markdown]
# # Saving Notebook State

# %%
import dill
dill.dump_session('notebook_env_first_half.db')

# %% [markdown]
# # Loading Notebook State

# %%
import dill
# dill.load_session('notebook_env_first_half.db')
