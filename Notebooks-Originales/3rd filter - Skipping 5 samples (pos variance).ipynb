# %%
from generate_data import Data
from evaluate import *
from models import *

import pandas as pd
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
device = torch.device("cpu" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
# %autosave 120
# Out:
# Autosaving every 120 seconds

# %% [markdown]
# # Get the synthetic dataset

# %%
# %%time
data = Data(layer_size=16)
# Out:
# Wall time: 765 ms
# c:\Users\juand\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but OneHotEncoder was fitted without feature names
#   warnings.warn(

# %%
# %%time
train, val, test = data.get_splits(['skip'], [5])

train_unshuffled = train.copy()
np.random.shuffle(train)

x_train, y_train = data.get_x_y(train)
x_val, y_val = data.get_x_y(val)
x_test, y_test = data.get_x_y(test)

train_original = data.reverse_encoding(data.get_x_y(train_unshuffled)[0])
val_original = data.reverse_encoding(x_val)
test_original = data.reverse_encoding(x_test)
# Out:
# Number of samples: 794 train | 635 val | 2540 test
# Wall time: 471 ms

# %% [markdown]
# #### Peek at unshuffled train data

# %%
train_original[:20]
# Out:
# [[',..._.._,.___._.', 'w,,_,.,_,__.._.,', 'cr__,._,._,._,__', False],
#  [',,.._.....,,,,,_', 'w_,.._.,...,_.,_', '...__cr..,__,_..', False],
#  [',__._,_.___._.,_', 'w...._,__.__.___', ',,,,,__...cr_,,.', False],
#  ['.._...._,,_,_.,,', '.w_,,....,._,.__', 'cr,_,.__.._,_,..', False],
#  [',__,.__._,.__,..', '.w,,.,.,.,._,_,.', ',..._cr,,.,..,_,', False],
#  ['..,_,__.,__..___', '.w_.,..,,.,._,,,', '.__.__.,._cr__._', False],
#  ['.._,,,.,..,,._.,', '.,w__,,..,,,,.__', 'cr.,._...,,__.,.', False],
#  [',,,.,,,._,_.,_.,', '__w,__,,_,__,__.', '..,_,cr_,,_,.___', False],
#  [',_.._._,,..,.,.,', ',_w,,,..___,__.,', '____.,,,_.cr___,', False],
#  [',_.,___.,,___._.', '.._w._,_.,,._,.,', 'cr_,.,,.,....___', False],
#  [',,__..,,,..__._,', '.,,w..__,_,,._,.', '_.,_.cr_..,_.,,,', False],
#  [',_,..,_,_..._.,,', '.,,w,,_,.__,.,,.', '____,__,,.cr__,.', False],
#  ['._,..,,.__.._.__', '..,_w..__._,__.,', 'cr.,,_.,.._,_,..', False],
#  ['...,..,,_.,.._,.', '.,,_w.,.,.,_,_,.', '___,_cr.,_,.,.._', False],
#  ['....,.,.,,_._.,.', ',,..w_.__..._.._', ',._,,__,,,cr_,,_', False],
#  ['_.__.,__.,,__,..', '_,,_,w.,.._,,..,', 'cr_,_,_,..__.,._', False],
#  [',..,.,..____.___', ',..,_w_,,_.,,.,_', ',__._cr_._._,_.,', False],
#  ['_..,,..,___,.,.,', '.,,_,w,.,...____', '._,._,,.,.cr.,..', False],
#  ['__._....,,___,,,', '....._w,..,.,...', 'cr__._,_..___.._', False],
#  ['_,.,___,,...,.__', '__,...w_,,_._,_,', '.,.,.cr..,,._._,', False]]

# %%
pos_train_ratio = get_stats_and_ratio(train_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 45 | F2-uw 45 | F2-w 48 | F2-noop 51 |
# F3 cr:    F2-wu 45 | F2-uw 45 | F2-w 48 | F2-noop 51 |
# F3 r:    F2-wu 48 | F2-uw 48 | F2-w 52 | F2-noop 54 |
# F3 noop:    F2-wu 51 | F2-uw 51 | F2-w 54 | F2-noop 58 |
#
# Positive samples count: 346
# Total samples count: 794
# Positive class ratio: 0.4357682619647355

# %% [markdown]
# #### Peek at test data

# %%
test_original[:15]
# Out:
# [[',.....,,,,,,.._.', '___._,.,,,,_._,,', '._...,..,....dr,', True],
#  ['_,,.___..,.__,_,', '_,.,.wu....,,.._', '_.,.r__..,,.__..', True],
#  [',,_,.,_.,,,._,_.', ',_,..,.,,.,_,__.', 'cr_,.__,,...,___', False],
#  ['..,.__.__,,_,___', '____,__._.,uw__.', ',__.,_cr___._,_.', False],
#  [',.,._,..,,,__,_,', ',_,...,__,,,.,wu', '__._..,,__r_.,..', True],
#  ['_.,.,_,.__,_.,,_', '_w.,,.,__.,..,,_', '.,...,.,,_,.____', False],
#  ['__...,_,,,,,..,_', '._..,..,,..,_,,,', 'r...,_,,_.,.,,,.', True],
#  ['___,,_.___.__._,', ',,uw,,,_.___,_._', '_,_.,_._r_.,_,._', True],
#  ['._,,_,,__..,___.', '_,_,,..,..,,_,_,', '_.__._.,,._.r,,.', True],
#  ['._,__.__,.__._,_', '._...,.,__._,,.,', '___dr__,.,.._,_,', True],
#  ['._..,._.,._,..,_', 'wu._...,.,__,.,.', ',.._,_..__,.,,._', False],
#  ['__..,,,.____,.,_', '__.,_,__.,,...,,', '___,..dr,,,.,_,,', True],
#  ['..,_,.._...,..__', ',_,_._,.,...w___', '....__cr...__,_,', False],
#  ['.__..,_,...,,,__', '_,_,,,_,..w__,,.', ',_,__.cr._,__.._', False],
#  ['.,_._,,_.._._.__', '____,,_,,uw,.,,,', '._..__..,,_,....', False]]

# %%
pos_test_ratio = get_stats_and_ratio(test_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 143 | F2-uw 150 | F2-w 164 | F2-noop 163 |
# F3 cr:    F2-wu 134 | F2-uw 148 | F2-w 155 | F2-noop 161 |
# F3 r:    F2-wu 153 | F2-uw 147 | F2-w 149 | F2-noop 180 |
# F3 noop:    F2-wu 174 | F2-uw 169 | F2-w 170 | F2-noop 180 |
#
# Positive samples count: 1106
# Total samples count: 2540
# Positive class ratio: 0.43543307086614175

# %% [markdown]
# #### Peek at val data

# %%
val_original[:15]
# Out:
# [['.__,,._,_,_._,,.', '_..,.,.wu,__..,.', '_..,.._.,_,..__.', False],
#  [',,,._._.,...._,,', ',,_.._.,__._wu_,', '.,.r_,_.__._.,,_', True],
#  ['___.,.....,,__..', ',,..,,.._.._,_,.', '.,._,..._.,._,.,', False],
#  [',_,...,._,_,,_..', ',.,.__.,.,_.__.,', '.._,dr...,.._,_.', True],
#  ['..,,,.._,..,,,..', ',_._,.,,.,.._.,.', ',._r,._____.,.._', True],
#  ['..,_..__,.,_....', ',_.w,,,.__,.__.,', '_,....,cr.,,._..', False],
#  ['._.._.___._..._,', '_,.__wu,_.,..,..', '_._,,,_.._cr,.._', False],
#  ['.,_.,,_,,,.,__,,', '_..,.,,,w,...._.', '.__,.._....,__.r', True],
#  [',,.__.._..,.,_..', ',_.wu,__,,.,,._.', ',,._,.r_._.,..,.', True],
#  ['_._,,.,.____.,.,', '.,,,.uw,..,,.,_,', ',__,,,,.,,_,_,,.', False],
#  ['_,_._.,,.,__,,__', '___.....__.__._w', '....,....,__cr..', False],
#  ['_,,_,,,___,,_._,', '.,._._,.._._..._', ',.._____,_.___.,', False],
#  ['_,,,...,...,.._.', ',_._..__,....__.', '.._._,.,,_.____.', False],
#  ['__,.__._,,._.,__', '_,.._.__._._,uw,', '...,__,..___,___', False],
#  ['..,_,.,_..,._,__', '._.___,,..w_,,__', ',..,,.._,._cr_._', False]]

# %%
pos_val_ratio = get_stats_and_ratio(val_original)
# Out:
# Number of samples by case:
# F3 dr:    F2-wu 37 | F2-uw 30 | F2-w 28 | F2-noop 41 |
# F3 cr:    F2-wu 46 | F2-uw 32 | F2-w 37 | F2-noop 43 |
# F3 r:    F2-wu 39 | F2-uw 45 | F2-w 55 | F2-noop 38 |
# F3 noop:    F2-wu 30 | F2-uw 35 | F2-w 48 | F2-noop 51 |
#
# Positive samples count: 276
# Total samples count: 635
# Positive class ratio: 0.4346456692913386

# %% [markdown]
# #### Send label arrays to device

# %%
y_train = torch.from_numpy(y_train.astype(float)).float().to(device)
y_val = torch.from_numpy(y_val.astype(float)).float().to(device)
y_test = torch.from_numpy(y_test.astype(float)).float().to(device)

# %% [markdown]
# #### Get data in normal format (same as CNN format)

# %%
x_train_normal = data.to_conv_format(x_train)
x_val_normal = data.to_conv_format(x_val)
x_test_normal = data.to_conv_format(x_test)
for i in range(len(x_train_normal)):
    x_train_normal[i] = x_train_normal[i].to(device)
    x_val_normal[i] = x_val_normal[i].to(device)
    x_test_normal[i] = x_test_normal[i].to(device)

# %%
x_train_normal[0].shape
# Out:
# torch.Size([794, 128])

# %% [markdown]
# #### Get data in convolutional format, send to device

# %%
x_train_cnn = data.to_conv_format(x_train)
x_val_cnn = data.to_conv_format(x_val)
x_test_cnn = data.to_conv_format(x_test)
for i in range(len(x_train_cnn)):
    x_train_cnn[i] = x_train_cnn[i].to(device)
    x_val_cnn[i] = x_val_cnn[i].to(device)
    x_test_cnn[i] = x_test_cnn[i].to(device)

# %%
x_train_cnn[0].shape
# Out:
# torch.Size([794, 128])

# %% [markdown]
# #### Get data in LSTM format, send to device

# %%
x_train_lstm = data.to_lstm_format(x_train)
x_val_lstm = data.to_lstm_format(x_val)
x_test_lstm = data.to_lstm_format(x_test)
for i in range(len(x_train_lstm)):
    x_train_lstm[i] = x_train_lstm[i].to(device)
    x_val_lstm[i] = x_val_lstm[i].to(device)
    x_test_lstm[i] = x_test_lstm[i].to(device)

# %%
x_train_lstm[0].shape
# Out:
# torch.Size([794, 16, 8])

# %% [markdown]
# ### Define training parameters

# %%
num_experiments = 20
epochs = 200
early_stopping_limit = 100

experiment_name = "skip_5"

# %% [markdown]
# ### Define training procedure for each model

# %%
def train_models(constructor, x_train, x_val, x_test, weight_decay, *argv):
    accuracies = []
    precisions = []
    recalls = []
    f1s = []
    wrong_preds = []
    best_accuracy = 0
    
    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []

    for i in range(num_experiments):
        model = constructor(*argv)
        model.to(device)

        criterion = nn.BCEWithLogitsLoss(pos_weight=torch.Tensor([(1-pos_train_ratio)/pos_train_ratio]).to(device))
        optimizer = optim.Adam(model.parameters(), weight_decay=weight_decay)

        train_losses.append([])
        val_losses.append([])
        train_accs.append([])
        val_accs.append([])
        
        best_acc = 0

        early_stopping_cnt = 0

        for epoch in range(1, epochs + 1):
            train_loss, train_acc = train_epoch(model, x_train, y_train, criterion, optimizer, epoch, 10, verbose=False)
            val_loss, val_acc = eval_epoch(model, x_val, y_val, criterion, 'Validation', verbose=False)

            
            train_losses[-1].append(train_loss)
            val_losses[-1].append(val_loss)
            train_accs[-1].append(train_acc)
            val_accs[-1].append(val_acc)
            
            model_name = constructor.__name__[:constructor.__name__.find('_')]
            if val_acc > best_acc:
                best_acc = val_acc
                torch.save(model.state_dict(), f'./temp/{model_name}_model_TEMP_{experiment_name}')    
                early_stopping_cnt = 0
            else:
                early_stopping_cnt += 1

            if early_stopping_cnt >= early_stopping_limit:
                break


        model.load_state_dict(torch.load(f'./temp/{model_name}_model_TEMP_{experiment_name}'))

        accuracies.append(get_accuracy_by_cases(model, x_test, y_test, test_original))
        precisions.append(get_precision(model, x_test, y_test, test_original))
        recalls.append(get_recall(model, x_test, y_test, test_original))
        f1s.append(get_f1(precisions[-1], recalls[-1]))
        wrong_preds.append(get_wrong_predictions(model, x_test, y_test, test_original))

        if accuracies[-1]['Overall'] > best_accuracy:
            torch.save(model.state_dict(), f'./bestmodels/best_{model_name}_model_{experiment_name}')    
            best_accuracy = accuracies[-1]['Overall']

        print(i + 1, "/", num_experiments, "models trained | Current model test accuracy:", accuracies[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test precision:", precisions[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test recall:", recalls[-1]['Overall'])
        print(i + 1, "/", num_experiments, "models trained | Current model test f1:", f1s[-1]['Overall'])
    return accuracies, precisions, recalls, f1s, wrong_preds, [train_losses, val_losses, train_accs, val_accs]

# %% [markdown]
# # Train models

# %%
# %%time
cnn_accuracies, cnn_precisions, cnn_recalls, cnn_f1s, cnn_wrong_preds, cnn_epoch_stats = train_models(CNN_Model, x_train_cnn, x_val_cnn, x_test_cnn, 0.0001, data, 64, 128, 4, -1, 'keras')
# Out:
# C:\Users\juand\AppData\Local\Temp\ipykernel_48988\3365763532.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_{experiment_name}'))
# 1 / 20 models trained | Current model test accuracy: 0.9964566929133858
# 1 / 20 models trained | Current model test precision: 0.9972801450589301
# 1 / 20 models trained | Current model test recall: 0.9945750452079566
# 1 / 20 models trained | Current model test f1: 0.9959257582616567
# 2 / 20 models trained | Current model test accuracy: 0.9988188976377953
# 2 / 20 models trained | Current model test precision: 0.9990950226244344
# 2 / 20 models trained | Current model test recall: 0.9981916817359855
# 2 / 20 models trained | Current model test f1: 0.9986431478968791
# 3 / 20 models trained | Current model test accuracy: 0.9960629921259843
# 3 / 20 models trained | Current model test precision: 0.9990892531876139
# 3 / 20 models trained | Current model test recall: 0.9918625678119349
# 3 / 20 models trained | Current model test f1: 0.9954627949183303
# 4 / 20 models trained | Current model test accuracy: 0.9984251968503937
# 4 / 20 models trained | Current model test precision: 0.9972924187725631
# 4 / 20 models trained | Current model test recall: 0.9990958408679927
# 4 / 20 models trained | Current model test f1: 0.998193315266486
# 5 / 20 models trained | Current model test accuracy: 1.0
# 5 / 20 models trained | Current model test precision: 1.0
# 5 / 20 models trained | Current model test recall: 1.0
# 5 / 20 models trained | Current model test f1: 1.0
# 6 / 20 models trained | Current model test accuracy: 0.9976377952755906
# 6 / 20 models trained | Current model test precision: 1.0
# 6 / 20 models trained | Current model test recall: 0.9945750452079566
# 6 / 20 models trained | Current model test f1: 0.9972801450589301
# 7 / 20 models trained | Current model test accuracy: 0.9988188976377953
# 7 / 20 models trained | Current model test precision: 0.9990950226244344
# 7 / 20 models trained | Current model test recall: 0.9981916817359855
# 7 / 20 models trained | Current model test f1: 0.9986431478968791
# 8 / 20 models trained | Current model test accuracy: 0.9992125984251968
# 8 / 20 models trained | Current model test precision: 1.0
# 8 / 20 models trained | Current model test recall: 0.9981916817359855
# 8 / 20 models trained | Current model test f1: 0.9990950226244344
# 9 / 20 models trained | Current model test accuracy: 1.0
# 9 / 20 models trained | Current model test precision: 1.0
# 9 / 20 models trained | Current model test recall: 1.0
# 9 / 20 models trained | Current model test f1: 1.0
# 10 / 20 models trained | Current model test accuracy: 0.997244094488189
# 10 / 20 models trained | Current model test precision: 1.0
# 10 / 20 models trained | Current model test recall: 0.9936708860759493
# 10 / 20 models trained | Current model test f1: 0.9968253968253968
# 11 / 20 models trained | Current model test accuracy: 0.9976377952755906
# 11 / 20 models trained | Current model test precision: 0.9990925589836661
# 11 / 20 models trained | Current model test recall: 0.9954792043399638
# 11 / 20 models trained | Current model test f1: 0.9972826086956522
# 12 / 20 models trained | Current model test accuracy: 0.9956692913385827
# 12 / 20 models trained | Current model test precision: 0.995475113122172
# 12 / 20 models trained | Current model test recall: 0.9945750452079566
# 12 / 20 models trained | Current model test f1: 0.9950248756218905
# 13 / 20 models trained | Current model test accuracy: 0.9980314960629921
# 13 / 20 models trained | Current model test precision: 0.9981900452488688
# 13 / 20 models trained | Current model test recall: 0.9972875226039783
# 13 / 20 models trained | Current model test f1: 0.9977385798281321
# 14 / 20 models trained | Current model test accuracy: 0.9988188976377953
# 14 / 20 models trained | Current model test precision: 0.9990950226244344
# 14 / 20 models trained | Current model test recall: 0.9981916817359855
# 14 / 20 models trained | Current model test f1: 0.9986431478968791
# 15 / 20 models trained | Current model test accuracy: 0.9992125984251968
# 15 / 20 models trained | Current model test precision: 0.9981949458483754
# 15 / 20 models trained | Current model test recall: 1.0
# 15 / 20 models trained | Current model test f1: 0.999096657633243
# 16 / 20 models trained | Current model test accuracy: 0.9992125984251968
# 16 / 20 models trained | Current model test precision: 0.9990958408679927
# 16 / 20 models trained | Current model test recall: 0.9990958408679927
# 16 / 20 models trained | Current model test f1: 0.9990958408679927
# 17 / 20 models trained | Current model test accuracy: 0.9988188976377953
# 17 / 20 models trained | Current model test precision: 0.9972948602344455
# 17 / 20 models trained | Current model test recall: 1.0
# 17 / 20 models trained | Current model test f1: 0.9986455981941309
# 18 / 20 models trained | Current model test accuracy: 0.9996062992125985
# 18 / 20 models trained | Current model test precision: 1.0
# 18 / 20 models trained | Current model test recall: 0.9990958408679927
# 18 / 20 models trained | Current model test f1: 0.9995477159656264
# 19 / 20 models trained | Current model test accuracy: 0.9992125984251968
# 19 / 20 models trained | Current model test precision: 0.9990958408679927
# 19 / 20 models trained | Current model test recall: 0.9990958408679927
# 19 / 20 models trained | Current model test f1: 0.9990958408679927
# 20 / 20 models trained | Current model test accuracy: 0.9996062992125985
# 20 / 20 models trained | Current model test precision: 1.0
# 20 / 20 models trained | Current model test recall: 0.9990958408679927
# 20 / 20 models trained | Current model test f1: 0.9995477159656264
# Wall time: 1h 47min 31s

# %%
# %%time
lstm_accuracies, lstm_precisions, lstm_recalls, lstm_f1s, lstm_wrong_preds, lstm_epoch_stats = train_models(LSTM_Model, x_train_lstm, x_val_lstm, x_test_lstm, 0.0001, data, 16, 32, 8, 'keras')
# Out:
# C:\Users\juand\AppData\Local\Temp\ipykernel_48988\3365763532.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_{experiment_name}'))
# 1 / 20 models trained | Current model test accuracy: 0.9437007874015748
# 1 / 20 models trained | Current model test precision: 0.8855084067253803
# 1 / 20 models trained | Current model test recall: 1.0
# 1 / 20 models trained | Current model test f1: 0.9392781316348197
# 2 / 20 models trained | Current model test accuracy: 0.9984251968503937
# 2 / 20 models trained | Current model test precision: 0.9963963963963964
# 2 / 20 models trained | Current model test recall: 1.0
# 2 / 20 models trained | Current model test f1: 0.9981949458483754
# 3 / 20 models trained | Current model test accuracy: 1.0
# 3 / 20 models trained | Current model test precision: 1.0
# 3 / 20 models trained | Current model test recall: 1.0
# 3 / 20 models trained | Current model test f1: 1.0
# 4 / 20 models trained | Current model test accuracy: 0.9996062992125985
# 4 / 20 models trained | Current model test precision: 0.999096657633243
# 4 / 20 models trained | Current model test recall: 1.0
# 4 / 20 models trained | Current model test f1: 0.9995481247175779
# 5 / 20 models trained | Current model test accuracy: 0.9996062992125985
# 5 / 20 models trained | Current model test precision: 0.999096657633243
# 5 / 20 models trained | Current model test recall: 1.0
# 5 / 20 models trained | Current model test f1: 0.9995481247175779
# 6 / 20 models trained | Current model test accuracy: 0.9992125984251968
# 6 / 20 models trained | Current model test precision: 0.9981949458483754
# 6 / 20 models trained | Current model test recall: 1.0
# 6 / 20 models trained | Current model test f1: 0.999096657633243
# 7 / 20 models trained | Current model test accuracy: 1.0
# 7 / 20 models trained | Current model test precision: 1.0
# 7 / 20 models trained | Current model test recall: 1.0
# 7 / 20 models trained | Current model test f1: 1.0
# 8 / 20 models trained | Current model test accuracy: 0.9984251968503937
# 8 / 20 models trained | Current model test precision: 1.0
# 8 / 20 models trained | Current model test recall: 0.9963833634719711
# 8 / 20 models trained | Current model test f1: 0.9981884057971016
# 9 / 20 models trained | Current model test accuracy: 0.9988188976377953
# 9 / 20 models trained | Current model test precision: 0.9972948602344455
# 9 / 20 models trained | Current model test recall: 1.0
# 9 / 20 models trained | Current model test f1: 0.9986455981941309
# 10 / 20 models trained | Current model test accuracy: 1.0
# 10 / 20 models trained | Current model test precision: 1.0
# 10 / 20 models trained | Current model test recall: 1.0
# 10 / 20 models trained | Current model test f1: 1.0
# 11 / 20 models trained | Current model test accuracy: 1.0
# 11 / 20 models trained | Current model test precision: 1.0
# 11 / 20 models trained | Current model test recall: 1.0
# 11 / 20 models trained | Current model test f1: 1.0
# 12 / 20 models trained | Current model test accuracy: 1.0
# 12 / 20 models trained | Current model test precision: 1.0
# 12 / 20 models trained | Current model test recall: 1.0
# 12 / 20 models trained | Current model test f1: 1.0
# 13 / 20 models trained | Current model test accuracy: 0.9980314960629921
# 13 / 20 models trained | Current model test precision: 0.9954995499549955
# 13 / 20 models trained | Current model test recall: 1.0
# 13 / 20 models trained | Current model test f1: 0.997744700045106
# 14 / 20 models trained | Current model test accuracy: 0.9988188976377953
# 14 / 20 models trained | Current model test precision: 0.9972948602344455
# 14 / 20 models trained | Current model test recall: 1.0
# 14 / 20 models trained | Current model test f1: 0.9986455981941309
# 15 / 20 models trained | Current model test accuracy: 0.9409448818897638
# 15 / 20 models trained | Current model test precision: 0.8867313915857605
# 15 / 20 models trained | Current model test recall: 0.9909584086799277
# 15 / 20 models trained | Current model test f1: 0.9359521776259608
# 16 / 20 models trained | Current model test accuracy: 1.0
# 16 / 20 models trained | Current model test precision: 1.0
# 16 / 20 models trained | Current model test recall: 1.0
# 16 / 20 models trained | Current model test f1: 1.0
# 17 / 20 models trained | Current model test accuracy: 1.0
# 17 / 20 models trained | Current model test precision: 1.0
# 17 / 20 models trained | Current model test recall: 1.0
# 17 / 20 models trained | Current model test f1: 1.0
# 18 / 20 models trained | Current model test accuracy: 0.9996062992125985
# 18 / 20 models trained | Current model test precision: 1.0
# 18 / 20 models trained | Current model test recall: 0.9990958408679927
# 18 / 20 models trained | Current model test f1: 0.9995477159656264
# 19 / 20 models trained | Current model test accuracy: 0.9988188976377953
# 19 / 20 models trained | Current model test precision: 0.9990950226244344
# 19 / 20 models trained | Current model test recall: 0.9981916817359855
# 19 / 20 models trained | Current model test f1: 0.9986431478968791
# 20 / 20 models trained | Current model test accuracy: 0.9980314960629921
# 20 / 20 models trained | Current model test precision: 0.9954995499549955
# 20 / 20 models trained | Current model test recall: 1.0
# 20 / 20 models trained | Current model test f1: 0.997744700045106
# Wall time: 34min 44s

# %%
# %%time
deepset_accuracies, deepset_precisions, deepset_recalls, deepset_f1s, deepset_wrong_preds, deepset_epoch_stats = train_models(DEEPSET_Model, x_train_normal, x_val_normal, x_test_normal, 0.0001, data, 128, 32, 8, 'keras')
# Out:
# C:\Users\juand\AppData\Local\Temp\ipykernel_48988\3365763532.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_{experiment_name}'))
# 1 / 20 models trained | Current model test accuracy: 0.7586614173228347
# 1 / 20 models trained | Current model test precision: 0.6455995274660367
# 1 / 20 models trained | Current model test recall: 0.9882459312839059
# 1 / 20 models trained | Current model test f1: 0.7809932118613792
# 2 / 20 models trained | Current model test accuracy: 0.7582677165354331
# 2 / 20 models trained | Current model test precision: 0.6457345971563981
# 2 / 20 models trained | Current model test recall: 0.9855334538878843
# 2 / 20 models trained | Current model test f1: 0.7802433786685754
# 3 / 20 models trained | Current model test accuracy: 0.7629921259842519
# 3 / 20 models trained | Current model test precision: 0.648936170212766
# 3 / 20 models trained | Current model test recall: 0.9927667269439421
# 3 / 20 models trained | Current model test f1: 0.7848463187991422
# 4 / 20 models trained | Current model test accuracy: 0.7618110236220472
# 4 / 20 models trained | Current model test precision: 0.6479621972829297
# 4 / 20 models trained | Current model test recall: 0.9918625678119349
# 4 / 20 models trained | Current model test f1: 0.7838513754912468
# 5 / 20 models trained | Current model test accuracy: 0.7606299212598425
# 5 / 20 models trained | Current model test precision: 0.6468160377358491
# 5 / 20 models trained | Current model test recall: 0.9918625678119349
# 5 / 20 models trained | Current model test f1: 0.7830121341898644
# 6 / 20 models trained | Current model test accuracy: 0.7543307086614173
# 6 / 20 models trained | Current model test precision: 0.642434988179669
# 6 / 20 models trained | Current model test recall: 0.9828209764918626
# 6 / 20 models trained | Current model test f1: 0.7769835596854897
# 7 / 20 models trained | Current model test accuracy: 0.7586614173228347
# 7 / 20 models trained | Current model test precision: 0.6454277286135693
# 7 / 20 models trained | Current model test recall: 0.9891500904159132
# 7 / 20 models trained | Current model test f1: 0.7811495894323456
# 8 / 20 models trained | Current model test accuracy: 0.7641732283464567
# 8 / 20 models trained | Current model test precision: 0.6497341996455995
# 8 / 20 models trained | Current model test recall: 0.9945750452079566
# 8 / 20 models trained | Current model test f1: 0.7859949982136478
# 9 / 20 models trained | Current model test accuracy: 0.760236220472441
# 9 / 20 models trained | Current model test precision: 0.6469544648137197
# 9 / 20 models trained | Current model test recall: 0.9891500904159132
# 9 / 20 models trained | Current model test f1: 0.7822667143367894
# 10 / 20 models trained | Current model test accuracy: 0.7594488188976378
# 10 / 20 models trained | Current model test precision: 0.6468842729970327
# 10 / 20 models trained | Current model test recall: 0.9855334538878843
# 10 / 20 models trained | Current model test f1: 0.7810820494446435
# 11 / 20 models trained | Current model test accuracy: 0.7606299212598425
# 11 / 20 models trained | Current model test precision: 0.6480380499405469
# 11 / 20 models trained | Current model test recall: 0.9855334538878843
# 11 / 20 models trained | Current model test f1: 0.7819225251076038
# 12 / 20 models trained | Current model test accuracy: 0.75748031496063
# 12 / 20 models trained | Current model test precision: 0.6436107854630715
# 12 / 20 models trained | Current model test recall: 0.9927667269439421
# 12 / 20 models trained | Current model test f1: 0.7809388335704124
# 13 / 20 models trained | Current model test accuracy: 0.752755905511811
# 13 / 20 models trained | Current model test precision: 0.6427718040621266
# 13 / 20 models trained | Current model test recall: 0.972875226039783
# 13 / 20 models trained | Current model test f1: 0.7741007194244605
# 14 / 20 models trained | Current model test accuracy: 0.7562992125984253
# 14 / 20 models trained | Current model test precision: 0.6441681468324453
# 14 / 20 models trained | Current model test recall: 0.9837251356238698
# 14 / 20 models trained | Current model test f1: 0.7785330948121646
# 15 / 20 models trained | Current model test accuracy: 0.7562992125984253
# 15 / 20 models trained | Current model test precision: 0.6451997614788313
# 15 / 20 models trained | Current model test recall: 0.9783001808318263
# 15 / 20 models trained | Current model test f1: 0.7775781530722241
# 16 / 20 models trained | Current model test accuracy: 0.7551181102362204
# 16 / 20 models trained | Current model test precision: 0.6449101796407186
# 16 / 20 models trained | Current model test recall: 0.9737793851717902
# 16 / 20 models trained | Current model test f1: 0.7759365994236311
# 17 / 20 models trained | Current model test accuracy: 0.7562992125984253
# 17 / 20 models trained | Current model test precision: 0.6457211250748055
# 17 / 20 models trained | Current model test recall: 0.9755877034358047
# 17 / 20 models trained | Current model test f1: 0.7770975873244509
# 18 / 20 models trained | Current model test accuracy: 0.7559055118110236
# 18 / 20 models trained | Current model test precision: 0.6446428571428572
# 18 / 20 models trained | Current model test recall: 0.9792043399638336
# 18 / 20 models trained | Current model test f1: 0.7774587221823402
# 19 / 20 models trained | Current model test accuracy: 0.7614173228346457
# 19 / 20 models trained | Current model test precision: 0.6482799525504152
# 19 / 20 models trained | Current model test recall: 0.9882459312839059
# 19 / 20 models trained | Current model test f1: 0.7829512893982808
# 20 / 20 models trained | Current model test accuracy: 0.75748031496063
# 20 / 20 models trained | Current model test precision: 0.6453143534994069
# 20 / 20 models trained | Current model test recall: 0.9837251356238698
# 20 / 20 models trained | Current model test f1: 0.7793696275071633
# Wall time: 37min 51s

# %%
# %%time
deepsetv2_accuracies, deepsetv2_precisions, deepsetv2_recalls, deepsetv2_f1s, deepsetv2_wrong_preds, deepsetv2_epoch_stats = train_models(DEEPSETV2_Model, x_train_normal, x_val_normal, x_test_normal, 0.0001, data, 32, 8, 'keras')
# Out:
# C:\Users\juand\AppData\Local\Temp\ipykernel_48988\3365763532.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_{experiment_name}'))
# 1 / 20 models trained | Current model test accuracy: 0.43543307086614175
# 1 / 20 models trained | Current model test precision: 0.43543307086614175
# 1 / 20 models trained | Current model test recall: 1.0
# 1 / 20 models trained | Current model test f1: 0.6066922654964344
# 2 / 20 models trained | Current model test accuracy: 0.43543307086614175
# 2 / 20 models trained | Current model test precision: 0.43543307086614175
# 2 / 20 models trained | Current model test recall: 1.0
# 2 / 20 models trained | Current model test f1: 0.6066922654964344
# 3 / 20 models trained | Current model test accuracy: 0.43543307086614175
# 3 / 20 models trained | Current model test precision: 0.43543307086614175
# 3 / 20 models trained | Current model test recall: 1.0
# 3 / 20 models trained | Current model test f1: 0.6066922654964344
# 4 / 20 models trained | Current model test accuracy: 0.43543307086614175
# 4 / 20 models trained | Current model test precision: 0.43543307086614175
# 4 / 20 models trained | Current model test recall: 1.0
# 4 / 20 models trained | Current model test f1: 0.6066922654964344
# 5 / 20 models trained | Current model test accuracy: 0.43543307086614175
# 5 / 20 models trained | Current model test precision: 0.43543307086614175
# 5 / 20 models trained | Current model test recall: 1.0
# 5 / 20 models trained | Current model test f1: 0.6066922654964344
# 6 / 20 models trained | Current model test accuracy: 0.43543307086614175
# 6 / 20 models trained | Current model test precision: 0.43543307086614175
# 6 / 20 models trained | Current model test recall: 1.0
# 6 / 20 models trained | Current model test f1: 0.6066922654964344
# 7 / 20 models trained | Current model test accuracy: 0.43543307086614175
# 7 / 20 models trained | Current model test precision: 0.43543307086614175
# 7 / 20 models trained | Current model test recall: 1.0
# 7 / 20 models trained | Current model test f1: 0.6066922654964344
# 8 / 20 models trained | Current model test accuracy: 0.43543307086614175
# 8 / 20 models trained | Current model test precision: 0.43543307086614175
# 8 / 20 models trained | Current model test recall: 1.0
# 8 / 20 models trained | Current model test f1: 0.6066922654964344
# 9 / 20 models trained | Current model test accuracy: 0.43543307086614175
# 9 / 20 models trained | Current model test precision: 0.43543307086614175
# 9 / 20 models trained | Current model test recall: 1.0
# 9 / 20 models trained | Current model test f1: 0.6066922654964344
# 10 / 20 models trained | Current model test accuracy: 0.43543307086614175
# 10 / 20 models trained | Current model test precision: 0.43543307086614175
# 10 / 20 models trained | Current model test recall: 1.0
# 10 / 20 models trained | Current model test f1: 0.6066922654964344
# 11 / 20 models trained | Current model test accuracy: 0.43543307086614175
# 11 / 20 models trained | Current model test precision: 0.43543307086614175
# 11 / 20 models trained | Current model test recall: 1.0
# 11 / 20 models trained | Current model test f1: 0.6066922654964344
# 12 / 20 models trained | Current model test accuracy: 0.43543307086614175
# 12 / 20 models trained | Current model test precision: 0.43543307086614175
# 12 / 20 models trained | Current model test recall: 1.0
# 12 / 20 models trained | Current model test f1: 0.6066922654964344
# 13 / 20 models trained | Current model test accuracy: 0.43543307086614175
# 13 / 20 models trained | Current model test precision: 0.43543307086614175
# 13 / 20 models trained | Current model test recall: 1.0
# 13 / 20 models trained | Current model test f1: 0.6066922654964344
# 14 / 20 models trained | Current model test accuracy: 0.43543307086614175
# 14 / 20 models trained | Current model test precision: 0.43543307086614175
# 14 / 20 models trained | Current model test recall: 1.0
# 14 / 20 models trained | Current model test f1: 0.6066922654964344
# 15 / 20 models trained | Current model test accuracy: 0.43543307086614175
# 15 / 20 models trained | Current model test precision: 0.43543307086614175
# 15 / 20 models trained | Current model test recall: 1.0
# 15 / 20 models trained | Current model test f1: 0.6066922654964344
# 16 / 20 models trained | Current model test accuracy: 0.43543307086614175
# 16 / 20 models trained | Current model test precision: 0.43543307086614175
# 16 / 20 models trained | Current model test recall: 1.0
# 16 / 20 models trained | Current model test f1: 0.6066922654964344
# 17 / 20 models trained | Current model test accuracy: 0.43543307086614175
# 17 / 20 models trained | Current model test precision: 0.43543307086614175
# 17 / 20 models trained | Current model test recall: 1.0
# 17 / 20 models trained | Current model test f1: 0.6066922654964344
# 18 / 20 models trained | Current model test accuracy: 0.43543307086614175
# 18 / 20 models trained | Current model test precision: 0.43543307086614175
# 18 / 20 models trained | Current model test recall: 1.0
# 18 / 20 models trained | Current model test f1: 0.6066922654964344
# 19 / 20 models trained | Current model test accuracy: 0.43543307086614175
# 19 / 20 models trained | Current model test precision: 0.43543307086614175
# 19 / 20 models trained | Current model test recall: 1.0
# 19 / 20 models trained | Current model test f1: 0.6066922654964344
# 20 / 20 models trained | Current model test accuracy: 0.43543307086614175
# 20 / 20 models trained | Current model test precision: 0.43543307086614175
# 20 / 20 models trained | Current model test recall: 1.0
# 20 / 20 models trained | Current model test f1: 0.6066922654964344
# Wall time: 12min 35s

# %%
# %%time
feedforward_accuracies, feedforward_precisions, feedforward_recalls, feedforward_f1s, feedforward_wrong_preds, feedforward_epoch_stats = train_models(FEEDFORWARD_Model, x_train_normal, x_val_normal, x_test_normal, 0.0001, data, 128, 32, 8, 'keras')
# Out:
# C:\Users\juand\AppData\Local\Temp\ipykernel_48988\3365763532.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'./{model_name}_model_TEMP_{experiment_name}'))
# 1 / 20 models trained | Current model test accuracy: 0.7562992125984253
# 1 / 20 models trained | Current model test precision: 0.6443390634262004
# 1 / 20 models trained | Current model test recall: 0.9828209764918626
# 1 / 20 models trained | Current model test f1: 0.778374507697816
# 2 / 20 models trained | Current model test accuracy: 0.7578740157480315
# 2 / 20 models trained | Current model test precision: 0.6453522794552989
# 2 / 20 models trained | Current model test recall: 0.9855334538878843
# 2 / 20 models trained | Current model test f1: 0.7799642218246868
# 3 / 20 models trained | Current model test accuracy: 0.760236220472441
# 3 / 20 models trained | Current model test precision: 0.6467808623744832
# 3 / 20 models trained | Current model test recall: 0.9900542495479204
# 3 / 20 models trained | Current model test f1: 0.782422293676313
# 4 / 20 models trained | Current model test accuracy: 0.7468503937007874
# 4 / 20 models trained | Current model test precision: 0.6403881140084899
# 4 / 20 models trained | Current model test recall: 0.9547920433996383
# 4 / 20 models trained | Current model test f1: 0.766606170598911
# 5 / 20 models trained | Current model test accuracy: 0.7598425196850394
# 5 / 20 models trained | Current model test precision: 0.6467455621301775
# 5 / 20 models trained | Current model test recall: 0.9882459312839059
# 5 / 20 models trained | Current model test f1: 0.7818311874105865
# 6 / 20 models trained | Current model test accuracy: 0.7578740157480315
# 6 / 20 models trained | Current model test precision: 0.6455245998814464
# 6 / 20 models trained | Current model test recall: 0.984629294755877
# 6 / 20 models trained | Current model test f1: 0.7798066595059077
# 7 / 20 models trained | Current model test accuracy: 0.7570866141732283
# 7 / 20 models trained | Current model test precision: 0.644589000591366
# 7 / 20 models trained | Current model test recall: 0.9855334538878843
# 7 / 20 models trained | Current model test f1: 0.7794065069717554
# 8 / 20 models trained | Current model test accuracy: 0.7555118110236221
# 8 / 20 models trained | Current model test precision: 0.6444312090530078
# 8 / 20 models trained | Current model test recall: 0.9783001808318263
# 8 / 20 models trained | Current model test f1: 0.7770197486535009
# 9 / 20 models trained | Current model test accuracy: 0.7618110236220472
# 9 / 20 models trained | Current model test precision: 0.6481371969248965
# 9 / 20 models trained | Current model test recall: 0.9909584086799277
# 9 / 20 models trained | Current model test f1: 0.7836968180193064
# 10 / 20 models trained | Current model test accuracy: 0.7594488188976378
# 10 / 20 models trained | Current model test precision: 0.6470588235294118
# 10 / 20 models trained | Current model test recall: 0.984629294755877
# 10 / 20 models trained | Current model test f1: 0.7809250627465042
# 11 / 20 models trained | Current model test accuracy: 0.7543307086614173
# 11 / 20 models trained | Current model test precision: 0.6446578631452581
# 11 / 20 models trained | Current model test recall: 0.9710669077757685
# 11 / 20 models trained | Current model test f1: 0.7748917748917749
# 12 / 20 models trained | Current model test accuracy: 0.7594488188976378
# 12 / 20 models trained | Current model test precision: 0.6460176991150443
# 12 / 20 models trained | Current model test recall: 0.9900542495479204
# 12 / 20 models trained | Current model test f1: 0.7818636201356658
# 13 / 20 models trained | Current model test accuracy: 0.7543307086614173
# 13 / 20 models trained | Current model test precision: 0.644311377245509
# 13 / 20 models trained | Current model test recall: 0.972875226039783
# 13 / 20 models trained | Current model test f1: 0.7752161383285302
# 14 / 20 models trained | Current model test accuracy: 0.7519685039370079
# 14 / 20 models trained | Current model test precision: 0.6433734939759036
# 14 / 20 models trained | Current model test recall: 0.9656419529837251
# 14 / 20 models trained | Current model test f1: 0.772234273318872
# 15 / 20 models trained | Current model test accuracy: 0.7468503937007874
# 15 / 20 models trained | Current model test precision: 0.6373887240356083
# 15 / 20 models trained | Current model test recall: 0.9710669077757685
# 15 / 20 models trained | Current model test f1: 0.7696166248656396
# 16 / 20 models trained | Current model test accuracy: 0.75748031496063
# 16 / 20 models trained | Current model test precision: 0.6444575471698113
# 16 / 20 models trained | Current model test recall: 0.9882459312839059
# 16 / 20 models trained | Current model test f1: 0.7801570306923625
# 17 / 20 models trained | Current model test accuracy: 0.7594488188976378
# 17 / 20 models trained | Current model test precision: 0.6468842729970327
# 17 / 20 models trained | Current model test recall: 0.9855334538878843
# 17 / 20 models trained | Current model test f1: 0.7810820494446435
# 18 / 20 models trained | Current model test accuracy: 0.7598425196850394
# 18 / 20 models trained | Current model test precision: 0.6476190476190476
# 18 / 20 models trained | Current model test recall: 0.9837251356238698
# 18 / 20 models trained | Current model test f1: 0.7810480976310122
# 19 / 20 models trained | Current model test accuracy: 0.7507874015748032
# 19 / 20 models trained | Current model test precision: 0.6427278213639107
# 19 / 20 models trained | Current model test recall: 0.9629294755877035
# 19 / 20 models trained | Current model test f1: 0.7709011943539631
# 20 / 20 models trained | Current model test accuracy: 0.7507874015748032
# 20 / 20 models trained | Current model test precision: 0.6415320167564332
# 20 / 20 models trained | Current model test recall: 0.969258589511754
# 20 / 20 models trained | Current model test f1: 0.772056175729204
# Wall time: 36min 42s

# %% [markdown]
# # Evaluation

# %% [markdown]
# ### Get best 50% performing models

# %%
top_half = int(num_experiments / 2)
best_cnn_accs = filter_top_k_accuracies(cnn_accuracies, top_half)
best_lstm_accs = filter_top_k_accuracies(lstm_accuracies, top_half)
best_deepset_accs = filter_top_k_accuracies(deepset_accuracies, top_half)
best_deepsetv2_accs = filter_top_k_accuracies(deepsetv2_accuracies, top_half)
best_feedforward_accs = filter_top_k_accuracies(feedforward_accuracies, top_half)

# %% [markdown]
# ## Accuracy breakdown by cases for all the models

# %%
all_accuracies = [cnn_accuracies, lstm_accuracies, deepset_accuracies, deepsetv2_accuracies, feedforward_accuracies]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']

# %%
get_stats_df(all_accuracies, model_names, test_original)
# Out:
#                        Overall cr_noop   cr_uw    cr_w   cr_wu dr_noop  \
# CNN                      99.8%  100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM                     99.4%  100.0%  100.0%  100.0%  100.0%   99.9%
# DeepSet(like in paper)   75.8%   24.8%   26.3%   24.0%   24.8%  100.0%
# DeepSet(sum at start)    43.5%    0.0%    0.0%    0.0%    0.0%  100.0%
# Feedforward              75.6%   24.8%   26.2%   24.1%   24.8%  100.0%
# Sample count              2540     161     148     155     134     163
#
#                          dr_uw    dr_w  dr_wu noop_noop noop_uw  noop_w  \
# CNN                     100.0%   99.2%  99.1%    100.0%  100.0%  100.0%
# LSTM                     99.9%   99.8%  89.2%    100.0%  100.0%  100.0%
# DeepSet(like in paper)   99.9%   97.8%   0.1%     99.3%   99.0%   99.1%
# DeepSet(sum at start)   100.0%  100.0%   0.0%      0.0%    0.0%    0.0%
# Feedforward              99.8%   98.0%   0.1%     98.9%   99.3%   99.1%
# Sample count               150     164    143       180     169     170
#
#                        noop_wu  r_noop    r_uw     r_w    r_wu
# CNN                     100.0%  100.0%  100.0%  100.0%   99.1%
# LSTM                    100.0%  100.0%  100.0%  100.0%   99.9%
# DeepSet(like in paper)   99.2%   97.7%   97.6%   98.7%   98.1%
# DeepSet(sum at start)     0.0%  100.0%  100.0%  100.0%  100.0%
# Feedforward              99.3%   96.7%   96.9%   97.3%   96.9%
# Sample count               174     180     147     149     153

# %% [markdown]
# ## Accuracy breakdown by cases for top 50% of models

# %%
best_accuracies = [best_cnn_accs, best_lstm_accs, best_deepset_accs, best_deepsetv2_accs, best_feedforward_accs]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']
collapsed_cases = ['dr', 'r', 'cr', 'noop']

# %%
get_stats_df(best_accuracies, model_names, test_original, collapsed_cases)
# Out:
#                        Overall   f3_cr   f3_dr f3_noop    f3_r
# CNN                      99.9%  100.0%   99.9%  100.0%   99.9%
# LSTM                    100.0%  100.0%  100.0%  100.0%  100.0%
# DeepSet(like in paper)   76.1%   24.9%   76.4%   99.4%   98.7%
# DeepSet(sum at start)    43.5%    0.0%   76.9%    0.0%  100.0%
# Feedforward              75.9%   25.0%   76.5%   99.1%   98.2%
# Sample count              2540     598     620     693     629

# %%
best_accuracies = [best_cnn_accs, best_lstm_accs, best_deepset_accs, best_deepsetv2_accs, best_feedforward_accs]
model_names = ['CNN', 'LSTM', 'DeepSet(like in paper)', 'DeepSet(sum at start)', 'Feedforward']
collapsed_cases = ['r', 'cr', 'noop']

# %%
get_stats_df(best_accuracies, model_names, test_original, collapsed_cases)
# Out:
#                        Overall dr_noop   dr_uw    dr_w  dr_wu   f3_cr f3_noop  \
# CNN                      99.9%  100.0%  100.0%   99.9%  99.6%  100.0%  100.0%
# LSTM                    100.0%  100.0%   99.9%  100.0%  99.9%  100.0%  100.0%
# DeepSet(like in paper)   76.1%   99.9%   99.9%   98.0%   0.1%   24.9%   99.4%
# DeepSet(sum at start)    43.5%  100.0%  100.0%  100.0%   0.0%    0.0%    0.0%
# Feedforward              75.9%  100.0%   99.9%   98.2%   0.1%   25.0%   99.1%
# Sample count              2540     163     150     164    143     598     693
#
#                           f3_r
# CNN                      99.9%
# LSTM                    100.0%
# DeepSet(like in paper)   98.7%
# DeepSet(sum at start)   100.0%
# Feedforward              98.2%
# Sample count               629

# %% [markdown]
# ## Accuracies per CNN model

# %%
get_stats_per_model(cnn_accuracies, ['CNN #' + str(i) for i in range(len(cnn_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#              Overall   f3_cr   f3_dr f3_noop    f3_r
# CNN #0         99.6%  100.0%   98.5%  100.0%  100.0%
# CNN #1         99.9%  100.0%   99.8%  100.0%   99.7%
# CNN #2         99.6%  100.0%   99.4%  100.0%   99.0%
# CNN #3         99.8%  100.0%   99.5%  100.0%   99.8%
# CNN #4        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #5         99.8%  100.0%   99.2%  100.0%   99.8%
# CNN #6         99.9%  100.0%   99.7%  100.0%   99.8%
# CNN #7         99.9%  100.0%  100.0%  100.0%   99.7%
# CNN #8        100.0%  100.0%  100.0%  100.0%  100.0%
# CNN #9         99.7%  100.0%   98.9%  100.0%  100.0%
# CNN #10        99.8%  100.0%   99.8%  100.0%   99.2%
# CNN #11        99.6%  100.0%   98.9%  100.0%   99.4%
# CNN #12        99.8%  100.0%   99.7%  100.0%   99.5%
# CNN #13        99.9%  100.0%   99.5%  100.0%  100.0%
# CNN #14        99.9%  100.0%   99.7%  100.0%  100.0%
# CNN #15        99.9%  100.0%   99.8%  100.0%   99.8%
# CNN #16        99.9%  100.0%   99.5%  100.0%  100.0%
# CNN #17       100.0%  100.0%  100.0%  100.0%   99.8%
# CNN #18        99.9%  100.0%   99.8%  100.0%   99.8%
# CNN #19       100.0%  100.0%  100.0%  100.0%   99.8%
# Sample count    2540     598     620     693     629

# %% [markdown]
# ## Accuracies per LSTM model

# %%
get_stats_per_model(lstm_accuracies, ['LSTM #' + str(i) for i in range(len(lstm_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#              Overall   f3_cr   f3_dr f3_noop    f3_r
# LSTM #0        94.4%  100.0%   76.9%  100.0%  100.0%
# LSTM #1        99.8%  100.0%   99.4%  100.0%  100.0%
# LSTM #2       100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #3       100.0%  100.0%   99.8%  100.0%  100.0%
# LSTM #4       100.0%  100.0%   99.8%  100.0%  100.0%
# LSTM #5        99.9%  100.0%   99.7%  100.0%  100.0%
# LSTM #6       100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #7        99.8%  100.0%   99.7%  100.0%   99.7%
# LSTM #8        99.9%  100.0%   99.5%  100.0%  100.0%
# LSTM #9       100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #10      100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #11      100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #12       99.8%  100.0%   99.2%  100.0%  100.0%
# LSTM #13       99.9%  100.0%   99.5%  100.0%  100.0%
# LSTM #14       94.1%  100.0%   75.8%  100.0%  100.0%
# LSTM #15      100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #16      100.0%  100.0%  100.0%  100.0%  100.0%
# LSTM #17      100.0%  100.0%   99.8%  100.0%  100.0%
# LSTM #18       99.9%  100.0%   99.8%  100.0%   99.7%
# LSTM #19       99.8%  100.0%   99.2%  100.0%  100.0%
# Sample count    2540     598     620     693     629

# %% [markdown]
# ## Accuracies per DeepSets V1 model

# %%
get_stats_per_model(deepset_accuracies, ['DeepSet(like in paper) #' + str(i) for i in range(len(deepset_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                            Overall  f3_cr  f3_dr f3_noop   f3_r
# DeepSet(like in paper) #0    75.9%  24.9%  76.8%   98.7%  98.3%
# DeepSet(like in paper) #1    75.8%  25.1%  76.1%   99.0%  98.3%
# DeepSet(like in paper) #2    76.3%  24.9%  76.3%   99.7%  99.4%
# DeepSet(like in paper) #3    76.2%  25.1%  76.5%   99.3%  99.0%
# DeepSet(like in paper) #4    76.1%  24.9%  76.5%   99.0%  99.0%
# DeepSet(like in paper) #5    75.4%  24.9%  76.5%   98.1%  97.5%
# DeepSet(like in paper) #6    75.9%  24.7%  76.3%   98.8%  98.7%
# DeepSet(like in paper) #7    76.4%  25.1%  76.6%   99.7%  99.4%
# DeepSet(like in paper) #8    76.0%  24.9%  76.5%   99.3%  98.6%
# DeepSet(like in paper) #9    75.9%  24.9%  76.1%   99.6%  98.3%
# DeepSet(like in paper) #10   76.1%  25.1%  76.0%   99.9%  98.4%
# DeepSet(like in paper) #11   75.7%  24.7%  77.1%   97.7%  98.7%
# DeepSet(like in paper) #12   75.3%  24.9%  76.3%   99.1%  95.9%
# DeepSet(like in paper) #13   75.6%  25.1%  76.6%   98.4%  97.6%
# DeepSet(like in paper) #14   75.6%  24.9%  76.3%   99.6%  96.8%
# DeepSet(like in paper) #15   75.5%  25.1%  76.1%   99.7%  96.2%
# DeepSet(like in paper) #16   75.6%  25.3%  75.8%   99.7%  96.8%
# DeepSet(like in paper) #17   75.6%  24.9%  75.8%   99.3%  97.5%
# DeepSet(like in paper) #18   76.1%  24.9%  76.6%   99.7%  98.4%
# DeepSet(like in paper) #19   75.7%  24.9%  76.6%   99.1%  97.5%
# Sample count                  2540    598    620     693    629

# %% [markdown]
# ## Accuracies per DeepSets V2 model

# %%
get_stats_per_model(deepsetv2_accuracies, ['DeepSet(sum at start) #' + str(i) for i in range(len(deepsetv2_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                           Overall f3_cr  f3_dr f3_noop    f3_r
# DeepSet(sum at start) #0    43.5%  0.0%  76.9%    0.0%  100.0%
# DeepSet(sum at start) #1    43.5%  0.0%  76.9%    0.0%  100.0%
# DeepSet(sum at start) #2    43.5%  0.0%  76.9%    0.0%  100.0%
# DeepSet(sum at start) #3    43.5%  0.0%  76.9%    0.0%  100.0%
# DeepSet(sum at start) #4    43.5%  0.0%  76.9%    0.0%  100.0%
# DeepSet(sum at start) #5    43.5%  0.0%  76.9%    0.0%  100.0%
# DeepSet(sum at start) #6    43.5%  0.0%  76.9%    0.0%  100.0%
# DeepSet(sum at start) #7    43.5%  0.0%  76.9%    0.0%  100.0%
# DeepSet(sum at start) #8    43.5%  0.0%  76.9%    0.0%  100.0%
# DeepSet(sum at start) #9    43.5%  0.0%  76.9%    0.0%  100.0%
# DeepSet(sum at start) #10   43.5%  0.0%  76.9%    0.0%  100.0%
# DeepSet(sum at start) #11   43.5%  0.0%  76.9%    0.0%  100.0%
# DeepSet(sum at start) #12   43.5%  0.0%  76.9%    0.0%  100.0%
# DeepSet(sum at start) #13   43.5%  0.0%  76.9%    0.0%  100.0%
# DeepSet(sum at start) #14   43.5%  0.0%  76.9%    0.0%  100.0%
# DeepSet(sum at start) #15   43.5%  0.0%  76.9%    0.0%  100.0%
# DeepSet(sum at start) #16   43.5%  0.0%  76.9%    0.0%  100.0%
# DeepSet(sum at start) #17   43.5%  0.0%  76.9%    0.0%  100.0%
# DeepSet(sum at start) #18   43.5%  0.0%  76.9%    0.0%  100.0%
# DeepSet(sum at start) #19   43.5%  0.0%  76.9%    0.0%  100.0%
# Sample count                 2540   598    620     693     629

# %% [markdown]
# ## Accuracies per FeedForward model

# %%
get_stats_per_model(feedforward_accuracies, ['Feedforward #' + str(i) for i in range(len(feedforward_accuracies))], test_original, ['cr', 'dr', 'noop', 'r'])
# Out:
#                 Overall  f3_cr  f3_dr f3_noop   f3_r
# Feedforward #0    75.6%  25.1%  76.8%   98.7%  97.1%
# Feedforward #1    75.8%  25.1%  76.8%   98.8%  97.6%
# Feedforward #2    76.0%  24.7%  76.3%   99.3%  98.9%
# Feedforward #3    74.7%  25.1%  76.0%   99.7%  93.0%
# Feedforward #4    76.0%  24.9%  76.6%   99.3%  98.3%
# Feedforward #5    75.8%  25.3%  76.6%   98.8%  97.6%
# Feedforward #6    75.7%  24.7%  76.3%   98.8%  98.1%
# Feedforward #7    75.6%  24.9%  76.3%   99.3%  96.8%
# Feedforward #8    76.2%  24.7%  76.8%   99.7%  98.6%
# Feedforward #9    75.9%  25.1%  76.1%   99.6%  98.1%
# Feedforward #10   75.4%  25.1%  76.1%   99.7%  95.9%
# Feedforward #11   75.9%  25.3%  76.1%   98.6%  99.0%
# Feedforward #12   75.4%  24.9%  76.0%   99.7%  96.2%
# Feedforward #13   75.2%  25.4%  76.3%   99.6%  94.6%
# Feedforward #14   74.7%  24.9%  76.8%   97.3%  95.1%
# Feedforward #15   75.7%  25.1%  76.1%   98.3%  98.7%
# Feedforward #16   75.9%  24.9%  76.5%   99.6%  97.9%
# Feedforward #17   76.0%  25.1%  76.9%   99.6%  97.5%
# Feedforward #18   75.1%  25.1%  76.3%   99.7%  94.3%
# Feedforward #19   75.1%  24.6%  76.1%   99.3%  95.4%
# Sample count       2540    598    620     693    629

# %% [markdown]
# # Training evolution

# %% [markdown]
# ### CNN

# %%
display_epochs_stats(cnn_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### LSTM

# %%
display_epochs_stats(lstm_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### DeepSets V1

# %%
display_epochs_stats(deepset_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### DeepSets V2

# %%
display_epochs_stats(deepsetv2_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# ### FeedForward

# %%
display_epochs_stats(feedforward_epoch_stats, num_experiments, display_train_loss=False, display_val_loss=False)

# %% [markdown]
# # Best performing models

# %%
best_lstm_model = LSTM_Model(data, 16, 32, 8).to(device)
best_lstm_model.load_state_dict(torch.load('./bestmodels/best_LSTM_model_' + experiment_name))
best_cnn_model = CNN_Model(data, 64, 128, 4, -1,).to(device)
best_cnn_model.load_state_dict(torch.load('./bestmodels/best_CNN_model_' + experiment_name))
best_deepset_model = DEEPSET_Model(data).to(device)
best_deepset_model.load_state_dict(torch.load('./bestmodels/best_DEEPSET_model_' + experiment_name))
best_deepsetv2_model = DEEPSETV2_Model(data).to(device)
best_deepsetv2_model.load_state_dict(torch.load('./bestmodels/best_DEEPSETV2_model_' + experiment_name))
best_feedforward_model = FEEDFORWARD_Model(data).to(device)
best_feedforward_model.load_state_dict(torch.load('./bestmodels/best_FEEDFORWARD_model_' + experiment_name))
# Out:
# C:\Users\juand\AppData\Local\Temp\ipykernel_48988\156461178.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_lstm_model.load_state_dict(torch.load('best_LSTM_model_' + experiment_name))
# C:\Users\juand\AppData\Local\Temp\ipykernel_48988\156461178.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_cnn_model.load_state_dict(torch.load('best_CNN_model_' + experiment_name))
# C:\Users\juand\AppData\Local\Temp\ipykernel_48988\156461178.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_deepset_model.load_state_dict(torch.load('best_DEEPSET_model_' + experiment_name))
# C:\Users\juand\AppData\Local\Temp\ipykernel_48988\156461178.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_deepsetv2_model.load_state_dict(torch.load('best_DEEPSETV2_model_' + experiment_name))
# C:\Users\juand\AppData\Local\Temp\ipykernel_48988\156461178.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_feedforward_model.load_state_dict(torch.load('best_FEEDFORWARD_model_' + experiment_name))
# <All keys matched successfully>

# %%
get_summary_df(["CNN", "LSTM", "DEEPSET", "DEEPSETv2", "FEEDFORWARD"], [cnn_accuracies, lstm_accuracies, deepset_accuracies, deepsetv2_accuracies, feedforward_accuracies], [cnn_precisions, lstm_precisions, deepset_precisions, deepsetv2_precisions, feedforward_precisions], [cnn_recalls, lstm_recalls, deepset_recalls, deepsetv2_recalls, feedforward_recalls], [cnn_f1s, lstm_f1s, deepset_f1s, deepsetv2_f1s, feedforward_f1s])
# Out:
#         Modelo  Accuracy  Precision    Recall  F1-score
# 0          CNN  1.000000   1.000000  1.000000  1.000000
# 1         LSTM  1.000000   1.000000  1.000000  1.000000
# 2      DEEPSET  0.764173   0.649734  0.994575  0.785995
# 3    DEEPSETv2  0.435433   0.435433  1.000000  0.606692
# 4  FEEDFORWARD  0.761811   0.648137  0.990958  0.783697

# %% [markdown]
# ## Top wrong predictions for best performing CNN model

# %%
print_wrong_preds([get_wrong_predictions(best_cnn_model, x_test_cnn, y_test, test_original)], top_k=10)
# Out:
# Top 10 false positives:
#
#
# Top 10 false negatives:
#
# _..._,,_,wu,.,,, r,__,.._.,.,,._. | label: True | actual prediction: 0.5238696336746216

# %% [markdown]
# ## Top wrong predictions for best performing LSTM model

# %%
print_wrong_preds([get_wrong_predictions(best_lstm_model, x_test_lstm, y_test, test_original)], top_k=10)
# Out:
# Top 10 false positives:
#
#
# Top 10 false negatives:

# %% [markdown]
# ## Top wrong predictions for best performing DeepSets V1 model

# %%
print_wrong_preds([get_wrong_predictions(best_deepset_model, x_test_normal, y_test, test_original)], top_k=10)
# Out:
# Top 10 false positives:
#
# ,..____.,w,,,,__ .,.,cr.,,,..,,._ | label: False | actual prediction: 0.9999997615814209
# .,.,,wu_.,._,_,, ,cr_,.,,,,,._,__ | label: False | actual prediction: 0.9999997615814209
# _wu_,,_,_,,____, dr.,,.,..,_,_,__ | label: False | actual prediction: 0.9999997615814209
# __,..,_,..._..,, _..cr__..,,,,.., | label: False | actual prediction: 0.9999997615814209
# ,uw_..,,,.,..,,_ ..,...._,.,cr_,_ | label: False | actual prediction: 0.9999996423721313
# .,,_,,wu.._.,._, ,.,,_dr._.,,,.., | label: False | actual prediction: 0.9999995231628418
# _wu._,,_.._..,._ ,..cr_.,.,,,,,,, | label: False | actual prediction: 0.9999995231628418
# ,,...,,._wu.,... ,_._.,._,.dr.,_, | label: False | actual prediction: 0.9999994039535522
# _,_,_...__,wu.,, ._,cr,..,..,,,__ | label: False | actual prediction: 0.9999992847442627
# .,..,.,.__..uw,. ,_,._,_,.,,cr,., | label: False | actual prediction: 0.9999991655349731
#
# Top 10 false negatives:
#
# _....,_..,.w,_,_ ..dr_...._.,,.,_ | label: True | actual prediction: 0.011906536296010017
# __,__..__.___..w ,._._.,___..dr., | label: True | actual prediction: 0.013291330076754093
# _,uw,_..__,__,._ ..,r,,,,_.,__,_. | label: True | actual prediction: 0.017480550333857536
# .,.,,_,.,,.,,,,, ..___,._,__,.r,. | label: True | actual prediction: 0.11182745546102524
# .,_..,..,,._,._. ._.r_,_.____..,_ | label: True | actual prediction: 0.1476754993200302
# ,,_wu_,,._,.,,., .r_,_.,,_.___,,_ | label: True | actual prediction: 0.4984850287437439
# _,__,..._,__..w, .__,,,,..,._.dr. | label: True | actual prediction: 0.5346478223800659
# _,.._,.wu_,...,, .,_r,__.__.____, | label: True | actual prediction: 0.5446956753730774
# _.....,,,_____._ __,_.,._r,_,.___ | label: True | actual prediction: 0.6178448796272278

# %% [markdown]
# ## Top wrong predictions for best performing DeepSets V2 model

# %%
print_wrong_preds([get_wrong_predictions(best_deepsetv2_model, x_test_normal, y_test, test_original)], top_k=10)
# Out:
# Top 10 false positives:
#
#
# Top 10 false negatives:
#
# ___._,.,,,,_._,, ._...,..,....dr, | label: True | actual prediction: 0.5
# ,_,...,__,,,.,wu __._..,,__r_.,.. | label: True | actual prediction: 0.5
# ,,uw,,,_.___,_._ _,_.,_._r_.,_,._ | label: True | actual prediction: 0.5
# _,_,,..,..,,_,_, _.__._.,,._.r,,. | label: True | actual prediction: 0.5
# ,..___w_._.,,_,, _,,_,.......,r_, | label: True | actual prediction: 0.5
# ._..___.,,_..._. dr__.,,,,,__,,__ | label: True | actual prediction: 0.5
# wu__,._.,____,,, ,.__,.._.,__,,,r | label: True | actual prediction: 0.5
# .._w,_,.._._._., ._,,__._r_,_,,., | label: True | actual prediction: 0.5
# ,w._._,,,,.,,._. _,dr_.,_,,.,.__. | label: True | actual prediction: 0.5
# ._.,..,..,_wu... ___,_r..._,_._,, | label: True | actual prediction: 0.5

# %% [markdown]
# ## Top wrong predictions for best performing Feedforward model

# %%
print_wrong_preds([get_wrong_predictions(best_feedforward_model, x_test_normal, y_test, test_original)], top_k=10)
# Out:
# Top 10 false positives:
#
# __.,_uw__._._.,_ .,._.,,,cr.,,,__ | label: False | actual prediction: 0.9999990463256836
# .,_,.,,_,...wu._ .cr._._,_._,,.,_ | label: False | actual prediction: 0.999998927116394
# _wu_,,_,_,,____, dr.,,.,..,_,_,__ | label: False | actual prediction: 0.9999988079071045
# ._.___,,_._.__._ _.,__,,..cr.,.._ | label: False | actual prediction: 0.9999986886978149
# ,_.__._,,wu.,,_. .cr.,..__,_,..,_ | label: False | actual prediction: 0.9999985694885254
# ,,,,._,._,.__wu. dr,...__,.,_,_., | label: False | actual prediction: 0.9999985694885254
# ,.,wu.,.,__.,,_. dr.._.._.,_.,_,_ | label: False | actual prediction: 0.9999984502792358
# ,,...,,._wu.,... ,_._.,._,.dr.,_, | label: False | actual prediction: 0.9999984502792358
# _,.,_,wu,..._.,, dr__.._,._._.,,_ | label: False | actual prediction: 0.9999983310699463
# _,,._,._.w,.,_,. .,,_,.cr,.___.,_ | label: False | actual prediction: 0.9999983310699463
#
# Top 10 false negatives:
#
# __,__..__.___..w ,._._.,___..dr., | label: True | actual prediction: 0.00017820060020312667
# _,uw,_..__,__,._ ..,r,,,,_.,__,_. | label: True | actual prediction: 0.00850515253841877
# .,.,,_,.,,.,,,,, ..___,._,__,.r,. | label: True | actual prediction: 0.026982367038726807
# ,__.,.,,.._,,,_w _._r_,,,__,,_.,_ | label: True | actual prediction: 0.04421363025903702
# ._,_...__w...__, ,_,r.,_,,.,._,.. | label: True | actual prediction: 0.10406234860420227
# ,,,..,_.,,_wu_,_ ,,_r._._..,.__,, | label: True | actual prediction: 0.235849067568779
# .,_..,..,,._,._. ._.r_,_.____..,_ | label: True | actual prediction: 0.2429925948381424
# _._,,.,._._,_,__ ,,._._..,__r_.,. | label: True | actual prediction: 0.2776648700237274
# .wu.__,_...,,_._ ,,,,,,_.r__,.,,, | label: True | actual prediction: 0.2887817621231079
# ...,.,,__,,.____ _..r,____,_____. | label: True | actual prediction: 0.32616516947746277

# %% [markdown]
# # Saving Notebook State

# %%
import dill
dill.dump_session('notebook_env_' + experiment_name + '.db')

# %% [markdown]
# # Loading Notebook State

# %%
import dill
experiment_name = "skip_5"
# dill.load_session('notebook_env_' + experiment_name + '.db')
